# %%
from brickmapper import Mapper
from rdflib import BRICK
import urllib.request
import csv

# %%
# read haystack proto definitions off their website

defns = []
request = urllib.request.Request("https://project-haystack.org/download/protos.csv", headers={'User-Agent': "Python script"})
response = urllib.request.urlopen(request)
rdr = csv.DictReader(response.read().decode('utf8').splitlines())
for row in rdr:
    # save each proto (e.g. 'air temp sensor point') as a dictionary
    defns.append({'name': row['proto']})

defns
# Out:
# [{'name': 'air co2 concentration sensor point'},
#  {'name': 'air co2 concentration sp point'},
#  {'name': 'air dewPoint sensor point'},
#  {'name': 'air dewPoint sp point'},
#  {'name': 'air enthalpy sensor point'},
#  {'name': 'air enthalpy sp point'},
#  {'name': 'air flow sensor point'},
#  {'name': 'air flow sp point'},
#  {'name': 'air humidity sensor point'},
#  {'name': 'air humidity sp point'},
#  {'name': 'air pressure sensor point'},
#  {'name': 'air pressure sp point'},
#  {'name': 'air temp sensor point'},
#  {'name': 'air temp sp point'},
#  {'name': 'air velocity sensor point'},
#  {'name': 'air velocity sp point'},
#  {'name': 'alarm sensor point'},
#  {'name': 'avg ac elec current angle sensor point'},
#  {'name': 'avg ac elec current imbalance sensor point'},
#  {'name': 'avg ac elec current magnitude sensor point'},
#  {'name': 'avg ac elec current thd sensor point'},
#  {'name': 'avg ac elec pf sensor point'},
#  {'name': 'avg ac elec volt angle sensor point'},
#  {'name': 'avg ac elec volt imbalance sensor point'},
#  {'name': 'avg ac elec volt magnitude sensor point'},
#  {'name': 'avg ac elec volt thd sensor point'},
#  {'name': 'bypass damper cmd point'},
#  {'name': 'chilled water bypass equip'},
#  {'name': 'chilled water bypass flow sensor point'},
#  {'name': 'chilled water bypass flow sp point'},
#  {'name': 'chilled water bypass pipe equip'},
#  {'name': 'chilled water bypass point'},
#  {'name': 'chilled water bypass pressure sensor point'},
#  {'name': 'chilled water bypass pressure sp point'},
#  {'name': 'chilled water bypass pump alarm sensor point'},
#  {'name': 'chilled water bypass pump enable cmd point'},
#  {'name': 'chilled water bypass pump enable sensor point'},
#  {'name': 'chilled water bypass pump equip'},
#  {'name': 'chilled water bypass pump motor equip'},
#  {'name': 'chilled water bypass pump point'},
#  {'name': 'chilled water bypass pump run cmd point'},
#  {'name': 'chilled water bypass pump run sensor point'},
#  {'name': 'chilled water bypass pump vfd freq cmd point'},
#  {'name': 'chilled water bypass pump vfd freq sensor point'},
#  {'name': 'chilled water bypass pump vfd speed cmd point'},
#  {'name': 'chilled water bypass pump vfd speed sensor point'},
#  {'name': 'chilled water bypass temp sensor point'},
#  {'name': 'chilled water bypass temp sp point'},
#  {'name': 'chilled water bypass valve actuator equip'},
#  {'name': 'chilled water bypass valve cmd point'},
#  {'name': 'chilled water bypass valve sensor point'},
#  {'name': 'chilled water cool valve cmd point'},
#  {'name': 'chilled water delta flow point'},
#  {'name': 'chilled water delta flow sensor point'},
#  {'name': 'chilled water delta pressure point'},
#  {'name': 'chilled water delta temp point'},
#  {'name': 'chilled water delta temp sensor point'},
#  {'name': 'chilled water entering equip'},
#  {'name': 'chilled water entering flow sensor point'},
#  {'name': 'chilled water entering flow sp point'},
#  {'name': 'chilled water entering pipe equip'},
#  {'name': 'chilled water entering point'},
#  {'name': 'chilled water entering pressure sensor point'},
#  {'name': 'chilled water entering pressure sp point'},
#  {'name': 'chilled water entering pump alarm sensor point'},
#  {'name': 'chilled water entering pump enable cmd point'},
#  {'name': 'chilled water entering pump enable sensor point'},
#  {'name': 'chilled water entering pump equip'},
#  {'name': 'chilled water entering pump motor equip'},
#  {'name': 'chilled water entering pump point'},
#  {'name': 'chilled water entering pump run cmd point'},
#  {'name': 'chilled water entering pump run sensor point'},
#  {'name': 'chilled water entering pump vfd freq cmd point'},
#  {'name': 'chilled water entering pump vfd freq sensor point'},
#  {'name': 'chilled water entering pump vfd speed cmd point'},
#  {'name': 'chilled water entering pump vfd speed sensor point'},
#  {'name': 'chilled water entering temp sensor point'},
#  {'name': 'chilled water entering temp sp point'},
#  {'name': 'chilled water entering valve actuator equip'},
#  {'name': 'chilled water entering valve cmd point'},
#  {'name': 'chilled water entering valve sensor point'},
#  {'name': 'chilled water header equip'},
#  {'name': 'chilled water header flow sensor point'},
#  {'name': 'chilled water header flow sp point'},
#  {'name': 'chilled water header pipe equip'},
#  {'name': 'chilled water header point'},
#  {'name': 'chilled water header pressure sensor point'},
#  {'name': 'chilled water header pressure sp point'},
#  {'name': 'chilled water header pump alarm sensor point'},
#  {'name': 'chilled water header pump enable cmd point'},
#  {'name': 'chilled water header pump enable sensor point'},
#  {'name': 'chilled water header pump equip'},
#  {'name': 'chilled water header pump motor equip'},
#  {'name': 'chilled water header pump point'},
#  {'name': 'chilled water header pump run cmd point'},
#  {'name': 'chilled water header pump run sensor point'},
#  {'name': 'chilled water header pump vfd freq cmd point'},
#  {'name': 'chilled water header pump vfd freq sensor point'},
#  {'name': 'chilled water header pump vfd speed cmd point'},
#  {'name': 'chilled water header pump vfd speed sensor point'},
#  {'name': 'chilled water header temp sensor point'},
#  {'name': 'chilled water header temp sp point'},
#  {'name': 'chilled water header valve actuator equip'},
#  {'name': 'chilled water header valve cmd point'},
#  {'name': 'chilled water header valve sensor point'},
#  {'name': 'chilled water heatExchanger equip'},
#  {'name': 'chilled water leaving equip'},
#  {'name': 'chilled water leaving flow sensor point'},
#  {'name': 'chilled water leaving flow sp point'},
#  {'name': 'chilled water leaving pipe equip'},
#  {'name': 'chilled water leaving point'},
#  {'name': 'chilled water leaving pressure sensor point'},
#  {'name': 'chilled water leaving pressure sp point'},
#  {'name': 'chilled water leaving pump alarm sensor point'},
#  {'name': 'chilled water leaving pump enable cmd point'},
#  {'name': 'chilled water leaving pump enable sensor point'},
#  {'name': 'chilled water leaving pump equip'},
#  {'name': 'chilled water leaving pump motor equip'},
#  {'name': 'chilled water leaving pump point'},
#  {'name': 'chilled water leaving pump run cmd point'},
#  {'name': 'chilled water leaving pump run sensor point'},
#  {'name': 'chilled water leaving pump vfd freq cmd point'},
#  {'name': 'chilled water leaving pump vfd freq sensor point'},
#  {'name': 'chilled water leaving pump vfd speed cmd point'},
#  {'name': 'chilled water leaving pump vfd speed sensor point'},
#  {'name': 'chilled water leaving temp sensor point'},
#  {'name': 'chilled water leaving temp sp point'},
#  {'name': 'chilled water leaving valve actuator equip'},
#  {'name': 'chilled water leaving valve cmd point'},
#  {'name': 'chilled water leaving valve sensor point'},
#  {'name': 'chilled water mixing valve cmd point'},
#  {'name': 'chilled water valve isolation cmd point'},
#  {'name': 'chiller equip'},
#  {'name': 'circ equip'},
#  {'name': 'circ flow sensor point'},
#  {'name': 'circ flow sp point'},
#  {'name': 'circ pipe equip'},
#  {'name': 'circ point'},
#  {'name': 'circ pressure sensor point'},
#  {'name': 'circ pressure sp point'},
#  {'name': 'circ pump alarm sensor point'},
#  {'name': 'circ pump enable cmd point'},
#  {'name': 'circ pump enable sensor point'},
#  {'name': 'circ pump equip'},
#  {'name': 'circ pump motor equip'},
#  {'name': 'circ pump point'},
#  {'name': 'circ pump run cmd point'},
#  {'name': 'circ pump run sensor point'},
#  {'name': 'circ pump vfd freq cmd point'},
#  {'name': 'circ pump vfd freq sensor point'},
#  {'name': 'circ pump vfd speed cmd point'},
#  {'name': 'circ pump vfd speed sensor point'},
#  {'name': 'circ temp sensor point'},
#  {'name': 'circ temp sp point'},
#  {'name': 'circ valve actuator equip'},
#  {'name': 'circ valve cmd point'},
#  {'name': 'circ valve sensor point'},
#  {'name': 'condensate entering equip'},
#  {'name': 'condensate entering flow sensor point'},
#  {'name': 'condensate entering flow sp point'},
#  {'name': 'condensate entering pipe equip'},
#  {'name': 'condensate entering point'},
#  {'name': 'condensate entering pressure sensor point'},
#  {'name': 'condensate entering pressure sp point'},
#  {'name': 'condensate entering pump alarm sensor point'},
#  {'name': 'condensate entering pump enable cmd point'},
#  {'name': 'condensate entering pump enable sensor point'},
#  {'name': 'condensate entering pump equip'},
#  {'name': 'condensate entering pump motor equip'},
#  {'name': 'condensate entering pump point'},
#  {'name': 'condensate entering pump run cmd point'},
#  {'name': 'condensate entering pump run sensor point'},
#  {'name': 'condensate entering pump vfd freq cmd point'},
#  {'name': 'condensate entering pump vfd freq sensor point'},
#  {'name': 'condensate entering pump vfd speed cmd point'},
#  {'name': 'condensate entering pump vfd speed sensor point'},
#  {'name': 'condensate entering temp sensor point'},
#  {'name': 'condensate entering temp sp point'},
#  {'name': 'condensate entering valve actuator equip'},
#  {'name': 'condensate entering valve cmd point'},
#  {'name': 'condensate entering valve sensor point'},
#  {'name': 'condenser refrig pressure sensor point'},
#  {'name': 'condenser refrig temp sensor point'},
#  {'name': 'condenser run cmd point'},
#  {'name': 'condenser run sensor point'},
#  {'name': 'condenser water bypass equip'},
#  {'name': 'condenser water bypass flow sensor point'},
#  {'name': 'condenser water bypass flow sp point'},
#  {'name': 'condenser water bypass pipe equip'},
#  {'name': 'condenser water bypass point'},
#  {'name': 'condenser water bypass pressure sensor point'},
#  {'name': 'condenser water bypass pressure sp point'},
#  {'name': 'condenser water bypass pump alarm sensor point'},
#  {'name': 'condenser water bypass pump enable cmd point'},
#  {'name': 'condenser water bypass pump enable sensor point'},
#  {'name': 'condenser water bypass pump equip'},
#  {'name': 'condenser water bypass pump motor equip'},
#  {'name': 'condenser water bypass pump point'},
#  {'name': 'condenser water bypass pump run cmd point'},
#  {'name': 'condenser water bypass pump run sensor point'},
#  {'name': 'condenser water bypass pump vfd freq cmd point'},
#  {'name': 'condenser water bypass pump vfd freq sensor point'},
#  {'name': 'condenser water bypass pump vfd speed cmd point'},
#  {'name': 'condenser water bypass pump vfd speed sensor point'},
#  {'name': 'condenser water bypass temp sensor point'},
#  {'name': 'condenser water bypass temp sp point'},
#  {'name': 'condenser water bypass valve actuator equip'},
#  {'name': 'condenser water bypass valve cmd point'},
#  {'name': 'condenser water bypass valve sensor point'},
#  {'name': 'condenser water delta flow sensor point'},
#  {'name': 'condenser water delta pressure sensor point'},
#  {'name': 'condenser water delta temp sensor point'},
#  {'name': 'condenser water entering equip'},
#  {'name': 'condenser water entering flow sensor point'},
#  {'name': 'condenser water entering flow sp point'},
#  {'name': 'condenser water entering pipe equip'},
#  {'name': 'condenser water entering point'},
#  {'name': 'condenser water entering pressure sensor point'},
#  {'name': 'condenser water entering pressure sp point'},
#  {'name': 'condenser water entering pump alarm sensor point'},
#  {'name': 'condenser water entering pump enable cmd point'},
#  {'name': 'condenser water entering pump enable sensor point'},
#  {'name': 'condenser water entering pump equip'},
#  {'name': 'condenser water entering pump motor equip'},
#  {'name': 'condenser water entering pump point'},
#  {'name': 'condenser water entering pump run cmd point'},
#  {'name': 'condenser water entering pump run sensor point'},
#  {'name': 'condenser water entering pump vfd freq cmd point'},
#  {'name': 'condenser water entering pump vfd freq sensor point'},
#  {'name': 'condenser water entering pump vfd speed cmd point'},
#  {'name': 'condenser water entering pump vfd speed sensor point'},
#  {'name': 'condenser water entering temp sensor point'},
#  {'name': 'condenser water entering temp sp point'},
#  {'name': 'condenser water entering valve actuator equip'},
#  {'name': 'condenser water entering valve cmd point'},
#  {'name': 'condenser water entering valve sensor point'},
#  {'name': 'condenser water leaving equip'},
#  {'name': 'condenser water leaving flow sensor point'},
#  {'name': 'condenser water leaving flow sp point'},
#  {'name': 'condenser water leaving pipe equip'},
#  {'name': 'condenser water leaving point'},
#  {'name': 'condenser water leaving pressure sensor point'},
#  {'name': 'condenser water leaving pressure sp point'},
#  {'name': 'condenser water leaving pump alarm sensor point'},
#  {'name': 'condenser water leaving pump enable cmd point'},
#  {'name': 'condenser water leaving pump enable sensor point'},
#  {'name': 'condenser water leaving pump equip'},
#  {'name': 'condenser water leaving pump motor equip'},
#  {'name': 'condenser water leaving pump point'},
#  {'name': 'condenser water leaving pump run cmd point'},
#  {'name': 'condenser water leaving pump run sensor point'},
#  {'name': 'condenser water leaving pump vfd freq cmd point'},
#  {'name': 'condenser water leaving pump vfd freq sensor point'},
#  {'name': 'condenser water leaving pump vfd speed cmd point'},
#  {'name': 'condenser water leaving pump vfd speed sensor point'},
#  {'name': 'condenser water leaving temp sensor point'},
#  {'name': 'condenser water leaving temp sp point'},
#  {'name': 'condenser water leaving valve actuator equip'},
#  {'name': 'condenser water leaving valve cmd point'},
#  {'name': 'condenser water leaving valve sensor point'},
#  {'name': 'condenser water valve isolation cmd point'},
#  {'name': 'controller device'},
#  {'name': 'cool cmd point'},
#  {'name': 'cool water flow thermal meter equip'},
#  {'name': 'cool well equip'},
#  {'name': 'coolingCoil equip'},
#  {'name': 'coolingTower equip'},
#  {'name': 'crac fcu equip'},
#  {'name': 'damper actuator equip'},
#  {'name': 'damper cmd point'},
#  {'name': 'damper sensor point'},
#  {'name': 'dc elec stateOfCharge sensor point'},
#  {'name': 'dessicantDehumidifier cmd point'},
#  {'name': 'discharge air co2 concentration sensor point'},
#  {'name': 'discharge air co2 concentration sp point'},
#  {'name': 'discharge air dewPoint sensor point'},
#  {'name': 'discharge air dewPoint sp point'},
#  {'name': 'discharge air enthalpy sensor point'},
#  {'name': 'discharge air enthalpy sp point'},
#  {'name': 'discharge air flow sensor point'},
#  {'name': 'discharge air flow sp point'},
#  {'name': 'discharge air humidity sensor point'},
#  {'name': 'discharge air humidity sp point'},
#  {'name': 'discharge air pressure sensor point'},
#  {'name': 'discharge air pressure sp point'},
#  {'name': 'discharge air temp sensor point'},
#  {'name': 'discharge air temp sp point'},
#  {'name': 'discharge chilled water cool valve cmd point'},
#  {'name': 'discharge coolingCoil equip'},
#  {'name': 'discharge damper actuator equip'},
#  {'name': 'discharge damper cmd point'},
#  {'name': 'discharge damper sensor point'},
#  {'name': 'discharge duct equip'},
#  {'name': 'discharge equip'},
#  {'name': 'discharge fan alarm sensor point'},
#  {'name': 'discharge fan enable cmd point'},
#  {'name': 'discharge fan enable sensor point'},
#  {'name': 'discharge fan equip'},
#  {'name': 'discharge fan motor equip'},
#  {'name': 'discharge fan point'},
#  {'name': 'discharge fan run cmd point'},
#  {'name': 'discharge fan run sensor point'},
#  {'name': 'discharge fan vfd freq cmd point'},
#  {'name': 'discharge fan vfd freq sensor point'},
#  {'name': 'discharge fan vfd speed cmd point'},
#  {'name': 'discharge fan vfd speed sensor point'},
#  {'name': 'discharge heatingCoil equip'},
#  {'name': 'discharge hot water heat valve cmd point'},
#  {'name': 'discharge point'},
#  {'name': 'discharge stage:1 cool run cmd point'},
#  {'name': 'discharge stage:1 heat run cmd point'},
#  {'name': 'discharge steam heat valve cmd point'},
#  {'name': 'ductArea sp point'},
#  {'name': 'economizer air co2 concentration sensor point'},
#  {'name': 'economizer air co2 concentration sp point'},
#  {'name': 'economizer air dewPoint sensor point'},
#  {'name': 'economizer air dewPoint sp point'},
#  {'name': 'economizer air enthalpy sensor point'},
#  {'name': 'economizer air enthalpy sp point'},
#  {'name': 'economizer air flow sensor point'},
#  {'name': 'economizer air flow sp point'},
#  {'name': 'economizer air humidity sensor point'},
#  {'name': 'economizer air humidity sp point'},
#  {'name': 'economizer air pressure sensor point'},
#  {'name': 'economizer air pressure sp point'},
#  {'name': 'economizer air temp sensor point'},
#  {'name': 'economizer air temp sp point'},
#  {'name': 'economizer chilled water cool valve cmd point'},
#  {'name': 'economizer coolingCoil equip'},
#  {'name': 'economizer damper actuator equip'},
#  {'name': 'economizer damper cmd point'},
#  {'name': 'economizer damper sensor point'},
#  {'name': 'economizer duct equip'},
#  {'name': 'economizer equip'},
#  {'name': 'economizer fan alarm sensor point'},
#  {'name': 'economizer fan enable cmd point'},
#  {'name': 'economizer fan enable sensor point'},
#  {'name': 'economizer fan equip'},
#  {'name': 'economizer fan motor equip'},
#  {'name': 'economizer fan point'},
#  {'name': 'economizer fan run cmd point'},
#  {'name': 'economizer fan run sensor point'},
#  {'name': 'economizer fan vfd freq cmd point'},
#  {'name': 'economizer fan vfd freq sensor point'},
#  {'name': 'economizer fan vfd speed cmd point'},
#  {'name': 'economizer fan vfd speed sensor point'},
#  {'name': 'economizer heatingCoil equip'},
#  {'name': 'economizer hot water heat valve cmd point'},
#  {'name': 'economizer point'},
#  {'name': 'economizer stage:1 cool run cmd point'},
#  {'name': 'economizer stage:1 heat run cmd point'},
#  {'name': 'economizer steam heat valve cmd point'},
#  {'name': 'economizing cmd point'},
#  {'name': 'efficiency sensor point'},
#  {'name': 'enable cmd point'},
#  {'name': 'enable sensor point'},
#  {'name': 'equip'},
#  {'name': 'evaporator refrig pressure sensor point'},
#  {'name': 'evaporator refrig temp sensor point'},
#  {'name': 'evse cable equip'},
#  {'name': 'evse evseStatus sensor point'},
#  {'name': 'evse port equip'},
#  {'name': 'exhaust air co2 concentration sensor point'},
#  {'name': 'exhaust air co2 concentration sp point'},
#  {'name': 'exhaust air dewPoint sensor point'},
#  {'name': 'exhaust air dewPoint sp point'},
#  {'name': 'exhaust air enthalpy sensor point'},
#  {'name': 'exhaust air enthalpy sp point'},
#  {'name': 'exhaust air flow sensor point'},
#  {'name': 'exhaust air flow sp point'},
#  {'name': 'exhaust air humidity sensor point'},
#  {'name': 'exhaust air humidity sp point'},
#  {'name': 'exhaust air pressure sensor point'},
#  {'name': 'exhaust air pressure sp point'},
#  {'name': 'exhaust air temp sensor point'},
#  {'name': 'exhaust air temp sp point'},
#  {'name': 'exhaust chilled water cool valve cmd point'},
#  {'name': 'exhaust coolingCoil equip'},
#  {'name': 'exhaust damper actuator equip'},
#  {'name': 'exhaust damper cmd point'},
#  {'name': 'exhaust damper sensor point'},
#  {'name': 'exhaust duct equip'},
#  {'name': 'exhaust equip'},
#  {'name': 'exhaust fan alarm sensor point'},
#  {'name': 'exhaust fan enable cmd point'},
#  {'name': 'exhaust fan enable sensor point'},
#  {'name': 'exhaust fan equip'},
#  {'name': 'exhaust fan motor equip'},
#  {'name': 'exhaust fan point'},
#  {'name': 'exhaust fan run cmd point'},
#  {'name': 'exhaust fan run sensor point'},
#  {'name': 'exhaust fan vfd freq cmd point'},
#  {'name': 'exhaust fan vfd freq sensor point'},
#  {'name': 'exhaust fan vfd speed cmd point'},
#  {'name': 'exhaust fan vfd speed sensor point'},
#  {'name': 'exhaust heatingCoil equip'},
#  {'name': 'exhaust hot water heat valve cmd point'},
#  {'name': 'exhaust point'},
#  {'name': 'exhaust stage:1 cool run cmd point'},
#  {'name': 'exhaust stage:1 heat run cmd point'},
#  {'name': 'exhaust steam heat valve cmd point'},
#  {'name': 'extraction well equip'},
#  {'name': 'faceBypass cmd point'},
#  {'name': 'fan alarm sensor point'},
#  {'name': 'fan enable cmd point'},
#  {'name': 'fan enable sensor point'},
#  {'name': 'fan equip'},
#  {'name': 'fan motor equip'},
#  {'name': 'fan point'},
#  {'name': 'fan run cmd point'},
#  {'name': 'fan run sensor point'},
#  {'name': 'fan vfd freq cmd point'},
#  {'name': 'fan vfd freq sensor point'},
#  {'name': 'fan vfd speed cmd point'},
#  {'name': 'fan vfd speed sensor point'},
#  {'name': 'filter sensor point'},
#  {'name': 'flow sensor point'},
#  {'name': 'flow sp point'},
#  {'name': 'flowInverter equip'},
#  {'name': 'flue air co2 concentration sensor point'},
#  {'name': 'flue air co2 concentration sp point'},
#  {'name': 'flue air dewPoint sensor point'},
#  {'name': 'flue air dewPoint sp point'},
#  {'name': 'flue air enthalpy sensor point'},
#  {'name': 'flue air enthalpy sp point'},
#  {'name': 'flue air flow sensor point'},
#  {'name': 'flue air flow sp point'},
#  {'name': 'flue air humidity sensor point'},
#  {'name': 'flue air humidity sp point'},
#  {'name': 'flue air pressure sensor point'},
#  {'name': 'flue air pressure sp point'},
#  {'name': 'flue air temp sensor point'},
#  {'name': 'flue air temp sp point'},
#  {'name': 'flue chilled water cool valve cmd point'},
#  {'name': 'flue coolingCoil equip'},
#  {'name': 'flue damper actuator equip'},
#  {'name': 'flue damper cmd point'},
#  {'name': 'flue damper sensor point'},
#  {'name': 'flue duct equip'},
#  {'name': 'flue equip'},
#  {'name': 'flue fan alarm sensor point'},
#  {'name': 'flue fan enable cmd point'},
#  {'name': 'flue fan enable sensor point'},
#  {'name': 'flue fan equip'},
#  {'name': 'flue fan motor equip'},
#  {'name': 'flue fan point'},
#  {'name': 'flue fan run cmd point'},
#  {'name': 'flue fan run sensor point'},
#  {'name': 'flue fan vfd freq cmd point'},
#  {'name': 'flue fan vfd freq sensor point'},
#  {'name': 'flue fan vfd speed cmd point'},
#  {'name': 'flue fan vfd speed sensor point'},
#  {'name': 'flue heatingCoil equip'},
#  {'name': 'flue hot water heat valve cmd point'},
#  {'name': 'flue point'},
#  {'name': 'flue stage:1 cool run cmd point'},
#  {'name': 'flue stage:1 heat run cmd point'},
#  {'name': 'flue steam heat valve cmd point'},
#  {'name': 'freezeStat sensor point'},
#  {'name': 'ground water flow sensor point'},
#  {'name': 'ground water pressure sensor point'},
#  {'name': 'ground water volume sensor point'},
#  {'name': 'heat cmd point'},
#  {'name': 'heatExchanger equip'},
#  {'name': 'heatWheel cmd point'},
#  {'name': 'heatingCoil equip'},
#  {'name': 'hot water boiler equip'},
#  {'name': 'hot water bypass equip'},
#  {'name': 'hot water bypass flow sensor point'},
#  {'name': 'hot water bypass flow sp point'},
#  {'name': 'hot water bypass pipe equip'},
#  {'name': 'hot water bypass point'},
#  {'name': 'hot water bypass pressure sensor point'},
#  {'name': 'hot water bypass pressure sp point'},
#  {'name': 'hot water bypass pump alarm sensor point'},
#  {'name': 'hot water bypass pump enable cmd point'},
#  {'name': 'hot water bypass pump enable sensor point'},
#  {'name': 'hot water bypass pump equip'},
#  {'name': 'hot water bypass pump motor equip'},
#  {'name': 'hot water bypass pump point'},
#  {'name': 'hot water bypass pump run cmd point'},
#  {'name': 'hot water bypass pump run sensor point'},
#  {'name': 'hot water bypass pump vfd freq cmd point'},
#  {'name': 'hot water bypass pump vfd freq sensor point'},
#  {'name': 'hot water bypass pump vfd speed cmd point'},
#  {'name': 'hot water bypass pump vfd speed sensor point'},
#  {'name': 'hot water bypass temp sensor point'},
#  {'name': 'hot water bypass temp sp point'},
#  {'name': 'hot water bypass valve actuator equip'},
#  {'name': 'hot water bypass valve cmd point'},
#  {'name': 'hot water bypass valve sensor point'},
#  {'name': 'hot water delta flow sensor point'},
#  {'name': 'hot water delta pressure sensor point'},
#  {'name': 'hot water delta temp sensor point'},
#  {'name': 'hot water entering equip'},
#  {'name': 'hot water entering flow sensor point'},
#  {'name': 'hot water entering flow sp point'},
#  {'name': 'hot water entering pipe equip'},
#  {'name': 'hot water entering point'},
#  {'name': 'hot water entering pressure sensor point'},
#  {'name': 'hot water entering pressure sp point'},
#  {'name': 'hot water entering pump alarm sensor point'},
#  {'name': 'hot water entering pump enable cmd point'},
#  {'name': 'hot water entering pump enable sensor point'},
#  {'name': 'hot water entering pump equip'},
#  {'name': 'hot water entering pump motor equip'},
#  {'name': 'hot water entering pump point'},
#  {'name': 'hot water entering pump run cmd point'},
#  {'name': 'hot water entering pump run sensor point'},
#  {'name': 'hot water entering pump vfd freq cmd point'},
#  {'name': 'hot water entering pump vfd freq sensor point'},
#  {'name': 'hot water entering pump vfd speed cmd point'},
#  {'name': 'hot water entering pump vfd speed sensor point'},
#  {'name': 'hot water entering temp sensor point'},
#  {'name': 'hot water entering temp sp point'},
#  {'name': 'hot water entering valve actuator equip'},
#  {'name': 'hot water entering valve cmd point'},
#  {'name': 'hot water entering valve sensor point'},
#  {'name': 'hot water header equip'},
#  {'name': 'hot water header flow sensor point'},
#  {'name': 'hot water header flow sp point'},
#  {'name': 'hot water header pipe equip'},
#  {'name': 'hot water header point'},
#  {'name': 'hot water header pressure sensor point'},
#  {'name': 'hot water header pressure sp point'},
#  {'name': 'hot water header pump alarm sensor point'},
#  {'name': 'hot water header pump enable cmd point'},
#  {'name': 'hot water header pump enable sensor point'},
#  {'name': 'hot water header pump equip'},
#  {'name': 'hot water header pump motor equip'},
#  {'name': 'hot water header pump point'},
#  {'name': 'hot water header pump run cmd point'},
#  {'name': 'hot water header pump run sensor point'},
#  {'name': 'hot water header pump vfd freq cmd point'},
#  {'name': 'hot water header pump vfd freq sensor point'},
#  {'name': 'hot water header pump vfd speed cmd point'},
#  {'name': 'hot water header pump vfd speed sensor point'},
#  {'name': 'hot water header temp sensor point'},
#  {'name': 'hot water header temp sp point'},
#  {'name': 'hot water header valve actuator equip'},
#  {'name': 'hot water header valve cmd point'},
#  {'name': 'hot water header valve sensor point'},
#  {'name': 'hot water heat valve cmd point'},
#  {'name': 'hot water heatExchanger equip'},
#  {'name': 'hot water leaving equip'},
#  {'name': 'hot water leaving flow sensor point'},
#  {'name': 'hot water leaving flow sp point'},
#  {'name': 'hot water leaving pipe equip'},
#  {'name': 'hot water leaving point'},
#  {'name': 'hot water leaving pressure sensor point'},
#  {'name': 'hot water leaving pressure sp point'},
#  {'name': 'hot water leaving pump alarm sensor point'},
#  {'name': 'hot water leaving pump enable cmd point'},
#  {'name': 'hot water leaving pump enable sensor point'},
#  {'name': 'hot water leaving pump equip'},
#  {'name': 'hot water leaving pump motor equip'},
#  {'name': 'hot water leaving pump point'},
#  {'name': 'hot water leaving pump run cmd point'},
#  {'name': 'hot water leaving pump run sensor point'},
#  {'name': 'hot water leaving pump vfd freq cmd point'},
#  {'name': 'hot water leaving pump vfd freq sensor point'},
#  {'name': 'hot water leaving pump vfd speed cmd point'},
#  {'name': 'hot water leaving pump vfd speed sensor point'},
#  {'name': 'hot water leaving temp sensor point'},
#  {'name': 'hot water leaving temp sp point'},
#  {'name': 'hot water leaving valve actuator equip'},
#  {'name': 'hot water leaving valve cmd point'},
#  {'name': 'hot water leaving valve sensor point'},
#  {'name': 'hot water mixing valve cmd point'},
#  {'name': 'humidifier enable cmd point'},
#  {'name': 'humidifier equip'},
#  {'name': 'humidifier run cmd point'},
#  {'name': 'hvacMode sp point'},
#  {'name': 'import ac elec active energy hisTotalized sensor point'},
#  {'name': 'import ac elec active power max sp point'},
#  {'name': 'import ac elec active power sensor point'},
#  {'name': 'import ac elec magnitude current max sp point'},
#  {'name': 'import ac elec magnitude current sensor point'},
#  {'name': 'import ac elec magnitude volt sensor point'},
#  {'name': 'import ac elec pfScope pf sensor point'},
#  {'name': 'import dc elec current max sp point'},
#  {'name': 'import dc elec current sensor point'},
#  {'name': 'import dc elec energy hisTotalized sensor point'},
#  {'name': 'import dc elec power max sp point'},
#  {'name': 'import dc elec power sensor point'},
#  {'name': 'import dc elec volt sensor point'},
#  {'name': 'infiltration well equip'},
#  {'name': 'inlet air co2 concentration sensor point'},
#  {'name': 'inlet air co2 concentration sp point'},
#  {'name': 'inlet air dewPoint sensor point'},
#  {'name': 'inlet air dewPoint sp point'},
#  {'name': 'inlet air enthalpy sensor point'},
#  {'name': 'inlet air enthalpy sp point'},
#  {'name': 'inlet air flow sensor point'},
#  {'name': 'inlet air flow sp point'},
#  {'name': 'inlet air humidity sensor point'},
#  {'name': 'inlet air humidity sp point'},
#  {'name': 'inlet air pressure sensor point'},
#  {'name': 'inlet air pressure sp point'},
#  {'name': 'inlet air temp sensor point'},
#  {'name': 'inlet air temp sp point'},
#  {'name': 'inlet chilled water cool valve cmd point'},
#  {'name': 'inlet coolingCoil equip'},
#  {'name': 'inlet damper actuator equip'},
#  {'name': 'inlet damper cmd point'},
#  {'name': 'inlet damper sensor point'},
#  {'name': 'inlet duct equip'},
#  {'name': 'inlet equip'},
#  {'name': 'inlet fan alarm sensor point'},
#  {'name': 'inlet fan enable cmd point'},
#  {'name': 'inlet fan enable sensor point'},
#  {'name': 'inlet fan equip'},
#  {'name': 'inlet fan motor equip'},
#  {'name': 'inlet fan point'},
#  {'name': 'inlet fan run cmd point'},
#  {'name': 'inlet fan run sensor point'},
#  {'name': 'inlet fan vfd freq cmd point'},
#  {'name': 'inlet fan vfd freq sensor point'},
#  {'name': 'inlet fan vfd speed cmd point'},
#  {'name': 'inlet fan vfd speed sensor point'},
#  {'name': 'inlet heatingCoil equip'},
#  {'name': 'inlet hot water heat valve cmd point'},
#  {'name': 'inlet point'},
#  {'name': 'inlet stage:1 cool run cmd point'},
#  {'name': 'inlet stage:1 heat run cmd point'},
#  {'name': 'inlet steam heat valve cmd point'},
#  {'name': 'level sensor point'},
#  {'name': 'light illuminance sensor point'},
#  {'name': 'light level sensor point'},
#  {'name': 'light level sp point'},
#  {'name': 'light luminous flux sensor point'},
#  {'name': 'load cmd point'},
#  {'name': 'load sensor point'},
#  {'name': 'makeup water entering equip'},
#  {'name': 'makeup water entering flow sensor point'},
#  {'name': 'makeup water entering flow sp point'},
#  {'name': 'makeup water entering pipe equip'},
#  {'name': 'makeup water entering point'},
#  {'name': 'makeup water entering pressure sensor point'},
#  {'name': 'makeup water entering pressure sp point'},
#  {'name': 'makeup water entering pump alarm sensor point'},
#  {'name': 'makeup water entering pump enable cmd point'},
#  {'name': 'makeup water entering pump enable sensor point'},
#  {'name': 'makeup water entering pump equip'},
#  {'name': 'makeup water entering pump motor equip'},
#  {'name': 'makeup water entering pump point'},
#  {'name': 'makeup water entering pump run cmd point'},
#  {'name': 'makeup water entering pump run sensor point'},
#  {'name': 'makeup water entering pump vfd freq cmd point'},
#  {'name': 'makeup water entering pump vfd freq sensor point'},
#  {'name': 'makeup water entering pump vfd speed cmd point'},
#  {'name': 'makeup water entering pump vfd speed sensor point'},
#  {'name': 'makeup water entering temp sensor point'},
#  {'name': 'makeup water entering temp sp point'},
#  {'name': 'makeup water entering valve actuator equip'},
#  {'name': 'makeup water entering valve cmd point'},
#  {'name': 'makeup water entering valve sensor point'},
#  {'name': 'mixed air co2 concentration sensor point'},
#  {'name': 'mixed air co2 concentration sp point'},
#  {'name': 'mixed air dewPoint sensor point'},
#  {'name': 'mixed air dewPoint sp point'},
#  {'name': 'mixed air enthalpy sensor point'},
#  {'name': 'mixed air enthalpy sp point'},
#  {'name': 'mixed air flow sensor point'},
#  {'name': 'mixed air flow sp point'},
#  {'name': 'mixed air humidity sensor point'},
#  {'name': 'mixed air humidity sp point'},
#  {'name': 'mixed air pressure sensor point'},
#  {'name': 'mixed air pressure sp point'},
#  {'name': 'mixed air temp sensor point'},
#  {'name': 'mixed air temp sp point'},
#  {'name': 'mixed chilled water cool valve cmd point'},
#  {'name': 'mixed coolingCoil equip'},
#  {'name': 'mixed damper actuator equip'},
#  {'name': 'mixed damper cmd point'},
#  {'name': 'mixed damper sensor point'},
#  {'name': 'mixed duct equip'},
#  {'name': 'mixed equip'},
#  {'name': 'mixed fan alarm sensor point'},
#  {'name': 'mixed fan enable cmd point'},
#  {'name': 'mixed fan enable sensor point'},
#  {'name': 'mixed fan equip'},
#  {'name': 'mixed fan motor equip'},
#  {'name': 'mixed fan point'},
#  {'name': 'mixed fan run cmd point'},
#  {'name': 'mixed fan run sensor point'},
#  {'name': 'mixed fan vfd freq cmd point'},
#  {'name': 'mixed fan vfd freq sensor point'},
#  {'name': 'mixed fan vfd speed cmd point'},
#  {'name': 'mixed fan vfd speed sensor point'},
#  {'name': 'mixed heatingCoil equip'},
#  {'name': 'mixed hot water heat valve cmd point'},
#  {'name': 'mixed point'},
#  {'name': 'mixed stage:1 cool run cmd point'},
#  {'name': 'mixed stage:1 heat run cmd point'},
#  {'name': 'mixed steam heat valve cmd point'},
#  {'name': 'networking device'},
#  {'name': 'occupancy sensor point'},
#  {'name': 'occupied sensor point'},
#  {'name': 'occupied sp point'},
#  {'name': 'outside air co2 concentration sensor point'},
#  {'name': 'outside air co2 concentration sp point'},
#  {'name': 'outside air dewPoint sensor point'},
#  {'name': 'outside air dewPoint sp point'},
#  {'name': 'outside air enthalpy sensor point'},
#  {'name': 'outside air enthalpy sp point'},
#  {'name': 'outside air flow sensor point'},
#  {'name': 'outside air flow sp point'},
#  {'name': 'outside air humidity sensor point'},
#  {'name': 'outside air humidity sp point'},
#  {'name': 'outside air pressure sensor point'},
#  {'name': 'outside air pressure sp point'},
#  {'name': 'outside air temp sensor point'},
#  {'name': 'outside air temp sp point'},
#  {'name': 'outside chilled water cool valve cmd point'},
#  {'name': 'outside coolingCoil equip'},
#  {'name': 'outside damper actuator equip'},
#  {'name': 'outside damper cmd point'},
#  {'name': 'outside damper sensor point'},
#  {'name': 'outside duct equip'},
#  {'name': 'outside equip'},
#  {'name': 'outside fan alarm sensor point'},
#  {'name': 'outside fan enable cmd point'},
#  {'name': 'outside fan enable sensor point'},
#  {'name': 'outside fan equip'},
#  {'name': 'outside fan motor equip'},
#  {'name': 'outside fan point'},
#  {'name': 'outside fan run cmd point'},
#  {'name': 'outside fan run sensor point'},
#  {'name': 'outside fan vfd freq cmd point'},
#  {'name': 'outside fan vfd freq sensor point'},
#  {'name': 'outside fan vfd speed cmd point'},
#  {'name': 'outside fan vfd speed sensor point'},
#  {'name': 'outside heatingCoil equip'},
#  {'name': 'outside hot water heat valve cmd point'},
#  {'name': 'outside point'},
#  {'name': 'outside stage:1 cool run cmd point'},
#  {'name': 'outside stage:1 heat run cmd point'},
#  {'name': 'outside steam heat valve cmd point'},
#  {'name': 'perimeterHeat cmd point'},
#  {'name': 'phase:"A" ac elec current angle sensor point'},
#  {'name': 'phase:"A" ac elec current imbalance sensor point'},
#  {'name': 'phase:"A" ac elec current magnitude sensor point'},
#  {'name': 'phase:"A" ac elec current thd sensor point'},
#  {'name': 'phase:"A" ac elec pf sensor point'},
#  {'name': 'phase:"A" ac elec volt angle sensor point'},
#  {'name': 'phase:"A" ac elec volt imbalance sensor point'},
#  {'name': 'phase:"A" ac elec volt magnitude sensor point'},
#  {'name': 'phase:"A" ac elec volt thd sensor point'},
#  {'name': 'phase:"A" active ac elec power sensor point'},
#  {'name': 'phase:"A" apparent ac elec power sensor point'},
#  {'name': 'phase:"A" net ac elec active energy sensor point'},
#  {'name': 'phase:"A" reactive ac elec power sensor point'},
#  {'name': 'point'},
#  {'name': 'pressure sensor point'},
#  {'name': 'pressure sp point'},
#  {'name': 'pump alarm sensor point'},
#  {'name': 'pump enable cmd point'},
#  {'name': 'pump enable sensor point'},
#  {'name': 'pump equip'},
#  {'name': 'pump motor equip'},
#  {'name': 'pump point'},
#  {'name': 'pump run cmd point'},
#  {'name': 'pump run sensor point'},
#  {'name': 'pump vfd freq cmd point'},
#  {'name': 'pump vfd freq sensor point'},
#  {'name': 'pump vfd speed cmd point'},
#  {'name': 'pump vfd speed sensor point'},
#  {'name': 'purge water flow sensor point'},
#  {'name': 'purge water volume sensor point'},
#  {'name': 'rack equip'},
#  {'name': 'reheat cmd point'},
#  {'name': 'return air co2 concentration sensor point'},
#  {'name': 'return air co2 concentration sp point'},
#  {'name': 'return air dewPoint sensor point'},
#  {'name': 'return air dewPoint sp point'},
#  {'name': 'return air enthalpy sensor point'},
#  {'name': 'return air enthalpy sp point'},
#  {'name': 'return air flow sensor point'},
#  {'name': 'return air flow sp point'},
#  {'name': 'return air humidity sensor point'},
#  {'name': 'return air humidity sp point'},
#  {'name': 'return air pressure sensor point'},
#  {'name': 'return air pressure sp point'},
#  {'name': 'return air temp sensor point'},
#  {'name': 'return air temp sp point'},
#  {'name': 'return chilled water cool valve cmd point'},
#  {'name': 'return coolingCoil equip'},
#  {'name': 'return damper actuator equip'},
#  {'name': 'return damper cmd point'},
#  {'name': 'return damper sensor point'},
#  {'name': 'return duct equip'},
#  {'name': 'return equip'},
#  {'name': 'return fan alarm sensor point'},
#  {'name': 'return fan enable cmd point'},
#  {'name': 'return fan enable sensor point'},
#  {'name': 'return fan equip'},
#  {'name': 'return fan motor equip'},
#  {'name': 'return fan point'},
#  {'name': 'return fan run cmd point'},
#  {'name': 'return fan run sensor point'},
#  {'name': 'return fan vfd freq cmd point'},
#  {'name': 'return fan vfd freq sensor point'},
#  {'name': 'return fan vfd speed cmd point'},
#  {'name': 'return fan vfd speed sensor point'},
#  {'name': 'return heatingCoil equip'},
#  {'name': 'return hot water heat valve cmd point'},
#  {'name': 'return point'},
#  {'name': 'return stage:1 cool run cmd point'},
#  {'name': 'return stage:1 heat run cmd point'},
#  {'name': 'return steam heat valve cmd point'},
#  {'name': 'run cmd point'},
#  {'name': 'run sensor point'},
#  {'name': 'server device'},
#  {'name': 'space'},
#  {'name': 'stage:1 cool run cmd point'},
#  {'name': 'stage:1 heat run cmd point'},
#  {'name': 'steam boiler equip'},
#  {'name': 'steam bypass equip'},
#  {'name': 'steam bypass flow sensor point'},
#  {'name': 'steam bypass flow sp point'},
#  {'name': 'steam bypass pipe equip'},
#  {'name': 'steam bypass point'},
#  {'name': 'steam bypass pressure sensor point'},
#  {'name': 'steam bypass pressure sp point'},
#  {'name': 'steam bypass pump alarm sensor point'},
#  {'name': 'steam bypass pump enable cmd point'},
#  {'name': 'steam bypass pump enable sensor point'},
#  {'name': 'steam bypass pump equip'},
#  {'name': 'steam bypass pump motor equip'},
#  {'name': 'steam bypass pump point'},
#  {'name': 'steam bypass pump run cmd point'},
#  {'name': 'steam bypass pump run sensor point'},
#  {'name': 'steam bypass pump vfd freq cmd point'},
#  {'name': 'steam bypass pump vfd freq sensor point'},
#  {'name': 'steam bypass pump vfd speed cmd point'},
#  {'name': 'steam bypass pump vfd speed sensor point'},
#  {'name': 'steam bypass temp sensor point'},
#  {'name': 'steam bypass temp sp point'},
#  {'name': 'steam bypass valve actuator equip'},
#  {'name': 'steam bypass valve cmd point'},
#  {'name': 'steam bypass valve sensor point'},
#  {'name': 'steam delta flow sensor point'},
#  {'name': 'steam delta pressure sensor point'},
#  {'name': 'steam delta temp sensor point'},
#  {'name': 'steam header equip'},
#  {'name': 'steam header flow sensor point'},
#  {'name': 'steam header flow sp point'},
#  {'name': 'steam header pipe equip'},
#  {'name': 'steam header point'},
#  {'name': 'steam header pressure sensor point'},
#  {'name': 'steam header pressure sp point'},
#  {'name': 'steam header pump alarm sensor point'},
#  {'name': 'steam header pump enable cmd point'},
#  {'name': 'steam header pump enable sensor point'},
#  {'name': 'steam header pump equip'},
#  {'name': 'steam header pump motor equip'},
#  {'name': 'steam header pump point'},
#  {'name': 'steam header pump run cmd point'},
#  {'name': 'steam header pump run sensor point'},
#  {'name': 'steam header pump vfd freq cmd point'},
#  {'name': 'steam header pump vfd freq sensor point'},
#  {'name': 'steam header pump vfd speed cmd point'},
#  {'name': 'steam header pump vfd speed sensor point'},
#  {'name': 'steam header temp sensor point'},
#  {'name': 'steam header temp sp point'},
#  {'name': 'steam header valve actuator equip'},
#  {'name': 'steam header valve cmd point'},
#  {'name': 'steam header valve sensor point'},
#  {'name': 'steam heat valve cmd point'},
#  {'name': 'steam heatExchanger equip'},
#  {'name': 'steam leaving equip'},
#  {'name': 'steam leaving flow sensor point'},
#  {'name': 'steam leaving flow sp point'},
#  {'name': 'steam leaving pipe equip'},
#  {'name': 'steam leaving point'},
#  {'name': 'steam leaving pressure sensor point'},
#  {'name': 'steam leaving pressure sp point'},
#  {'name': 'steam leaving pump alarm sensor point'},
#  {'name': 'steam leaving pump enable cmd point'},
#  {'name': 'steam leaving pump enable sensor point'},
#  {'name': 'steam leaving pump equip'},
#  {'name': 'steam leaving pump motor equip'},
#  {'name': 'steam leaving pump point'},
#  {'name': 'steam leaving pump run cmd point'},
#  {'name': 'steam leaving pump run sensor point'},
#  {'name': 'steam leaving pump vfd freq cmd point'},
#  {'name': 'steam leaving pump vfd freq sensor point'},
#  {'name': 'steam leaving pump vfd speed cmd point'},
#  {'name': 'steam leaving pump vfd speed sensor point'},
#  {'name': 'steam leaving temp sensor point'},
#  {'name': 'steam leaving temp sp point'},
#  {'name': 'steam leaving valve actuator equip'},
#  {'name': 'steam leaving valve cmd point'},
#  {'name': 'steam leaving valve sensor point'},
#  {'name': 'steam mixing valve cmd point'},
#  {'name': 'temp sensor point'},
#  {'name': 'temp sp point'},
#  {'name': 'thermostat equip'},
#  {'name': 'total ac elec demand sensor point'},
#  {'name': 'total active ac elec power sensor point'},
#  {'name': 'total apparent ac elec power sensor point'},
#  {'name': 'total export ac elec active energy sensor point'},
#  {'name': 'total import ac elec active energy sensor point'},
#  {'name': 'total net ac elec active energy sensor point'},
#  {'name': 'total reactive ac elec power sensor point'},
#  {'name': 'valve actuator equip'},
#  {'name': 'valve cmd point'},
#  {'name': 'valve sensor point'},
#  {'name': 'ventilation air co2 concentration sensor point'},
#  {'name': 'ventilation air co2 concentration sp point'},
#  {'name': 'ventilation air dewPoint sensor point'},
#  {'name': 'ventilation air dewPoint sp point'},
#  {'name': 'ventilation air enthalpy sensor point'},
#  {'name': 'ventilation air enthalpy sp point'},
#  {'name': 'ventilation air flow sensor point'},
#  {'name': 'ventilation air flow sp point'},
#  {'name': 'ventilation air humidity sensor point'},
#  {'name': 'ventilation air humidity sp point'},
#  {'name': 'ventilation air pressure sensor point'},
#  {'name': 'ventilation air pressure sp point'},
#  {'name': 'ventilation air temp sensor point'},
#  {'name': 'ventilation air temp sp point'},
#  {'name': 'ventilation chilled water cool valve cmd point'},
#  {'name': 'ventilation coolingCoil equip'},
#  {'name': 'ventilation damper actuator equip'},
#  {'name': 'ventilation damper cmd point'},
#  {'name': 'ventilation damper sensor point'},
#  {'name': 'ventilation duct equip'},
#  {'name': 'ventilation equip'},
#  {'name': 'ventilation fan alarm sensor point'},
#  {'name': 'ventilation fan enable cmd point'},
#  {'name': 'ventilation fan enable sensor point'},
#  {'name': 'ventilation fan equip'},
#  {'name': 'ventilation fan motor equip'},
#  {'name': 'ventilation fan point'},
#  {'name': 'ventilation fan run cmd point'},
#  {'name': 'ventilation fan run sensor point'},
#  {'name': 'ventilation fan vfd freq cmd point'},
#  {'name': 'ventilation fan vfd freq sensor point'},
#  {'name': 'ventilation fan vfd speed cmd point'},
#  {'name': 'ventilation fan vfd speed sensor point'},
#  {'name': 'ventilation heatingCoil equip'},
#  {'name': 'ventilation hot water heat valve cmd point'},
#  {'name': 'ventilation point'},
#  {'name': 'ventilation stage:1 cool run cmd point'},
#  {'name': 'ventilation stage:1 heat run cmd point'},
#  {'name': 'ventilation steam heat valve cmd point'},
#  {'name': 'vfd freq cmd point'},
#  {'name': 'vfd freq sensor point'},
#  {'name': 'vfd speed cmd point'},
#  {'name': 'vfd speed sensor point'},
#  {'name': 'vrf branchSelector equip'},
#  {'name': 'vrf indoorUnit equip'},
#  {'name': 'vrf outdoorUnit equip'},
#  {'name': 'vrf refrig plant equip'},
#  {'name': 'warm water flow thermal meter equip'},
#  {'name': 'warm well equip'},
#  {'name': 'water flow sensor point'},
#  {'name': 'water level sensor point'},
#  {'name': 'water pressure sensor point'},
#  {'name': 'water pump alarm sensor point'},
#  {'name': 'water pump enable cmd point'},
#  {'name': 'water pump enable sensor point'},
#  {'name': 'water pump equip'},
#  {'name': 'water pump motor equip'},
#  {'name': 'water pump point'},
#  {'name': 'water pump run cmd point'},
#  {'name': 'water pump run sensor point'},
#  {'name': 'water pump vfd freq cmd point'},
#  {'name': 'water pump vfd freq sensor point'},
#  {'name': 'water pump vfd speed cmd point'},
#  {'name': 'water pump vfd speed sensor point'},
#  {'name': 'water temp sensor point'},
#  {'name': 'water volume sensor point'},
#  {'name': 'weather air dewPoint sensor point'},
#  {'name': 'weather air enthalpy sensor point'},
#  {'name': 'weather air feelsLike sensor point'},
#  {'name': 'weather air humidity sensor point'},
#  {'name': 'weather air temp sensor point'},
#  {'name': 'weather air wetBulb sensor point'},
#  {'name': 'weather atmospheric pressure sensor point'},
#  {'name': 'weather cloudage sensor point'},
#  {'name': 'weather daytime sensor point'},
#  {'name': 'weather precipitation sensor point'},
#  {'name': 'weather solar irradiance sensor point'},
#  {'name': 'weather visibility sensor point'},
#  {'name': 'weather weatherCond sensor point'},
#  {'name': 'weather wind direction sensor point'},
#  {'name': 'weather wind speed sensor point'},
#  {'name': 'zone air ch2o concentration sensor point'},
#  {'name': 'zone air co concentration sensor point'},
#  {'name': 'zone air co2 concentration sensor point'},
#  {'name': 'zone air co2 concentration sp point'},
#  {'name': 'zone air dewPoint sensor point'},
#  {'name': 'zone air dewPoint sp point'},
#  {'name': 'zone air enthalpy sensor point'},
#  {'name': 'zone air enthalpy sp point'},
#  {'name': 'zone air humidity sensor point'},
#  {'name': 'zone air humidity sp point'},
#  ...]

# %%
# create a new Mapper object which knows about the definitions. This will
# access OpenAI to compute embeddings if necessary
m = Mapper(defns, "haystack_proto.index")

# define which set of Brick classes we want to match against
# all points which aren't parameters (these have similar enough names it can confuse the mapping)
points = m.get_brick_classes(BRICK.Point, [BRICK.Parameter])
# all equipment in Brick
equips = m.get_brick_classes(BRICK.Equipment)
# concatenate these two lists of Brick classes
bcs = points + equips

bcs
# Out:
# 2024-12-19 13:29:37.159 | INFO     | brickmapper:populate_external_embeddings:66 - Restored haystack_proto.index
# [BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Static_Pressure_Sensor'), label='Static Pressure Sensor', definition="Measures resistance to airflow in a heating and cooling system's components and duct work", definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Underfloor_Air_Plenum_Static_Pressure_Sensor'), label='Underfloor Air Plenum Static Pressure Sensor', definition='Measures the outward push of air against the plenum surfaces and used to measure the resistance when air moves through the plenum', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Air_Quality_Sensor'), label='Air Quality Sensor', definition='A sensor which provides a measure of air quality', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Medium_Temperature_Hot_Water_Temperature_Load_Shed_Setpoint'), label='Entering Medium Temperature Hot Water Temperature Load Shed Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Flow_Setpoint'), label='Flow Setpoint', definition='Sets flow', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Differential_Pressure_Deadband_Setpoint'), label='Chilled Water Differential Pressure Deadband Setpoint', definition='Sets the size of a deadband of differential pressure of chilled water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Condenser_Water_Temperature_Setpoint'), label='Leaving Condenser Water Temperature Setpoint', definition='The temperature setpoint for the leaving condenser water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Max_Water_Level_Alarm'), label='Max Water Level Alarm', definition='Alarm indicating that the maximum water level was reached', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Command'), label='Command', definition='A Command is an output point that directly determines the behavior of equipment and/or affects relevant operational points.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Damper_Position_Sensor'), label='Damper Position Sensor', definition='Measures the current position of a damper in terms of the percent of fully open', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Cooling_Discharge_Air_Flow_Setpoint'), label='Cooling Discharge Air Flow Setpoint', definition='Sets discharge air flow for cooling', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heating_Discharge_Air_Temperature_Deadband_Setpoint'), label='Heating Discharge Air Temperature Deadband Setpoint', definition='Sets the size of a deadband of temperature of heating discharge air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Low_Discharge_Air_Flow_Alarm'), label='Low Discharge Air Flow Alarm', definition='An alarm that indicates that the discharge air flow is lower than normal.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Discharge_Air_Velocity_Pressure_Sensor'), label='Discharge Air Velocity Pressure Sensor', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Direction_Sensor'), label='Direction Sensor', definition='Measures the direction in degrees in which a phenomenon is occuring', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Motor_Current_Sensor'), label='Motor Current Sensor', definition='Measures the current consumed by a motor', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Outside_Illuminance_Sensor'), label='Outside Illuminance Sensor', definition='Measures the total luminous flux incident on an outside, per unit area', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Motor_On_Off_Status'), label='Motor On Off Status', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Max_Water_Temperature_Setpoint'), label='Max Water Temperature Setpoint', definition='Setpoint for max water temperature', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Cooling_Supply_Air_Flow_Setpoint'), label='Unoccupied Cooling Supply Air Flow Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Differential_Pressure_Setpoint'), label='Hot Water Differential Pressure Setpoint', definition='Sets the target water differential pressure between an upstream and downstream point in a water pipe or conduit used to carry hot water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#High_Head_Pressure_Alarm'), label='High Head Pressure Alarm', definition='An alarm that indicates a high pressure generated on the output side of a gas compressor in a refrigeration or air conditioning system.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hail_Sensor'), label='Hail Sensor', definition='Measures hail in terms of its size and damage potential', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Average_Discharge_Air_Flow_Sensor'), label='Average Discharge Air Flow Sensor', definition='The computed average flow of discharge air over some interval', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Domestic_Hot_Water_Temperature_Sensor'), label='Domestic Hot Water Temperature Sensor', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Bypass_Water_Flow_Sensor'), label='Bypass Water Flow Sensor', definition='Measures the rate of flow of bypass water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Gauge_Pressure_Sensor'), label='Hot Water Gauge Pressure Sensor', definition='Sensor measuring the gauge pressure (zero-referenced against ambient air pressure) of hot water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Effective_Target_Zone_Air_Temperature_Setpoint'), label='Effective Target Zone Air Temperature Setpoint', definition='Target Setpoint (also known as Common Setpoint) is a reference point representing the desired air temperature in a specific zone of a building. This setpoint acts as a baseline from which the cooling and heating setpoints are established by adding or subtracting a deadband width', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Automatic_Mode_Command'), label='Automatic Mode Command', definition='Controls whether or not a device or controller is operating in "Automatic" mode', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Emergency_Power_Off_System_Activated_By_Leak_Detection_System_Status'), label='Emergency Power Off System Activated By Leak Detection System Status', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Box_Mode_Command'), label='Box Mode Command', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#System_Shutdown_Status'), label='System Shutdown Status', definition='Indicates if a system has been shutdown', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Differential_Temperature_Sensor'), label='Chilled Water Differential Temperature Sensor', definition='Measures the difference in temperature between the entering water to the chiller or other water cooling device and leaving water from the same chiller or other water cooling device', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Air_Differential_Pressure_Sensor'), label='Air Differential Pressure Sensor', definition='Measures the difference in pressure between two regions of air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Differential_Supply_Return_Water_Temperature_Sensor'), label='Differential Supply Return Water Temperature Sensor', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Stages_Status'), label='Stages Status', definition='Indicates which stage a control loop or equipment is in', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Emergency_Power_Off_System_Activated_By_High_Temperature_Status'), label='Emergency Power Off System Activated By High Temperature Status', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Lighting_Level_Command'), label='Lighting Level Command', definition='Controls the amount of the light provided by the device typically in percentages.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Load_Shed_Status'), label='Load Shed Status', definition='Indicates if a load shedding policy is in effect', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Occupied_Cooling_Supply_Air_Flow_Setpoint'), label='Occupied Cooling Supply Air Flow Setpoint', definition='Sets supply air flow rate for cooling when occupied', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Fan_Command'), label='Fan Command', definition='Controls properties of fans', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Overridden_On_Status'), label='Overridden On Status', definition='Indicates if a control loop, relay or equipment has been turned on when it would otherwise be scheduled to be off', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Hot_Water_Flow_Setpoint'), label='Entering Hot Water Flow Setpoint', definition='Sets the target flow rate of hot entering water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Enable_Command'), label='Enable Command', definition='Commands that enable functionality', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Min_Water_Temperature_Setpoint'), label='Min Water Temperature Setpoint', definition='Setpoint for min water temperature', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Output_Voltage_Sensor'), label='Output Voltage Sensor', definition='Measures the voltage output by some process or device', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Static_Pressure_Setpoint'), label='Hot Water Static Pressure Setpoint', definition='Sets static pressure of hot air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Level_Sensor'), label='Water Level Sensor', definition='Measures the height/level of water in some container', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Thermostat_Status'), label='Thermostat Status', definition='Status of a thermostat', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Discharge_Air_Static_Pressure_Setpoint'), label='Discharge Air Static Pressure Setpoint', definition='Sets static pressure of discharge air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Pressure_Alarm'), label='Pressure Alarm', definition='An alarm that indicates the off-normal conditions associated with pressure.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Water_Differential_Pressure_Deadband_Setpoint'), label='Entering Water Differential Pressure Deadband Setpoint', definition='Sets the size of a deadband of differential pressure of entering water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Air_Temperature_Sensor'), label='Return Air Temperature Sensor', definition='Measures the temperature of return air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Usage_Sensor'), label='Hot Water Usage Sensor', definition='Measures the amount of hot water that is consumed, over some period of time', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Duct_Pressure_Status'), label='Supply Air Duct Pressure Status', definition='Indicates if air pressure in supply duct is within expected bounds', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Speed_Mode_Status'), label='Speed Mode Status', definition='Indicates the speed mode of a motor with various categorical settings, such as a multi-state value including low, medium, and high.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Tint_Command'), label='Tint Command', definition='The target level of window tint.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Disable_Command'), label='Disable Command', definition='Commands that disable functionality', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Zone_Air_Cooling_Temperature_Setpoint'), label='Zone Air Cooling Temperature Setpoint', definition='The upper (cooling) setpoint for zone air temperature', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Medium_Temperature_Hot_Water_Temperature_Sensor'), label='Leaving Medium Temperature Hot Water Temperature Sensor', definition='Measures the temperature of medium-temperature hot water supplied by a hot water system', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Medium_Temperature_Hot_Water_Temperature_Load_Shed_Status'), label='Leaving Medium Temperature Hot Water Temperature Load Shed Status', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Loss_Alarm'), label='Water Loss Alarm', definition='An alarm that indicates a loss of water e.g. during transport', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Energy_Usage_Sensor'), label='Energy Usage Sensor', definition='Measures the total amount of energy used over some period of time', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Valve_Status'), label='Valve Status', definition='The current status of the valve.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Occupancy_Command'), label='Occupancy Command', definition='Controls whether or not a device or controller is operating in "Occupied" mode', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Damper_Position_Command'), label='Damper Position Command', definition='Controls the position (the degree of openness) of a damper', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Curtailment_Override_Command'), label='Curtailment Override Command', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Frequency_Command'), label='Frequency Command', definition="Controls the frequency of a device's operation (e.g. rotational frequency)", definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Short_Cycle_Alarm'), label='Short Cycle Alarm', definition='An alarm that indicates a short cycle occurred. A short cycle occurs when a cooling cycle is prevented from completing its full cycle', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Outside_Air_Enthalpy_Sensor'), label='Outside Air Enthalpy Sensor', definition='Measures the total heat content of outside air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Velocity_Pressure_Sensor'), label='Supply Air Velocity Pressure Sensor', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Min_Frequency_Command'), label='Min Frequency Command', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Differential_Temperature_Sensor'), label='Hot Water Differential Temperature Sensor', definition='Measures the difference in temperature between the entering water to the boiler or other water heating device and leaving water from the same boiler or other water heating device', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#High_CO2_Alarm'), label='High CO2 Alarm', definition='A device that indicates high concentration of carbon dioxide.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Bypass_Water_Flow_Setpoint'), label='Bypass Water Flow Setpoint', definition='Sets the target flow rate of bypass water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Water_Flow_Sensor'), label='Leaving Water Flow Sensor', definition='Measures the rate of flow of water that is leaving a piece of equipment or system', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Filter_Air_Differential_Pressure_Sensor'), label='Filter Air Differential Pressure Sensor', definition='Measures the difference in air pressure before and after an air filter.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Occupied_Zone_Air_Temperaure_Setpoint'), label='Occupied Zone Air Temperaure Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Off_Status'), label='Off Status', definition='Indicates if a control loop, relay or equipment is off', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Water_Flow_Setpoint'), label='Supply Water Flow Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Supply_Flow_Setpoint'), label='Hot Water Supply Flow Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Air_Temperature_Alarm'), label='Air Temperature Alarm', definition='An alarm that indicates the off-normal conditions associated with the temperature of air.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Low_Supply_Air_Temperature_Alarm'), label='Low Supply Air Temperature Alarm', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Exhaust_Air_Dewpoint_Sensor'), label='Exhaust Air Dewpoint Sensor', definition='Measures dewpoint of exhaust air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Speed_Reset_Command'), label='Speed Reset Command', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Discharge_Air_Temperature_Alarm'), label='Discharge Air Temperature Alarm', definition='An alarm that indicates the off-normal conditions associated with the temperature of discharge air.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Warm_Cool_Adjust_Sensor'), label='Warm Cool Adjust Sensor', definition='User provided adjustment of zone temperature, typically in the range of +/- 5 degrees', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Enable_Hot_Water_System_Outside_Air_Temperature_Setpoint'), label='Enable Hot Water System Outside Air Temperature Setpoint', definition='Enables hot water system when outside air temperature reaches the indicated value', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Max_Frequency_Command'), label='Max Frequency Command', definition='Sets the maximum permitted frequency', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Discharge_Air_Temperature_Setpoint'), label='Discharge Air Temperature Setpoint', definition='Sets temperature of discharge air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Static_Pressure_Setpoint'), label='Supply Air Static Pressure Setpoint', definition='Sets static pressure of supply air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Power_Factor_Sensor'), label='Power Factor Sensor', definition='Sensors measuring power Factor, under periodic conditions, is the ratio of the absolute value of the active power (P) to the apparent power (S).', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Dehumidification_Start_Stop_Status'), label='Dehumidification Start Stop Status', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Reheat_Command'), label='Reheat Command', definition='A command to activate reheating, which is used for either heating or for dehumidification purposes', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#CO_Sensor'), label='CO Sensor', definition='Measures properties of CO', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Temperature_Sensor'), label='Temperature Sensor', definition='Measures temperature: the physical property of matter that quantitatively expresses the common notions of hot and cold', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Humidity_Alarm'), label='Humidity Alarm', definition='An alarm that indicates the off-normal conditions associated with the concentration of water vapor in the air.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Emergency_Generator_Alarm'), label='Emergency Generator Alarm', definition='An alarm that indicates off-normal conditions associated with an emergency generator', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Flow_Sensor'), label='Hot Water Flow Sensor', definition='Measures the rate of flow in a hot water circuit', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Solar_Azimuth_Angle_Sensor'), label='Solar Azimuth Angle Sensor', definition='Measures the azimuth angle of the sun', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heating_Supply_Air_Flow_Setpoint'), label='Heating Supply Air Flow Setpoint', definition='Sets supply air flow rate for heating', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Maintenance_Required_Alarm'), label='Maintenance Required Alarm', definition='An alarm that indicates that repair/maintenance is required on an associated device or equipment', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Fault_Reset_Command'), label='Fault Reset Command', definition='Clears a fault status', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Position_Command'), label='Position Command', definition='Controls or reports the position of some object', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Natural_Gas_Temperature_Sensor'), label='Natural Gas Temperature Sensor', definition='Measures the temperature of natural gas', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Water_Temperature_Setpoint'), label='Leaving Water Temperature Setpoint', definition='Sets temperature of leaving water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Condenser_Water_Flow_Sensor'), label='Condenser Water Flow Sensor', definition='Measures the flow of the condenser water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Effective_Discharge_Air_Temperature_Setpoint'), label='Effective Discharge Air Temperature Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Discharge_Flow_Sensor'), label='Hot Water Discharge Flow Sensor', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Deadband_Setpoint'), label='Deadband Setpoint', definition='Sets the size of a deadband', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heat_Sink_Temperature_Sensor'), label='Heat Sink Temperature Sensor', definition='Measure temperature of the heat sink on a device such as a VFD.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Water_Flow_Sensor'), label='Supply Water Flow Sensor', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Air_CO2_Setpoint'), label='Return Air CO2 Setpoint', definition='Sets some property of CO2 in Return Air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#PM1_Sensor'), label='PM1 Sensor', definition='Detects matter of size 1 micron', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Occupied_Heating_Temperature_Deadband_Setpoint'), label='Occupied Heating Temperature Deadband Setpoint', definition='Sets the size of a deadband of temperature for heating when occupied', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Differential_Pressure_Load_Shed_Reset_Status'), label='Hot Water Differential Pressure Load Shed Reset Status', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Lead_Lag_Command'), label='Lead Lag Command', definition='Enables lead/lag operation', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Cooling_Temperature_Deadband_Setpoint'), label='Unoccupied Cooling Temperature Deadband Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Discharge_Condenser_Water_Temperature_Sensor'), label='Discharge Condenser Water Temperature Sensor', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Occupied_Heating_Temperature_Setpoint'), label='Occupied Heating Temperature Setpoint', definition='Sets temperature for heating when occupied', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Bypass_Command'), label='Bypass Command', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Valve_Command'), label='Valve Command', definition='Controls or reports the openness of a valve (typically as a proportion of its full range of motion)', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Enthalpy_Sensor'), label='Enthalpy Sensor', definition='Measures the total heat content of some substance', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Cooling_Zone_Air_Temperature_Setpoint'), label='Unoccupied Cooling Zone Air Temperature Setpoint', definition='Sets temperature of air when unoccupied for cooling within a specific zone', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Hot_Water_Temperature_Setpoint'), label='Return Hot Water Temperature Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Air_Differential_Pressure_Setpoint'), label='Air Differential Pressure Setpoint', definition='Sets the target air differential pressure between an upstream and downstream point in a air duct or conduit', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Fan_On_Off_Status'), label='Fan On Off Status', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Piezoelectric_Sensor'), label='Piezoelectric Sensor', definition='Senses changes pressure, acceleration, temperature, force or strain via the piezoelectric effect', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Luminance_Sensor'), label='Luminance Sensor', definition='Measures the luminous intensity per unit area of light travelling in a given direction', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Cooling_Demand_Sensor'), label='Cooling Demand Sensor', definition='Measures the amount of power consumed by a cooling process; typically found by multiplying the tonnage of a unit (e.g. RTU) by the efficiency rating in kW/ton', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Discharge_Condenser_Water_Flow_Sensor'), label='Discharge Condenser Water Flow Sensor', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Solar_Irradiance_Sensor'), label='Solar Irradiance Sensor', definition='Measures solar irradiance levels for photovoltaic systems', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Bypass_Air_Humidity_Setpoint'), label='Bypass Air Humidity Setpoint', definition='Humidity setpoint for bypass air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Effective_Heating_Zone_Air_Temperature_Setpoint'), label='Effective Heating Zone Air Temperature Setpoint', definition='The effective heating setpoint for a specific zone in a building.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Speed_Command'), label='Speed Command', definition='A command to set speed to a certain degree.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Inside_Face_Surface_Temperature_Sensor'), label='Inside Face Surface Temperature Sensor', definition='Measures the inside surface (relative to the space) of the radiant panel of the radiant heating and cooling HVAC system.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Air_Differential_Pressure_Setpoint'), label='Return Air Differential Pressure Setpoint', definition='Sets the target air differential pressure between an upstream and downstream point in a return air duct or conduit', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Underfloor_Air_Temperature_Sensor'), label='Underfloor Air Temperature Sensor', definition='Measures the temperature of underfloor air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Outside_Face_Surface_Temperature_Setpoint'), label='Outside Face Surface Temperature Setpoint', definition='Sets temperature for the outside face surface temperature of the radiant panel.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#TVOC_Level_Sensor'), label='TVOC Level Sensor', definition='A sensor measuring the level of all VOCs in air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Medium_Temperature_Hot_Water_Differential_Pressure_Load_Shed_Reset_Status'), label='Medium Temperature Hot Water Differential Pressure Load Shed Reset Status', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Wind_Speed_Sensor'), label='Wind Speed Sensor', definition='Measured speed of wind, caused by air moving from high to low pressure', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Torque_Sensor'), label='Torque Sensor', definition='Measures torque, the tendency of a force to rotate an object about some axis', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Outside_Air_Temperature_Sensor'), label='Outside Air Temperature Sensor', definition='Measures the temperature of outside air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Standby_Cooling_Zone_Air_Temperature_Setpoint'), label='Standby Cooling Zone Air Temperature Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Air_Grains_Sensor'), label='Return Air Grains Sensor', definition='Measures the mass of water vapor in return air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Deionised_Water_Conductivity_Sensor'), label='Deionised Water Conductivity Sensor', definition='Measures the electrical conductance of deionised water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Outside_Air_Temperature_Enable_Differential_Sensor'), label='Outside Air Temperature Enable Differential Sensor', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#High_Humidity_Alarm'), label='High Humidity Alarm', definition='An alarm that indicates high concentration of water vapor in the air.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Exhaust_Air_Humidity_Sensor'), label='Exhaust Air Humidity Sensor', definition='Measures the relative humidity of exhaust air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Preheat_Discharge_Air_Temperature_Sensor'), label='Preheat Discharge Air Temperature Sensor', definition='Measures the temperature of discharge air before heating is applied', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Flow_Setpoint'), label='Water Flow Setpoint', definition='Sets the target flow rate of water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_High_Temperature_Hot_Water_Temperature_Sensor'), label='Leaving High Temperature Hot Water Temperature Sensor', definition='Measures the temperature of high-temperature hot water supplied by a hot water system', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Heating_Supply_Air_Flow_Setpoint'), label='Unoccupied Heating Supply Air Flow Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Discharge_Air_Temperature_Deadband_Setpoint'), label='Discharge Air Temperature Deadband Setpoint', definition='Sets the size of a deadband of temperature of discharge air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Condenser_Water_Temperature_Setpoint'), label='Return Condenser Water Temperature Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Differential_Temperature_Setpoint'), label='Water Differential Temperature Setpoint', definition='Sets the target differential temperature between the start and end of a heat transfer cycle in a water circuit', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Zone_Occupied_Load_Shed_Command'), label='Zone Occupied Load Shed Command', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Supply_Flow_Setpoint'), label='Chilled Water Supply Flow Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Power_Alarm'), label='Power Alarm', definition='An alarm that indicates the off-normal conditions associated with electrical power.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#CO_Level_Sensor'), label='CO Level Sensor', definition='Measures the concentration of CO', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Building_Air_Humidity_Setpoint'), label='Building Air Humidity Setpoint', definition='Setpoint for humidity in a building', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Air_Humidity_Setpoint'), label='Return Air Humidity Setpoint', definition='Humidity setpoint for return air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Tint_Status'), label='Tint Status', definition='The current level of window tint, errors, or transient states.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Voltage_Imbalance_Sensor'), label='Voltage Imbalance Sensor', definition='A sensor which measures the voltage difference (imbalance) between phases of an electrical system', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#DC_Bus_Voltage_Sensor'), label='DC Bus Voltage Sensor', definition='Measures the voltage across a DC bus', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Reactive_Power_Sensor'), label='Reactive Power Sensor', definition='Measures the portion of power that, averaged over a complete cycle of the AC waveform, is due to stored energy which returns to the source in each cycle', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Load_Setpoint'), label='Load Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Setpoint'), label='Setpoint', definition='A Setpoint is an input value at which the desired property is set', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Load_Shed_Command'), label='Unoccupied Load Shed Command', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Run_Status'), label='Run Status', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Discharge_Flow_Setpoint'), label='Hot Water Discharge Flow Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Flow_Sensor'), label='Chilled Water Flow Sensor', definition='Measures the rate of flow in a chilled water circuit', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Mixed_Air_Temperature_Setpoint'), label='Mixed Air Temperature Setpoint', definition='Sets temperature of mixed air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Occupied_Air_Temperature_Setpoint'), label='Occupied Air Temperature Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Differential_Temperature_Sensor'), label='Water Differential Temperature Sensor', definition='Measures the difference in water temperature between an upstream and downstream point in a pipe or conduit', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Operating_Mode_Status'), label='Operating Mode Status', definition='Indicates the current operating mode of a system, device or control loop', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Exhaust_Air_Flow_Setpoint'), label='Exhaust Air Flow Setpoint', definition='Sets exhaust air flow rate', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Heating_Mode_Status'), label='Unoccupied Heating Mode Status', definition='Indicates whether a system, device or control loop is in an unoccupied heating mode', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Exhaust_Fan_Disable_Command'), label='Exhaust Fan Disable Command', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Supply_Temperature_Sensor'), label='Chilled Water Supply Temperature Sensor', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Exhaust_Air_Stack_Flow_Sensor'), label='Exhaust Air Stack Flow Sensor', definition='Measures the rate of flow of air in the exhaust air stack', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Filter_Water_Differential_Pressure_Sensor'), label='Filter Water Differential Pressure Sensor', definition='Measures the difference in water pressure before and after a water filter.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Low_Voltage_Alarm'), label='Low Voltage Alarm', definition='An alarm that indicates the voltage is lower than its normal state.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Even_Month_Status'), label='Even Month Status', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#CO2_Setpoint'), label='CO2 Setpoint', definition='Sets some property of CO2', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Occupied_Load_Shed_Command'), label='Occupied Load Shed Command', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heating_Zone_Air_Temperature_Setpoint'), label='Heating Zone Air Temperature Setpoint', definition='The heating setpoint for a specific zone in a building.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#PV_Current_Output_Sensor'), label='PV Current Output Sensor', definition='See Photovoltaic_Current_Output_Sensor', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Acceleration_Time_Setpoint'), label='Acceleration Time Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Air_Grains_Sensor'), label='Air Grains Sensor', definition='Measures the mass of water vapor in air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Hot_Water_Temperature_High_Reset_Setpoint'), label='Leaving Hot Water Temperature High Reset Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Air_Pressure_Sensor'), label='Air Pressure Sensor', definition='Measures the pressure of the surrounding air.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Flow_Reset_Setpoint'), label='Supply Air Flow Reset Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heating_Demand_Setpoint'), label='Heating Demand Setpoint', definition='Sets the rate required for heating', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Voltage_Alarm'), label='Voltage Alarm', definition='An alarm that indicates the voltage is not in a normal state.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Air_Alarm'), label='Air Alarm', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Intake_Air_Temperature_Sensor'), label='Intake Air Temperature Sensor', definition='Measures air at the interface between the building and the outside', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Mixed_Air_Humidity_Sensor'), label='Mixed Air Humidity Sensor', definition='Measures the humidity of mixed air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Occupied_Heating_Discharge_Air_Flow_Setpoint'), label='Occupied Heating Discharge Air Flow Setpoint', definition='Sets discharge air flow for heating when occupied', definitions=[]),
# ...
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Standby_CRAC'), label='Standby CRAC', definition='A CRAC that is activated as part of a lead/lag operation or when an alarm occurs in a primary unit', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Cooled_Chiller'), label='Water Cooled Chiller', definition='A chiller system using water in the heat exchange process, employed in industrial or commercial facilities for cooling', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heat_Wheel_VFD'), label='Heat Wheel VFD', definition='A VFD that drives a heat wheel', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Intake_Air_Filter'), label='Intake Air Filter', definition='Filters air intake', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Dual_Duct_Air_Handling_Unit'), label='Dual Duct Air Handling Unit', definition='An air handling unit that contains hot and cold decks to supply heating and cooling to a building', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Thermal_Energy_Storage_Tank'), label='Chilled Water Thermal Energy Storage Tank', definition='A Thermal Energy Storage (TES) tank is a specialized container for storing thermal energy, enabling more efficient cooling by balancing supply and demand. It helps reduce operational costs and minimizes the need for larger equipment.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Electric_Boiler'), label='Electric Boiler', definition='A closed, pressure vessel that uses electricity for heating water or other fluids to supply steam or hot water for heating, humidification, or other applications.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Mixed_Air_Filter'), label='Mixed Air Filter', definition='A filter that is applied to the mixture of recirculated and outside air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Cooling_Only_Air_Source_Condensing_Unit'), label='Cooling Only Air Source Condensing Unit', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Horizontal_Fan_Coil_Unit'), label='Horizontal Fan Coil Unit', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Radiant_Ceiling_Panel'), label='Radiant Ceiling Panel', definition='Radiant panel heating and cooling system that are usually made from metal and suspended under the ceiling or insulated from the building structure.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Gas_Meter'), label='Gas Meter', definition='A meter that measures the usage or consumption of gas', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Pressure_Relief_Valve'), label='Water Pressure Relief Valve', definition='Valve designed to automatically relieve excessive water pressure.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Embedded_Surface_System_Panel'), label='Embedded Surface System Panel', definition='Radiant panel heating and cooling system where the energy heat source or sink is embedded in a radiant layer which is thermally insulated from the building structure.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#RVAV'), label='RVAV', definition='See Variable_Air_Volume_Box_With_Reheat', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Controller'), label='Controller', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Fan_VFD'), label='Fan VFD', definition='Variable-frequency drive for fans', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Cold_Deck'), label='Cold Deck', definition='Part of a dual duct air handling unit that supplies cooling to a building', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Coil'), label='Coil', definition='Cooling or heating element made of pipe or tube that may or may not be finned and formed into helical or serpentine shape (ASHRAE Dictionary)', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Switchgear'), label='Switchgear', definition='A main disconnect or service disconnect feeds power to a switchgear, which then distributes power to the rest of the building through smaller amperage-rated disconnects.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Thermal_Power_Meter'), label='Thermal Power Meter', definition='A standalone thermal power meter', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Solar_Thermal_Collector'), label='Solar Thermal Collector', definition='A type of solar panels that converts solar radiation into thermal energy.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Valve'), label='Water Valve', definition='A valve that modulates the flow of water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Displacement_Flow_Air_Diffuser'), label='Displacement Flow Air Diffuser', definition='An air diffuser that is designed for low discharge air speeds to minimize turbulence and induction of room air. This diffuser is used with displacement ventilation systems.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Access_Control_Equipment'), label='Access Control Equipment', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Ceiling_Fan'), label='Ceiling Fan', definition='A fan installed on the ceiling of a room for the purpose of air circulation', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#FCU'), label='FCU', definition='See Fan_Coil_Unit', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Thermostat'), label='Thermostat', definition='An automatic control device used to maintain temperature at a fixed or adjustable setpoint.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Fan_Coil_Unit'), label='Fan Coil Unit', definition="Terminal device consisting of a heating and/or cooling heat exchanger or 'coil' and fan that is used to control the temperature in the space where it is installed", definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#MAU'), label='MAU', definition='See Makeup_Air_Unit', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Thermal_Energy_Storage_Tank'), label='Hot Water Thermal Energy Storage Tank', definition='A Thermal Energy Storage (TES) tank is a specialized container for storing thermal energy, enabling more efficient heating by balancing supply and demand. It helps reduce operational costs and minimizes the need for larger equipment.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Equipment'), label='Equipment', definition='devices that serve all or part of the building and may include electric power, lighting, transportation, or service water heating, including, but not limited to, furnaces, boilers, air conditioners, heat pumps, chillers, water heaters, lamps, luminaires, ballasts, elevators, escalators, or other devices or installations.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Relief_Fan'), label='Relief Fan', definition="A fan that is a component of a Relief Air System, ensuring building doesn't become over-pressurised", definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Gas_Distribution'), label='Gas Distribution', definition='Utilize a gas distribution source to represent how gas is distributed across multiple destinations', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Mixing_Valve'), label='Mixing Valve', definition='Valve used for mixing hot and cold fluid to a desired temperature.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Distribution'), label='Water Distribution', definition='Utilize a water distribution source to represent how water is distributed across multiple destinations (pipes)', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heating_Valve'), label='Heating Valve', definition='A valve that controls air temperature by modulating the amount of hot water flowing through a heating coil', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Condenser_Water_Valve'), label='Condenser Water Valve', definition='A valve that modulates the flow of condenser water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Electric_Baseboard_Radiator'), label='Electric Baseboard Radiator', definition='Electric heating device located at or near the floor', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Steam_Distribution'), label='Steam Distribution', definition='Utilize a steam distribution source to represent how steam is distributed across multiple destinations', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Gas_Valve'), label='Gas Valve', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Steam_Pressure_Relief_Valve'), label='Steam Pressure Relief Valve', definition='Valve designed to automatically relieve excessive steam pressure.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Bus_Riser'), label='Bus Riser', definition='Bus Risers are commonly fed from a switchgear and rise up through a series of floors to the main power distribution source for each floor.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Steam_Radiator'), label='Steam Radiator', definition='Radiator that uses steam', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Eye_Wash_Station'), label='Eye Wash Station', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Reheat_Valve'), label='Reheat Valve', definition='A valve that controls air temperature by modulating the amount of hot water flowing through a reheat coil', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Exhaust_Damper'), label='Exhaust Damper', definition='A damper that modulates the flow of exhaust air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Cooling_Tower_Fan'), label='Cooling Tower Fan', definition='A fan that pulls air through a cooling tower and across the louvers where the water falls to aid in heat exchange by the process of evaporation', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Manual_Fire_Alarm_Activation_Equipment'), label='Manual Fire Alarm Activation Equipment', definition='A device for manually activating fire alarm', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Separation_Tank'), label='Separation Tank', definition='A tank used in conjunction with a filter to facilitate the separation of filtrate material for disposal.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Pressure_Reducing_Valve'), label='Pressure Reducing Valve', definition='Valve used to reduce a high supply pressure to a usable level; maintains uniform outlet pressure despite inlet pressure variation.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#CAV'), label='CAV', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Thermal_Expansion_Tank'), label='Hot Water Thermal Expansion Tank', definition='A thermal expansion tank used in hot water heating systems.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Cooling_Valve'), label='Cooling Valve', definition='A valve that controls air temperature by modulating the amount of cold water flowing through a cooling coil', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Dry_Cooler'), label='Dry Cooler', definition='A dry cooler is a fluid cooler that uses air, a relatively dry, non-liquid fluid to accomplish process cooling. (https://submer.com/submer-academy/library/dry-cooler/)', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Inverter'), label='Inverter', definition='A device that changes direct current into alternating current', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Pump'), label='Water Pump', definition='A pump that performs work on water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Air_Plenum'), label='Return Air Plenum', definition='A component of the HVAC the receives air from the room to recirculate or exhaust to or from the building', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heat_Pump_Ground_Source_Condensing_Unit'), label='Heat Pump Ground Source Condensing Unit', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Bypass_Damper'), label='Bypass Damper', definition='A bypass damper is a type of damper that is employed in forced-air bypass applications to reduce the buildup of static pressure, usually when certain zone dampers are closed.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Shading_Equipment'), label='Shading Equipment', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Energy_Storage'), label='Energy Storage', definition='Devices or equipment that store energy in its various forms', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Booster_Pump'), label='Chilled Water Booster Pump', definition='Used to increase the pressure and flow of chilled water in a system to ensure adequate supply where needed.', definitions=[]),
#  ...]

# %%
# compute a 'stable' mapping (1:1 mapping)
stable = m.get_mapping(bcs, allow_collisions=False)
# compute an 'unstable' mapping that allows 1:n and n:1 matches
unstable = m.get_mapping(bcs, allow_collisions=True)

# loop through and print the stable/unstable matches
for k,v in unstable.items():
    print(f"{k}:\n\tunstable: {v}\n\tstable: {stable.get(k)}")
# Out:
# 00%|████████████████████████████████████████████████████████████████████████████████████| 1121/1121 [00:00<00:00, 2830.12it/s]
# {rdflib.term.URIRef('https://brickschema.org/schema/Brick#Absolute_Humidity_Sensor'): ['outside '
#                                                                                        'air '
#                                                                                        'humidity '
#                                                                                        'sensor '
#                                                                                        'point',
#                                                                                        'ventilation '
#                                                                                        'air '
#                                                                                        'humidity '
#                                                                                        'sensor '
#                                                                                        'point',
#                                                                                        'exhaust '
#                                                                                        'air '
#                                                                                        'humidity '
#                                                                                        'sensor '
#                                                                                        'point',
#                                                                                        'weather '
#                                                                                        'air '
#                                                                                        'humidity '
#                                                                                        'sensor '
#                                                                                        'point',
#                                                                                        'air '
#                                                                                        'humidity '
#                                                                                        'sensor '
#                                                                                        'point',
#                                                                                        'mixed '
#                                                                                        'air '
#                                                                                        'humidity '
#                                                                                        'sensor '
#                                                                                        'point',
#                                                                                        'discharge '
#                                                                                        'air '
#                                                                                        'humidity '
#                                                                                        'sensor '
#                                                                                        'point',
#                                                                                        'economizer '
#                                                                                        'air '
#                                                                                        'humidity '
#                                                                                        'sensor '
#                                                                                        'point',
#                                                                                        'flue '
#                                                                                        'air '
#                                                                                        'humidity '
#                                                                                        'sensor '
#                                                                                        'point',
#                                                                                        'inlet '
#                                                                                        'air '
#                                                                                        'humidity '
#                                                                                        'sensor '
#                                                                                        'point',
#                                                                                        'weather '
#                                                                                        'air '
#                                                                                        'feelsLike '
#                                                                                        'sensor '
#                                                                                        'point',
#                                                                                        'return '
#                                                                                        'air '
#                                                                                        'humidity '
#                                                                                        'sensor '
#                                                                                        'point',
#                                                                                        'weather '
#                                                                                        'air '
#                                                                                        'dewPoint '
#                                                                                        'sensor '
#                                                                                        'point',
#                                                                                        'weather '
#                                                                                        'air '
#                                                                                        'wetBulb '
#                                                                                        'sensor '
#                                                                                        'point',
#                                                                                        'weather '
#                                                                                        'atmospheric '
#                                                                                        'pressure '
#                                                                                        'sensor '
#                                                                                        'point',
#                                                                                        'zone '
#                                                                                        'air '
#                                                                                        'humidity '
#                                                                                        'sensor '
#                                                                                        'point',
#                                                                                        'water '
#                                                                                        'volume '
#                                                                                        'sensor '
#                                                                                        'point',
#                                                                                        'phase:"A" '
#                                                                                        'ac '
#                                                                                        'elec '
#                                                                                        'volt '
#                                                                                        'magnitude '
#                                                                                        'sensor '
#                                                                                        'point',
#                                                                                        'outside '
#                                                                                        'air '
#                                                                                        'dewPoint '
#                                                                                        'sensor '
#                                                                                        'point',
#                                                                                        'air '
#                                                                                        'dewPoint '
#                                                                                        'sensor '
#                                                                                        'point'],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Absorption_Chiller'): ['chilled '
#                                                                                  'water '
#                                                                                  'heatExchanger '
#                                                                                  'equip',
#                                                                                  'chilled '
#                                                                                  'water '
#                                                                                  'entering '
#                                                                                  'equip',
#                                                                                  'chilled '
#                                                                                  'water '
#                                                                                  'entering '
#                                                                                  'point',
#                                                                                  'chiller '
#                                                                                  'equip',
#                                                                                  'chilled '
#                                                                                  'water '
#                                                                                  'bypass '
#                                                                                  'equip',
#                                                                                  'chilled '
#                                                                                  'water '
#                                                                                  'leaving '
#                                                                                  'equip',
#                                                                                  'chilled '
#                                                                                  'water '
#                                                                                  'entering '
#                                                                                  'pump '
#                                                                                  'point',
#                                                                                  'chilled '
#                                                                                  'water '
#                                                                                  'entering '
#                                                                                  'pump '
#                                                                                  'equip',
#                                                                                  'chilled '
#                                                                                  'water '
#                                                                                  'header '
#                                                                                  'point',
#                                                                                  'chilled '
#                                                                                  'water '
#                                                                                  'bypass '
#                                                                                  'pump '
#                                                                                  'equip',
#                                                                                  'chilled '
#                                                                                  'water '
#                                                                                  'bypass '
#                                                                                  'point',
#                                                                                  'chilled '
#                                                                                  'water '
#                                                                                  'header '
#                                                                                  'pump '
#                                                                                  'point',
#                                                                                  'chilled '
#                                                                                  'water '
#                                                                                  'entering '
#                                                                                  'pipe '
#                                                                                  'equip',
#                                                                                  'chilled '
#                                                                                  'water '
#                                                                                  'bypass '
#                                                                                  'pump '
#                                                                                  'point',
#                                                                                  'chilled '
#                                                                                  'water '
#                                                                                  'header '
#                                                                                  'equip',
#                                                                                  'chilled '
#                                                                                  'water '
#                                                                                  'leaving '
#                                                                                  'point',
#                                                                                  'chilled '
#                                                                                  'water '
#                                                                                  'header '
#                                                                                  'pump '
#                                                                                  'equip',
#                                                                                  'chilled '
#                                                                                  'water '
#                                                                                  'entering '
#                                                                                  'valve '
#                                                                                  'actuator '
#                                                                                  'equip',
#                                                                                  'chilled '
#                                                                                  'water '
#                                                                                  'entering '
#                                                                                  'pump '
#                                                                                  'motor '
#                                                                                  'equip',
#                                                                                  'chilled '
#                                                                                  'water '
#                                                                                  'leaving '
#                                                                                  'pump '
#                                                                                  'equip'],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Acceleration_Time_Setpoint'): ['phase:"A" '
#                                                                                          'ac '
#                                                                                          'elec '
#                                                                                          'volt '
#                                                                                          'magnitude '
#                                                                                          'sensor '
#                                                                                          'point',
#                                                                                          'phase:"A" '
#                                                                                          'ac '
#                                                                                          'elec '
#                                                                                          'volt '
#                                                                                          'angle '
#                                                                                          'sensor '
#                                                                                          'point',
#                                                                                          'phase:"A" '
#                                                                                          'ac '
#                                                                                          'elec '
#                                                                                          'volt '
#                                                                                          'thd '
#                                                                                          'sensor '
#                                                                                          'point',
#                                                                                          'phase:"A" '
#                                                                                          'ac '
#                                                                                          'elec '
#                                                                                          'current '
#                                                                                          'magnitude '
#                                                                                          'sensor '
#                                                                                          'point',
#                                                                                          'phase:"A" '
#                                                                                          'ac '
#                                                                                          'elec '
#                                                                                          'volt '
#                                                                                          'imbalance '
#                                                                                          'sensor '
#                                                                                          'point',
#                                                                                          'phase:"A" '
#                                                                                          'ac '
#                                                                                          'elec '
#                                                                                          'current '
#                                                                                          'thd '
#                                                                                          'sensor '
#                                                                                          'point',
#                                                                                          'phase:"A" '
#                                                                                          'ac '
#                                                                                          'elec '
#                                                                                          'current '
#                                                                                          'angle '
#                                                                                          'sensor '
#                                                                                          'point',
#                                                                                          'phase:"A" '
#                                                                                          'active '
#                                                                                          'ac '
#                                                                                          'elec '
#                                                                                          'power '
#                                                                                          'sensor '
#                                                                                          'point',
#                                                                                          'phase:"A" '
#                                                                                          'reactive '
#                                                                                          'ac '
#                                                                                          'elec '
#                                                                                          'power '
#                                                                                          'sensor '
#                                                                                          'point',
#                                                                                          'phase:"A" '
#                                                                                          'ac '
#                                                                                          'elec '
#                                                                                          'pf '
#                                                                                          'sensor '
#                                                                                          'point',
#                                                                                          'phase:"A" '
#                                                                                          'apparent '
#                                                                                          'ac '
#                                                                                          'elec '
#                                                                                          'power '
#                                                                                          'sensor '
#                                                                                          'point',
#                                                                                          'phase:"A" '
#                                                                                          'net '
#                                                                                          'ac '
#                                                                                          'elec '
#                                                                                          'active '
#                                                                                          'energy '
#                                                                                          'sensor '
#                                                                                          'point',
#                                                                                          'phase:"A" '
#                                                                                          'ac '
#                                                                                          'elec '
#                                                                                          'current '
#                                                                                          'imbalance '
#                                                                                          'sensor '
#                                                                                          'point',
#                                                                                          'temp '
#                                                                                          'sp '
#                                                                                          'point',
#                                                                                          'temp '
#                                                                                          'sensor '
#                                                                                          'point',
#                                                                                          'alarm '
#                                                                                          'sensor '
#                                                                                          'point',
#                                                                                          'weather '
#                                                                                          'daytime '
#                                                                                          'sensor '
#                                                                                          'point',
#                                                                                          'total '
#                                                                                          'apparent '
#                                                                                          'ac '
#                                                                                          'elec '
#                                                                                          'power '
#                                                                                          'sensor '
#                                                                                          'point',
#                                                                                          'pressure '
#                                                                                          'sensor '
#                                                                                          'point',
#                                                                                          'total '
#                                                                                          'net '
#                                                                                          'ac '
#                                                                                          'elec '
#                                                                                          'active '
#                                                                                          'energy '
#                                                                                          'sensor '
#                                                                                          'point'],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Access_Control_Equipment'): ['equip',
#                                                                                        'mixed '
#                                                                                        'equip',
#                                                                                        'ventilation '
#                                                                                        'duct '
#                                                                                        'equip',
#                                                                                        'ventilation '
#                                                                                        'equip',
#                                                                                        'return '
#                                                                                        'equip',
#                                                                                        'return '
#                                                                                        'duct '
#                                                                                        'equip',
#                                                                                        'circ '
#                                                                                        'equip',
#                                                                                        'outside '
#                                                                                        'duct '
#                                                                                        'equip',
#                                                                                        'flue '
#                                                                                        'duct '
#                                                                                        'equip',
#                                                                                        'outside '
#                                                                                        'damper '
#                                                                                        'actuator '
#                                                                                        'equip',
#                                                                                        'outside '
#                                                                                        'heatingCoil '
#                                                                                        'equip',
#                                                                                        'ventilation '
#                                                                                        'fan '
#                                                                                        'equip',
#                                                                                        'ventilation '
#                                                                                        'heatingCoil '
#                                                                                        'equip',
#                                                                                        'vrf '
#                                                                                        'indoorUnit '
#                                                                                        'equip',
#                                                                                        'vrf '
#                                                                                        'branchSelector '
#                                                                                        'equip',
#                                                                                        'ventilation '
#                                                                                        'coolingCoil '
#                                                                                        'equip',
#                                                                                        'pump '
#                                                                                        'equip',
#                                                                                        'rack '
#                                                                                        'equip',
#                                                                                        'cool '
#                                                                                        'well '
#                                                                                        'equip',
#                                                                                        'fan '
#                                                                                        'equip'],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Access_Reader'): ['space',
#                                                                             'point',
#                                                                             'phase:"A" '
#                                                                             'ac '
#                                                                             'elec '
#                                                                             'volt '
#                                                                             'angle '
#                                                                             'sensor '
#                                                                             'point',
#                                                                             'phase:"A" '
#                                                                             'ac '
#                                                                             'elec '
#                                                                             'volt '
#                                                                             'magnitude '
#                                                                             'sensor '
#                                                                             'point',
#                                                                             'fan '
#                                                                             'point',
#                                                                             'phase:"A" '
#                                                                             'ac '
#                                                                             'elec '
#                                                                             'volt '
#                                                                             'thd '
#                                                                             'sensor '
#                                                                             'point',
#                                                                             'phase:"A" '
#                                                                             'reactive '
#                                                                             'ac '
#                                                                             'elec '
#                                                                             'power '
#                                                                             'sensor '
#                                                                             'point',
#                                                                             'fan '
#                                                                             'enable '
#                                                                             'sensor '
#                                                                             'point',
#                                                                             'equip',
#                                                                             'controller '
#                                                                             'device',
#                                                                             'phase:"A" '
#                                                                             'ac '
#                                                                             'elec '
#                                                                             'current '
#                                                                             'angle '
#                                                                             'sensor '
#                                                                             'point',
#                                                                             'phase:"A" '
#                                                                             'ac '
#                                                                             'elec '
#                                                                             'current '
#                                                                             'thd '
#                                                                             'sensor '
#                                                                             'point',
#                                                                             'occupancy '
#                                                                             'sensor '
#                                                                             'point',
#                                                                             'phase:"A" '
#                                                                             'active '
#                                                                             'ac '
#                                                                             'elec '
#                                                                             'power '
#                                                                             'sensor '
#                                                                             'point',
#                                                                             'phase:"A" '
#                                                                             'net '
#                                                                             'ac '
#                                                                             'elec '
#                                                                             'active '
#                                                                             'energy '
#                                                                             'sensor '
#                                                                             'point',
#                                                                             'phase:"A" '
#                                                                             'ac '
#                                                                             'elec '
#                                                                             'current '
#                                                                             'magnitude '
#                                                                             'sensor '
#                                                                             'point',
#                                                                             'outside '
#                                                                             'fan '
#                                                                             'point',
#                                                                             'outside '
#                                                                             'fan '
#                                                                             'enable '
#                                                                             'sensor '
#                                                                             'point',
#                                                                             'phase:"A" '
#                                                                             'ac '
#                                                                             'elec '
#                                                                             'pf '
#                                                                             'sensor '
#                                                                             'point',
#                                                                             'fan '
#                                                                             'equip'],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Active_Chilled_Beam'): ['chilled '
#                                                                                   'water '
#                                                                                   'header '
#                                                                                   'point',
#                                                                                   'chilled '
#                                                                                   'water '
#                                                                                   'entering '
#                                                                                   'point',
#                                                                                   'chilled '
#                                                                                   'water '
#                                                                                   'entering '
#                                                                                   'equip',
#                                                                                   'chilled '
#                                                                                   'water '
#                                                                                   'header '
#                                                                                   'pump '
#                                                                                   'point',
#                                                                                   'chilled '
#                                                                                   'water '
#                                                                                   'delta '
#                                                                                   'flow '
#                                                                                   'point',
#                                                                                   'chilled '
#                                                                                   'water '
#                                                                                   'entering '
#                                                                                   'pump '
#                                                                                   'point',
#                                                                                   'chilled '
#                                                                                   'water '
#                                                                                   'heatExchanger '
#                                                                                   'equip',
#                                                                                   'chilled '
#                                                                                   'water '
#                                                                                   'bypass '
#                                                                                   'point',
#                                                                                   'chilled '
#                                                                                   'water '
#                                                                                   'header '
#                                                                                   'flow '
#                                                                                   'sensor '
#                                                                                   'point',
#                                                                                   'chilled '
#                                                                                   'water '
#                                                                                   'entering '
#                                                                                   'pipe '
#                                                                                   'equip',
#                                                                                   'chilled '
#                                                                                   'water '
#                                                                                   'header '
#                                                                                   'equip',
#                                                                                   'chilled '
#                                                                                   'water '
#                                                                                   'header '
#                                                                                   'pipe '
#                                                                                   'equip',
# ...
#                                                                                                           'water '
#                                                                                                           'entering '
#                                                                                                           'equip',
#                                                                                                           'chilled '
#                                                                                                           'water '
#                                                                                                           'leaving '
#                                                                                                           'point',
#                                                                                                           'chilled '
#                                                                                                           'water '
#                                                                                                           'entering '
#                                                                                                           'flow '
#                                                                                                           'sensor '
#                                                                                                           'point',
#                                                                                                           'chilled '
#                                                                                                           'water '
#                                                                                                           'entering '
#                                                                                                           'valve '
#                                                                                                           'cmd '
#                                                                                                           'point',
#                                                                                                           'chilled '
#                                                                                                           'water '
#                                                                                                           'delta '
#                                                                                                           'temp '
#                                                                                                           'point',
#                                                                                                           'chilled '
#                                                                                                           'water '
#                                                                                                           'header '
#                                                                                                           'point',
#                                                                                                           'chilled '
#                                                                                                           'water '
#                                                                                                           'entering '
#                                                                                                           'flow '
#                                                                                                           'sp '
#                                                                                                           'point',
#                                                                                                           'chilled '
#                                                                                                           'water '
#                                                                                                           'entering '
#                                                                                                           'pipe '
#                                                                                                           'equip',
#                                                                                                           'chilled '
#                                                                                                           'water '
#                                                                                                           'entering '
#                                                                                                           'pressure '
#                                                                                                           'sp '
#                                                                                                           'point',
#                                                                                                           'chilled '
#                                                                                                           'water '
#                                                                                                           'entering '
#                                                                                                           'pump '
#                                                                                                           'equip',
#                                                                                                           'chilled '
#                                                                                                           'water '
#                                                                                                           'entering '
#                                                                                                           'pump '
#                                                                                                           'enable '
#                                                                                                           'sensor '
#                                                                                                           'point',
#                                                                                                           'chilled '
#                                                                                                           'water '
#                                                                                                           'bypass '
#                                                                                                           'temp '
#                                                                                                           'sensor '
#                                                                                                           'point'],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Condenser_Water_Flow_Sensor'): ['condenser '
#                                                                                                    'water '
#                                                                                                    'entering '
#                                                                                                    'flow '
#                                                                                                    'sensor '
#                                                                                                    'point',
#                                                                                                    'condensate '
#                                                                                                    'entering '
#                                                                                                    'flow '
#                                                                                                    'sensor '
#                                                                                                    'point',
#                                                                                                    'condenser '
#                                                                                                    'water '
#                                                                                                    'entering '
#                                                                                                    'valve '
#                                                                                                    'sensor '
#                                                                                                    'point',
#                                                                                                    'condenser '
#                                                                                                    'water '
#                                                                                                    'entering '
#                                                                                                    'pressure '
#                                                                                                    'sensor '
#                                                                                                    'point',
#                                                                                                    'chilled '
#                                                                                                    'water '
#                                                                                                    'entering '
#                                                                                                    'flow '
#                                                                                                    'sensor '
#                                                                                                    'point',
#                                                                                                    'condenser '
#                                                                                                    'water '
#                                                                                                    'entering '
#                                                                                                    'temp '
#                                                                                                    'sensor '
#                                                                                                    'point',
#                                                                                                    'condenser '
#                                                                                                    'water '
#                                                                                                    'leaving '
#                                                                                                    'flow '
#                                                                                                    'sensor '
#                                                                                                    'point',
#                                                                                                    'condenser '
#                                                                                                    'water '
#                                                                                                    'entering '
#                                                                                                    'point',
#                                                                                                    'condensate '
#                                                                                                    'entering '
#                                                                                                    'valve '
#                                                                                                    'sensor '
#                                                                                                    'point',
#                                                                                                    'condensate '
#                                                                                                    'entering '
#                                                                                                    'pressure '
#                                                                                                    'sensor '
#                                                                                                    'point',
#                                                                                                    'condensate '
#                                                                                                    'entering '
#                                                                                                    'temp '
#                                                                                                    'sensor '
#                                                                                                    'point',
#                                                                                                    'condensate '
#                                                                                                    'entering '
#                                                                                                    'point',
#                                                                                                    'condenser '
#                                                                                                    'water '
#                                                                                                    'entering '
#                                                                                                    'pump '
#                                                                                                    'run '
#                                                                                                    'sensor '
#                                                                                                    'point',
#                                                                                                    'condenser '
#                                                                                                    'water '
#                                                                                                    'leaving '
#                                                                                                    'pressure '
#                                                                                                    'sensor '
#                                                                                                    'point',
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
