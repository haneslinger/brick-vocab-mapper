# %%
from brickmapper import Mapper
from rdflib import BRICK
import urllib.request
import csv
import numpy as np

# %%
# read haystack proto definitions off their website

defns = []
request = urllib.request.Request("https://project-haystack.org/download/protos.csv", headers={'User-Agent': "Python script"})
response = urllib.request.urlopen(request)
rdr = csv.DictReader(response.read().decode('utf8').splitlines())
for row in rdr:
    # save each proto (e.g. 'air temp sensor point') as a dictionary
    defns.append({'name': row['proto']})

defns
# Out:
# [{'name': 'air co2 concentration sensor point'},
#  {'name': 'air co2 concentration sp point'},
#  {'name': 'air dewPoint sensor point'},
#  {'name': 'air dewPoint sp point'},
#  {'name': 'air enthalpy sensor point'},
#  {'name': 'air enthalpy sp point'},
#  {'name': 'air flow sensor point'},
#  {'name': 'air flow sp point'},
#  {'name': 'air humidity sensor point'},
#  {'name': 'air humidity sp point'},
#  {'name': 'air pressure sensor point'},
#  {'name': 'air pressure sp point'},
#  {'name': 'air temp sensor point'},
#  {'name': 'air temp sp point'},
#  {'name': 'air velocity sensor point'},
#  {'name': 'air velocity sp point'},
#  {'name': 'alarm sensor point'},
#  {'name': 'avg ac elec current angle sensor point'},
#  {'name': 'avg ac elec current imbalance sensor point'},
#  {'name': 'avg ac elec current magnitude sensor point'},
#  {'name': 'avg ac elec current thd sensor point'},
#  {'name': 'avg ac elec pf sensor point'},
#  {'name': 'avg ac elec volt angle sensor point'},
#  {'name': 'avg ac elec volt imbalance sensor point'},
#  {'name': 'avg ac elec volt magnitude sensor point'},
#  {'name': 'avg ac elec volt thd sensor point'},
#  {'name': 'bypass damper cmd point'},
#  {'name': 'chilled water bypass equip'},
#  {'name': 'chilled water bypass flow sensor point'},
#  {'name': 'chilled water bypass flow sp point'},
#  {'name': 'chilled water bypass pipe equip'},
#  {'name': 'chilled water bypass point'},
#  {'name': 'chilled water bypass pressure sensor point'},
#  {'name': 'chilled water bypass pressure sp point'},
#  {'name': 'chilled water bypass pump alarm sensor point'},
#  {'name': 'chilled water bypass pump enable cmd point'},
#  {'name': 'chilled water bypass pump enable sensor point'},
#  {'name': 'chilled water bypass pump equip'},
#  {'name': 'chilled water bypass pump motor equip'},
#  {'name': 'chilled water bypass pump point'},
#  {'name': 'chilled water bypass pump run cmd point'},
#  {'name': 'chilled water bypass pump run sensor point'},
#  {'name': 'chilled water bypass pump vfd freq cmd point'},
#  {'name': 'chilled water bypass pump vfd freq sensor point'},
#  {'name': 'chilled water bypass pump vfd speed cmd point'},
#  {'name': 'chilled water bypass pump vfd speed sensor point'},
#  {'name': 'chilled water bypass temp sensor point'},
#  {'name': 'chilled water bypass temp sp point'},
#  {'name': 'chilled water bypass valve actuator equip'},
#  {'name': 'chilled water bypass valve cmd point'},
#  {'name': 'chilled water bypass valve sensor point'},
#  {'name': 'chilled water cool valve cmd point'},
#  {'name': 'chilled water delta flow point'},
#  {'name': 'chilled water delta flow sensor point'},
#  {'name': 'chilled water delta pressure point'},
#  {'name': 'chilled water delta temp point'},
#  {'name': 'chilled water delta temp sensor point'},
#  {'name': 'chilled water entering equip'},
#  {'name': 'chilled water entering flow sensor point'},
#  {'name': 'chilled water entering flow sp point'},
#  {'name': 'chilled water entering pipe equip'},
#  {'name': 'chilled water entering point'},
#  {'name': 'chilled water entering pressure sensor point'},
#  {'name': 'chilled water entering pressure sp point'},
#  {'name': 'chilled water entering pump alarm sensor point'},
#  {'name': 'chilled water entering pump enable cmd point'},
#  {'name': 'chilled water entering pump enable sensor point'},
#  {'name': 'chilled water entering pump equip'},
#  {'name': 'chilled water entering pump motor equip'},
#  {'name': 'chilled water entering pump point'},
#  {'name': 'chilled water entering pump run cmd point'},
#  {'name': 'chilled water entering pump run sensor point'},
#  {'name': 'chilled water entering pump vfd freq cmd point'},
#  {'name': 'chilled water entering pump vfd freq sensor point'},
#  {'name': 'chilled water entering pump vfd speed cmd point'},
#  {'name': 'chilled water entering pump vfd speed sensor point'},
#  {'name': 'chilled water entering temp sensor point'},
#  {'name': 'chilled water entering temp sp point'},
#  {'name': 'chilled water entering valve actuator equip'},
#  {'name': 'chilled water entering valve cmd point'},
#  {'name': 'chilled water entering valve sensor point'},
#  {'name': 'chilled water header equip'},
#  {'name': 'chilled water header flow sensor point'},
#  {'name': 'chilled water header flow sp point'},
#  {'name': 'chilled water header pipe equip'},
#  {'name': 'chilled water header point'},
#  {'name': 'chilled water header pressure sensor point'},
#  {'name': 'chilled water header pressure sp point'},
#  {'name': 'chilled water header pump alarm sensor point'},
#  {'name': 'chilled water header pump enable cmd point'},
#  {'name': 'chilled water header pump enable sensor point'},
#  {'name': 'chilled water header pump equip'},
#  {'name': 'chilled water header pump motor equip'},
#  {'name': 'chilled water header pump point'},
#  {'name': 'chilled water header pump run cmd point'},
#  {'name': 'chilled water header pump run sensor point'},
#  {'name': 'chilled water header pump vfd freq cmd point'},
#  {'name': 'chilled water header pump vfd freq sensor point'},
#  {'name': 'chilled water header pump vfd speed cmd point'},
#  {'name': 'chilled water header pump vfd speed sensor point'},
#  {'name': 'chilled water header temp sensor point'},
#  {'name': 'chilled water header temp sp point'},
#  {'name': 'chilled water header valve actuator equip'},
#  {'name': 'chilled water header valve cmd point'},
#  {'name': 'chilled water header valve sensor point'},
#  {'name': 'chilled water heatExchanger equip'},
#  {'name': 'chilled water leaving equip'},
#  {'name': 'chilled water leaving flow sensor point'},
#  {'name': 'chilled water leaving flow sp point'},
#  {'name': 'chilled water leaving pipe equip'},
#  {'name': 'chilled water leaving point'},
#  {'name': 'chilled water leaving pressure sensor point'},
#  {'name': 'chilled water leaving pressure sp point'},
#  {'name': 'chilled water leaving pump alarm sensor point'},
#  {'name': 'chilled water leaving pump enable cmd point'},
#  {'name': 'chilled water leaving pump enable sensor point'},
#  {'name': 'chilled water leaving pump equip'},
#  {'name': 'chilled water leaving pump motor equip'},
#  {'name': 'chilled water leaving pump point'},
#  {'name': 'chilled water leaving pump run cmd point'},
#  {'name': 'chilled water leaving pump run sensor point'},
#  {'name': 'chilled water leaving pump vfd freq cmd point'},
#  {'name': 'chilled water leaving pump vfd freq sensor point'},
#  {'name': 'chilled water leaving pump vfd speed cmd point'},
#  {'name': 'chilled water leaving pump vfd speed sensor point'},
#  {'name': 'chilled water leaving temp sensor point'},
#  {'name': 'chilled water leaving temp sp point'},
#  {'name': 'chilled water leaving valve actuator equip'},
#  {'name': 'chilled water leaving valve cmd point'},
#  {'name': 'chilled water leaving valve sensor point'},
#  {'name': 'chilled water mixing valve cmd point'},
#  {'name': 'chilled water valve isolation cmd point'},
#  {'name': 'chiller equip'},
#  {'name': 'circ equip'},
#  {'name': 'circ flow sensor point'},
#  {'name': 'circ flow sp point'},
#  {'name': 'circ pipe equip'},
#  {'name': 'circ point'},
#  {'name': 'circ pressure sensor point'},
#  {'name': 'circ pressure sp point'},
#  {'name': 'circ pump alarm sensor point'},
#  {'name': 'circ pump enable cmd point'},
#  {'name': 'circ pump enable sensor point'},
#  {'name': 'circ pump equip'},
#  {'name': 'circ pump motor equip'},
#  {'name': 'circ pump point'},
#  {'name': 'circ pump run cmd point'},
#  {'name': 'circ pump run sensor point'},
#  {'name': 'circ pump vfd freq cmd point'},
#  {'name': 'circ pump vfd freq sensor point'},
#  {'name': 'circ pump vfd speed cmd point'},
#  {'name': 'circ pump vfd speed sensor point'},
#  {'name': 'circ temp sensor point'},
#  {'name': 'circ temp sp point'},
#  {'name': 'circ valve actuator equip'},
#  {'name': 'circ valve cmd point'},
#  {'name': 'circ valve sensor point'},
#  {'name': 'condensate entering equip'},
#  {'name': 'condensate entering flow sensor point'},
#  {'name': 'condensate entering flow sp point'},
#  {'name': 'condensate entering pipe equip'},
#  {'name': 'condensate entering point'},
#  {'name': 'condensate entering pressure sensor point'},
#  {'name': 'condensate entering pressure sp point'},
#  {'name': 'condensate entering pump alarm sensor point'},
#  {'name': 'condensate entering pump enable cmd point'},
#  {'name': 'condensate entering pump enable sensor point'},
#  {'name': 'condensate entering pump equip'},
#  {'name': 'condensate entering pump motor equip'},
#  {'name': 'condensate entering pump point'},
#  {'name': 'condensate entering pump run cmd point'},
#  {'name': 'condensate entering pump run sensor point'},
#  {'name': 'condensate entering pump vfd freq cmd point'},
#  {'name': 'condensate entering pump vfd freq sensor point'},
#  {'name': 'condensate entering pump vfd speed cmd point'},
#  {'name': 'condensate entering pump vfd speed sensor point'},
#  {'name': 'condensate entering temp sensor point'},
#  {'name': 'condensate entering temp sp point'},
#  {'name': 'condensate entering valve actuator equip'},
#  {'name': 'condensate entering valve cmd point'},
#  {'name': 'condensate entering valve sensor point'},
#  {'name': 'condenser refrig pressure sensor point'},
#  {'name': 'condenser refrig temp sensor point'},
#  {'name': 'condenser run cmd point'},
#  {'name': 'condenser run sensor point'},
#  {'name': 'condenser water bypass equip'},
#  {'name': 'condenser water bypass flow sensor point'},
#  {'name': 'condenser water bypass flow sp point'},
#  {'name': 'condenser water bypass pipe equip'},
#  {'name': 'condenser water bypass point'},
#  {'name': 'condenser water bypass pressure sensor point'},
#  {'name': 'condenser water bypass pressure sp point'},
#  {'name': 'condenser water bypass pump alarm sensor point'},
#  {'name': 'condenser water bypass pump enable cmd point'},
#  {'name': 'condenser water bypass pump enable sensor point'},
#  {'name': 'condenser water bypass pump equip'},
#  {'name': 'condenser water bypass pump motor equip'},
#  {'name': 'condenser water bypass pump point'},
#  {'name': 'condenser water bypass pump run cmd point'},
#  {'name': 'condenser water bypass pump run sensor point'},
#  {'name': 'condenser water bypass pump vfd freq cmd point'},
#  {'name': 'condenser water bypass pump vfd freq sensor point'},
#  {'name': 'condenser water bypass pump vfd speed cmd point'},
#  {'name': 'condenser water bypass pump vfd speed sensor point'},
#  {'name': 'condenser water bypass temp sensor point'},
#  {'name': 'condenser water bypass temp sp point'},
#  {'name': 'condenser water bypass valve actuator equip'},
#  {'name': 'condenser water bypass valve cmd point'},
#  {'name': 'condenser water bypass valve sensor point'},
#  {'name': 'condenser water delta flow sensor point'},
#  {'name': 'condenser water delta pressure sensor point'},
#  {'name': 'condenser water delta temp sensor point'},
#  {'name': 'condenser water entering equip'},
#  {'name': 'condenser water entering flow sensor point'},
#  {'name': 'condenser water entering flow sp point'},
#  {'name': 'condenser water entering pipe equip'},
#  {'name': 'condenser water entering point'},
#  {'name': 'condenser water entering pressure sensor point'},
#  {'name': 'condenser water entering pressure sp point'},
#  {'name': 'condenser water entering pump alarm sensor point'},
#  {'name': 'condenser water entering pump enable cmd point'},
#  {'name': 'condenser water entering pump enable sensor point'},
#  {'name': 'condenser water entering pump equip'},
#  {'name': 'condenser water entering pump motor equip'},
#  {'name': 'condenser water entering pump point'},
#  {'name': 'condenser water entering pump run cmd point'},
#  {'name': 'condenser water entering pump run sensor point'},
#  {'name': 'condenser water entering pump vfd freq cmd point'},
#  {'name': 'condenser water entering pump vfd freq sensor point'},
#  {'name': 'condenser water entering pump vfd speed cmd point'},
#  {'name': 'condenser water entering pump vfd speed sensor point'},
#  {'name': 'condenser water entering temp sensor point'},
#  {'name': 'condenser water entering temp sp point'},
#  {'name': 'condenser water entering valve actuator equip'},
#  {'name': 'condenser water entering valve cmd point'},
#  {'name': 'condenser water entering valve sensor point'},
#  {'name': 'condenser water leaving equip'},
#  {'name': 'condenser water leaving flow sensor point'},
#  {'name': 'condenser water leaving flow sp point'},
#  {'name': 'condenser water leaving pipe equip'},
#  {'name': 'condenser water leaving point'},
#  {'name': 'condenser water leaving pressure sensor point'},
#  {'name': 'condenser water leaving pressure sp point'},
#  {'name': 'condenser water leaving pump alarm sensor point'},
#  {'name': 'condenser water leaving pump enable cmd point'},
#  {'name': 'condenser water leaving pump enable sensor point'},
#  {'name': 'condenser water leaving pump equip'},
#  {'name': 'condenser water leaving pump motor equip'},
#  {'name': 'condenser water leaving pump point'},
#  {'name': 'condenser water leaving pump run cmd point'},
#  {'name': 'condenser water leaving pump run sensor point'},
#  {'name': 'condenser water leaving pump vfd freq cmd point'},
#  {'name': 'condenser water leaving pump vfd freq sensor point'},
#  {'name': 'condenser water leaving pump vfd speed cmd point'},
#  {'name': 'condenser water leaving pump vfd speed sensor point'},
#  {'name': 'condenser water leaving temp sensor point'},
#  {'name': 'condenser water leaving temp sp point'},
#  {'name': 'condenser water leaving valve actuator equip'},
#  {'name': 'condenser water leaving valve cmd point'},
#  {'name': 'condenser water leaving valve sensor point'},
#  {'name': 'condenser water valve isolation cmd point'},
#  {'name': 'controller device'},
#  {'name': 'cool cmd point'},
#  {'name': 'cool water flow thermal meter equip'},
#  {'name': 'cool well equip'},
#  {'name': 'coolingCoil equip'},
#  {'name': 'coolingTower equip'},
#  {'name': 'crac fcu equip'},
#  {'name': 'damper actuator equip'},
#  {'name': 'damper cmd point'},
#  {'name': 'damper sensor point'},
#  {'name': 'dc elec stateOfCharge sensor point'},
#  {'name': 'dessicantDehumidifier cmd point'},
#  {'name': 'discharge air co2 concentration sensor point'},
#  {'name': 'discharge air co2 concentration sp point'},
#  {'name': 'discharge air dewPoint sensor point'},
#  {'name': 'discharge air dewPoint sp point'},
#  {'name': 'discharge air enthalpy sensor point'},
#  {'name': 'discharge air enthalpy sp point'},
#  {'name': 'discharge air flow sensor point'},
#  {'name': 'discharge air flow sp point'},
#  {'name': 'discharge air humidity sensor point'},
#  {'name': 'discharge air humidity sp point'},
#  {'name': 'discharge air pressure sensor point'},
#  {'name': 'discharge air pressure sp point'},
#  {'name': 'discharge air temp sensor point'},
#  {'name': 'discharge air temp sp point'},
#  {'name': 'discharge chilled water cool valve cmd point'},
#  {'name': 'discharge coolingCoil equip'},
#  {'name': 'discharge damper actuator equip'},
#  {'name': 'discharge damper cmd point'},
#  {'name': 'discharge damper sensor point'},
#  {'name': 'discharge duct equip'},
#  {'name': 'discharge equip'},
#  {'name': 'discharge fan alarm sensor point'},
#  {'name': 'discharge fan enable cmd point'},
#  {'name': 'discharge fan enable sensor point'},
#  {'name': 'discharge fan equip'},
#  {'name': 'discharge fan motor equip'},
#  {'name': 'discharge fan point'},
#  {'name': 'discharge fan run cmd point'},
#  {'name': 'discharge fan run sensor point'},
#  {'name': 'discharge fan vfd freq cmd point'},
#  {'name': 'discharge fan vfd freq sensor point'},
#  {'name': 'discharge fan vfd speed cmd point'},
#  {'name': 'discharge fan vfd speed sensor point'},
#  {'name': 'discharge heatingCoil equip'},
#  {'name': 'discharge hot water heat valve cmd point'},
#  {'name': 'discharge point'},
#  {'name': 'discharge stage:1 cool run cmd point'},
#  {'name': 'discharge stage:1 heat run cmd point'},
#  {'name': 'discharge steam heat valve cmd point'},
#  {'name': 'ductArea sp point'},
#  {'name': 'economizer air co2 concentration sensor point'},
#  {'name': 'economizer air co2 concentration sp point'},
#  {'name': 'economizer air dewPoint sensor point'},
#  {'name': 'economizer air dewPoint sp point'},
#  {'name': 'economizer air enthalpy sensor point'},
#  {'name': 'economizer air enthalpy sp point'},
#  {'name': 'economizer air flow sensor point'},
#  {'name': 'economizer air flow sp point'},
#  {'name': 'economizer air humidity sensor point'},
#  {'name': 'economizer air humidity sp point'},
#  {'name': 'economizer air pressure sensor point'},
#  {'name': 'economizer air pressure sp point'},
#  {'name': 'economizer air temp sensor point'},
#  {'name': 'economizer air temp sp point'},
#  {'name': 'economizer chilled water cool valve cmd point'},
#  {'name': 'economizer coolingCoil equip'},
#  {'name': 'economizer damper actuator equip'},
#  {'name': 'economizer damper cmd point'},
#  {'name': 'economizer damper sensor point'},
#  {'name': 'economizer duct equip'},
#  {'name': 'economizer equip'},
#  {'name': 'economizer fan alarm sensor point'},
#  {'name': 'economizer fan enable cmd point'},
#  {'name': 'economizer fan enable sensor point'},
#  {'name': 'economizer fan equip'},
#  {'name': 'economizer fan motor equip'},
#  {'name': 'economizer fan point'},
#  {'name': 'economizer fan run cmd point'},
#  {'name': 'economizer fan run sensor point'},
#  {'name': 'economizer fan vfd freq cmd point'},
#  {'name': 'economizer fan vfd freq sensor point'},
#  {'name': 'economizer fan vfd speed cmd point'},
#  {'name': 'economizer fan vfd speed sensor point'},
#  {'name': 'economizer heatingCoil equip'},
#  {'name': 'economizer hot water heat valve cmd point'},
#  {'name': 'economizer point'},
#  {'name': 'economizer stage:1 cool run cmd point'},
#  {'name': 'economizer stage:1 heat run cmd point'},
#  {'name': 'economizer steam heat valve cmd point'},
#  {'name': 'economizing cmd point'},
#  {'name': 'efficiency sensor point'},
#  {'name': 'enable cmd point'},
#  {'name': 'enable sensor point'},
#  {'name': 'equip'},
#  {'name': 'evaporator refrig pressure sensor point'},
#  {'name': 'evaporator refrig temp sensor point'},
#  {'name': 'evse cable equip'},
#  {'name': 'evse evseStatus sensor point'},
#  {'name': 'evse port equip'},
#  {'name': 'exhaust air co2 concentration sensor point'},
#  {'name': 'exhaust air co2 concentration sp point'},
#  {'name': 'exhaust air dewPoint sensor point'},
#  {'name': 'exhaust air dewPoint sp point'},
#  {'name': 'exhaust air enthalpy sensor point'},
#  {'name': 'exhaust air enthalpy sp point'},
#  {'name': 'exhaust air flow sensor point'},
#  {'name': 'exhaust air flow sp point'},
#  {'name': 'exhaust air humidity sensor point'},
#  {'name': 'exhaust air humidity sp point'},
#  {'name': 'exhaust air pressure sensor point'},
#  {'name': 'exhaust air pressure sp point'},
#  {'name': 'exhaust air temp sensor point'},
#  {'name': 'exhaust air temp sp point'},
#  {'name': 'exhaust chilled water cool valve cmd point'},
#  {'name': 'exhaust coolingCoil equip'},
#  {'name': 'exhaust damper actuator equip'},
#  {'name': 'exhaust damper cmd point'},
#  {'name': 'exhaust damper sensor point'},
#  {'name': 'exhaust duct equip'},
#  {'name': 'exhaust equip'},
#  {'name': 'exhaust fan alarm sensor point'},
#  {'name': 'exhaust fan enable cmd point'},
#  {'name': 'exhaust fan enable sensor point'},
#  {'name': 'exhaust fan equip'},
#  {'name': 'exhaust fan motor equip'},
#  {'name': 'exhaust fan point'},
#  {'name': 'exhaust fan run cmd point'},
#  {'name': 'exhaust fan run sensor point'},
#  {'name': 'exhaust fan vfd freq cmd point'},
#  {'name': 'exhaust fan vfd freq sensor point'},
#  {'name': 'exhaust fan vfd speed cmd point'},
#  {'name': 'exhaust fan vfd speed sensor point'},
#  {'name': 'exhaust heatingCoil equip'},
#  {'name': 'exhaust hot water heat valve cmd point'},
#  {'name': 'exhaust point'},
#  {'name': 'exhaust stage:1 cool run cmd point'},
#  {'name': 'exhaust stage:1 heat run cmd point'},
#  {'name': 'exhaust steam heat valve cmd point'},
#  {'name': 'extraction well equip'},
#  {'name': 'faceBypass cmd point'},
#  {'name': 'fan alarm sensor point'},
#  {'name': 'fan enable cmd point'},
#  {'name': 'fan enable sensor point'},
#  {'name': 'fan equip'},
#  {'name': 'fan motor equip'},
#  {'name': 'fan point'},
#  {'name': 'fan run cmd point'},
#  {'name': 'fan run sensor point'},
#  {'name': 'fan vfd freq cmd point'},
#  {'name': 'fan vfd freq sensor point'},
#  {'name': 'fan vfd speed cmd point'},
#  {'name': 'fan vfd speed sensor point'},
#  {'name': 'filter sensor point'},
#  {'name': 'flow sensor point'},
#  {'name': 'flow sp point'},
#  {'name': 'flowInverter equip'},
#  {'name': 'flue air co2 concentration sensor point'},
#  {'name': 'flue air co2 concentration sp point'},
#  {'name': 'flue air dewPoint sensor point'},
#  {'name': 'flue air dewPoint sp point'},
#  {'name': 'flue air enthalpy sensor point'},
#  {'name': 'flue air enthalpy sp point'},
#  {'name': 'flue air flow sensor point'},
#  {'name': 'flue air flow sp point'},
#  {'name': 'flue air humidity sensor point'},
#  {'name': 'flue air humidity sp point'},
#  {'name': 'flue air pressure sensor point'},
#  {'name': 'flue air pressure sp point'},
#  {'name': 'flue air temp sensor point'},
#  {'name': 'flue air temp sp point'},
#  {'name': 'flue chilled water cool valve cmd point'},
#  {'name': 'flue coolingCoil equip'},
#  {'name': 'flue damper actuator equip'},
#  {'name': 'flue damper cmd point'},
#  {'name': 'flue damper sensor point'},
#  {'name': 'flue duct equip'},
#  {'name': 'flue equip'},
#  {'name': 'flue fan alarm sensor point'},
#  {'name': 'flue fan enable cmd point'},
#  {'name': 'flue fan enable sensor point'},
#  {'name': 'flue fan equip'},
#  {'name': 'flue fan motor equip'},
#  {'name': 'flue fan point'},
#  {'name': 'flue fan run cmd point'},
#  {'name': 'flue fan run sensor point'},
#  {'name': 'flue fan vfd freq cmd point'},
#  {'name': 'flue fan vfd freq sensor point'},
#  {'name': 'flue fan vfd speed cmd point'},
#  {'name': 'flue fan vfd speed sensor point'},
#  {'name': 'flue heatingCoil equip'},
#  {'name': 'flue hot water heat valve cmd point'},
#  {'name': 'flue point'},
#  {'name': 'flue stage:1 cool run cmd point'},
#  {'name': 'flue stage:1 heat run cmd point'},
#  {'name': 'flue steam heat valve cmd point'},
#  {'name': 'freezeStat sensor point'},
#  {'name': 'ground water flow sensor point'},
#  {'name': 'ground water pressure sensor point'},
#  {'name': 'ground water volume sensor point'},
#  {'name': 'heat cmd point'},
#  {'name': 'heatExchanger equip'},
#  {'name': 'heatWheel cmd point'},
#  {'name': 'heatingCoil equip'},
#  {'name': 'hot water boiler equip'},
#  {'name': 'hot water bypass equip'},
#  {'name': 'hot water bypass flow sensor point'},
#  {'name': 'hot water bypass flow sp point'},
#  {'name': 'hot water bypass pipe equip'},
#  {'name': 'hot water bypass point'},
#  {'name': 'hot water bypass pressure sensor point'},
#  {'name': 'hot water bypass pressure sp point'},
#  {'name': 'hot water bypass pump alarm sensor point'},
#  {'name': 'hot water bypass pump enable cmd point'},
#  {'name': 'hot water bypass pump enable sensor point'},
#  {'name': 'hot water bypass pump equip'},
#  {'name': 'hot water bypass pump motor equip'},
#  {'name': 'hot water bypass pump point'},
#  {'name': 'hot water bypass pump run cmd point'},
#  {'name': 'hot water bypass pump run sensor point'},
#  {'name': 'hot water bypass pump vfd freq cmd point'},
#  {'name': 'hot water bypass pump vfd freq sensor point'},
#  {'name': 'hot water bypass pump vfd speed cmd point'},
#  {'name': 'hot water bypass pump vfd speed sensor point'},
#  {'name': 'hot water bypass temp sensor point'},
#  {'name': 'hot water bypass temp sp point'},
#  {'name': 'hot water bypass valve actuator equip'},
#  {'name': 'hot water bypass valve cmd point'},
#  {'name': 'hot water bypass valve sensor point'},
#  {'name': 'hot water delta flow sensor point'},
#  {'name': 'hot water delta pressure sensor point'},
#  {'name': 'hot water delta temp sensor point'},
#  {'name': 'hot water entering equip'},
#  {'name': 'hot water entering flow sensor point'},
#  {'name': 'hot water entering flow sp point'},
#  {'name': 'hot water entering pipe equip'},
#  {'name': 'hot water entering point'},
#  {'name': 'hot water entering pressure sensor point'},
#  {'name': 'hot water entering pressure sp point'},
#  {'name': 'hot water entering pump alarm sensor point'},
#  {'name': 'hot water entering pump enable cmd point'},
#  {'name': 'hot water entering pump enable sensor point'},
#  {'name': 'hot water entering pump equip'},
#  {'name': 'hot water entering pump motor equip'},
#  {'name': 'hot water entering pump point'},
#  {'name': 'hot water entering pump run cmd point'},
#  {'name': 'hot water entering pump run sensor point'},
#  {'name': 'hot water entering pump vfd freq cmd point'},
#  {'name': 'hot water entering pump vfd freq sensor point'},
#  {'name': 'hot water entering pump vfd speed cmd point'},
#  {'name': 'hot water entering pump vfd speed sensor point'},
#  {'name': 'hot water entering temp sensor point'},
#  {'name': 'hot water entering temp sp point'},
#  {'name': 'hot water entering valve actuator equip'},
#  {'name': 'hot water entering valve cmd point'},
#  {'name': 'hot water entering valve sensor point'},
#  {'name': 'hot water header equip'},
#  {'name': 'hot water header flow sensor point'},
#  {'name': 'hot water header flow sp point'},
#  {'name': 'hot water header pipe equip'},
#  {'name': 'hot water header point'},
#  {'name': 'hot water header pressure sensor point'},
#  {'name': 'hot water header pressure sp point'},
#  {'name': 'hot water header pump alarm sensor point'},
#  {'name': 'hot water header pump enable cmd point'},
#  {'name': 'hot water header pump enable sensor point'},
#  {'name': 'hot water header pump equip'},
#  {'name': 'hot water header pump motor equip'},
#  {'name': 'hot water header pump point'},
#  {'name': 'hot water header pump run cmd point'},
#  {'name': 'hot water header pump run sensor point'},
#  {'name': 'hot water header pump vfd freq cmd point'},
#  {'name': 'hot water header pump vfd freq sensor point'},
#  {'name': 'hot water header pump vfd speed cmd point'},
#  {'name': 'hot water header pump vfd speed sensor point'},
#  {'name': 'hot water header temp sensor point'},
#  {'name': 'hot water header temp sp point'},
#  {'name': 'hot water header valve actuator equip'},
#  {'name': 'hot water header valve cmd point'},
#  {'name': 'hot water header valve sensor point'},
#  {'name': 'hot water heat valve cmd point'},
#  {'name': 'hot water heatExchanger equip'},
#  {'name': 'hot water leaving equip'},
#  {'name': 'hot water leaving flow sensor point'},
#  {'name': 'hot water leaving flow sp point'},
#  {'name': 'hot water leaving pipe equip'},
#  {'name': 'hot water leaving point'},
#  {'name': 'hot water leaving pressure sensor point'},
#  {'name': 'hot water leaving pressure sp point'},
#  {'name': 'hot water leaving pump alarm sensor point'},
#  {'name': 'hot water leaving pump enable cmd point'},
#  {'name': 'hot water leaving pump enable sensor point'},
#  {'name': 'hot water leaving pump equip'},
#  {'name': 'hot water leaving pump motor equip'},
#  {'name': 'hot water leaving pump point'},
#  {'name': 'hot water leaving pump run cmd point'},
#  {'name': 'hot water leaving pump run sensor point'},
#  {'name': 'hot water leaving pump vfd freq cmd point'},
#  {'name': 'hot water leaving pump vfd freq sensor point'},
#  {'name': 'hot water leaving pump vfd speed cmd point'},
#  {'name': 'hot water leaving pump vfd speed sensor point'},
#  {'name': 'hot water leaving temp sensor point'},
#  {'name': 'hot water leaving temp sp point'},
#  {'name': 'hot water leaving valve actuator equip'},
#  {'name': 'hot water leaving valve cmd point'},
#  {'name': 'hot water leaving valve sensor point'},
#  {'name': 'hot water mixing valve cmd point'},
#  {'name': 'humidifier enable cmd point'},
#  {'name': 'humidifier equip'},
#  {'name': 'humidifier run cmd point'},
#  {'name': 'hvacMode sp point'},
#  {'name': 'import ac elec active energy hisTotalized sensor point'},
#  {'name': 'import ac elec active power max sp point'},
#  {'name': 'import ac elec active power sensor point'},
#  {'name': 'import ac elec magnitude current max sp point'},
#  {'name': 'import ac elec magnitude current sensor point'},
#  {'name': 'import ac elec magnitude volt sensor point'},
#  {'name': 'import ac elec pfScope pf sensor point'},
#  {'name': 'import dc elec current max sp point'},
#  {'name': 'import dc elec current sensor point'},
#  {'name': 'import dc elec energy hisTotalized sensor point'},
#  {'name': 'import dc elec power max sp point'},
#  {'name': 'import dc elec power sensor point'},
#  {'name': 'import dc elec volt sensor point'},
#  {'name': 'infiltration well equip'},
#  {'name': 'inlet air co2 concentration sensor point'},
#  {'name': 'inlet air co2 concentration sp point'},
#  {'name': 'inlet air dewPoint sensor point'},
#  {'name': 'inlet air dewPoint sp point'},
#  {'name': 'inlet air enthalpy sensor point'},
#  {'name': 'inlet air enthalpy sp point'},
#  {'name': 'inlet air flow sensor point'},
#  {'name': 'inlet air flow sp point'},
#  {'name': 'inlet air humidity sensor point'},
#  {'name': 'inlet air humidity sp point'},
#  {'name': 'inlet air pressure sensor point'},
#  {'name': 'inlet air pressure sp point'},
#  {'name': 'inlet air temp sensor point'},
#  {'name': 'inlet air temp sp point'},
#  {'name': 'inlet chilled water cool valve cmd point'},
#  {'name': 'inlet coolingCoil equip'},
#  {'name': 'inlet damper actuator equip'},
#  {'name': 'inlet damper cmd point'},
#  {'name': 'inlet damper sensor point'},
#  {'name': 'inlet duct equip'},
#  {'name': 'inlet equip'},
#  {'name': 'inlet fan alarm sensor point'},
#  {'name': 'inlet fan enable cmd point'},
#  {'name': 'inlet fan enable sensor point'},
#  {'name': 'inlet fan equip'},
#  {'name': 'inlet fan motor equip'},
#  {'name': 'inlet fan point'},
#  {'name': 'inlet fan run cmd point'},
#  {'name': 'inlet fan run sensor point'},
#  {'name': 'inlet fan vfd freq cmd point'},
#  {'name': 'inlet fan vfd freq sensor point'},
#  {'name': 'inlet fan vfd speed cmd point'},
#  {'name': 'inlet fan vfd speed sensor point'},
#  {'name': 'inlet heatingCoil equip'},
#  {'name': 'inlet hot water heat valve cmd point'},
#  {'name': 'inlet point'},
#  {'name': 'inlet stage:1 cool run cmd point'},
#  {'name': 'inlet stage:1 heat run cmd point'},
#  {'name': 'inlet steam heat valve cmd point'},
#  {'name': 'level sensor point'},
#  {'name': 'light illuminance sensor point'},
#  {'name': 'light level sensor point'},
#  {'name': 'light level sp point'},
#  {'name': 'light luminous flux sensor point'},
#  {'name': 'load cmd point'},
#  {'name': 'load sensor point'},
#  {'name': 'makeup water entering equip'},
#  {'name': 'makeup water entering flow sensor point'},
#  {'name': 'makeup water entering flow sp point'},
#  {'name': 'makeup water entering pipe equip'},
#  {'name': 'makeup water entering point'},
#  {'name': 'makeup water entering pressure sensor point'},
#  {'name': 'makeup water entering pressure sp point'},
#  {'name': 'makeup water entering pump alarm sensor point'},
#  {'name': 'makeup water entering pump enable cmd point'},
#  {'name': 'makeup water entering pump enable sensor point'},
#  {'name': 'makeup water entering pump equip'},
#  {'name': 'makeup water entering pump motor equip'},
#  {'name': 'makeup water entering pump point'},
#  {'name': 'makeup water entering pump run cmd point'},
#  {'name': 'makeup water entering pump run sensor point'},
#  {'name': 'makeup water entering pump vfd freq cmd point'},
#  {'name': 'makeup water entering pump vfd freq sensor point'},
#  {'name': 'makeup water entering pump vfd speed cmd point'},
#  {'name': 'makeup water entering pump vfd speed sensor point'},
#  {'name': 'makeup water entering temp sensor point'},
#  {'name': 'makeup water entering temp sp point'},
#  {'name': 'makeup water entering valve actuator equip'},
#  {'name': 'makeup water entering valve cmd point'},
#  {'name': 'makeup water entering valve sensor point'},
#  {'name': 'mixed air co2 concentration sensor point'},
#  {'name': 'mixed air co2 concentration sp point'},
#  {'name': 'mixed air dewPoint sensor point'},
#  {'name': 'mixed air dewPoint sp point'},
#  {'name': 'mixed air enthalpy sensor point'},
#  {'name': 'mixed air enthalpy sp point'},
#  {'name': 'mixed air flow sensor point'},
#  {'name': 'mixed air flow sp point'},
#  {'name': 'mixed air humidity sensor point'},
#  {'name': 'mixed air humidity sp point'},
#  {'name': 'mixed air pressure sensor point'},
#  {'name': 'mixed air pressure sp point'},
#  {'name': 'mixed air temp sensor point'},
#  {'name': 'mixed air temp sp point'},
#  {'name': 'mixed chilled water cool valve cmd point'},
#  {'name': 'mixed coolingCoil equip'},
#  {'name': 'mixed damper actuator equip'},
#  {'name': 'mixed damper cmd point'},
#  {'name': 'mixed damper sensor point'},
#  {'name': 'mixed duct equip'},
#  {'name': 'mixed equip'},
#  {'name': 'mixed fan alarm sensor point'},
#  {'name': 'mixed fan enable cmd point'},
#  {'name': 'mixed fan enable sensor point'},
#  {'name': 'mixed fan equip'},
#  {'name': 'mixed fan motor equip'},
#  {'name': 'mixed fan point'},
#  {'name': 'mixed fan run cmd point'},
#  {'name': 'mixed fan run sensor point'},
#  {'name': 'mixed fan vfd freq cmd point'},
#  {'name': 'mixed fan vfd freq sensor point'},
#  {'name': 'mixed fan vfd speed cmd point'},
#  {'name': 'mixed fan vfd speed sensor point'},
#  {'name': 'mixed heatingCoil equip'},
#  {'name': 'mixed hot water heat valve cmd point'},
#  {'name': 'mixed point'},
#  {'name': 'mixed stage:1 cool run cmd point'},
#  {'name': 'mixed stage:1 heat run cmd point'},
#  {'name': 'mixed steam heat valve cmd point'},
#  {'name': 'networking device'},
#  {'name': 'occupancy sensor point'},
#  {'name': 'occupied sensor point'},
#  {'name': 'occupied sp point'},
#  {'name': 'outside air co2 concentration sensor point'},
#  {'name': 'outside air co2 concentration sp point'},
#  {'name': 'outside air dewPoint sensor point'},
#  {'name': 'outside air dewPoint sp point'},
#  {'name': 'outside air enthalpy sensor point'},
#  {'name': 'outside air enthalpy sp point'},
#  {'name': 'outside air flow sensor point'},
#  {'name': 'outside air flow sp point'},
#  {'name': 'outside air humidity sensor point'},
#  {'name': 'outside air humidity sp point'},
#  {'name': 'outside air pressure sensor point'},
#  {'name': 'outside air pressure sp point'},
#  {'name': 'outside air temp sensor point'},
#  {'name': 'outside air temp sp point'},
#  {'name': 'outside chilled water cool valve cmd point'},
#  {'name': 'outside coolingCoil equip'},
#  {'name': 'outside damper actuator equip'},
#  {'name': 'outside damper cmd point'},
#  {'name': 'outside damper sensor point'},
#  {'name': 'outside duct equip'},
#  {'name': 'outside equip'},
#  {'name': 'outside fan alarm sensor point'},
#  {'name': 'outside fan enable cmd point'},
#  {'name': 'outside fan enable sensor point'},
#  {'name': 'outside fan equip'},
#  {'name': 'outside fan motor equip'},
#  {'name': 'outside fan point'},
#  {'name': 'outside fan run cmd point'},
#  {'name': 'outside fan run sensor point'},
#  {'name': 'outside fan vfd freq cmd point'},
#  {'name': 'outside fan vfd freq sensor point'},
#  {'name': 'outside fan vfd speed cmd point'},
#  {'name': 'outside fan vfd speed sensor point'},
#  {'name': 'outside heatingCoil equip'},
#  {'name': 'outside hot water heat valve cmd point'},
#  {'name': 'outside point'},
#  {'name': 'outside stage:1 cool run cmd point'},
#  {'name': 'outside stage:1 heat run cmd point'},
#  {'name': 'outside steam heat valve cmd point'},
#  {'name': 'perimeterHeat cmd point'},
#  {'name': 'phase:"A" ac elec current angle sensor point'},
#  {'name': 'phase:"A" ac elec current imbalance sensor point'},
#  {'name': 'phase:"A" ac elec current magnitude sensor point'},
#  {'name': 'phase:"A" ac elec current thd sensor point'},
#  {'name': 'phase:"A" ac elec pf sensor point'},
#  {'name': 'phase:"A" ac elec volt angle sensor point'},
#  {'name': 'phase:"A" ac elec volt imbalance sensor point'},
#  {'name': 'phase:"A" ac elec volt magnitude sensor point'},
#  {'name': 'phase:"A" ac elec volt thd sensor point'},
#  {'name': 'phase:"A" active ac elec power sensor point'},
#  {'name': 'phase:"A" apparent ac elec power sensor point'},
#  {'name': 'phase:"A" net ac elec active energy sensor point'},
#  {'name': 'phase:"A" reactive ac elec power sensor point'},
#  {'name': 'point'},
#  {'name': 'pressure sensor point'},
#  {'name': 'pressure sp point'},
#  {'name': 'pump alarm sensor point'},
#  {'name': 'pump enable cmd point'},
#  {'name': 'pump enable sensor point'},
#  {'name': 'pump equip'},
#  {'name': 'pump motor equip'},
#  {'name': 'pump point'},
#  {'name': 'pump run cmd point'},
#  {'name': 'pump run sensor point'},
#  {'name': 'pump vfd freq cmd point'},
#  {'name': 'pump vfd freq sensor point'},
#  {'name': 'pump vfd speed cmd point'},
#  {'name': 'pump vfd speed sensor point'},
#  {'name': 'purge water flow sensor point'},
#  {'name': 'purge water volume sensor point'},
#  {'name': 'rack equip'},
#  {'name': 'reheat cmd point'},
#  {'name': 'return air co2 concentration sensor point'},
#  {'name': 'return air co2 concentration sp point'},
#  {'name': 'return air dewPoint sensor point'},
#  {'name': 'return air dewPoint sp point'},
#  {'name': 'return air enthalpy sensor point'},
#  {'name': 'return air enthalpy sp point'},
#  {'name': 'return air flow sensor point'},
#  {'name': 'return air flow sp point'},
#  {'name': 'return air humidity sensor point'},
#  {'name': 'return air humidity sp point'},
#  {'name': 'return air pressure sensor point'},
#  {'name': 'return air pressure sp point'},
#  {'name': 'return air temp sensor point'},
#  {'name': 'return air temp sp point'},
#  {'name': 'return chilled water cool valve cmd point'},
#  {'name': 'return coolingCoil equip'},
#  {'name': 'return damper actuator equip'},
#  {'name': 'return damper cmd point'},
#  {'name': 'return damper sensor point'},
#  {'name': 'return duct equip'},
#  {'name': 'return equip'},
#  {'name': 'return fan alarm sensor point'},
#  {'name': 'return fan enable cmd point'},
#  {'name': 'return fan enable sensor point'},
#  {'name': 'return fan equip'},
#  {'name': 'return fan motor equip'},
#  {'name': 'return fan point'},
#  {'name': 'return fan run cmd point'},
#  {'name': 'return fan run sensor point'},
#  {'name': 'return fan vfd freq cmd point'},
#  {'name': 'return fan vfd freq sensor point'},
#  {'name': 'return fan vfd speed cmd point'},
#  {'name': 'return fan vfd speed sensor point'},
#  {'name': 'return heatingCoil equip'},
#  {'name': 'return hot water heat valve cmd point'},
#  {'name': 'return point'},
#  {'name': 'return stage:1 cool run cmd point'},
#  {'name': 'return stage:1 heat run cmd point'},
#  {'name': 'return steam heat valve cmd point'},
#  {'name': 'run cmd point'},
#  {'name': 'run sensor point'},
#  {'name': 'server device'},
#  {'name': 'space'},
#  {'name': 'stage:1 cool run cmd point'},
#  {'name': 'stage:1 heat run cmd point'},
#  {'name': 'steam boiler equip'},
#  {'name': 'steam bypass equip'},
#  {'name': 'steam bypass flow sensor point'},
#  {'name': 'steam bypass flow sp point'},
#  {'name': 'steam bypass pipe equip'},
#  {'name': 'steam bypass point'},
#  {'name': 'steam bypass pressure sensor point'},
#  {'name': 'steam bypass pressure sp point'},
#  {'name': 'steam bypass pump alarm sensor point'},
#  {'name': 'steam bypass pump enable cmd point'},
#  {'name': 'steam bypass pump enable sensor point'},
#  {'name': 'steam bypass pump equip'},
#  {'name': 'steam bypass pump motor equip'},
#  {'name': 'steam bypass pump point'},
#  {'name': 'steam bypass pump run cmd point'},
#  {'name': 'steam bypass pump run sensor point'},
#  {'name': 'steam bypass pump vfd freq cmd point'},
#  {'name': 'steam bypass pump vfd freq sensor point'},
#  {'name': 'steam bypass pump vfd speed cmd point'},
#  {'name': 'steam bypass pump vfd speed sensor point'},
#  {'name': 'steam bypass temp sensor point'},
#  {'name': 'steam bypass temp sp point'},
#  {'name': 'steam bypass valve actuator equip'},
#  {'name': 'steam bypass valve cmd point'},
#  {'name': 'steam bypass valve sensor point'},
#  {'name': 'steam delta flow sensor point'},
#  {'name': 'steam delta pressure sensor point'},
#  {'name': 'steam delta temp sensor point'},
#  {'name': 'steam header equip'},
#  {'name': 'steam header flow sensor point'},
#  {'name': 'steam header flow sp point'},
#  {'name': 'steam header pipe equip'},
#  {'name': 'steam header point'},
#  {'name': 'steam header pressure sensor point'},
#  {'name': 'steam header pressure sp point'},
#  {'name': 'steam header pump alarm sensor point'},
#  {'name': 'steam header pump enable cmd point'},
#  {'name': 'steam header pump enable sensor point'},
#  {'name': 'steam header pump equip'},
#  {'name': 'steam header pump motor equip'},
#  {'name': 'steam header pump point'},
#  {'name': 'steam header pump run cmd point'},
#  {'name': 'steam header pump run sensor point'},
#  {'name': 'steam header pump vfd freq cmd point'},
#  {'name': 'steam header pump vfd freq sensor point'},
#  {'name': 'steam header pump vfd speed cmd point'},
#  {'name': 'steam header pump vfd speed sensor point'},
#  {'name': 'steam header temp sensor point'},
#  {'name': 'steam header temp sp point'},
#  {'name': 'steam header valve actuator equip'},
#  {'name': 'steam header valve cmd point'},
#  {'name': 'steam header valve sensor point'},
#  {'name': 'steam heat valve cmd point'},
#  {'name': 'steam heatExchanger equip'},
#  {'name': 'steam leaving equip'},
#  {'name': 'steam leaving flow sensor point'},
#  {'name': 'steam leaving flow sp point'},
#  {'name': 'steam leaving pipe equip'},
#  {'name': 'steam leaving point'},
#  {'name': 'steam leaving pressure sensor point'},
#  {'name': 'steam leaving pressure sp point'},
#  {'name': 'steam leaving pump alarm sensor point'},
#  {'name': 'steam leaving pump enable cmd point'},
#  {'name': 'steam leaving pump enable sensor point'},
#  {'name': 'steam leaving pump equip'},
#  {'name': 'steam leaving pump motor equip'},
#  {'name': 'steam leaving pump point'},
#  {'name': 'steam leaving pump run cmd point'},
#  {'name': 'steam leaving pump run sensor point'},
#  {'name': 'steam leaving pump vfd freq cmd point'},
#  {'name': 'steam leaving pump vfd freq sensor point'},
#  {'name': 'steam leaving pump vfd speed cmd point'},
#  {'name': 'steam leaving pump vfd speed sensor point'},
#  {'name': 'steam leaving temp sensor point'},
#  {'name': 'steam leaving temp sp point'},
#  {'name': 'steam leaving valve actuator equip'},
#  {'name': 'steam leaving valve cmd point'},
#  {'name': 'steam leaving valve sensor point'},
#  {'name': 'steam mixing valve cmd point'},
#  {'name': 'temp sensor point'},
#  {'name': 'temp sp point'},
#  {'name': 'thermostat equip'},
#  {'name': 'total ac elec demand sensor point'},
#  {'name': 'total active ac elec power sensor point'},
#  {'name': 'total apparent ac elec power sensor point'},
#  {'name': 'total export ac elec active energy sensor point'},
#  {'name': 'total import ac elec active energy sensor point'},
#  {'name': 'total net ac elec active energy sensor point'},
#  {'name': 'total reactive ac elec power sensor point'},
#  {'name': 'valve actuator equip'},
#  {'name': 'valve cmd point'},
#  {'name': 'valve sensor point'},
#  {'name': 'ventilation air co2 concentration sensor point'},
#  {'name': 'ventilation air co2 concentration sp point'},
#  {'name': 'ventilation air dewPoint sensor point'},
#  {'name': 'ventilation air dewPoint sp point'},
#  {'name': 'ventilation air enthalpy sensor point'},
#  {'name': 'ventilation air enthalpy sp point'},
#  {'name': 'ventilation air flow sensor point'},
#  {'name': 'ventilation air flow sp point'},
#  {'name': 'ventilation air humidity sensor point'},
#  {'name': 'ventilation air humidity sp point'},
#  {'name': 'ventilation air pressure sensor point'},
#  {'name': 'ventilation air pressure sp point'},
#  {'name': 'ventilation air temp sensor point'},
#  {'name': 'ventilation air temp sp point'},
#  {'name': 'ventilation chilled water cool valve cmd point'},
#  {'name': 'ventilation coolingCoil equip'},
#  {'name': 'ventilation damper actuator equip'},
#  {'name': 'ventilation damper cmd point'},
#  {'name': 'ventilation damper sensor point'},
#  {'name': 'ventilation duct equip'},
#  {'name': 'ventilation equip'},
#  {'name': 'ventilation fan alarm sensor point'},
#  {'name': 'ventilation fan enable cmd point'},
#  {'name': 'ventilation fan enable sensor point'},
#  {'name': 'ventilation fan equip'},
#  {'name': 'ventilation fan motor equip'},
#  {'name': 'ventilation fan point'},
#  {'name': 'ventilation fan run cmd point'},
#  {'name': 'ventilation fan run sensor point'},
#  {'name': 'ventilation fan vfd freq cmd point'},
#  {'name': 'ventilation fan vfd freq sensor point'},
#  {'name': 'ventilation fan vfd speed cmd point'},
#  {'name': 'ventilation fan vfd speed sensor point'},
#  {'name': 'ventilation heatingCoil equip'},
#  {'name': 'ventilation hot water heat valve cmd point'},
#  {'name': 'ventilation point'},
#  {'name': 'ventilation stage:1 cool run cmd point'},
#  {'name': 'ventilation stage:1 heat run cmd point'},
#  {'name': 'ventilation steam heat valve cmd point'},
#  {'name': 'vfd freq cmd point'},
#  {'name': 'vfd freq sensor point'},
#  {'name': 'vfd speed cmd point'},
#  {'name': 'vfd speed sensor point'},
#  {'name': 'vrf branchSelector equip'},
#  {'name': 'vrf indoorUnit equip'},
#  {'name': 'vrf outdoorUnit equip'},
#  {'name': 'vrf refrig plant equip'},
#  {'name': 'warm water flow thermal meter equip'},
#  {'name': 'warm well equip'},
#  {'name': 'water flow sensor point'},
#  {'name': 'water level sensor point'},
#  {'name': 'water pressure sensor point'},
#  {'name': 'water pump alarm sensor point'},
#  {'name': 'water pump enable cmd point'},
#  {'name': 'water pump enable sensor point'},
#  {'name': 'water pump equip'},
#  {'name': 'water pump motor equip'},
#  {'name': 'water pump point'},
#  {'name': 'water pump run cmd point'},
#  {'name': 'water pump run sensor point'},
#  {'name': 'water pump vfd freq cmd point'},
#  {'name': 'water pump vfd freq sensor point'},
#  {'name': 'water pump vfd speed cmd point'},
#  {'name': 'water pump vfd speed sensor point'},
#  {'name': 'water temp sensor point'},
#  {'name': 'water volume sensor point'},
#  {'name': 'weather air dewPoint sensor point'},
#  {'name': 'weather air enthalpy sensor point'},
#  {'name': 'weather air feelsLike sensor point'},
#  {'name': 'weather air humidity sensor point'},
#  {'name': 'weather air temp sensor point'},
#  {'name': 'weather air wetBulb sensor point'},
#  {'name': 'weather atmospheric pressure sensor point'},
#  {'name': 'weather cloudage sensor point'},
#  {'name': 'weather daytime sensor point'},
#  {'name': 'weather precipitation sensor point'},
#  {'name': 'weather solar irradiance sensor point'},
#  {'name': 'weather visibility sensor point'},
#  {'name': 'weather weatherCond sensor point'},
#  {'name': 'weather wind direction sensor point'},
#  {'name': 'weather wind speed sensor point'},
#  {'name': 'zone air ch2o concentration sensor point'},
#  {'name': 'zone air co concentration sensor point'},
#  {'name': 'zone air co2 concentration sensor point'},
#  {'name': 'zone air co2 concentration sp point'},
#  {'name': 'zone air dewPoint sensor point'},
#  {'name': 'zone air dewPoint sp point'},
#  {'name': 'zone air enthalpy sensor point'},
#  {'name': 'zone air enthalpy sp point'},
#  {'name': 'zone air humidity sensor point'},
#  {'name': 'zone air humidity sp point'},
#  ...]

# %%
# create a new Mapper object which knows about the definitions. This will
# access OpenAI to compute embeddings if necessary
m = Mapper(defns, "haystack_proto.index")

# define which set of Brick classes we want to match against
# all points which aren't parameters (these have similar enough names it can confuse the mapping)
points = m.get_brick_classes(BRICK.Point, [BRICK.Parameter])
# all equipment in Brick
equips = m.get_brick_classes(BRICK.Equipment)
# concatenate these two lists of Brick classes
bcs = points + equips

bcs
# Out:
# 2024-12-19 15:40:23.196 | INFO     | brickmapper:populate_external_embeddings:66 - Restored haystack_proto.index
# [BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Differential_Temperature_Setpoint'), label='Water Differential Temperature Setpoint', definition='Sets the target differential temperature between the start and end of a heat transfer cycle in a water circuit', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Temperature_Differential_Reset_Setpoint'), label='Temperature Differential Reset Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Differential_Pressure_Sensor'), label='Differential Pressure Sensor', definition='Measures the difference between two applied pressures', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heat_Exchanger_Leaving_Water_Temperature_Sensor'), label='Heat Exchanger Leaving Water Temperature Sensor', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heat_Sensor'), label='Heat Sensor', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Cooling_Temperature_Setpoint'), label='Unoccupied Cooling Temperature Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Pressure_Alarm'), label='Pressure Alarm', definition='An alarm that indicates the off-normal conditions associated with pressure.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Maintenance_Mode_Command'), label='Maintenance Mode Command', definition='Controls whether or not a device or controller is operating in "Maintenance" mode', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Flow_Setpoint'), label='Hot Water Flow Setpoint', definition='Sets the target flow rate of hot water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Cooling_Mode_Status'), label='Cooling Mode Status', definition='Indicates whether a system, device or control loop is in a cooling mode', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Humidity_Setpoint'), label='Supply Air Humidity Setpoint', definition='Humidity setpoint for supply air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Smoke_Detection_Alarm'), label='Smoke Detection Alarm', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Enable_Command'), label='Enable Command', definition='Commands that enable functionality', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Low_Air_Flow_Alarm'), label='Low Air Flow Alarm', definition='An alarm that indicates that the air flow is lower than normal.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Rated_Speed_Setpoint'), label='Rated Speed Setpoint', definition='Sets rated speed', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Differential_Pressure_Load_Shed_Reset_Status'), label='Chilled Water Differential Pressure Load Shed Reset Status', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Deionised_Water_Conductivity_Sensor'), label='Deionised Water Conductivity Sensor', definition='Measures the electrical conductance of deionised water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Rain_Level_Sensor'), label='Rain Level Sensor', definition='Measures the amount of precipitation fallen', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Differential_Discharge_Return_Water_Temperature_Sensor'), label='Differential Discharge Return Water Temperature Sensor', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Differential_Temperature_Sensor'), label='Hot Water Differential Temperature Sensor', definition='Measures the difference in temperature between the entering water to the boiler or other water heating device and leaving water from the same boiler or other water heating device', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#PM10_Level_Sensor'), label='PM10 Level Sensor', definition='Detects level of particulates of size 10 microns', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Illuminance_Setpoint'), label='Illuminance Setpoint', definition='Target Illuminance of the zone.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Flow_Setpoint'), label='Chilled Water Flow Setpoint', definition='Sets the target flow rate of chilled water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Discharge_Air_Flow_High_Reset_Setpoint'), label='Discharge Air Flow High Reset Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Static_Pressure_Setpoint'), label='Chilled Water Static Pressure Setpoint', definition='Sets static pressure of chilled water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Air_Quality_Sensor'), label='Air Quality Sensor', definition='A sensor which provides a measure of air quality', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Valve_Position_Command'), label='Valve Position Command', definition='Controls the position (the degree of openness) of a valve', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#System_Enable_Command'), label='System Enable Command', definition='Enables operation of a system', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Bypass_Water_Flow_Setpoint'), label='Bypass Water Flow Setpoint', definition='Sets the target flow rate of bypass water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Gauge_Pressure_Sensor'), label='Chilled Water Gauge Pressure Sensor', definition='Sensor measuring the gauge pressure (zero-referenced against ambient air pressure) of chilled water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Demand_Sensor'), label='Demand Sensor', definition='Measures the amount of power consumed by the use of some process; typically found by multiplying the tonnage of a unit (e.g. RTU) by the efficiency rating in kW/ton', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Low_Outside_Air_Temperature_Enable_Setpoint'), label='Low Outside Air Temperature Enable Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heating_Zone_Air_Temperature_Setpoint'), label='Heating Zone Air Temperature Setpoint', definition='The heating setpoint for a specific zone in a building.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Discharge_Flow_Sensor'), label='Chilled Water Discharge Flow Sensor', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Automatic_Mode_Command'), label='Automatic Mode Command', definition='Controls whether or not a device or controller is operating in "Automatic" mode', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Outside_Air_Enthalpy_Sensor'), label='Outside Air Enthalpy Sensor', definition='Measures the total heat content of outside air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Ammonia_Sensor'), label='Ammonia Sensor', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Usage_Sensor'), label='Hot Water Usage Sensor', definition='Measures the amount of hot water that is consumed, over some period of time', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Discharge_Air_Temperature_Reset_Differential_Setpoint'), label='Discharge Air Temperature Reset Differential Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Supply_Flow_Setpoint'), label='Chilled Water Supply Flow Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Water_Differential_Pressure_Deadband_Setpoint'), label='Leaving Water Differential Pressure Deadband Setpoint', definition='Sets the size of a deadband of differential pressure of leaving water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Zone_Air_Temperature_Setpoint'), label='Zone Air Temperature Setpoint', definition='Sets temperature of zone air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Vent_Operating_Mode_Status'), label='Vent Operating Mode Status', definition='Indicates the current operating mode of a vent', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Solar_Radiance_Sensor'), label='Solar Radiance Sensor', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Reheat_Command'), label='Reheat Command', definition='A command to activate reheating, which is used for either heating or for dehumidification purposes', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Differential_Pressure_Sensor'), label='Supply Air Differential Pressure Sensor', definition='Measures the difference in pressure between an upstream and downstream of an air duct or other air conduit used to supply air into the building', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Occupied_Supply_Air_Flow_Setpoint'), label='Occupied Supply Air Flow Setpoint', definition='Sets supply air flow rate when occupied', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Power_Sensor'), label='Power Sensor', definition='Measures the amount of instantaneous power consumed', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Supply_Flow_Sensor'), label='Chilled Water Supply Flow Sensor', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Point'), label='Point', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Discharge_Air_Flow_Demand_Setpoint'), label='Discharge Air Flow Demand Setpoint', definition='Sets the rate of discharge air flow required for a process', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Deionised_Water_Level_Sensor'), label='Deionised Water Level Sensor', definition='Measures the height/level of deionised water in some container', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Occupancy_Command'), label='Occupancy Command', definition='Controls whether or not a device or controller is operating in "Occupied" mode', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Differential_Pressure_Sensor'), label='Chilled Water Differential Pressure Sensor', definition='Measures the difference in water pressure on either side of a chilled water valve', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Exhaust_Air_Static_Pressure_Sensor'), label='Exhaust Air Static Pressure Sensor', definition='The static pressure of air within exhaust regions of an HVAC system', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Filter_Status'), label='Filter Status', definition='Indicates if a filter needs to be replaced', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#PM2.5_Level_Sensor'), label='PM2.5 Level Sensor', definition='Detects level of particulates of size 2.5 microns', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Natural_Gas_Temperature_Sensor'), label='Natural Gas Temperature Sensor', definition='Measures the temperature of natural gas', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#High_Humidity_Alarm'), label='High Humidity Alarm', definition='An alarm that indicates high concentration of water vapor in the air.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Chilled_Water_Temperature_Setpoint'), label='Return Chilled Water Temperature Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Boiler_Command'), label='Boiler Command', definition='A command to control a boiler', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Condenser_Water_Temperature_Sensor'), label='Supply Condenser Water Temperature Sensor', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Differential_Temperature_Sensor'), label='Chilled Water Differential Temperature Sensor', definition='Measures the difference in temperature between the entering water to the chiller or other water cooling device and leaving water from the same chiller or other water cooling device', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Mode_Status'), label='Unoccupied Mode Status', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Deadband_Setpoint'), label='Deadband Setpoint', definition='Sets the size of a deadband', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Static_Pressure_Deadband_Setpoint'), label='Supply Air Static Pressure Deadband Setpoint', definition='Sets the size of a deadband of static pressure of supply air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Overridden_Status'), label='Overridden Status', definition='Indicates if the expected operating status of an equipment or control loop has been overridden', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Temperature_Cooling_Setpoint'), label='Supply Air Temperature Cooling Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Building_Air_Static_Pressure_Sensor'), label='Building Air Static Pressure Sensor', definition='The static pressure of air within a building', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Condenser_Water_Flow_Sensor'), label='Entering Condenser Water Flow Sensor', definition='Measures the flow of the entering condenser water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Natural_Gas_Flow_Sensor'), label='Natural Gas Flow Sensor', definition='Measures the rate of flow of natural gas', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Enable_Status'), label='Enable Status', definition='Indicates if a system or piece of functionality has been enabled', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Exhaust_Air_Velocity_Pressure_Sensor'), label='Exhaust Air Velocity Pressure Sensor', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Flow_Setpoint'), label='Supply Air Flow Setpoint', definition='Sets supply air flow rate', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Effective_Target_Zone_Air_Temperature_Setpoint'), label='Effective Target Zone Air Temperature Setpoint', definition='Target Setpoint (also known as Common Setpoint) is a reference point representing the desired air temperature in a specific zone of a building. This setpoint acts as a baseline from which the cooling and heating setpoints are established by adding or subtracting a deadband width', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Filter_Differential_Pressure_Sensor'), label='Filter Differential Pressure Sensor', definition='Measures the difference in pressure on either side of a filter', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Air_Differential_Pressure_Sensor'), label='Return Air Differential Pressure Sensor', definition='Measures the difference in pressure between the return and supply side', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Differential_Pressure_Deadband_Setpoint'), label='Differential Pressure Deadband Setpoint', definition='Sets the size of a deadband of differential pressure', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Collection_Basin_Water_Level_Alarm'), label='Collection Basin Water Level Alarm', definition='An alarm that indicates a high or low level of water in the collection basin, e.g. within a Cooling_Tower', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heating_Demand_Sensor'), label='Heating Demand Sensor', definition='Measures the amount of power consumed by a heating process; typically found by multiplying the tonnage of a unit (e.g. RTU) by the efficiency rating in kW/ton', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Temperature_Low_Reset_Setpoint'), label='Temperature Low Reset Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Condenser_Water_Temperature_Sensor'), label='Condenser Water Temperature Sensor', definition='Measures the temperature of condenser water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Demand_Setpoint'), label='Demand Setpoint', definition='Sets the rate required for a process', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Overridden_Off_Status'), label='Overridden Off Status', definition='Indicates if a control loop, relay or equipment has been turned off when it would otherwise be scheduled to be on', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Speed_Status'), label='Speed Status', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Zone_Occupied_Load_Shed_Command'), label='Zone Occupied Load Shed Command', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Discharge_Air_Temperature_Cooling_Setpoint'), label='Discharge Air Temperature Cooling Setpoint', definition='Sets temperature of discharge air for cooling', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Tint_Command'), label='Tint Command', definition='The target level of window tint.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Occupied_Cooling_Temperature_Deadband_Setpoint'), label='Occupied Cooling Temperature Deadband Setpoint', definition='Sets the size of a deadband of temperature for cooling when occupied', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Differential_Speed_Setpoint'), label='Differential Speed Setpoint', definition='Sets differential speed', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Domestic_Hot_Water_Temperature_Setpoint'), label='Domestic Hot Water Temperature Setpoint', definition='Sets temperature of domestic hot water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Cooling_Zone_Air_Temperature_Setpoint'), label='Cooling Zone Air Temperature Setpoint', definition='The cooling setpoint for a specific zone in a building.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Valve_Status'), label='Valve Status', definition='The current status of the valve.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Zone_Air_Heating_Temperature_Setpoint'), label='Zone Air Heating Temperature Setpoint', definition='The lower (heating) setpoint for zone air temperature', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Absolute_Humidity_Sensor'), label='Absolute Humidity Sensor', definition='Measures the present state of absolute humidity', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Occupied_Cooling_Zone_Air_Temperature_Setpoint'), label='Occupied Cooling Zone Air Temperature Setpoint', definition='Sets temperature for zone air cooling when occupied', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Open_Heating_Valve_Outside_Air_Temperature_Setpoint'), label='Open Heating Valve Outside Air Temperature Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Occupancy_Status'), label='Occupancy Status', definition='Indicates if a room or space is occupied', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#VFD_Enable_Command'), label='VFD Enable Command', definition='Enables operation of a variable frequency drive', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Temperature_Deadband_Setpoint'), label='Supply Air Temperature Deadband Setpoint', definition='Sets the size of a deadband of temperature of supply air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Cooling_Discharge_Air_Flow_Setpoint'), label='Cooling Discharge Air Flow Setpoint', definition='Sets discharge air flow for cooling', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#PM10_Sensor'), label='PM10 Sensor', definition='Detects matter of size 10 microns', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Cooling_Demand_Setpoint'), label='Cooling Demand Setpoint', definition='Sets the rate required for cooling', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leak_Alarm'), label='Leak Alarm', definition='An alarm that indicates leaks occured in systems containing fluids', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Operating_Mode_Status'), label='Operating Mode Status', definition='Indicates the current operating mode of a system, device or control loop', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Temperature_Adjust_Sensor'), label='Temperature Adjust Sensor', definition='Measures user-provided adjustment of temperature', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Valve_Position_Alarm'), label='Valve Position Alarm', definition='An alarm that indicates that the valve position is not in a normal state.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#CO2_Alarm'), label='CO2 Alarm', definition='An alarm that indicates the off-normal conditions associated with the presence of carbon dioxide.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Time_Setpoint'), label='Time Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Disable_Command'), label='Disable Command', definition='Commands that disable functionality', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Low_Outside_Air_Temperature_Enable_Differential_Sensor'), label='Low Outside Air Temperature Enable Differential Sensor', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Water_Flow_Setpoint'), label='Supply Water Flow Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Piezoelectric_Sensor'), label='Piezoelectric Sensor', definition='Senses changes pressure, acceleration, temperature, force or strain via the piezoelectric effect', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Air_Humidity_Sensor'), label='Return Air Humidity Sensor', definition='Measures the relative humidity of return air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Return_Temperature_Sensor'), label='Hot Water Return Temperature Sensor', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Return_Air_Temperature_Setpoint'), label='Unoccupied Return Air Temperature Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Low_Return_Air_Temperature_Alarm'), label='Low Return Air Temperature Alarm', definition='An alarm that indicates that return air temperature is too low', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Smoke_Detection_Alarm'), label='Supply Air Smoke Detection Alarm', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Tint_Status'), label='Tint Status', definition='The current level of window tint, errors, or transient states.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Cooling_Command'), label='Cooling Command', definition='Controls the amount of cooling to be delivered (typically as a proportion of total cooling output)', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Illuminance_Sensor'), label='Illuminance Sensor', definition='Measures the total luminous flux incident on a surface, per unit area', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Temporary_Occupancy_Status'), label='Temporary Occupancy Status', definition='For systems that differentiate between scheduled occupied/unoccupied mode, this indicates if a space is temporarily occupied when it would otherwise be unoccupied', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Preheat_Command'), label='Preheat Command', definition='A command to activate preheating. Typically used to preheat cool air coming from a mixing box or economizer', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Direction_Command'), label='Direction Command', definition='Commands that affect the direction of some phenomenon', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Hot_Water_Temperature_Sensor'), label='Entering Hot Water Temperature Sensor', definition='Measures the temperature of water enteringed to a hot water system', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Average_Heating_Demand_Sensor'), label='Average Heating Demand Sensor', definition='Measures the average power consumed by a heating process as the amount of power consumed over some interval', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Sash_Position_Sensor'), label='Sash Position Sensor', definition='Measures the current position of a sash in terms of the percent of fully open', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Static_Pressure_Sensor'), label='Supply Air Static Pressure Sensor', definition='The static pressure of air within supply regions of an HVAC system', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Air_Temperature_Setpoint'), label='Air Temperature Setpoint', definition='Sets temperature of air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Air_CO2_Sensor'), label='Return Air CO2 Sensor', definition='Measures the concentration of CO2 in return air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Cooling_Mode_Status'), label='Unoccupied Cooling Mode Status', definition='Indicates whether a system, device or control loop is in an unoccupied cooling mode', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Air_Differential_Pressure_Sensor'), label='Air Differential Pressure Sensor', definition='Measures the difference in pressure between two regions of air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Duration_Sensor'), label='Duration Sensor', definition='Measures the duration of a phenomenon or event', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#PM1_Level_Sensor'), label='PM1 Level Sensor', definition='Detects level of particulates of size 1 microns', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Output_Frequency_Sensor'), label='Output Frequency Sensor', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Fault_Status'), label='Fault Status', definition='Indicates the presence of a fault in a device, system or control loop', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Water_Flow_Sensor'), label='Supply Water Flow Sensor', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Imbalance_Sensor'), label='Imbalance Sensor', definition='A sensor which measures difference (imbalance) between phases of an electrical system', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Occupied_Air_Temperature_Heating_Setpoint'), label='Occupied Air Temperature Heating Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Humidity_Setpoint'), label='Unoccupied Humidity Setpoint', definition='Target humidity level when the location is unoccupied.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Thermal_Power_Sensor'), label='Thermal Power Sensor', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Min_Frequency_Command'), label='Min Frequency Command', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Discharge_Air_Temperature_Setpoint'), label='Discharge Air Temperature Setpoint', definition='Sets temperature of discharge air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Current_Sensor'), label='Current Sensor', definition='Senses the amperes of electrical current passing through the sensor', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Temperature_Setpoint'), label='Water Temperature Setpoint', definition='Sets temperature of water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Load_Shed_Command'), label='Load Shed Command', definition='Controls load shedding behavior provided by a control system', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Differential_Pressure_Load_Shed_Status'), label='Differential Pressure Load Shed Status', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Condenser_Water_Temperature_Setpoint'), label='Supply Condenser Water Temperature Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Thermal_Energy_Usage_Sensor'), label='Thermal Energy Usage Sensor', definition='A sensor that records the quantity of thermal energy consumed in a given period', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Damper_Position_Sensor'), label='Damper Position Sensor', definition='Measures the current position of a damper in terms of the percent of fully open', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Voltage_Ratio_Setpoint'), label='Voltage Ratio Setpoint', definition='Sets the ratio of voltage in a transformer', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Zone_Air_Humidity_Sensor'), label='Zone Air Humidity Sensor', definition='Measures the relative humidity of zone air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Heating_Temperature_Setpoint'), label='Unoccupied Heating Temperature Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Static_Pressure_Setpoint'), label='Static Pressure Setpoint', definition='Sets static pressure', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#CO2_Sensor'), label='CO2 Sensor', definition='Measures properties of CO2 in air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Radon_Concentration_Sensor'), label='Radon Concentration Sensor', definition='Measures the concentration of radioactivity due to radon', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Temperature_Alarm'), label='Water Temperature Alarm', definition='An alarm that indicates the off-normal conditions associated with temperature of water.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Position_Command'), label='Position Command', definition='Controls or reports the position of some object', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Domestic_Hot_Water_Discharge_Temperature_Setpoint'), label='Domestic Hot Water Discharge Temperature Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Gauge_Pressure_Sensor'), label='Hot Water Gauge Pressure Sensor', definition='Sensor measuring the gauge pressure (zero-referenced against ambient air pressure) of hot water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Cycle_Alarm'), label='Cycle Alarm', definition='An alarm that indicates off-normal conditions associated with HVAC cycles', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Duct_Air_Static_Pressure_Setpoint'), label='Duct Air Static Pressure Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Valve_Command'), label='Valve Command', definition='Controls or reports the openness of a valve (typically as a proportion of its full range of motion)', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Emergency_Air_Flow_System_Status'), label='Emergency Air Flow System Status', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Hot_Water_Temperature_Setpoint'), label='Leaving Hot Water Temperature Setpoint', definition='Temperature setpoint for leaving hot water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Exhaust_Air_Flow_Sensor'), label='Exhaust Air Flow Sensor', definition='Measures the rate of flow of exhaust air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Discharge_Air_Differential_Pressure_Sensor'), label='Discharge Air Differential Pressure Sensor', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Medium_Temperature_Hot_Water_Temperature_Load_Shed_Setpoint'), label='Entering Medium Temperature Hot Water Temperature Load Shed Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Flow_Demand_Setpoint'), label='Supply Air Flow Demand Setpoint', definition='Sets the rate of supply air flow required for a process', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Medium_Temperature_Hot_Water_Temperature_Load_Shed_Status'), label='Entering Medium Temperature Hot Water Temperature Load Shed Status', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Differential_Speed_Sensor'), label='Differential Speed Sensor', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Cooling_Zone_Air_Temperature_Setpoint'), label='Unoccupied Cooling Zone Air Temperature Setpoint', definition='Sets temperature of air when unoccupied for cooling within a specific zone', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Position_Sensor'), label='Position Sensor', definition='Measures the current position of a component in terms of a fraction of its full range of motion', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Exhaust_Air_Dewpoint_Sensor'), label='Exhaust Air Dewpoint Sensor', definition='Measures dewpoint of exhaust air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Power_Loss_Alarm'), label='Power Loss Alarm', definition='An alarm that indicates a power failure.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Discharge_Air_Static_Pressure_Deadband_Setpoint'), label='Discharge Air Static Pressure Deadband Setpoint', definition='Sets the size of a deadband of static pressure of discharge air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Max_Air_Temperature_Setpoint'), label='Max Air Temperature Setpoint', definition='Setpoint for maximum air temperature', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Reset_Command'), label='Reset Command', definition='Commands that reset a flag, property or value to its default', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Medium_Temperature_Hot_Water_Differential_Pressure_Setpoint'), label='Medium Temperature Hot Water Differential Pressure Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Remotely_On_Off_Status'), label='Remotely On Off Status', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Pressure_Setpoint'), label='Pressure Setpoint', definition='Sets pressure', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Wind_Direction_Sensor'), label='Wind Direction Sensor', definition='Measures the direction of wind in degrees relative to North', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Air_Differential_Pressure_Setpoint'), label='Air Differential Pressure Setpoint', definition='Sets the target air differential pressure between an upstream and downstream point in a air duct or conduit', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Water_Temperature_Setpoint'), label='Return Water Temperature Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Current_Output_Sensor'), label='Current Output Sensor', definition='Senses the amperes of electrical current produced as output by a device', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Standby_Cooling_Zone_Air_Temperature_Setpoint'), label='Standby Cooling Zone Air Temperature Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Occupied_Cooling_Temperature_Setpoint'), label='Occupied Cooling Temperature Setpoint', definition='Sets temperature for cooling when occupied', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Gas_Sensor'), label='Gas Sensor', definition='Measures gas concentration (other than CO2)', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Exhaust_Air_Stack_Flow_Setpoint'), label='Exhaust Air Stack Flow Setpoint', definition='Sets exhaust air stack flow rate', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Chilled_Water_Temperature_Setpoint'), label='Leaving Chilled Water Temperature Setpoint', definition='Temperature setpoint for leaving chilled water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Discharge_Air_Humidity_Sensor'), label='Discharge Air Humidity Sensor', definition='Measures the relative humidity of discharge air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Discharge_Hot_Water_Temperature_Setpoint'), label='Discharge Hot Water Temperature Setpoint', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Max_Frequency_Command'), label='Max Frequency Command', definition='Sets the maximum permitted frequency', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Air_Enthalpy_Sensor'), label='Return Air Enthalpy Sensor', definition='Measures the total heat content of return air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Hot_Water_Temperature_Setpoint'), label='Entering Hot Water Temperature Setpoint', definition='Sets the temperature of entering (downstream of the hot water load) hot water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#High_Temperature_Hot_Water_Return_Temperature_Sensor'), label='High Temperature Hot Water Return Temperature Sensor', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Discharge_Air_Temperature_Deadband_Setpoint'), label='Discharge Air Temperature Deadband Setpoint', definition='Sets the size of a deadband of temperature of discharge air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Outside_Air_Dewpoint_Sensor'), label='Outside Air Dewpoint Sensor', definition='Senses the dewpoint temperature of outside air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Exhaust_Air_Humidity_Setpoint'), label='Exhaust Air Humidity Setpoint', definition='Humidity setpoint for exhaust air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Bypass_Air_Flow_Sensor'), label='Bypass Air Flow Sensor', definition='Measures the rate of flow of bypass air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Temperature_Sensor'), label='Supply Air Temperature Sensor', definition='Measures the temperature of supply air', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Peak_Demand_Sensor'), label='Peak Demand Sensor', definition='The peak power consumed by a process over some period of time', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Condenser_Water_Temperature_Sensor'), label='Leaving Condenser Water Temperature Sensor', definition='Measures the temperature of the leaving condenser water', definitions=[]),
# ...
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Rain_Water_Storage_Tank'), label='Rain Water Storage Tank', definition='A tank engineered to capture and store rainwater, usually for non-potable uses.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Circulator_Pump'), label='Hot Water Circulator Pump', definition='Used to move hot water in a closed circuit, ensuring continuous flow.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Heating_Valve'), label='Return Heating Valve', definition='A valve installed on the return side of a heat exchanger', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Disconnect_Switch'), label='Disconnect Switch', definition="A disconnect switch performs the task of manually cutting or reconnecting power from an electrical supply by creating or closing an air insulation gap between two conduction points. Also known as an 'Isolation Switch'.", definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Refrigerant_Metering_Device'), label='Refrigerant Metering Device', definition='Responsible for regulating refrigerant flow, which includes mechanisms like TXVs, EXVs, and capillary tubes', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Access_Control_Equipment'), label='Access Control Equipment', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Vibration_Sensor_Equipment'), label='Vibration Sensor Equipment', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Valve'), label='Hot Water Valve', definition='A valve regulating the flow of hot water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Steam_Valve'), label='Steam Valve', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Isolation_Damper'), label='Isolation Damper', definition='A damper that isolates a section of ductwork or other air handling system.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Building_Hot_Water_Meter'), label='Building Hot Water Meter', definition='A meter that measures the usage or consumption of hot water of a whole building', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Battery'), label='Battery', definition='A container that stores chemical energy that can be converted into electricity and used as a source of power', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Coil'), label='Hot Water Coil', definition='A heating element typically made of pipe, tube or wire that emits heat that is filled with hot water.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#BACnet_Controller'), label='BACnet Controller', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Building_Water_Meter'), label='Building Water Meter', definition='A meter that measures the usage or consumption of water of a whole building', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Dry_Cooler'), label='Dry Cooler', definition='A dry cooler is a fluid cooler that uses air, a relatively dry, non-liquid fluid to accomplish process cooling. (https://submer.com/submer-academy/library/dry-cooler/)', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Sensor_Equipment'), label='Sensor Equipment', definition='A piece of equipment for sensing some physical properties', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Network_Router'), label='Network Router', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Domestic_Hot_Water_Valve'), label='Domestic Hot Water Valve', definition='A valve regulating the flow of domestic hot water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Constant_Air_Volume_Box'), label='Constant Air Volume Box', definition='A terminal unit for which supply air flow rate is constant and the supply air temperature is varied to meet thermal load', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Steam_Radiator'), label='Steam Radiator', definition='Radiator that uses steam', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Packaged_Water_Source_Heat_Pump'), label='Packaged Water Source Heat Pump', definition='A self-contained unit that uses water as a heat source or sink for heating and cooling purposes.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#CRAH'), label='CRAH', definition='a computer room air handler (CRAH) uses fans, cooling coils and a water-chiller system to remove heat.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Thermal_Expansion_Tank'), label='Chilled Water Thermal Expansion Tank', definition='A thermal expansion tank designed specifically for chilled water systems.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Fire_Alarm'), label='Fire Alarm', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Underfloor_Air_Plenum'), label='Underfloor Air Plenum', definition='An open space between a structural concrete slab and the underside of a raised access floor system that connects to an air handling unit to receive conditioned and/or ventilating air before delivery to the room(s)', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Coil'), label='Coil', definition='Cooling or heating element made of pipe or tube that may or may not be finned and formed into helical or serpentine shape (ASHRAE Dictionary)', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Valve'), label='Water Valve', definition='A valve that modulates the flow of water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Makeup_Air_Unit'), label='Makeup Air Unit', definition='A device designed to condition ventilation air introduced into a space or to replace air exhausted from a process or general area exhaust. The device may be used to prevent negative pressure within buildings or to reduce airborne contaminants in a space.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#HVAC_Valve'), label='HVAC Valve', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heat_Pump_Air_Source_Condensing_Unit'), label='Heat Pump Air Source Condensing Unit', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Fire_Safety_Equipment'), label='Fire Safety Equipment', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Check_Valve'), label='Check Valve', definition='Valve that allows fluid to flow in only one direction, preventing reverse flow.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Fan_VFD'), label='Fan VFD', definition='Variable-frequency drive for fans', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Direct_Expansion_Cooling_Coil'), label='Direct Expansion Cooling Coil', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Boiler'), label='Boiler', definition='A closed, pressure vessel that uses fuel or electricity for heating water or other fluids to supply steam or hot water for heating, humidification, or other applications.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Pump'), label='Chilled Water Pump', definition='A pump that performs work on chilled water; typically part of a chilled water system', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Daylight_Sensor_Equipment'), label='Daylight Sensor Equipment', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Steam_Distribution'), label='Steam Distribution', definition='Utilize a steam distribution source to represent how steam is distributed across multiple destinations', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Beam'), label='Chilled Beam', definition='A device with an integrated coil that performs sensible heating of a space via circulation of room air. Chilled Beams are not designed to perform latent cooling; see Induction Units. Despite their name, Chilled Beams may perform heating or cooling of a space depending on their configuration.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Video_Surveillance_Equipment'), label='Video Surveillance Equipment', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#TABS_Panel'), label='TABS Panel', definition='See Thermally_Activated_Building_System_Panel', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Gateway'), label='Gateway', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Meter'), label='Chilled Water Meter', definition='A meter that measures the usage or consumption of chilled water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Building_Electrical_Meter'), label='Building Electrical Meter', definition='A meter that measures the usage or consumption of electricity of a whole building', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Discharge_Fan'), label='Discharge Fan', definition='Fan moving air discharged from HVAC vents', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Wall_Air_Conditioner'), label='Wall Air Conditioner', definition='A wall air conditioner, also known as a window air conditioner when installed in a window frame, is a self-contained unit that cools a room by drawing in warm air, cooling it over a refrigerant coil, and recirculating it back into the space.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Camera'), label='Camera', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Economizer'), label='Economizer', definition='Device that, on proper variable sensing, initiates control signals or actions to conserve energy. A control system that reduces the mechanical heating and cooling requirement.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Induction_Unit'), label='Induction Unit', definition='A device with an primary air connection and integrated coil and condensate pan that performs sensible and latent cooling of a space. Essentially an Active Chilled Beam with a built in condensate pan.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Cooling_Only_Ground_Source_Condensing_Unit'), label='Cooling Only Ground Source Condensing Unit', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Standby_CRAC'), label='Standby CRAC', definition='A CRAC that is activated as part of a lead/lag operation or when an alarm occurs in a primary unit', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Dimmer'), label='Dimmer', definition='A switch providing continuous control over all or part of a lighting installation; typically potentiometer-based', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Preheat_Hot_Water_Valve'), label='Preheat Hot Water Valve', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Steam_Pressure_Relief_Valve'), label='Steam Pressure Relief Valve', definition='Valve designed to automatically relieve excessive steam pressure.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Fresh_Air_Fan'), label='Fresh Air Fan', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Switchgear'), label='Switchgear', definition='A main disconnect or service disconnect feeds power to a switchgear, which then distributes power to the rest of the building through smaller amperage-rated disconnects.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Meter'), label='Water Meter', definition='A meter that measures the usage or consumption of water', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Relief_Damper'), label='Relief Damper', definition="A damper that is a component of a Relief Air System, ensuring building doesn't become over-pressurised", definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Storage_Tank'), label='Water Storage Tank', definition='A specialized type of tank intended for the storage of water for extended periods.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Pressure_Relief_Valve'), label='Water Pressure Relief Valve', definition='Valve designed to automatically relieve excessive water pressure.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Condensing_Natural_Gas_Boiler'), label='Condensing Natural Gas Boiler', definition='A closed, pressure vessel that uses natural gas and heat exchanger that capture and reuse any latent heat for heating water or other fluids to supply steam or hot water for heating, humidification, or other applications.', definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#CRAC'), label='CRAC', definition=None, definitions=[]),
#  BrickClassDefinition(class_=rdflib.term.URIRef('https://brickschema.org/schema/Brick#Condenser_Water_Valve'), label='Condenser Water Valve', definition='A valve that modulates the flow of condenser water', definitions=[]),
#  ...]

# %%
# compute a 'stable' mapping (1:1 mapping)
stable = m.get_mapping(bcs, allow_collisions=False)
# compute an 'unstable' mapping that allows 1:n and n:1 matches
unstable = m.get_mapping(bcs, allow_collisions=True)

# loop through and print the stable/unstable matches
for k,v in unstable.items():
    print(f"{k}:\n\tunstable: {v}\n\tstable: {stable.get(k)}")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1121/1121 [00:00<00:00, 3263.27it/s]
# chilled water delta temp sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Differential_Temperature_Setpoint'), 0.19118059)
# 	stable: https://brickschema.org/schema/Brick#Chilled_Water_Differential_Temperature_Sensor
# temp sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Temperature_Deadband_Setpoint'), 0.22695565)
# 	stable: https://brickschema.org/schema/Brick#Core_Temperature_Sensor
# water pressure sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Pressure_Status'), 0.21616995)
# 	stable: https://brickschema.org/schema/Brick#Hot_Water_Differential_Pressure_Sensor
# chilled water leaving temp sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Medium_Temperature_Hot_Water_Temperature_Load_Shed_Status'), 0.20692575)
# 	stable: https://brickschema.org/schema/Brick#Leaving_Chilled_Water_Temperature_Sensor
# weather air feelsLike sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hail_Sensor'), 0.2049647)
# 	stable: https://brickschema.org/schema/Brick#Warmest_Zone_Air_Temperature_Sensor
# zone air temp unocc cooling sp point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Cooling_Temperature_Deadband_Setpoint'), 0.20749497)
# 	stable: https://brickschema.org/schema/Brick#Unoccupied_Cooling_Zone_Air_Temperature_Setpoint
# controller device:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Remotely_On_Off_Status'), 0.2578795)
# 	stable: https://brickschema.org/schema/Brick#Interface
# hot water header point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Hot_Water_Temperature_Setpoint'), 0.19901949)
# 	stable: https://brickschema.org/schema/Brick#Hot_Water_Supply_Flow_Setpoint
# chilled water cool valve cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Cooling_Mode_Status'), 0.2149679)
# 	stable: https://brickschema.org/schema/Brick#Cooling_Enable_Command
# ventilation air humidity sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Low_Humidity_Alarm'), 0.18597782)
# 	stable: https://brickschema.org/schema/Brick#Zone_Air_Humidity_Sensor
# alarm sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Emergency_Push_Button_Status'), 0.2547906)
# 	stable: https://brickschema.org/schema/Brick#Alarm
# mixed fan enable cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Enable_Command'), 0.21763462)
# 	stable: https://brickschema.org/schema/Brick#Enable_Command
# air flow sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Low_Air_Flow_Alarm'), 0.19783437)
# 	stable: https://brickschema.org/schema/Brick#Air_Flow_Sensor
# fan vfd speed cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Speed_Reset_Command'), 0.23896801)
# 	stable: https://brickschema.org/schema/Brick#Speed_Command
# chilled water header pressure sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Differential_Pressure_Load_Shed_Status'), 0.22211581)
# 	stable: https://brickschema.org/schema/Brick#Chilled_Water_Static_Pressure_Setpoint
# ground water flow sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Deionised_Water_Conductivity_Sensor'), 0.19456589)
# 	stable: https://brickschema.org/schema/Brick#Hot_Water_Discharge_Flow_Sensor
# water level sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Ammonia_Sensor'), 0.21512723)
# 	stable: https://brickschema.org/schema/Brick#Water_Level_Sensor
# discharge air dewPoint sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Differential_Discharge_Return_Water_Temperature_Sensor'), 0.18171322)
# 	stable: https://brickschema.org/schema/Brick#Return_Air_Dewpoint_Sensor
# hot water entering temp sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Return_Temperature_Sensor'), 0.18301821)
# 	stable: https://brickschema.org/schema/Brick#Entering_High_Temperature_Hot_Water_Temperature_Sensor
# zone air pm10 concentration sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#PM10_Sensor'), 0.16755778)
# 	stable: https://brickschema.org/schema/Brick#PM10_Level_Sensor
# light illuminance sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Lighting'), 0.21868843)
# 	stable: https://brickschema.org/schema/Brick#Luminance_Sensor
# chilled water delta flow point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Safety_Shower'), 0.25595057)
# 	stable: https://brickschema.org/schema/Brick#Chilled_Water_Flow_Setpoint
# valve cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Valve_Command'), 0.17003012)
# 	stable: https://brickschema.org/schema/Brick#Valve_Position_Command
# pump enable cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Run_Enable_Command'), 0.23660666)
# 	stable: https://brickschema.org/schema/Brick#System_Enable_Command
# chilled water bypass flow sp point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Bypass_Water_Flow_Setpoint'), 0.18991566)
# 	stable: https://brickschema.org/schema/Brick#Bypass_Water_Flow_Setpoint
# total ac elec demand sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Demand_Sensor'), 0.19608873)
# 	stable: https://brickschema.org/schema/Brick#Demand_Sensor
# outside air temp sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Low_Supply_Air_Temperature_Alarm'), 0.20762992)
# 	stable: https://brickschema.org/schema/Brick#Outside_Air_Temperature_Sensor
# zone air temp standby heating sp point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Effective_Heating_Zone_Air_Temperature_Setpoint'), 0.19373071)
# 	stable: https://brickschema.org/schema/Brick#Standby_Heating_Zone_Air_Temperature_Setpoint
# chilled water leaving flow sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Water_Flow_Setpoint'), 0.18449026)
# 	stable: https://brickschema.org/schema/Brick#Leaving_Chilled_Water_Flow_Sensor
# outside air enthalpy sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Enthalpy_Sensor'), 0.19315588)
# 	stable: https://brickschema.org/schema/Brick#Outside_Air_Enthalpy_Sensor
# water volume sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Building_Water_Meter'), 0.22199553)
# 	stable: https://brickschema.org/schema/Brick#Collection_Basin_Water_Level_Sensor
# chilled water leaving pressure sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Water_Differential_Pressure_Deadband_Setpoint'), 0.19821978)
# 	stable: https://brickschema.org/schema/Brick#Chilled_Water_Differential_Pressure_Sensor
# zone air temp sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Effective_Zone_Air_Temperature_Setpoint'), 0.19968158)
# 	stable: https://brickschema.org/schema/Brick#Zone_Air_Temperature_Sensor
# hvacMode sp point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Preheat_Demand_Setpoint'), 0.24506229)
# 	stable: https://brickschema.org/schema/Brick#Occupied_Heating_Supply_Air_Flow_Setpoint
# weather solar irradiance sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Solar_Thermal_Collector'), 0.22374928)
# 	stable: https://brickschema.org/schema/Brick#Solar_Zenith_Angle_Sensor
# outside air pressure sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Building_Air_Static_Pressure_Setpoint'), 0.19700491)
# 	stable: https://brickschema.org/schema/Brick#Air_Differential_Pressure_Sensor
# occupancy sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Locally_On_Off_Status'), 0.25818336)
# 	stable: https://brickschema.org/schema/Brick#Occupancy_Sensor
# phase:"A" apparent ac elec power sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Peak_Demand_Sensor'), 0.1911689)
# 	stable: https://brickschema.org/schema/Brick#Power_Factor_Sensor
# chilled water header flow sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Supply_Flow_Sensor'), 0.14092839)
# 	stable: https://brickschema.org/schema/Brick#Chilled_Water_Flow_Sensor
# point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Status'), 0.23835349)
# 	stable: https://brickschema.org/schema/Brick#Point
# exhaust air pressure sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Exhaust_Air_Static_Pressure_Setpoint'), 0.1594103)
# 	stable: https://brickschema.org/schema/Brick#Exhaust_Air_Static_Pressure_Sensor
# filter sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Filter_Status'), 0.2836948)
# 	stable: https://brickschema.org/schema/Brick#Final_Filter
# zone air pm25 concentration sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#PM2.5_Sensor'), 0.16564173)
# 	stable: https://brickschema.org/schema/Brick#PM2.5_Level_Sensor
# outside air humidity sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Humidity_Deadband_Setpoint'), 0.20964563)
# 	stable: https://brickschema.org/schema/Brick#Outside_Air_Humidity_Sensor
# chilled water entering temp sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Water_Temperature_Deadband_Setpoint'), 0.19471908)
# 	stable: https://brickschema.org/schema/Brick#Entering_Chilled_Water_Temperature_Sensor
# outside steam heat valve cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heating_Enable_Command'), 0.2102508)
# 	stable: https://brickschema.org/schema/Brick#Boiler_Command
# condenser water entering temp sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Condenser_Water_Temperature_Setpoint'), 0.18051219)
# 	stable: https://brickschema.org/schema/Brick#Entering_Condenser_Water_Temperature_Sensor
# mixed damper sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Deadband_Setpoint'), 0.26375133)
# 	stable: https://brickschema.org/schema/Brick#Damper_Position_Setpoint
# ventilation air pressure sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Static_Pressure_Deadband_Setpoint'), 0.19978106)
# 	stable: https://brickschema.org/schema/Brick#Supply_Air_Velocity_Pressure_Sensor
# ventilation air temp sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heating_Supply_Air_Temperature_Deadband_Setpoint'), 0.209809)
# 	stable: https://brickschema.org/schema/Brick#Intake_Air_Temperature_Sensor
# condenser water entering flow sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Condenser_Water_Flow_Sensor'), 0.13192236)
# 	stable: https://brickschema.org/schema/Brick#Entering_Condenser_Water_Flow_Sensor
# water flow sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Flow_Setpoint'), 0.19878525)
# 	stable: https://brickschema.org/schema/Brick#Water_Flow_Sensor
# ventilation fan enable sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Enable_Status'), 0.25297582)
# 	stable: https://brickschema.org/schema/Brick#Low_Outside_Air_Temperature_Enable_Differential_Sensor
# ventilation air flow sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Supply_Air_Flow_Setpoint'), 0.20668113)
# 	stable: https://brickschema.org/schema/Brick#Supply_Air_Flow_Sensor
# return air pressure sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Air_Differential_Pressure_Sensor'), 0.16743046)
# 	stable: https://brickschema.org/schema/Brick#Return_Air_Differential_Pressure_Sensor
# steam delta pressure sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Differential_Pressure_Deadband_Setpoint'), 0.22079724)
# 	stable: https://brickschema.org/schema/Brick#Filter_Differential_Pressure_Sensor
# total reactive ac elec power sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heating_Demand_Sensor'), 0.20194304)
# 	stable: https://brickschema.org/schema/Brick#Reactive_Energy_Sensor
# discharge point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Disconnect_Switch'), 0.24273211)
# 	stable: https://brickschema.org/schema/Brick#Discharge_Water_Flow_Setpoint
# ventilation fan vfd speed cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Speed_Status'), 0.21601605)
# 	stable: https://brickschema.org/schema/Brick#Fan_Speed_Command
# space:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hold_Status'), 0.2641852)
# 	stable: https://brickschema.org/schema/Brick#Space_Heater
# coolingTower equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Occupied_Cooling_Mode_Status'), 0.22321838)
# 	stable: https://brickschema.org/schema/Brick#Cooling_Tower
# phase:"A" ac elec volt angle sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Switch_Status'), 0.2599718)
# 	stable: https://brickschema.org/schema/Brick#Angle_Sensor
# hot water header temp sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Domestic_Hot_Water_Supply_Temperature_Sensor'), 0.18787616)
# 	stable: https://brickschema.org/schema/Brick#High_Temperature_Hot_Water_Supply_Temperature_Sensor
# zone air temp standby cooling sp point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Cooling_Zone_Air_Temperature_Setpoint'), 0.18153894)
# 	stable: https://brickschema.org/schema/Brick#Standby_Cooling_Zone_Air_Temperature_Setpoint
# steam leaving valve sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Valve_Status'), 0.21234405)
# 	stable: https://brickschema.org/schema/Brick#Steam_Usage_Sensor
# zone air temp occ heating sp point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Occupied_Air_Temperature_Heating_Setpoint'), 0.19369757)
# 	stable: https://brickschema.org/schema/Brick#Occupied_Heating_Zone_Air_Temperature_Setpoint
# zone air temp occ cooling sp point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Effective_Air_Temperature_Cooling_Setpoint'), 0.20311171)
# 	stable: https://brickschema.org/schema/Brick#Occupied_Cooling_Zone_Air_Temperature_Setpoint
# ventilation fan vfd freq cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#VFD_Enable_Command'), 0.17124778)
# 	stable: https://brickschema.org/schema/Brick#Fan_VFD
# ventilation chilled water cool valve cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Cooling_Mode_Status'), 0.21889406)
# 	stable: https://brickschema.org/schema/Brick#Cooling_Valve
# steam leaving pump alarm sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Emergency_Power_Off_System_Activated_By_Leak_Detection_System_Status'), 0.20938414)
# 	stable: https://brickschema.org/schema/Brick#Valve_Position_Alarm
# outside air co2 concentration sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Radon_Concentration_Sensor'), 0.20407403)
# 	stable: https://brickschema.org/schema/Brick#Outside_Air_CO2_Sensor
# phase:"A" ac elec volt thd sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#System_Shutdown_Status'), 0.27461392)
# 	stable: https://brickschema.org/schema/Brick#Voltage_Sensor
# faceBypass cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Disable_Status'), 0.27472168)
# 	stable: https://brickschema.org/schema/Brick#Bypass_Command
# phase:"A" ac elec volt magnitude sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Last_Fault_Code_Status'), 0.27383423)
# 	stable: https://brickschema.org/schema/Brick#Electric_Power_Sensor
# return air humidity sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Air_Grains_Sensor'), 0.18327278)
# 	stable: https://brickschema.org/schema/Brick#Return_Air_Humidity_Sensor
# zone air temp unocc heating sp point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Heating_Temperature_Deadband_Setpoint'), 0.20600748)
# 	stable: https://brickschema.org/schema/Brick#Unoccupied_Heating_Zone_Air_Temperature_Setpoint
# return air temp sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Low_Return_Air_Temperature_Alarm'), 0.21337277)
# 	stable: https://brickschema.org/schema/Brick#Return_Air_Temperature_Sensor
# ventilation fan alarm sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Low_Supply_Air_Flow_Alarm'), 0.20459306)
# 	stable: https://brickschema.org/schema/Brick#Air_Flow_Alarm
# light luminous flux sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Luminaire_Driver'), 0.21826214)
# 	stable: https://brickschema.org/schema/Brick#Illuminance_Sensor
# reheat cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Preheat_Command'), 0.21023482)
# 	stable: https://brickschema.org/schema/Brick#Preheat_Command
# return air co2 concentration sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Air_CO2_Setpoint'), 0.19076252)
# 	stable: https://brickschema.org/schema/Brick#Return_Air_CO2_Sensor
# zone air pm01 concentration sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#PM1_Sensor'), 0.18641853)
# 	stable: https://brickschema.org/schema/Brick#PM1_Level_Sensor
# phase:"A" ac elec volt imbalance sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Imbalance_Sensor'), 0.14318138)
# 	stable: https://brickschema.org/schema/Brick#Voltage_Imbalance_Sensor
# fan vfd freq cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Min_Frequency_Command'), 0.22935867)
# 	stable: https://brickschema.org/schema/Brick#VFD_Enable_Command
# phase:"A" ac elec current magnitude sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Load_Current_Sensor'), 0.19879282)
# 	stable: https://brickschema.org/schema/Brick#Photovoltaic_Current_Output_Sensor
# water temp sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Water_Temperature_Setpoint'), 0.20887578)
# 	stable: https://brickschema.org/schema/Brick#Water_Temperature_Sensor
# discharge damper cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Standby_Load_Shed_Command'), 0.24629402)
# 	stable: https://brickschema.org/schema/Brick#Damper_Command
# phase:"A" net ac elec active energy sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Load_Shed_Status'), 0.26075697)
# 	stable: https://brickschema.org/schema/Brick#Energy_Generation_Sensor
# damper sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Damper_Position_Sensor'), 0.16027325)
# 	stable: https://brickschema.org/schema/Brick#Damper_Position_Sensor
# pressure sp point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Static_Pressure_Deadband_Setpoint'), 0.21245825)
# 	stable: https://brickschema.org/schema/Brick#Pressure_Setpoint
# discharge hot water heat valve cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Enable_Differential_Temperature_Command'), 0.22657132)
# 	stable: https://brickschema.org/schema/Brick#Hot_Water_Discharge_Flow_Setpoint
# discharge air flow sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Emergency_Air_Flow_System_Status'), 0.22490764)
# 	stable: https://brickschema.org/schema/Brick#Exhaust_Air_Stack_Flow_Sensor
# hot water leaving temp sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Medium_Temperature_Hot_Water_Temperature_High_Reset_Setpoint'), 0.18705344)
# 	stable: https://brickschema.org/schema/Brick#Leaving_Hot_Water_Temperature_Setpoint
# exhaust air flow sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Exhaust_Air_Stack_Flow_Sensor'), 0.15707523)
# 	stable: https://brickschema.org/schema/Brick#Exhaust_Air_Flow_Sensor
# hot water entering point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Medium_Temperature_Hot_Water_Temperature_Load_Shed_Status'), 0.19355118)
# 	stable: https://brickschema.org/schema/Brick#Entering_Hot_Water_Temperature_Setpoint
# vfd speed sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Differential_Speed_Sensor'), 0.21479464)
# 	stable: https://brickschema.org/schema/Brick#Differential_Speed_Sensor
# exhaust air dewPoint sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Exhaust_Air_Dewpoint_Sensor'), 0.11908358)
# 	stable: https://brickschema.org/schema/Brick#Exhaust_Air_Dewpoint_Sensor
# hot water entering pressure sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Medium_Temperature_Hot_Water_Differential_Pressure_Setpoint'), 0.184663)
# 	stable: https://brickschema.org/schema/Brick#Entering_Medium_Temperature_Hot_Water_Temperature_Sensor
# weather wind direction sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Direction_Status'), 0.2331422)
# 	stable: https://brickschema.org/schema/Brick#Wind_Direction_Sensor
# discharge air pressure sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Differential_Pressure_Setpoint'), 0.1822353)
# 	stable: https://brickschema.org/schema/Brick#Supply_Air_Differential_Pressure_Sensor
# exhaust air flow sp point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Exhaust_Air_Stack_Flow_Setpoint'), 0.1783899)
# 	stable: https://brickschema.org/schema/Brick#Exhaust_Air_Flow_Setpoint
# return air enthalpy sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Air_Enthalpy_Sensor'), 0.15699452)
# 	stable: https://brickschema.org/schema/Brick#Return_Air_Enthalpy_Sensor
# outside air dewPoint sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Outside_Air_Dewpoint_Sensor'), 0.11200172)
# 	stable: https://brickschema.org/schema/Brick#Outside_Air_Dewpoint_Sensor
# exhaust air humidity sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Exhaust_Air_Humidity_Setpoint'), 0.13961625)
# 	stable: https://brickschema.org/schema/Brick#Exhaust_Air_Humidity_Sensor
# steam bypass flow sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Bypass_Air_Flow_Sensor'), 0.17068022)
# 	stable: https://brickschema.org/schema/Brick#Bypass_Water_Flow_Sensor
# condenser water leaving temp sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Discharge_Condenser_Water_Temperature_Sensor'), 0.16712338)
# 	stable: https://brickschema.org/schema/Brick#Leaving_Condenser_Water_Temperature_Sensor
# chilled water entering flow sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Water_Flow_Setpoint'), 0.19385755)
# 	stable: https://brickschema.org/schema/Brick#Entering_Chilled_Water_Flow_Sensor
# ground water volume sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Building_Gas_Meter'), 0.23950481)
# 	stable: https://brickschema.org/schema/Brick#Water_Usage_Sensor
# weather wind speed sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Wind_Speed_Sensor'), 0.15439397)
# 	stable: https://brickschema.org/schema/Brick#Wind_Speed_Sensor
# zone air tvoc concentration sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#TVOC_Sensor'), 0.19657856)
# 	stable: https://brickschema.org/schema/Brick#TVOC_Level_Sensor
# phase:"A" ac elec current angle sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Current_Ratio_Setpoint'), 0.22342753)
# 	stable: https://brickschema.org/schema/Brick#Current_Sensor
# mixed air temp sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Mixed_Air_Temperature_Setpoint'), 0.16742676)
# 	stable: https://brickschema.org/schema/Brick#Mixed_Air_Temperature_Sensor
# condenser water bypass point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Pre_Filter'), 0.23494786)
# 	stable: https://brickschema.org/schema/Brick#Condenser_Water_Bypass_Valve
# ventilation heatingCoil equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Heating_Mode_Status'), 0.24163002)
# 	stable: https://brickschema.org/schema/Brick#HVAC_Equipment
# total net ac elec active energy sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Energy_Sensor'), 0.19252563)
# 	stable: https://brickschema.org/schema/Brick#Active_Power_Sensor
# return hot water heat valve cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Domestic_Hot_Water_System_Enable_Command'), 0.17713803)
# 	stable: https://brickschema.org/schema/Brick#Hot_Water_System_Enable_Command
# fan enable sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Adjust_Sensor'), 0.22670764)
# 	stable: https://brickschema.org/schema/Brick#Fan_Status
# hot water header pressure sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Differential_Pressure_Setpoint'), 0.18001997)
# 	stable: https://brickschema.org/schema/Brick#Medium_Temperature_Hot_Water_Differential_Pressure_Sensor
# chilled water header temp sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Cooling_Temperature_Setpoint'), 0.19100755)
# 	stable: https://brickschema.org/schema/Brick#Chilled_Water_Temperature_Sensor
# chilled water header pump alarm sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#No_Water_Alarm'), 0.1943124)
# 	stable: https://brickschema.org/schema/Brick#High_Head_Pressure_Alarm
# return steam heat valve cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Disable_Fixed_Enthalpy_Command'), 0.22559941)
# 	stable: https://brickschema.org/schema/Brick#Heating_Command
# discharge chilled water cool valve cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Fault_Reset_Command'), 0.24894685)
# 	stable: https://brickschema.org/schema/Brick#Discharge_Chilled_Water_Temperature_Setpoint
# exhaust air dewPoint sp point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Exhaust_Air_Stack_Flow_Deadband_Setpoint'), 0.19612855)
# 	stable: https://brickschema.org/schema/Brick#Exhaust_Air_Differential_Pressure_Setpoint
# hot water entering flow sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Hot_Water_Flow_Sensor'), 0.13856065)
# 	stable: https://brickschema.org/schema/Brick#Entering_Hot_Water_Flow_Sensor
# outside damper cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Lead_Lag_Command'), 0.24042344)
# 	stable: https://brickschema.org/schema/Brick#Damper_Position_Command
# steam leaving valve cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Steam_On_Off_Command'), 0.20016497)
# 	stable: https://brickschema.org/schema/Brick#Steam_On_Off_Command
# dessicantDehumidifier cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Dehumidification_Start_Stop_Status'), 0.20241523)
# 	stable: https://brickschema.org/schema/Brick#Humidify_Command
# pump point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Pump_On_Off_Status'), 0.21379924)
# 	stable: https://brickschema.org/schema/Brick#Pump_Status
# weather air wetBulb sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Air_Wet_Bulb_Temperature_Sensor'), 0.14842898)
# 	stable: https://brickschema.org/schema/Brick#Outside_Air_Wet_Bulb_Temperature_Sensor
# ventilation air co2 concentration sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#CO_Level_Sensor'), 0.1725294)
# 	stable: https://brickschema.org/schema/Brick#CO2_Level_Sensor
# valve sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Valve_Position_Sensor'), 0.17126459)
# 	stable: https://brickschema.org/schema/Brick#Valve_Position_Sensor
# phase:"A" reactive ac elec power sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Reactive_Energy_Sensor'), 0.15875345)
# 	stable: https://brickschema.org/schema/Brick#Reactive_Power_Sensor
# phase:"A" ac elec current imbalance sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Current_Imbalance_Sensor'), 0.14076096)
# 	stable: https://brickschema.org/schema/Brick#Current_Imbalance_Sensor
# hot water leaving point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Hot_Water_Temperature_Load_Shed_Status'), 0.20176172)
# 	stable: https://brickschema.org/schema/Brick#Leaving_Domestic_Hot_Water_Temperature_Setpoint
# fan alarm sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unit_Failure_Alarm'), 0.2122432)
# 	stable: https://brickschema.org/schema/Brick#Standby_Fan
# mixed air dewPoint sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Differential_Setpoint'), 0.22372502)
# 	stable: https://brickschema.org/schema/Brick#Differential_Air_Temperature_Setpoint
# fan enable cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Fan_Command'), 0.19136524)
# 	stable: https://brickschema.org/schema/Brick#Fan_Command
# condenser water bypass pump enable sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Pre_Filter_Status'), 0.28569156)
# 	stable: https://brickschema.org/schema/Brick#Overridden_On_Status
# outside air flow sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Intake_Air_Filter'), 0.20680654)
# 	stable: https://brickschema.org/schema/Brick#Outside_Air_Flow_Sensor
# mixed air humidity sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Mixed_Air_Filter'), 0.2104953)
# 	stable: https://brickschema.org/schema/Brick#Mixed_Air_Humidity_Sensor
# hot water leaving flow sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Hot_Water_Flow_Sensor'), 0.14733857)
# 	stable: https://brickschema.org/schema/Brick#Leaving_Hot_Water_Flow_Sensor
# equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Lockout_Status'), 0.24805033)
# 	stable: https://brickschema.org/schema/Brick#Equipment
# phase:"A" active ac elec power sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Lead_Lag_Status'), 0.26240855)
# 	stable: https://brickschema.org/schema/Brick#Power_Sensor
# exhaust fan enable cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Exhaust_Fan_Disable_Command'), 0.17800832)
# 	stable: None
# hot water header flow sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Return_Flow_Sensor'), 0.17316276)
# 	stable: https://brickschema.org/schema/Brick#Hot_Water_Flow_Sensor
# pressure sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Velocity_Pressure_Sensor'), 0.17577982)
# 	stable: https://brickschema.org/schema/Brick#Pressure_Sensor
# coolingCoil equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Dry_Cooler'), 0.20267344)
# 	stable: https://brickschema.org/schema/Brick#Cooling_Coil
# discharge air temp sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Discharge_Water_Temperature_Sensor'), 0.18325657)
# 	stable: https://brickschema.org/schema/Brick#Heat_Exchanger_Discharge_Water_Temperature_Sensor
# chilled water leaving pump alarm sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Loss_Alarm'), 0.19802272)
# 	stable: https://brickschema.org/schema/Brick#Leaving_Water_Temperature_Alarm
# humidifier equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Humidification_Start_Stop_Status'), 0.222736)
# 	stable: https://brickschema.org/schema/Brick#Humidifier
# hot water delta pressure sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Differential_Pressure_Deadband_Setpoint'), 0.19363177)
# 	stable: https://brickschema.org/schema/Brick#Hot_Water_Differential_Pressure_Setpoint
# mixed heatingCoil equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heating_Mode_Status'), 0.23368877)
# 	stable: https://brickschema.org/schema/Brick#Hot_Water_Coil
# weather air dewPoint sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Dewpoint_Setpoint'), 0.1589657)
# 	stable: https://brickschema.org/schema/Brick#Dewpoint_Sensor
# condenser refrig pressure sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Low_Suction_Pressure_Alarm'), 0.1961531)
# 	stable: https://brickschema.org/schema/Brick#Low_Suction_Pressure_Alarm
# condenser water leaving flow sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Condenser_Water_Flow_Sensor'), 0.16936779)
# 	stable: https://brickschema.org/schema/Brick#Leaving_Condenser_Water_Flow_Sensor
# stage:1 cool run cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Run_Status'), 0.25341177)
# 	stable: https://brickschema.org/schema/Brick#Run_Status
# water pump alarm sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Alarm'), 0.1893124)
# 	stable: https://brickschema.org/schema/Brick#Water_Alarm
# condensate entering pump alarm sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Condensate_Leak_Alarm'), 0.16679692)
# 	stable: https://brickschema.org/schema/Brick#Condensate_Leak_Alarm
# chilled water leaving point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Chilled_Water_Flow_Setpoint'), 0.1446575)
# 	stable: https://brickschema.org/schema/Brick#Leaving_Chilled_Water_Temperature_Setpoint
# ventilation fan vfd freq sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heat_Sink_Temperature_Sensor'), 0.19686753)
# 	stable: https://brickschema.org/schema/Brick#Heat_Sink_Temperature_Sensor
# ventilation coolingCoil equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Computer_Room_Air_Conditioning'), 0.20089054)
# 	stable: https://brickschema.org/schema/Brick#Direct_Expansion_Cooling_Coil
# outside damper actuator equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Open_Close_Status'), 0.2421059)
# 	stable: https://brickschema.org/schema/Brick#Damper
# pump vfd speed cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Pump_Command'), 0.17716706)
# 	stable: https://brickschema.org/schema/Brick#Pump_Command
# chilled water entering pump alarm sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Short_Cycle_Alarm'), 0.213036)
# 	stable: https://brickschema.org/schema/Brick#Entering_Water_Temperature_Alarm
# evaporator refrig pressure sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Refrigerant_Level_Sensor'), 0.18358016)
# 	stable: https://brickschema.org/schema/Brick#Refrigerant_Level_Sensor
# return stage:1 heat run cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Stages_Status'), 0.2270543)
# 	stable: https://brickschema.org/schema/Brick#Stage_Enable_Command
# load cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Load_Shed_Command'), 0.2605512)
# 	stable: https://brickschema.org/schema/Brick#Position_Command
# humidifier enable cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Enable_Fixed_Temperature_Command'), 0.22432488)
# 	stable: https://brickschema.org/schema/Brick#Humidifier_Fault_Status
# load sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Load_Setpoint'), 0.22583872)
# 	stable: https://brickschema.org/schema/Brick#Load_Setpoint
# flue air co2 concentration sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Formaldehyde_Level_Sensor'), 0.1861605)
# 	stable: https://brickschema.org/schema/Brick#CO_Level_Sensor
# discharge air dewPoint sp point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Air_Differential_Pressure_Setpoint'), 0.18572533)
# 	stable: https://brickschema.org/schema/Brick#Supply_Air_Differential_Pressure_Setpoint
# occupied sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Contact_Sensor'), 0.20313013)
# 	stable: https://brickschema.org/schema/Brick#Motion_Sensor
# zone air hvacMode sp point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Air_Handling_Unit'), 0.21622413)
# 	stable: https://brickschema.org/schema/Brick#Zone_Air_Conditioning_Mode_Status
# zone air no2 concentration sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#NO2_Level_Sensor'), 0.15583742)
# 	stable: https://brickschema.org/schema/Brick#NO2_Level_Sensor
# fan motor equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Motor_On_Off_Status'), 0.24152058)
# 	stable: https://brickschema.org/schema/Brick#Motor
# chilled water bypass pump enable cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_System_Enable_Command'), 0.15114892)
# 	stable: https://brickschema.org/schema/Brick#Chilled_Water_System_Enable_Command
# mixed fan vfd speed cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Speed_Mode_Status'), 0.25181252)
# 	stable: https://brickschema.org/schema/Brick#Rated_Speed_Setpoint
# ventilation air dewPoint sp point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Air_Plenum'), 0.22672158)
# 	stable: https://brickschema.org/schema/Brick#Air_Differential_Pressure_Setpoint
# chilled water entering point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Freeze_Status'), 0.24179709)
# 	stable: https://brickschema.org/schema/Brick#Entering_Chilled_Water_Flow_Setpoint
# chilled water entering pressure sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Water_Differential_Pressure_Deadband_Setpoint'), 0.196886)
# 	stable: https://brickschema.org/schema/Brick#Chilled_Water_Discharge_Temperature_Sensor
# chilled water bypass temp sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Disable_Fixed_Temperature_Command'), 0.2238751)
# 	stable: https://brickschema.org/schema/Brick#Supply_Chilled_Water_Temperature_Setpoint
# flue air humidity sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Humidifier_Fault_Status'), 0.20732754)
# 	stable: https://brickschema.org/schema/Brick#Bypass_Air_Humidity_Setpoint
# discharge steam heat valve cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Disable_Differential_Enthalpy_Command'), 0.22670335)
# 	stable: https://brickschema.org/schema/Brick#Discharge_Hot_Water_Temperature_Setpoint
# chilled water bypass valve cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Disable_Differential_Temperature_Command'), 0.21997434)
# 	stable: https://brickschema.org/schema/Brick#Differential_Pressure_Bypass_Valve
# return air flow sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Air_Filter'), 0.22080594)
# 	stable: https://brickschema.org/schema/Brick#Return_Air_Flow_Sensor
# fan vfd speed sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Motor_Speed_Sensor'), 0.21704495)
# 	stable: https://brickschema.org/schema/Brick#Motor_Speed_Sensor
# steam heatExchanger equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Baseboard_Radiator'), 0.21519923)
# 	stable: https://brickschema.org/schema/Brick#Condenser_Heat_Exchanger
# outside air enthalpy sp point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Enthalpy_Setpoint'), 0.20456475)
# 	stable: https://brickschema.org/schema/Brick#Enthalpy_Setpoint
# enable cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Box_Mode_Command'), 0.24746853)
# 	stable: https://brickschema.org/schema/Brick#Disable_Command
# air enthalpy sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Air_Enthalpy_Sensor'), 0.15951037)
# 	stable: https://brickschema.org/schema/Brick#Air_Enthalpy_Sensor
# exhaust air temp sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Exhaust_Air_Temperature_Sensor'), 0.15813088)
# 	stable: https://brickschema.org/schema/Brick#Exhaust_Air_Temperature_Sensor
# weather precipitation sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Rain_Duration_Sensor'), 0.19925529)
# 	stable: https://brickschema.org/schema/Brick#Weather_Station
# pump vfd freq sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Frequency_Setpoint'), 0.23181033)
# 	stable: https://brickschema.org/schema/Brick#Variable_Frequency_Drive
# zone air o3 concentration sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Ozone_Level_Sensor'), 0.16872692)
# 	stable: https://brickschema.org/schema/Brick#Ozone_Level_Sensor
# heatExchanger equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Evaporative_Heat_Exchanger'), 0.18460923)
# 	stable: https://brickschema.org/schema/Brick#Heat_Exchanger
# ventilation point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Gas_Distribution'), 0.23112363)
# 	stable: https://brickschema.org/schema/Brick#Constant_Air_Volume_Box
# economizer damper actuator equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Economizer_Damper'), 0.15095037)
# 	stable: https://brickschema.org/schema/Brick#Economizer_Damper
# outside fan equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Booster_Fan'), 0.18641186)
# 	stable: https://brickschema.org/schema/Brick#Booster_Fan
# heatingCoil equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Direct_Expansion_Heating_Coil'), 0.18132997)
# 	stable: https://brickschema.org/schema/Brick#Heating_Coil
# warm water flow thermal meter equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Building_Hot_Water_Meter'), 0.20215142)
# 	stable: https://brickschema.org/schema/Brick#Thermal_Power_Meter
# ventilation fan point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Fresh_Air_Fan'), 0.19568068)
# 	stable: https://brickschema.org/schema/Brick#Ceiling_Fan
# steam leaving pump point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Emergency_Wash_Station'), 0.24154842)
# 	stable: https://brickschema.org/schema/Brick#Steam_Baseboard_Radiator
# mixed equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Lighting_Equipment'), 0.23002708)
# 	stable: https://brickschema.org/schema/Brick#Sensor_Equipment
# outside coolingCoil equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Pre-Cooling_Air_Unit'), 0.19234806)
# 	stable: https://brickschema.org/schema/Brick#Coil
# outside duct equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Makeup_Air_Unit'), 0.20243824)
# 	stable: https://brickschema.org/schema/Brick#Dedicated_Outdoor_Air_System_Unit
# networking device:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Network_Video_Recorder'), 0.24085116)
# 	stable: https://brickschema.org/schema/Brick#Communication_Loss_Alarm
# outside heatingCoil equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Electric_Baseboard_Radiator'), 0.21682239)
# 	stable: https://brickschema.org/schema/Brick#Fan_Coil_Unit
# pump equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Pump'), 0.1630891)
# 	stable: https://brickschema.org/schema/Brick#Pump
# thermostat equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Thermostat'), 0.18983966)
# 	stable: https://brickschema.org/schema/Brick#Thermostat
# steam boiler equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Noncondensing_Natural_Gas_Boiler'), 0.18682319)
# 	stable: https://brickschema.org/schema/Brick#Boiler
# exhaust duct equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Fume_Hood'), 0.21170068)
# 	stable: https://brickschema.org/schema/Brick#Exhaust_Air_Stack_Flow_Deadband_Setpoint
# chilled water valve isolation cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Isolation_Valve'), 0.1982283)
# 	stable: https://brickschema.org/schema/Brick#Condenser_Water_Isolation_Valve
# chilled water heatExchanger equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Computer_Room_Air_Handler'), 0.20730418)
# 	stable: https://brickschema.org/schema/Brick#Chilled_Water_Coil
# water pump point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Drench_Hose'), 0.24025875)
# 	stable: https://brickschema.org/schema/Brick#Water_Pump
# makeup water entering valve actuator equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Makeup_Water_Valve'), 0.15904176)
# 	stable: https://brickschema.org/schema/Brick#Makeup_Water_Valve
# chilled water header valve sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Gas_Valve'), 0.23009634)
# 	stable: https://brickschema.org/schema/Brick#Chilled_Water_Return_Temperature_Sensor
# mixed damper actuator equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Damper'), 0.17860454)
# 	stable: https://brickschema.org/schema/Brick#Mixed_Damper
# chilled water header point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Active_Chilled_Beam'), 0.18910587)
# 	stable: https://brickschema.org/schema/Brick#Chilled_Water_Supply_Flow_Setpoint
# steam bypass pressure sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Differential_Pressure_Bypass_Valve'), 0.1871121)
# 	stable: https://brickschema.org/schema/Brick#Bypass_Air_Flow_Sensor
# exhaust point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Final_Filter'), 0.233814)
# 	stable: https://brickschema.org/schema/Brick#Exhaust_Air_Stack_Flow_Setpoint
# cool water flow thermal meter equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Thermal_Power_Meter'), 0.18260252)
# 	stable: https://brickschema.org/schema/Brick#Chilled_Water_Meter
# condenser water entering pump equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Condenser_Water_Pump'), 0.16536301)
# 	stable: https://brickschema.org/schema/Brick#Condenser_Water_Pump
# flowInverter equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Bus_Riser'), 0.24871188)
# 	stable: https://brickschema.org/schema/Brick#Inverter
# flue hot water heat valve cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Domestic_Hot_Water_Valve'), 0.17888266)
# 	stable: https://brickschema.org/schema/Brick#Hot_Water_Valve
# chilled water entering valve cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Valve'), 0.2042082)
# 	stable: https://brickschema.org/schema/Brick#Chilled_Water_Valve
# ventilation hot water heat valve cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#HVAC_Valve'), 0.20677757)
# 	stable: https://brickschema.org/schema/Brick#Reheat_Valve
# flue equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Fire_Safety_Equipment'), 0.22226536)
# 	stable: https://brickschema.org/schema/Brick#Fire_Safety_Equipment
# chilled water header pump point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Pump'), 0.1460734)
# 	stable: https://brickschema.org/schema/Brick#Chilled_Water_Pump
# steam leaving point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Steam_Distribution'), 0.18631357)
# 	stable: https://brickschema.org/schema/Brick#Steam_Distribution
# economizer equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Economizer'), 0.1575566)
# 	stable: https://brickschema.org/schema/Brick#Economizer
# discharge heatingCoil equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Switchgear'), 0.22702312)
# 	stable: https://brickschema.org/schema/Brick#Induction_Unit
# outside hot water heat valve cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Preheat_Hot_Water_Valve'), 0.19175082)
# 	stable: https://brickschema.org/schema/Brick#Enable_Hot_Water_System_Outside_Air_Temperature_Setpoint
# economizer heatingCoil equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Condensing_Natural_Gas_Boiler'), 0.17688024)
# 	stable: https://brickschema.org/schema/Brick#Condensing_Natural_Gas_Boiler
# condenser water entering valve sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Condenser_Water_Valve'), 0.16750443)
# 	stable: https://brickschema.org/schema/Brick#Condenser_Water_Valve
# hot water heatExchanger equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Radiator'), 0.18562764)
# 	stable: https://brickschema.org/schema/Brick#Heat_Wheel
# ventilation duct equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Air_Diffuser'), 0.20990694)
# 	stable: https://brickschema.org/schema/Brick#Dual_Duct_Air_Handling_Unit
# ventilation fan motor equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Fan'), 0.16765946)
# 	stable: https://brickschema.org/schema/Brick#Fan
# ventilation equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Filter'), 0.22862256)
# 	stable: https://brickschema.org/schema/Brick#Makeup_Air_Unit
# hot water mixing valve cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Thermostatic_Mixing_Valve'), 0.18521494)
# 	stable: https://brickschema.org/schema/Brick#Thermostatic_Mixing_Valve
# exhaust fan point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Exhaust_Fan'), 0.15442222)
# 	stable: https://brickschema.org/schema/Brick#Exhaust_Fan
# infiltration well equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Intrusion_Detection_Equipment'), 0.21778041)
# 	stable: https://brickschema.org/schema/Brick#Intrusion_Detection_Equipment
# outside fan point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Outside_Fan'), 0.15227944)
# 	stable: https://brickschema.org/schema/Brick#Outside_Fan
# steam bypass pump point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Bypass_Valve'), 0.16297722)
# 	stable: https://brickschema.org/schema/Brick#Bypass_Valve
# steam leaving valve actuator equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Valve'), 0.20212156)
# 	stable: https://brickschema.org/schema/Brick#Valve
# circ pump motor equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Compressor'), 0.21386439)
# 	stable: https://brickschema.org/schema/Brick#Compressor
# exhaust damper actuator equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Exhaust_Damper'), 0.16304249)
# 	stable: https://brickschema.org/schema/Brick#Exhaust_Damper
# chilled water header pump vfd freq sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Pump_VFD'), 0.17199183)
# 	stable: https://brickschema.org/schema/Brick#Pump_VFD
# chiller equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chiller'), 0.15456438)
# 	stable: https://brickschema.org/schema/Brick#Chiller
# hot water boiler equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Heater'), 0.18724918)
# 	stable: https://brickschema.org/schema/Brick#Natural_Gas_Boiler
# makeup water entering pipe equip:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Eye_Wash_Station'), 0.23689884)
# 	stable: https://brickschema.org/schema/Brick#Eye_Wash_Station
# perimeterHeat cmd point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Radiant_Panel'), 0.21924937)
# 	stable: https://brickschema.org/schema/Brick#Outside_Face_Surface_Temperature_Setpoint
# chilled water header pump vfd speed sensor point:
# 	unstable: (rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heat_Wheel_VFD'), 0.20732582)
# 	stable: https://brickschema.org/schema/Brick#Heat_Wheel_VFD

# %%
m.external_to_brick_mapping
# Out:
# {rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Differential_Temperature_Setpoint'): [('chilled water delta temp sensor point',
#    0.19118059),
#   ('water temp sensor point', 0.19473952),
#   ('chilled water header temp sensor point', 0.19523096),
#   ('chilled water delta temp point', 0.19701356),
#   ('chilled water entering temp sensor point', 0.19821191),
#   ('chilled water delta flow point', 0.19825143),
#   ('chilled water leaving temp sensor point', 0.20141846),
#   ('hot water delta temp sensor point', 0.20636845),
#   ('hot water header temp sensor point', 0.20742923),
#   ('chilled water bypass temp sensor point', 0.20902711),
#   ('chilled water delta flow sensor point', 0.20906842),
#   ('temp sensor point', 0.20934886),
#   ('hot water entering temp sensor point', 0.20998836),
#   ('chilled water entering temp sp point', 0.21088707),
#   ('condenser water entering temp sensor point', 0.21105224),
#   ('condenser water delta temp sensor point', 0.21210098),
#   ('chilled water header point', 0.21222126),
#   ('steam delta temp sensor point', 0.21275258),
#   ('chilled water header pressure sensor point', 0.2128334),
#   ('chilled water bypass temp sp point', 0.21335852)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Temperature_Differential_Reset_Setpoint'): [('temp sensor point',
#    0.2122848),
#   ('chilled water delta temp sensor point', 0.21551484),
#   ('chilled water header temp sensor point', 0.21606666),
#   ('outside air temp sensor point', 0.22192842),
#   ('temp sp point', 0.22217911),
#   ('chilled water leaving temp sensor point', 0.22260052),
#   ('chilled water entering temp sensor point', 0.2227357),
#   ('outside air dewPoint sensor point', 0.2237624),
#   ('water temp sensor point', 0.22438198),
#   ('chilled water bypass temp sensor point', 0.22478974),
#   ('steam leaving temp sensor point', 0.2250439),
#   ('weather air dewPoint sensor point', 0.22730553),
#   ('steam delta temp sensor point', 0.22780365),
#   ('chilled water header pressure sensor point', 0.22810167),
#   ('ventilation air dewPoint sensor point', 0.22886539),
#   ('weather daytime sensor point', 0.2289623),
#   ('chilled water delta flow sensor point', 0.2290383),
#   ('chilled water delta flow point', 0.22969902),
#   ('mixed air dewPoint sensor point', 0.22989273),
#   ('weather air temp sensor point', 0.23035002)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Differential_Pressure_Sensor'): [('water pressure sensor point',
#    0.17986876),
#   ('weather atmospheric pressure sensor point', 0.18094903),
#   ('pressure sensor point', 0.18321753),
#   ('circ pressure sensor point', 0.18722218),
#   ('outside air pressure sensor point', 0.18852973),
#   ('steam delta pressure sensor point', 0.18910575),
#   ('steam leaving pressure sensor point', 0.1893928),
#   ('ground water pressure sensor point', 0.19362497),
#   ('ventilation air pressure sensor point', 0.19527555),
#   ('discharge air pressure sensor point', 0.19630349),
#   ('mixed air pressure sensor point', 0.19648355),
#   ('chilled water header pressure sensor point', 0.19758332),
#   ('condenser water delta pressure sensor point', 0.1980679),
#   ('chilled water leaving pressure sensor point', 0.19893086),
#   ('steam bypass pressure sensor point', 0.19982105),
#   ('chilled water entering pressure sensor point', 0.2001962),
#   ('condenser water leaving pressure sensor point', 0.2037484),
#   ('condenser water entering pressure sensor point', 0.2061165),
#   ('air pressure sensor point', 0.20705116),
#   ('condensate entering pressure sensor point', 0.20720434)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heat_Exchanger_Leaving_Water_Temperature_Sensor'): [('chilled water leaving temp sensor point',
#    0.17236096),
#   ('condenser water leaving temp sensor point', 0.17733693),
#   ('hot water leaving temp sensor point', 0.18178141),
#   ('chilled water leaving flow sensor point', 0.18596369),
#   ('chilled water leaving pressure sensor point', 0.18644845),
#   ('chilled water leaving valve sensor point', 0.18808138),
#   ('hot water leaving valve sensor point', 0.19048035),
#   ('water temp sensor point', 0.19088858),
#   ('chilled water entering temp sensor point', 0.19141585),
#   ('chilled water header temp sensor point', 0.19187069),
#   ('hot water leaving pressure sensor point', 0.19339687),
#   ('condenser water entering temp sensor point', 0.19377804),
#   ('condenser water leaving pressure sensor point', 0.1946727),
#   ('chilled water leaving pump enable sensor point', 0.19502324),
#   ('hot water leaving flow sensor point', 0.19626683),
#   ('condenser water leaving valve sensor point', 0.1966874),
#   ('steam leaving temp sensor point', 0.19907016),
#   ('hot water entering temp sensor point', 0.1997447),
#   ('chilled water header pressure sensor point', 0.20089757),
#   ('chilled water header flow sensor point', 0.2011956)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heat_Sensor'): [('weather air feelsLike sensor point',
#    0.20285177),
#   ('temp sensor point', 0.20351619),
#   ('water temp sensor point', 0.21334463),
#   ('phase:"A" ac elec volt thd sensor point', 0.21363842),
#   ('hot water header temp sensor point', 0.21391338),
#   ('outside air temp sensor point', 0.21426493),
#   ('steam leaving temp sensor point', 0.21435559),
#   ('fan enable sensor point', 0.21668482),
#   ('phase:"A" ac elec volt magnitude sensor point', 0.216708),
#   ('phase:"A" ac elec volt angle sensor point', 0.21687543),
#   ('hot water entering temp sensor point', 0.21705168),
#   ('steam header temp sensor point', 0.21795297),
#   ('hot water header valve sensor point', 0.21879035),
#   ('weather daytime sensor point', 0.21953994),
#   ('phase:"A" net ac elec active energy sensor point', 0.22040284),
#   ('phase:"A" ac elec current angle sensor point', 0.22113657),
#   ('weather air temp sensor point', 0.22183663),
#   ('phase:"A" ac elec current thd sensor point', 0.22255594),
#   ('chilled water header temp sensor point', 0.2227698),
#   ('outside fan enable sensor point', 0.22349417)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Cooling_Temperature_Setpoint'): [('zone air temp unocc cooling sp point',
#    0.19939744),
#   ('zone air temp unocc heating sp point', 0.20328754),
#   ('chilled water header temp sensor point', 0.20750868),
#   ('chilled water leaving temp sensor point', 0.20812982),
#   ('chilled water entering temp sensor point', 0.21032232),
#   ('chilled water bypass temp sensor point', 0.2120316),
#   ('coolingTower equip', 0.21757096),
#   ('zone air temp occ cooling sp point', 0.21971071),
#   ('chilled water delta temp sensor point', 0.2200737),
#   ('zone air temp standby cooling sp point', 0.22129565),
#   ('chilled water header point', 0.22129852),
#   ('chilled water header pressure sensor point', 0.22307563),
#   ('chilled water delta temp point', 0.22413337),
#   ('temp sensor point', 0.22415334),
#   ('chilled water bypass temp sp point', 0.22437918),
#   ('temp sp point', 0.22462559),
#   ('ventilation chilled water cool valve cmd point', 0.22463357),
#   ('outside chilled water cool valve cmd point', 0.22576803),
#   ('chilled water bypass pressure sensor point', 0.22604454),
#   ('outside air temp sensor point', 0.22633559)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Pressure_Alarm'): [('water pressure sensor point',
#    0.19419003),
#   ('alarm sensor point', 0.19626999),
#   ('pump alarm sensor point', 0.19627094),
#   ('steam leaving pump alarm sensor point', 0.20057678),
#   ('water pump alarm sensor point', 0.2014606),
#   ('chilled water header pump alarm sensor point', 0.20287275),
#   ('weather atmospheric pressure sensor point', 0.20396781),
#   ('outside air pressure sensor point', 0.20570672),
#   ('chilled water bypass pump alarm sensor point', 0.21004343),
#   ('chilled water leaving pump alarm sensor point', 0.21078545),
#   ('fan alarm sensor point', 0.21088052),
#   ('ground water pressure sensor point', 0.21127099),
#   ('chilled water entering pump alarm sensor point', 0.21133703),
#   ('steam leaving pressure sensor point', 0.2117933),
#   ('steam header pump alarm sensor point', 0.21248287),
#   ('circ pressure sensor point', 0.21325707),
#   ('discharge air pressure sensor point', 0.21375751),
#   ('discharge fan alarm sensor point', 0.21393102),
#   ('outside fan alarm sensor point', 0.21414274),
#   ('ventilation air pressure sensor point', 0.2150287)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Maintenance_Mode_Command'): [('controller device',
#    0.2153309),
#   ('outside steam heat valve cmd point', 0.24320513),
#   ('valve cmd point', 0.24399835),
#   ('enable cmd point', 0.24645984),
#   ('discharge hot water heat valve cmd point', 0.24778289),
#   ('discharge steam heat valve cmd point', 0.24927384),
#   ('humidifier enable cmd point', 0.24948764),
#   ('discharge damper cmd point', 0.24960184),
#   ('discharge chilled water cool valve cmd point', 0.24966949),
#   ('ventilation chilled water cool valve cmd point', 0.2501136),
#   ('mixed steam heat valve cmd point', 0.25070256),
#   ('chilled water bypass valve cmd point', 0.2507254),
#   ('condensate entering valve cmd point', 0.25090653),
#   ('chilled water header valve cmd point', 0.2517029),
#   ('dessicantDehumidifier cmd point', 0.25174308),
#   ('fan enable cmd point', 0.25179744),
#   ('ventilation fan enable cmd point', 0.25223088),
#   ('ventilation hot water heat valve cmd point', 0.2523976),
#   ('chilled water cool valve cmd point', 0.25246352),
#   ('ventilation damper cmd point', 0.2526232)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Flow_Setpoint'): [('hot water header point',
#    0.18559474),
#   ('hot water header flow sensor point', 0.1870904),
#   ('discharge hot water heat valve cmd point', 0.19193918),
#   ('hot water header flow sp point', 0.19243997),
#   ('hot water entering point', 0.19309878),
#   ('flue hot water heat valve cmd point', 0.19348192),
#   ('return hot water heat valve cmd point', 0.1959024),
#   ('hot water entering flow sensor point', 0.19608581),
#   ('hot water entering flow sp point', 0.19660366),
#   ('chilled water delta flow point', 0.19716239),
#   ('outside hot water heat valve cmd point', 0.20099396),
#   ('chilled water entering flow sp point', 0.20156455),
#   ('hot water header temp sensor point', 0.20269799),
#   ('hot water delta flow sensor point', 0.20338815),
#   ('inlet hot water heat valve cmd point', 0.20450956),
#   ('ventilation hot water heat valve cmd point', 0.20453703),
#   ('hot water leaving flow sensor point', 0.2047962),
#   ('mixed hot water heat valve cmd point', 0.20521319),
#   ('hot water header valve sensor point', 0.2054398),
#   ('chilled water header flow sp point', 0.20596206)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Cooling_Mode_Status'): [('chilled water cool valve cmd point',
#    0.2149679),
#   ('ventilation chilled water cool valve cmd point', 0.2159574),
#   ('flue chilled water cool valve cmd point', 0.2165044),
#   ('outside chilled water cool valve cmd point', 0.21859604),
#   ('discharge chilled water cool valve cmd point', 0.21973586),
#   ('economizer chilled water cool valve cmd point', 0.22048998),
#   ('coolingCoil equip', 0.220626),
#   ('coolingTower equip', 0.22101593),
#   ('economizer stage:1 cool run cmd point', 0.22116804),
#   ('inlet chilled water cool valve cmd point', 0.22437239),
#   ('ventilation stage:1 cool run cmd point', 0.22781932),
#   ('mixed coolingCoil equip', 0.22912627),
#   ('mixed chilled water cool valve cmd point', 0.22991079),
#   ('return chilled water cool valve cmd point', 0.23102939),
#   ('economizer coolingCoil equip', 0.2311418),
#   ('exhaust chilled water cool valve cmd point', 0.23155493),
#   ('ventilation coolingCoil equip', 0.23200417),
#   ('cool water flow thermal meter equip', 0.23277563),
#   ('flue stage:1 cool run cmd point', 0.23283988),
#   ('outside coolingCoil equip', 0.23445427)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Humidity_Setpoint'): [('ventilation air humidity sensor point',
#    0.16307825),
#   ('outside air humidity sensor point', 0.17038369),
#   ('discharge air humidity sensor point', 0.17117387),
#   ('economizer air humidity sensor point', 0.17157507),
#   ('exhaust air humidity sensor point', 0.17272317),
#   ('weather air humidity sensor point', 0.17706954),
#   ('flue air humidity sensor point', 0.18039316),
#   ('inlet air humidity sensor point', 0.18096119),
#   ('mixed air humidity sensor point', 0.18104565),
#   ('ventilation air humidity sp point', 0.18214726),
#   ('air humidity sensor point', 0.18233824),
#   ('discharge air humidity sp point', 0.18354195),
#   ('return air humidity sensor point', 0.18505841),
#   ('outside air humidity sp point', 0.18686956),
#   ('economizer air humidity sp point', 0.18813276),
#   ('zone air humidity sensor point', 0.19066226),
#   ('ventilation air dewPoint sp point', 0.19086081),
#   ('ventilation air dewPoint sensor point', 0.19142252),
#   ('exhaust air humidity sp point', 0.19392323),
#   ('return air humidity sp point', 0.1942128)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Smoke_Detection_Alarm'): [('alarm sensor point',
#    0.19277483),
#   ('ventilation fan alarm sensor point', 0.20103145),
#   ('fan alarm sensor point', 0.20654207),
#   ('mixed fan alarm sensor point', 0.2075125),
#   ('exhaust fan alarm sensor point', 0.20976889),
#   ('flue fan alarm sensor point', 0.21174806),
#   ('pump alarm sensor point', 0.21256852),
#   ('steam leaving pump alarm sensor point', 0.21455318),
#   ('discharge fan alarm sensor point', 0.21599561),
#   ('outside fan alarm sensor point', 0.21996391),
#   ('chilled water header pump alarm sensor point', 0.22122651),
#   ('return fan alarm sensor point', 0.22148335),
#   ('water pump alarm sensor point', 0.22393191),
#   ('chilled water bypass pump alarm sensor point', 0.22539139),
#   ('steam header pump alarm sensor point', 0.2265153),
#   ('economizer fan alarm sensor point', 0.22709167),
#   ('steam bypass pump alarm sensor point', 0.22715008),
#   ('chilled water entering pump alarm sensor point', 0.22931278),
#   ('chilled water leaving pump alarm sensor point', 0.2298963),
#   ('occupancy sensor point', 0.23059398)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Enable_Command'): [('mixed fan enable cmd point',
#    0.21763462),
#   ('pump enable cmd point', 0.21917981),
#   ('enable cmd point', 0.22406119),
#   ('steam leaving pump enable cmd point', 0.22589165),
#   ('outside fan enable cmd point', 0.23231399),
#   ('exhaust fan enable cmd point', 0.23324144),
#   ('return fan enable cmd point', 0.23407859),
#   ('flue fan enable cmd point', 0.23633838),
#   ('discharge fan enable cmd point', 0.23634535),
#   ('ventilation fan enable cmd point', 0.23647511),
#   ('humidifier enable cmd point', 0.2371527),
#   ('circ pump enable cmd point', 0.23755771),
#   ('fan enable cmd point', 0.23824626),
#   ('steam bypass pump enable cmd point', 0.24028236),
#   ('water pump enable cmd point', 0.24046993),
#   ('faceBypass cmd point', 0.24055016),
#   ('steam header pump enable cmd point', 0.2419619),
#   ('inlet fan enable cmd point', 0.24235761),
#   ('economizer fan enable cmd point', 0.25199884),
#   ('valve cmd point', 0.2538073)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Low_Air_Flow_Alarm'): [('air flow sensor point',
#    0.19783437),
#   ('flue air flow sensor point', 0.19974297),
#   ('ventilation air flow sensor point', 0.20008284),
#   ('outside air flow sensor point', 0.20050484),
#   ('fan alarm sensor point', 0.20071995),
#   ('ventilation fan alarm sensor point', 0.20242214),
#   ('flue fan alarm sensor point', 0.2038725),
#   ('discharge air flow sensor point', 0.20522732),
#   ('discharge fan alarm sensor point', 0.2090624),
#   ('flue air pressure sensor point', 0.2108888),
#   ('alarm sensor point', 0.2120781),
#   ('exhaust fan alarm sensor point', 0.21235555),
#   ('ventilation air pressure sensor point', 0.21263254),
#   ('return air flow sensor point', 0.21321517),
#   ('chilled water leaving pump alarm sensor point', 0.2143051),
#   ('exhaust air flow sensor point', 0.21562487),
#   ('outside fan alarm sensor point', 0.21565479),
#   ('flue air dewPoint sensor point', 0.21572173),
#   ('pump alarm sensor point', 0.21628994),
#   ('air pressure sensor point', 0.21686798)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Rated_Speed_Setpoint'): [('fan vfd speed cmd point',
#    0.22516936),
#   ('ventilation fan vfd speed cmd point', 0.22971672),
#   ('mixed fan vfd speed cmd point', 0.23332173),
#   ('phase:"A" ac elec volt angle sensor point', 0.23405355),
#   ('fan vfd speed sensor point', 0.23477131),
#   ('steam bypass pump vfd speed cmd point', 0.2357766),
#   ('chilled water header pump vfd speed sensor point', 0.23583746),
#   ('phase:"A" ac elec volt magnitude sensor point', 0.23620069),
#   ('pump vfd speed cmd point', 0.23642176),
#   ('ventilation fan vfd speed sensor point', 0.2374534),
#   ('weather wind speed sensor point', 0.23810935),
#   ('phase:"A" ac elec volt thd sensor point', 0.23811817),
#   ('steam header pump vfd speed cmd point', 0.23859298),
#   ('steam bypass pump vfd speed sensor point', 0.23936224),
#   ('return fan vfd speed sensor point', 0.23969114),
#   ('steam header pump vfd speed sensor point', 0.24018848),
#   ('mixed fan vfd speed sensor point', 0.24140465),
#   ('steam leaving pump vfd speed cmd point', 0.24140549),
#   ('chilled water bypass pump vfd speed cmd point', 0.24156946),
#   ('economizer fan vfd speed sensor point', 0.24170458)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Differential_Pressure_Load_Shed_Reset_Status'): [('chilled water header pressure sensor point',
#    0.170573),
#   ('chilled water leaving pressure sensor point', 0.17706811),
#   ('chilled water entering pressure sensor point', 0.17905372),
#   ('chilled water bypass pressure sensor point', 0.17966455),
#   ('chilled water delta flow point', 0.18445367),
#   ('chilled water delta pressure point', 0.18517232),
#   ('chilled water header point', 0.18660653),
#   ('chilled water header pressure sp point', 0.18708885),
#   ('chilled water bypass pressure sp point', 0.18918437),
#   ('chilled water header flow sensor point', 0.18967342),
#   ('chilled water entering pressure sp point', 0.19122934),
#   ('chilled water leaving pressure sp point', 0.19134486),
#   ('chilled water header pump point', 0.19150668),
#   ('chilled water header temp sensor point', 0.19206893),
#   ('chilled water header valve sensor point', 0.19264925),
#   ('chilled water entering point', 0.1937877),
#   ('chilled water bypass point', 0.19420445),
#   ('chilled water bypass pump point', 0.19577515),
#   ('chilled water leaving point', 0.19588643),
#   ('chilled water header valve cmd point', 0.1964302)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Deionised_Water_Conductivity_Sensor'): [('ground water flow sensor point',
#    0.19456589),
#   ('water volume sensor point', 0.19570076),
#   ('water level sensor point', 0.19775414),
#   ('ground water volume sensor point', 0.20027477),
#   ('ground water pressure sensor point', 0.20033282),
#   ('water pressure sensor point', 0.20443058),
#   ('water flow sensor point', 0.20451051),
#   ('chilled water delta flow sensor point', 0.20706344),
#   ('water temp sensor point', 0.20756954),
#   ('chilled water entering pressure sensor point', 0.20852256),
#   ('chilled water entering flow sensor point', 0.21048272),
#   ('condenser water entering pressure sensor point', 0.21078628),
#   ('chilled water header flow sensor point', 0.2122423),
#   ('chilled water header pressure sensor point', 0.21248865),
#   ('chilled water entering pump enable sensor point', 0.21350169),
#   ('chilled water delta temp sensor point', 0.21379006),
#   ('chilled water entering valve sensor point', 0.21382236),
#   ('discharge air dewPoint sensor point', 0.2151112),
#   ('chilled water leaving pressure sensor point', 0.21536833),
#   ('chilled water leaving flow sensor point', 0.21543008)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Rain_Level_Sensor'): [('water level sensor point',
#    0.19325918),
#   ('weather precipitation sensor point', 0.19336158),
#   ('light level sensor point', 0.2008667),
#   ('water volume sensor point', 0.20109963),
#   ('ground water volume sensor point', 0.20185786),
#   ('weather cloudage sensor point', 0.20715314),
#   ('weather air feelsLike sensor point', 0.20719707),
#   ('ground water flow sensor point', 0.2074548),
#   ('weather atmospheric pressure sensor point', 0.20808887),
#   ('water flow sensor point', 0.21160644),
#   ('weather air wetBulb sensor point', 0.21249235),
#   ('water pressure sensor point', 0.21421015),
#   ('weather air dewPoint sensor point', 0.21554667),
#   ('flow sensor point', 0.2155484),
#   ('ground water pressure sensor point', 0.21608263),
#   ('weather weatherCond sensor point', 0.21608454),
#   ('level sensor point', 0.2186932),
#   ('weather visibility sensor point', 0.21900535),
#   ('phase:"A" ac elec volt magnitude sensor point', 0.21913189),
#   ('outside air humidity sensor point', 0.2197451)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Differential_Discharge_Return_Water_Temperature_Sensor'): [('discharge air dewPoint sensor point',
#    0.18171322),
#   ('discharge air temp sensor point', 0.18596673),
#   ('chilled water leaving temp sensor point', 0.1917404),
#   ('chilled water leaving flow sensor point', 0.19262958),
#   ('chilled water delta temp sensor point', 0.19282335),
#   ('water temp sensor point', 0.19335884),
#   ('discharge air enthalpy sensor point', 0.19508803),
#   ('chilled water leaving pressure sensor point', 0.19514948),
#   ('discharge air humidity sensor point', 0.19581461),
#   ('chilled water delta flow sensor point', 0.19617051),
#   ('chilled water header temp sensor point', 0.19633108),
#   ('water level sensor point', 0.19744593),
#   ('chilled water entering temp sensor point', 0.19806474),
#   ('chilled water header flow sensor point', 0.19830436),
#   ('chilled water header pressure sensor point', 0.19876987),
#   ('water volume sensor point', 0.1988132),
#   ('chilled water entering flow sensor point', 0.1991167),
#   ('ground water flow sensor point', 0.19915098),
#   ('discharge air flow sensor point', 0.19991082),
#   ('discharge air pressure sensor point', 0.20025074)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Differential_Temperature_Sensor'): [('hot water entering temp sensor point',
#    0.1667065),
#   ('hot water entering pressure sensor point', 0.17935878),
#   ('hot water header temp sensor point', 0.1807276),
#   ('hot water leaving temp sensor point', 0.18277717),
#   ('hot water entering valve sensor point', 0.18431127),
#   ('hot water delta temp sensor point', 0.18610936),
#   ('chilled water entering temp sensor point', 0.1865921),
#   ('condenser water entering temp sensor point', 0.18704534),
#   ('water temp sensor point', 0.18749356),
#   ('hot water entering flow sensor point', 0.19132638),
#   ('hot water leaving pressure sensor point', 0.19365263),
#   ('hot water header valve sensor point', 0.19386947),
#   ('chilled water delta temp sensor point', 0.19389659),
#   ('chilled water header temp sensor point', 0.19415164),
#   ('chilled water leaving temp sensor point', 0.19617546),
#   ('hot water entering point', 0.19622666),
#   ('steam leaving temp sensor point', 0.19718015),
#   ('hot water header pressure sensor point', 0.19740444),
#   ('warm water flow thermal meter equip', 0.19889969),
#   ('hot water leaving valve sensor point', 0.19962615)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#PM10_Level_Sensor'): [('zone air pm10 concentration sensor point',
#    0.1597879),
#   ('zone air pm01 concentration sensor point', 0.17474037),
#   ('zone air pm25 concentration sensor point', 0.17513627),
#   ('light level sensor point', 0.1756677),
#   ('water level sensor point', 0.20038682),
#   ('weather atmospheric pressure sensor point', 0.20275563),
#   ('weather air feelsLike sensor point', 0.2030366),
#   ('ventilation air dewPoint sensor point', 0.20542437),
#   ('weather air dewPoint sensor point', 0.20554948),
#   ('discharge air dewPoint sensor point', 0.20598704),
#   ('flue air dewPoint sensor point', 0.20728642),
#   ('light luminous flux sensor point', 0.20762342),
#   ('mixed air dewPoint sensor point', 0.20812619),
#   ('level sensor point', 0.20821738),
#   ('zone air dewPoint sensor point', 0.2082364),
#   ('outside air co2 concentration sensor point', 0.20941436),
#   ('light illuminance sensor point', 0.20968276),
#   ('outside air dewPoint sensor point', 0.20989984),
#   ('alarm sensor point', 0.21009582),
#   ('pressure sensor point', 0.2101416)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Illuminance_Setpoint'): [('light illuminance sensor point',
#    0.1683349),
#   ('light level sensor point', 0.20096046),
#   ('light luminous flux sensor point', 0.20900512),
#   ('light level sp point', 0.21905458),
#   ('weather solar irradiance sensor point', 0.2200396),
#   ('ventilation point', 0.2236439),
#   ('phase:"A" ac elec volt angle sensor point', 0.22497767),
#   ('phase:"A" ac elec volt thd sensor point', 0.22642136),
#   ('phase:"A" ac elec volt magnitude sensor point', 0.22677314),
#   ('occupancy sensor point', 0.2279669),
#   ('weather daytime sensor point', 0.22908431),
#   ('phase:"A" ac elec volt imbalance sensor point', 0.23002303),
#   ('phase:"A" ac elec current thd sensor point', 0.23144156),
#   ('phase:"A" net ac elec active energy sensor point', 0.23209727),
#   ('hvacMode sp point', 0.23255008),
#   ('phase:"A" ac elec current angle sensor point', 0.2330746),
#   ('point', 0.23323959),
#   ('phase:"A" active ac elec power sensor point', 0.23508883),
#   ('phase:"A" ac elec current magnitude sensor point', 0.23719203),
#   ('phase:"A" apparent ac elec power sensor point', 0.23739696)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Flow_Setpoint'): [('chilled water delta flow point',
#    0.14866555),
#   ('chilled water entering point', 0.15988928),
#   ('chilled water header flow sensor point', 0.16006958),
#   ('chilled water header point', 0.16140908),
#   ('chilled water entering flow sensor point', 0.16240251),
#   ('chilled water entering flow sp point', 0.16316462),
#   ('chilled water header flow sp point', 0.16519016),
#   ('chilled water bypass point', 0.16619527),
#   ('chilled water entering pump point', 0.16698658),
#   ('chilled water leaving flow sensor point', 0.16850817),
#   ('chilled water leaving point', 0.16957742),
#   ('chilled water header pump point', 0.17078227),
#   ('chilled water leaving flow sp point', 0.17100865),
#   ('chilled water header temp sensor point', 0.17111021),
#   ('chilled water bypass pump point', 0.1711623),
#   ('chilled water bypass flow sp point', 0.1714347),
#   ('chilled water delta flow sensor point', 0.17228895),
#   ('chilled water entering temp sensor point', 0.17296225),
#   ('chilled water header pressure sensor point', 0.17321748),
#   ('chilled water bypass flow sensor point', 0.17473072)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Static_Pressure_Setpoint'): [('chilled water header pressure sensor point',
#    0.14807957),
#   ('chilled water entering pressure sensor point', 0.15187693),
#   ('chilled water header pressure sp point', 0.15339804),
#   ('chilled water entering pressure sp point', 0.15377325),
#   ('chilled water leaving pressure sensor point', 0.15774912),
#   ('chilled water bypass pressure sp point', 0.15861905),
#   ('chilled water leaving pressure sp point', 0.15881771),
#   ('chilled water bypass pressure sensor point', 0.16062671),
#   ('chilled water header point', 0.16363698),
#   ('chilled water delta pressure point', 0.16390014),
#   ('chilled water header temp sensor point', 0.16704088),
#   ('chilled water entering point', 0.16849953),
#   ('chilled water delta flow point', 0.16964471),
#   ('chilled water header pump point', 0.17110234),
#   ('chilled water entering pump point', 0.17184234),
#   ('chilled water entering temp sensor point', 0.17341912),
#   ('chilled water header flow sp point', 0.17379683),
#   ('chilled water bypass point', 0.17425561),
#   ('chilled water header valve cmd point', 0.17482823),
#   ('chilled water header valve sensor point', 0.17511338)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Air_Quality_Sensor'): [('weather air feelsLike sensor point',
#    0.17849046),
#   ('weather air dewPoint sensor point', 0.19481373),
#   ('outside air humidity sensor point', 0.1977076),
#   ('zone air dewPoint sensor point', 0.1986559),
#   ('air pressure sensor point', 0.19900137),
#   ('ventilation air humidity sensor point', 0.20008898),
#   ('air dewPoint sensor point', 0.20089746),
#   ('outside air pressure sensor point', 0.20128477),
#   ('outside air dewPoint sensor point', 0.20206851),
#   ('ventilation air dewPoint sensor point', 0.20220715),
#   ('return air humidity sensor point', 0.2026658),
#   ('ventilation air pressure sensor point', 0.20302826),
#   ('weather air humidity sensor point', 0.20323849),
#   ('mixed air humidity sensor point', 0.203749),
#   ('discharge air humidity sensor point', 0.20512086),
#   ('weather air wetBulb sensor point', 0.20513147),
#   ('discharge air dewPoint sensor point', 0.2059353),
#   ('air enthalpy sensor point', 0.20655668),
#   ('flue air dewPoint sensor point', 0.20759171),
#   ('outside air co2 concentration sensor point', 0.20775896)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Valve_Position_Command'): [('valve cmd point',
#    0.16853106),
#   ('circ valve cmd point', 0.18206787),
#   ('outside steam heat valve cmd point', 0.18503827),
#   ('return steam heat valve cmd point', 0.1861552),
#   ('steam heat valve cmd point', 0.1895743),
#   ('ventilation hot water heat valve cmd point', 0.1921395),
#   ('ventilation chilled water cool valve cmd point', 0.19335628),
#   ('steam header valve cmd point', 0.19376367),
#   ('flue steam heat valve cmd point', 0.19539899),
#   ('ventilation steam heat valve cmd point', 0.19616324),
#   ('inlet steam heat valve cmd point', 0.19621706),
#   ('steam leaving valve cmd point', 0.19649887),
#   ('steam mixing valve cmd point', 0.19764471),
#   ('mixed steam heat valve cmd point', 0.19772047),
#   ('steam bypass valve cmd point', 0.19946617),
#   ('discharge steam heat valve cmd point', 0.19955516),
#   ('discharge hot water heat valve cmd point', 0.19973147),
#   ('chilled water header valve cmd point', 0.19987565),
#   ('flue hot water heat valve cmd point', 0.20011431),
#   ('chilled water entering valve cmd point', 0.20113063)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#System_Enable_Command'): [('pump enable cmd point',
#    0.21923667),
#   ('steam leaving pump enable cmd point', 0.22669566),
#   ('discharge fan enable cmd point', 0.22679323),
#   ('mixed fan enable cmd point', 0.22728759),
#   ('exhaust fan enable cmd point', 0.22839677),
#   ('ventilation fan enable cmd point', 0.22987181),
#   ('steam bypass pump enable cmd point', 0.23103231),
#   ('outside fan enable cmd point', 0.23137939),
#   ('humidifier enable cmd point', 0.2322095),
#   ('return fan enable cmd point', 0.233383),
#   ('flue fan enable cmd point', 0.23340017),
#   ('circ pump enable cmd point', 0.23410326),
#   ('steam header pump enable cmd point', 0.2360627),
#   ('inlet fan enable cmd point', 0.23696971),
#   ('water pump enable cmd point', 0.23738962),
#   ('enable cmd point', 0.23749566),
#   ('economizer fan enable cmd point', 0.2383334),
#   ('controller device', 0.23943251),
#   ('fan enable cmd point', 0.24267292),
#   ('chilled water bypass pump enable cmd point', 0.24719)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Bypass_Water_Flow_Setpoint'): [('chilled water bypass flow sp point',
#    0.18991566),
#   ('chilled water bypass flow sensor point', 0.19134146),
#   ('chilled water bypass pump point', 0.19177306),
#   ('steam bypass flow sensor point', 0.19209915),
#   ('chilled water bypass point', 0.19357252),
#   ('steam bypass pump point', 0.19372481),
#   ('chilled water bypass valve cmd point', 0.19842917),
#   ('condenser water bypass point', 0.20060712),
#   ('steam bypass flow sp point', 0.2024036),
#   ('condenser water bypass flow sensor point', 0.20475012),
#   ('chilled water bypass pressure sensor point', 0.20494187),
#   ('hot water bypass flow sensor point', 0.2049666),
#   ('condenser water bypass pump point', 0.2052126),
#   ('hot water bypass pump point', 0.20756459),
#   ('water flow sensor point', 0.20783108),
#   ('chilled water bypass valve sensor point', 0.20811498),
#   ('chilled water bypass pump enable cmd point', 0.20879954),
#   ('steam bypass point', 0.2095086),
#   ('hot water bypass point', 0.20994473),
#   ('chilled water bypass pump enable sensor point', 0.21054935)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Demand_Sensor'): [('total ac elec demand sensor point',
#    0.19608873),
#   ('total reactive ac elec power sensor point', 0.19772053),
#   ('efficiency sensor point', 0.19802725),
#   ('total net ac elec active energy sensor point', 0.2050941),
#   ('occupancy sensor point', 0.20714474),
#   ('total export ac elec active energy sensor point', 0.20990622),
#   ('total import ac elec active energy sensor point', 0.21081597),
#   ('phase:"A" reactive ac elec power sensor point', 0.21130061),
#   ('water volume sensor point', 0.21423817),
#   ('pressure sensor point', 0.21474224),
#   ('phase:"A" ac elec volt thd sensor point', 0.21573645),
#   ('economizer air dewPoint sensor point', 0.21589506),
#   ('phase:"A" apparent ac elec power sensor point', 0.21600354),
#   ('phase:"A" net ac elec active energy sensor point', 0.21625519),
#   ('phase:"A" ac elec volt magnitude sensor point', 0.21768117),
#   ('phase:"A" ac elec current thd sensor point', 0.21773875),
#   ('phase:"A" active ac elec power sensor point', 0.2180906),
#   ('total active ac elec power sensor point', 0.21869946),
#   ('total apparent ac elec power sensor point', 0.21889895),
#   ('flow sensor point', 0.21913087)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Low_Outside_Air_Temperature_Enable_Setpoint'): [('outside air temp sensor point',
#    0.18419462),
#   ('outside air dewPoint sensor point', 0.19824201),
#   ('outside fan enable sensor point', 0.1986593),
#   ('outside air dewPoint sp point', 0.20254117),
#   ('outside air temp sp point', 0.20472461),
#   ('ventilation air temp sensor point', 0.20576775),
#   ('weather air temp sensor point', 0.2062499),
#   ('outside air humidity sensor point', 0.20824444),
#   ('temp sensor point', 0.20924819),
#   ('air dewPoint sensor point', 0.20952392),
#   ('weather air feelsLike sensor point', 0.21089321),
#   ('outside air enthalpy sensor point', 0.21177167),
#   ('zone air dewPoint sensor point', 0.21195412),
#   ('weather air dewPoint sensor point', 0.21235508),
#   ('ventilation air dewPoint sensor point', 0.21240842),
#   ('outside air pressure sensor point', 0.21247995),
#   ('ventilation air dewPoint sp point', 0.21305323),
#   ('chilled water leaving temp sensor point', 0.21315789),
#   ('air dewPoint sp point', 0.21463841),
#   ('ventilation fan enable sensor point', 0.21496272)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heating_Zone_Air_Temperature_Setpoint'): [('zone air temp standby heating sp point',
#    0.18014878),
#   ('zone air temp occ heating sp point', 0.18567413),
#   ('zone air temp unocc heating sp point', 0.18740696),
#   ('zone air hvacMode sp point', 0.1894499),
#   ('ventilation air temp sensor point', 0.19320726),
#   ('zone air temp sensor point', 0.1937527),
#   ('weather air temp sensor point', 0.19778109),
#   ('temp sensor point', 0.19785255),
#   ('outside air temp sensor point', 0.19792724),
#   ('economizer air temp sensor point', 0.19992965),
#   ('zone air dewPoint sensor point', 0.20058662),
#   ('hvacMode sp point', 0.20161492),
#   ('weather air feelsLike sensor point', 0.20596015),
#   ('zone air temp standby cooling sp point', 0.20796365),
#   ('hot water header temp sensor point', 0.20893037),
#   ('flue air temp sensor point', 0.20894527),
#   ('zone air dewPoint sp point', 0.20962685),
#   ('steam leaving temp sensor point', 0.20988971),
#   ('thermostat equip', 0.2102238),
#   ('air dewPoint sensor point', 0.21059436)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Discharge_Flow_Sensor'): [('chilled water leaving flow sensor point',
#    0.13929325),
#   ('chilled water header flow sensor point', 0.1403138),
#   ('chilled water entering flow sensor point', 0.14148498),
#   ('chilled water bypass flow sensor point', 0.14654666),
#   ('chilled water delta flow sensor point', 0.15273994),
#   ('chilled water leaving pressure sensor point', 0.15277487),
#   ('chilled water bypass pressure sensor point', 0.1530183),
#   ('chilled water bypass valve sensor point', 0.1532126),
#   ('chilled water entering valve sensor point', 0.1547417),
#   ('chilled water header valve sensor point', 0.15474826),
#   ('chilled water entering pressure sensor point', 0.15504539),
#   ('chilled water header pressure sensor point', 0.15507972),
#   ('chilled water leaving valve sensor point', 0.15558338),
#   ('chilled water leaving pump enable sensor point', 0.15643513),
#   ('chilled water entering pump enable sensor point', 0.15970325),
#   ('chilled water bypass pump enable sensor point', 0.1622625),
#   ('chilled water header pump enable sensor point', 0.16248304),
#   ('chilled water header temp sensor point', 0.16454148),
#   ('chilled water leaving pump run sensor point', 0.16525304),
#   ('chilled water entering pump run sensor point', 0.16654384)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Automatic_Mode_Command'): [('controller device',
#    0.21047527),
#   ('phase:"A" ac elec volt angle sensor point', 0.25482),
#   ('enable cmd point', 0.25483775),
#   ('phase:"A" ac elec current angle sensor point', 0.25610614),
#   ('outside steam heat valve cmd point', 0.25832498),
#   ('phase:"A" active ac elec power sensor point', 0.25977218),
#   ('chilled water bypass valve cmd point', 0.2604587),
#   ('humidifier enable cmd point', 0.26089793),
#   ('outside fan enable cmd point', 0.26260078),
#   ('ventilation fan enable cmd point', 0.2631395),
#   ('valve cmd point', 0.26317567),
#   ('fan enable cmd point', 0.26345158),
#   ('phase:"A" ac elec volt thd sensor point', 0.26404387),
#   ('discharge hot water heat valve cmd point', 0.2641093),
#   ('phase:"A" ac elec current thd sensor point', 0.26415366),
#   ('phase:"A" ac elec volt magnitude sensor point', 0.26432627),
#   ('chilled water bypass pump enable cmd point', 0.26432896),
#   ('pump enable cmd point', 0.26511568),
#   ('chilled water cool valve cmd point', 0.2657805),
#   ('ventilation fan vfd speed cmd point', 0.2658968)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Outside_Air_Enthalpy_Sensor'): [('outside air enthalpy sensor point',
#    0.14544392),
#   ('weather air enthalpy sensor point', 0.16407669),
#   ('outside air temp sensor point', 0.16549373),
#   ('outside air humidity sensor point', 0.16583002),
#   ('ventilation air enthalpy sensor point', 0.16801554),
#   ('air enthalpy sensor point', 0.16866106),
#   ('weather air feelsLike sensor point', 0.17188072),
#   ('outside air dewPoint sensor point', 0.17189783),
#   ('return air enthalpy sensor point', 0.17537999),
#   ('outside air pressure sensor point', 0.17618346),
#   ('exhaust air enthalpy sensor point', 0.17619067),
#   ('flue air enthalpy sensor point', 0.1779108),
#   ('economizer air enthalpy sensor point', 0.17803979),
#   ('discharge air enthalpy sensor point', 0.17947501),
#   ('inlet air enthalpy sensor point', 0.18295139),
#   ('outside air co2 concentration sensor point', 0.18343955),
#   ('exhaust air humidity sensor point', 0.18352598),
#   ('weather air dewPoint sensor point', 0.18407089),
#   ('ventilation air humidity sensor point', 0.18526137),
#   ('air dewPoint sensor point', 0.18729162)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Ammonia_Sensor'): [('water level sensor point',
#    0.21512723),
#   ('zone air nh3 concentration sensor point', 0.21594894),
#   ('water volume sensor point', 0.21905667),
#   ('alarm sensor point', 0.21943015),
#   ('ground water volume sensor point', 0.22074455),
#   ('phase:"A" ac elec volt thd sensor point', 0.22096997),
#   ('occupancy sensor point', 0.22202581),
#   ('outside air humidity sensor point', 0.22233778),
#   ('ventilation air humidity sensor point', 0.22245407),
#   ('water pressure sensor point', 0.22279042),
#   ('air enthalpy sensor point', 0.22421509),
#   ('light level sensor point', 0.22483742),
#   ('ventilation air enthalpy sensor point', 0.22484243),
#   ('phase:"A" reactive ac elec power sensor point', 0.22516006),
#   ('ground water flow sensor point', 0.22556871),
#   ('phase:"A" ac elec volt magnitude sensor point', 0.22558743),
#   ('discharge air humidity sensor point', 0.22594649),
#   ('flow sensor point', 0.22657311),
#   ('mixed air humidity sensor point', 0.22680742),
#   ('ground water pressure sensor point', 0.22693676)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Usage_Sensor'): [('water volume sensor point',
#    0.1822781),
#   ('water temp sensor point', 0.18910897),
#   ('hot water header temp sensor point', 0.18973505),
#   ('hot water header valve sensor point', 0.19011658),
#   ('hot water entering valve sensor point', 0.19068134),
#   ('hot water entering pressure sensor point', 0.19138843),
#   ('hot water entering temp sensor point', 0.19161087),
#   ('hot water header pressure sensor point', 0.19544303),
#   ('water pressure sensor point', 0.19645125),
#   ('hot water header flow sensor point', 0.19805282),
#   ('hot water leaving pressure sensor point', 0.19885641),
#   ('ground water volume sensor point', 0.19944382),
#   ('water level sensor point', 0.20097595),
#   ('hot water entering flow sensor point', 0.20159519),
#   ('hot water leaving valve sensor point', 0.20318902),
#   ('hot water leaving temp sensor point', 0.20402575),
#   ('chilled water header temp sensor point', 0.20502853),
#   ('hot water header point', 0.2051931),
#   ('warm water flow thermal meter equip', 0.20556891),
#   ('water flow sensor point', 0.20639771)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Supply_Flow_Setpoint'): [('chilled water delta flow point',
#    0.15481901),
#   ('chilled water entering point', 0.15999931),
#   ('chilled water header point', 0.16021812),
#   ('chilled water header flow sensor point', 0.16024196),
#   ('chilled water bypass point', 0.16157079),
#   ('chilled water bypass pump point', 0.16390944),
#   ('chilled water entering flow sensor point', 0.16467035),
#   ('chilled water header pump point', 0.16527158),
#   ('chilled water header flow sp point', 0.16600055),
#   ('chilled water entering pump point', 0.16636944),
#   ('chilled water entering flow sp point', 0.16823727),
#   ('chilled water header pressure sensor point', 0.16895145),
#   ('chilled water bypass flow sensor point', 0.16972351),
#   ('chilled water bypass pressure sensor point', 0.17064047),
#   ('chilled water bypass flow sp point', 0.17074227),
#   ('chilled water leaving flow sensor point', 0.17180127),
#   ('chilled water header valve sensor point', 0.17190725),
#   ('chilled water header temp sensor point', 0.17345846),
#   ('chilled water entering pressure sensor point', 0.17353827),
#   ('chilled water leaving pump point', 0.17415744)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Water_Differential_Pressure_Deadband_Setpoint'): [('chilled water leaving pressure sensor point',
#    0.19821978),
#   ('chilled water leaving pressure sp point', 0.20753664),
#   ('chilled water leaving point', 0.21005917),
#   ('condenser water leaving pressure sensor point', 0.21092963),
#   ('chilled water leaving pump point', 0.2134161),
#   ('water pressure sensor point', 0.21508068),
#   ('steam leaving pressure sensor point', 0.21651173),
#   ('chilled water entering pressure sensor point', 0.21778077),
#   ('chilled water leaving flow sensor point', 0.21920347),
#   ('chilled water leaving flow sp point', 0.21980488),
#   ('condenser water leaving point', 0.22123438),
#   ('chilled water leaving temp sensor point', 0.22134346),
#   ('hot water leaving pressure sensor point', 0.22291732),
#   ('chilled water entering pressure sp point', 0.22455317),
#   ('chilled water bypass pressure sp point', 0.22513372),
#   ('chilled water leaving valve cmd point', 0.22522992),
#   ('chilled water delta pressure point', 0.22544795),
#   ('chilled water header pressure sensor point', 0.22555643),
#   ('chilled water delta flow point', 0.22560114),
#   ('water volume sensor point', 0.22567868)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Zone_Air_Temperature_Setpoint'): [('zone air temp sensor point',
#    0.18679583),
#   ('ventilation air temp sensor point', 0.19045967),
#   ('outside air temp sensor point', 0.19247031),
#   ('zone air dewPoint sensor point', 0.19515437),
#   ('weather air temp sensor point', 0.19592458),
#   ('temp sensor point', 0.19761759),
#   ('zone air hvacMode sp point', 0.1981352),
#   ('weather air feelsLike sensor point', 0.20142889),
#   ('economizer air temp sensor point', 0.2018168),
#   ('zone air dewPoint sp point', 0.20266396),
#   ('zone air temp standby heating sp point', 0.20307851),
#   ('zone air temp unocc heating sp point', 0.2039851),
#   ('return air temp sensor point', 0.20425886),
#   ('zone air temp occ heating sp point', 0.204602),
#   ('air dewPoint sensor point', 0.20529455),
#   ('ventilation air temp sp point', 0.20617008),
#   ('temp sp point', 0.2077595),
#   ('mixed air temp sensor point', 0.20905137),
#   ('zone air humidity sensor point', 0.209468),
#   ('air dewPoint sp point', 0.21014678)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Vent_Operating_Mode_Status'): [('hvacMode sp point',
#    0.21474755),
#   ('ventilation point', 0.22307765),
#   ('zone air hvacMode sp point', 0.2302978),
#   ('ventilation hot water heat valve cmd point', 0.23383737),
#   ('ventilation stage:1 heat run cmd point', 0.23731756),
#   ('ventilation fan run sensor point', 0.23794043),
#   ('ventilation fan enable sensor point', 0.23874092),
#   ('ventilation fan point', 0.23977876),
#   ('ventilation steam heat valve cmd point', 0.24114347),
#   ('ventilation fan vfd speed cmd point', 0.24135703),
#   ('ventilation fan enable cmd point', 0.24208969),
#   ('ventilation air pressure sensor point', 0.24244612),
#   ('ventilation chilled water cool valve cmd point', 0.24280912),
#   ('ventilation air temp sensor point', 0.24389172),
#   ('ventilation air flow sensor point', 0.2469213),
#   ('ventilation stage:1 cool run cmd point', 0.24723059),
#   ('ventilation duct equip', 0.24725258),
#   ('ventilation damper cmd point', 0.24738902),
#   ('ventilation air enthalpy sensor point', 0.24763787),
#   ('ventilation damper sensor point', 0.24865615)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Solar_Radiance_Sensor'): [('weather solar irradiance sensor point',
#    0.17176914),
#   ('light luminous flux sensor point', 0.18115753),
#   ('light illuminance sensor point', 0.18191922),
#   ('light level sensor point', 0.19265258),
#   ('weather daytime sensor point', 0.20621437),
#   ('phase:"A" ac elec volt angle sensor point', 0.21109593),
#   ('phase:"A" ac elec current angle sensor point', 0.21486026),
#   ('phase:"A" ac elec volt magnitude sensor point', 0.21681684),
#   ('weather air feelsLike sensor point', 0.21970087),
#   ('weather cloudage sensor point', 0.22424644),
#   ('phase:"A" ac elec current magnitude sensor point', 0.2247904),
#   ('phase:"A" net ac elec active energy sensor point', 0.22518754),
#   ('phase:"A" reactive ac elec power sensor point', 0.2263853),
#   ('weather visibility sensor point', 0.22709858),
#   ('weather wind direction sensor point', 0.22740608),
#   ('occupancy sensor point', 0.22785097),
#   ('phase:"A" ac elec volt thd sensor point', 0.22837865),
#   ('occupied sensor point', 0.22864395),
#   ('fan enable sensor point', 0.22869837),
#   ('total net ac elec active energy sensor point', 0.23029763)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Differential_Pressure_Sensor'): [('outside air pressure sensor point',
#    0.16369897),
#   ('ventilation air pressure sensor point', 0.16421282),
#   ('discharge air pressure sensor point', 0.16662699),
#   ('weather atmospheric pressure sensor point', 0.1794244),
#   ('air pressure sensor point', 0.18059814),
#   ('flue air pressure sensor point', 0.18086362),
#   ('return air pressure sensor point', 0.1817931),
#   ('discharge air dewPoint sensor point', 0.18218791),
#   ('ventilation air dewPoint sensor point', 0.18329334),
#   ('exhaust air pressure sensor point', 0.18377656),
#   ('mixed air pressure sensor point', 0.18709552),
# ...
#    0.21622413),
#   ('vrf indoorUnit equip', 0.21769756),
#   ('ventilation heatingCoil equip', 0.21862996),
#   ('outside duct equip', 0.22275841),
#   ('ventilation air humidity sensor point', 0.22300673),
#   ('outside heatingCoil equip', 0.22796488),
#   ('air dewPoint sensor point', 0.22846872),
#   ('ventilation duct equip', 0.2287879),
#   ('discharge air humidity sensor point', 0.22965825),
#   ('outside air humidity sensor point', 0.22995323),
#   ('air dewPoint sp point', 0.23083985),
#   ('ventilation air dewPoint sp point', 0.23094338),
#   ('air humidity sensor point', 0.23101908),
#   ('ventilation coolingCoil equip', 0.23142326),
#   ('ventilation air enthalpy sensor point', 0.23156184),
#   ('ventilation point', 0.23177636),
#   ('air enthalpy sensor point', 0.23196763),
#   ('exhaust air humidity sensor point', 0.23284376),
#   ('hvacMode sp point', 0.23286581),
#   ('flue air humidity sensor point', 0.23359871)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heating_Valve'): [('ventilation hot water heat valve cmd point',
#    0.17624986),
#   ('ventilation heatingCoil equip', 0.1815387),
#   ('flue hot water heat valve cmd point', 0.18729514),
#   ('discharge hot water heat valve cmd point', 0.19042772),
#   ('outside steam heat valve cmd point', 0.19156212),
#   ('outside hot water heat valve cmd point', 0.19193172),
#   ('economizer hot water heat valve cmd point', 0.19497359),
#   ('inlet hot water heat valve cmd point', 0.19682294),
#   ('outside heatingCoil equip', 0.19759548),
#   ('mixed heatingCoil equip', 0.19807297),
#   ('return hot water heat valve cmd point', 0.19840759),
#   ('heatingCoil equip', 0.1999085),
#   ('economizer heatingCoil equip', 0.2005933),
#   ('flue heatingCoil equip', 0.20097774),
#   ('inlet heatingCoil equip', 0.20145881),
#   ('mixed hot water heat valve cmd point', 0.2029748),
#   ('steam heatExchanger equip', 0.20304364),
#   ('hot water header valve sensor point', 0.20472425),
#   ('exhaust hot water heat valve cmd point', 0.20474648),
#   ('hot water heatExchanger equip', 0.20707655)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chiller'): [('chiller equip',
#    0.15456438),
#   ('chilled water heatExchanger equip', 0.15638298),
#   ('chilled water entering equip', 0.16992497),
#   ('chilled water leaving equip', 0.17635036),
#   ('chilled water entering pump equip', 0.18104452),
#   ('chilled water header pump equip', 0.18297791),
#   ('chilled water entering point', 0.18502116),
#   ('chilled water header equip', 0.18703163),
#   ('chilled water entering pipe equip', 0.18711728),
#   ('chilled water header pump point', 0.18729532),
#   ('chilled water leaving pump equip', 0.18789911),
#   ('chilled water header pipe equip', 0.18834287),
#   ('chilled water entering pump point', 0.18883741),
#   ('chilled water entering pump motor equip', 0.18886268),
#   ('chilled water header point', 0.1890344),
#   ('heatExchanger equip', 0.18903637),
#   ('chilled water bypass equip', 0.18921804),
#   ('chilled water header pump motor equip', 0.18986297),
#   ('chilled water bypass pump equip', 0.19275296),
#   ('chilled water leaving pipe equip', 0.19278127)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Bus_Riser'): [('flowInverter equip',
#    0.24871188),
#   ('equip', 0.2516874),
#   ('circ equip', 0.25241733),
#   ('rack equip', 0.25246638),
#   ('vrf branchSelector equip', 0.25413513),
#   ('phase:"A" reactive ac elec power sensor point', 0.25495142),
#   ('space', 0.25526088),
#   ('controller device', 0.25557792),
#   ('fan equip', 0.2566585),
#   ('pump point', 0.25721896),
#   ('return duct equip', 0.25824666),
#   ('vrf indoorUnit equip', 0.2599706),
#   ('phase:"A" active ac elec power sensor point', 0.25999886),
#   ('fan motor equip', 0.26035553),
#   ('outside duct equip', 0.2605549),
#   ('phase:"A" net ac elec active energy sensor point', 0.2611729),
#   ('outside heatingCoil equip', 0.26118827),
#   ('flue duct equip', 0.2617678),
#   ('discharge duct equip', 0.26194894),
#   ('discharge point', 0.26203412)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Heater'): [('hot water boiler equip',
#    0.18724918),
#   ('hot water heatExchanger equip', 0.18921125),
#   ('heatExchanger equip', 0.20329899),
#   ('chilled water heatExchanger equip', 0.20437813),
#   ('outside heatingCoil equip', 0.20892024),
#   ('hot water entering equip', 0.20982271),
#   ('steam heatExchanger equip', 0.20987797),
#   ('economizer heatingCoil equip', 0.21003842),
#   ('discharge heatingCoil equip', 0.2115227),
#   ('hot water header point', 0.21266592),
#   ('hot water header equip', 0.21405822),
#   ('heatingCoil equip', 0.21538347),
#   ('mixed heatingCoil equip', 0.21597058),
#   ('hot water entering point', 0.21766108),
#   ('steam boiler equip', 0.21784627),
#   ('inlet heatingCoil equip', 0.21852309),
#   ('hot water header pipe equip', 0.21868551),
#   ('flue heatingCoil equip', 0.21885407),
#   ('ventilation heatingCoil equip', 0.21963334),
#   ('hot water entering pipe equip', 0.22196871)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Solar_Thermal_Collector'): [('weather solar irradiance sensor point',
#    0.22374928),
#   ('cool water flow thermal meter equip', 0.23797047),
#   ('heatExchanger equip', 0.24325001),
#   ('phase:"A" ac elec volt thd sensor point', 0.24404424),
#   ('mixed heatingCoil equip', 0.2440747),
#   ('steam heatExchanger equip', 0.24429405),
#   ('outside heatingCoil equip', 0.24432933),
#   ('hot water heatExchanger equip', 0.24716455),
#   ('phase:"A" net ac elec active energy sensor point', 0.24801481),
#   ('ventilation heatingCoil equip', 0.24872696),
#   ('temp sensor point', 0.24899006),
#   ('phase:"A" ac elec current thd sensor point', 0.24991083),
#   ('warm water flow thermal meter equip', 0.24994332),
#   ('return heatingCoil equip', 0.25235373),
#   ('space', 0.25259334),
#   ('chilled water heatExchanger equip', 0.25315213),
#   ('coolingTower equip', 0.25340825),
#   ('hot water entering point', 0.25344676),
#   ('heatingCoil equip', 0.25416964),
#   ('flue heatingCoil equip', 0.2547382)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Eye_Wash_Station'): [('makeup water entering pipe equip',
#    0.23689884),
#   ('makeup water entering point', 0.24252635),
#   ('water pump point', 0.24339312),
#   ('makeup water entering pump point', 0.24503767),
#   ('space', 0.24650788),
#   ('makeup water entering equip', 0.24658555),
#   ('point', 0.2475946),
#   ('equip', 0.24806744),
#   ('makeup water entering pressure sensor point', 0.2491191),
#   ('water level sensor point', 0.24940205),
#   ('makeup water entering pump equip', 0.24957293),
#   ('makeup water entering valve sensor point', 0.24959475),
#   ('makeup water entering flow sensor point', 0.24960291),
#   ('water volume sensor point', 0.24970639),
#   ('ground water flow sensor point', 0.25044012),
#   ('water pressure sensor point', 0.25047314),
#   ('makeup water entering valve actuator equip', 0.25155687),
#   ('ground water pressure sensor point', 0.25165397),
#   ('chilled water entering point', 0.25205666),
#   ('water pump equip', 0.25207818)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Computer_Room_Air_Conditioning'): [('ventilation coolingCoil equip',
#    0.20089054),
#   ('ventilation heatingCoil equip', 0.20946205),
#   ('economizer coolingCoil equip', 0.21054697),
#   ('outside heatingCoil equip', 0.21080846),
#   ('controller device', 0.21170938),
#   ('coolingCoil equip', 0.21192235),
#   ('coolingTower equip', 0.21307135),
#   ('outside coolingCoil equip', 0.2166416),
#   ('economizer heatingCoil equip', 0.21993703),
#   ('chiller equip', 0.22219855),
#   ('flue coolingCoil equip', 0.22240472),
#   ('air dewPoint sensor point', 0.22477388),
#   ('ventilation equip', 0.22497255),
#   ('exhaust coolingCoil equip', 0.22520328),
#   ('weather air feelsLike sensor point', 0.22598404),
#   ('discharge coolingCoil equip', 0.22655386),
#   ('ventilation air humidity sensor point', 0.22665244),
#   ('heatingCoil equip', 0.22707886),
#   ('inlet coolingCoil equip', 0.22738934),
#   ('thermostat equip', 0.22764587)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Radiant_Panel'): [('perimeterHeat cmd point',
#    0.21924937),
#   ('mixed heatingCoil equip', 0.22012752),
#   ('ventilation heatingCoil equip', 0.22570276),
#   ('ventilation point', 0.22603929),
#   ('outside heatingCoil equip', 0.22632998),
#   ('thermostat equip', 0.23026043),
#   ('outside fan point', 0.23202473),
#   ('heatingCoil equip', 0.23234648),
#   ('ventilation fan point', 0.2324487),
#   ('hot water entering point', 0.23284793),
#   ('weather air feelsLike sensor point', 0.23549044),
#   ('return heatingCoil equip', 0.23632723),
#   ('space', 0.2365359),
#   ('hot water header point', 0.23695022),
#   ('weather solar irradiance sensor point', 0.23745257),
#   ('cool water flow thermal meter equip', 0.23775941),
#   ('flue heatingCoil equip', 0.23874712),
#   ('inlet heatingCoil equip', 0.23900819),
#   ('chilled water entering temp sensor point', 0.2403695),
#   ('coolingTower equip', 0.24062109)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#ICT_Equipment'): [('controller device',
#    0.21725672),
#   ('equip', 0.21910685),
#   ('flowInverter equip', 0.22132194),
#   ('circ equip', 0.22447222),
#   ('mixed equip', 0.22487235),
#   ('networking device', 0.22898793),
#   ('inlet equip', 0.23206288),
#   ('cool well equip', 0.23309559),
#   ('outside heatingCoil equip', 0.23657143),
#   ('heatingCoil equip', 0.23709816),
#   ('server device', 0.2374376),
#   ('coolingTower equip', 0.238146),
#   ('steam heatExchanger equip', 0.2402634),
#   ('outside coolingCoil equip', 0.24031365),
#   ('thermostat equip', 0.24035919),
#   ('coolingCoil equip', 0.24060214),
#   ('return equip', 0.24100184),
#   ('ventilation coolingCoil equip', 0.2410447),
#   ('circ pipe equip', 0.2421183),
#   ('inlet coolingCoil equip', 0.24281055)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heat_Wheel_VFD'): [('chilled water header pump vfd speed sensor point',
#    0.20732582),
#   ('ventilation fan vfd speed cmd point', 0.20774955),
#   ('chilled water header pump vfd speed cmd point', 0.21019274),
#   ('hot water header pump vfd speed sensor point', 0.21087295),
#   ('ventilation fan vfd speed sensor point', 0.21142393),
#   ('hot water header pump vfd speed cmd point', 0.21175486),
#   ('chilled water header pump vfd freq sensor point', 0.21230626),
#   ('ventilation fan vfd freq sensor point', 0.2135256),
#   ('fan motor equip', 0.21378154),
#   ('steam header pump vfd speed cmd point', 0.21525717),
#   ('hot water entering pump vfd speed cmd point', 0.2156272),
#   ('chilled water entering pump vfd speed sensor point', 0.21621412),
#   ('ventilation fan vfd freq cmd point', 0.21625614),
#   ('chilled water entering pump vfd speed cmd point', 0.21672434),
#   ('chilled water header pump vfd freq cmd point', 0.21675152),
#   ('hot water header pump vfd freq sensor point', 0.2174123),
#   ('flue fan vfd freq sensor point', 0.21764153),
#   ('fan vfd speed cmd point', 0.21778572),
#   ('hot water header pump vfd freq cmd point', 0.21810716),
#   ('hot water entering pump vfd speed sensor point', 0.21885562)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Stage_Riser'): [('space',
#    0.22815555),
#   ('point', 0.24266231),
#   ('return stage:1 cool run cmd point', 0.24358422),
#   ('return stage:1 heat run cmd point', 0.24438983),
#   ('stage:1 cool run cmd point', 0.24793285),
#   ('equip', 0.24959266),
#   ('stage:1 heat run cmd point', 0.24976784),
#   ('light level sensor point', 0.25191623),
#   ('circ equip', 0.25424576),
#   ('pump point', 0.25471717),
#   ('rack equip', 0.2549652),
#   ('outside stage:1 cool run cmd point', 0.25594735),
#   ('phase:"A" ac elec volt angle sensor point', 0.25674635),
#   ('level sensor point', 0.25755924),
#   ('flue stage:1 heat run cmd point', 0.2580222),
#   ('mixed stage:1 cool run cmd point', 0.25807452),
#   ('phase:"A" ac elec volt magnitude sensor point', 0.25822657),
#   ('flue stage:1 cool run cmd point', 0.26030397),
#   ('mixed stage:1 heat run cmd point', 0.2605545),
#   ('inlet stage:1 heat run cmd point', 0.26081258)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Baseboard_Radiator'): [('hot water header point',
#    0.19506478),
#   ('hot water entering point', 0.19672418),
#   ('hot water boiler equip', 0.19801319),
#   ('hot water heatExchanger equip', 0.2025345),
#   ('outside heatingCoil equip', 0.20503587),
#   ('hot water entering equip', 0.21003753),
#   ('flue hot water heat valve cmd point', 0.21123236),
#   ('discharge hot water heat valve cmd point', 0.21201211),
#   ('flue heatingCoil equip', 0.21224368),
#   ('mixed heatingCoil equip', 0.21302676),
#   ('outside hot water heat valve cmd point', 0.21320838),
#   ('ventilation heatingCoil equip', 0.21337569),
#   ('steam heatExchanger equip', 0.21437615),
#   ('return hot water heat valve cmd point', 0.21457559),
#   ('heatingCoil equip', 0.21670628),
#   ('inlet heatingCoil equip', 0.21767455),
#   ('heatExchanger equip', 0.21848196),
#   ('inlet hot water heat valve cmd point', 0.21983618),
#   ('hot water entering pump point', 0.21993577),
#   ('chilled water heatExchanger equip', 0.22005212)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heat_Wheel'): [('hot water heatExchanger equip',
#    0.16526091),
#   ('heatExchanger equip', 0.168518),
#   ('steam heatExchanger equip', 0.17459309),
#   ('chilled water heatExchanger equip', 0.18626815),
#   ('exhaust heatingCoil equip', 0.18748826),
#   ('outside heatingCoil equip', 0.19170398),
#   ('ventilation heatingCoil equip', 0.19537526),
#   ('heatingCoil equip', 0.20073473),
#   ('discharge heatingCoil equip', 0.20115882),
#   ('economizer heatingCoil equip', 0.2026344),
#   ('flue heatingCoil equip', 0.20437014),
#   ('mixed heatingCoil equip', 0.20456105),
#   ('exhaust coolingCoil equip', 0.20505041),
#   ('return heatingCoil equip', 0.20547456),
#   ('inlet heatingCoil equip', 0.20837104),
#   ('heatWheel cmd point', 0.21206903),
#   ('flue coolingCoil equip', 0.21357274),
#   ('ventilation coolingCoil equip', 0.21485507),
#   ('hot water boiler equip', 0.21547753),
#   ('outside coolingCoil equip', 0.21746081)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Building_Gas_Meter'): [('ground water volume sensor point',
#    0.23950481),
#   ('phase:"A" ac elec volt magnitude sensor point', 0.24104708),
#   ('phase:"A" net ac elec active energy sensor point', 0.24151742),
#   ('space', 0.24380887),
#   ('ground water flow sensor point', 0.24751288),
#   ('water volume sensor point', 0.24764794),
#   ('phase:"A" ac elec volt angle sensor point', 0.24775827),
#   ('mixed point', 0.24888808),
#   ('point', 0.24916142),
#   ('ground water pressure sensor point', 0.24972957),
#   ('phase:"A" ac elec current magnitude sensor point', 0.24979514),
#   ('phase:"A" ac elec volt thd sensor point', 0.24997813),
#   ('total net ac elec active energy sensor point', 0.25003254),
#   ('equip', 0.25022608),
#   ('phase:"A" reactive ac elec power sensor point', 0.25027394),
#   ('phase:"A" apparent ac elec power sensor point', 0.25053108),
#   ('pump point', 0.25057358),
#   ('occupancy sensor point', 0.25058436),
#   ('phase:"A" ac elec volt imbalance sensor point', 0.2507763),
#   ('flow sensor point', 0.25198328)],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Cold_Deck'): [('outside coolingCoil equip',
#    0.18741643),
#   ('outside duct equip', 0.18910414),
#   ('outside heatingCoil equip', 0.19129676),
#   ('ventilation coolingCoil equip', 0.19800097),
#   ('outside chilled water cool valve cmd point', 0.19939584),
#   ('flue coolingCoil equip', 0.20014316),
#   ('coolingCoil equip', 0.20055509),
#   ('coolingTower equip', 0.20171195),
#   ('mixed coolingCoil equip', 0.20314193),
#   ('ventilation chilled water cool valve cmd point', 0.20329386),
#   ('flue chilled water cool valve cmd point', 0.20335448),
#   ('chilled water heatExchanger equip', 0.20394742),
#   ('economizer coolingCoil equip', 0.2046898),
#   ('ventilation heatingCoil equip', 0.20476484),
#   ('discharge coolingCoil equip', 0.20499241),
#   ('discharge chilled water cool valve cmd point', 0.20650935),
#   ('chilled water header point', 0.20835435),
#   ('exhaust coolingCoil equip', 0.2104857),
#   ('mixed heatingCoil equip', 0.21054864),
#   ('economizer duct equip', 0.21082878)]}
