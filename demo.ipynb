# %%
from brickmapper import Mapper
from rdflib import BRICK
import urllib.request
import csv
import numpy as np

# %%
# read haystack proto definitions off their website

defns = []
request = urllib.request.Request("https://project-haystack.org/download/protos.csv", headers={'User-Agent': "Python script"})
response = urllib.request.urlopen(request)
rdr = csv.DictReader(response.read().decode('utf8').splitlines())
for row in rdr:
    # save each proto (e.g. 'air temp sensor point') as a dictionary
    defns.append({'name': row['proto']})

defns
# Out:
# [{'name': 'air co2 concentration sensor point'},
#  {'name': 'air co2 concentration sp point'},
#  {'name': 'air dewPoint sensor point'},
#  {'name': 'air dewPoint sp point'},
#  {'name': 'air enthalpy sensor point'},
#  {'name': 'air enthalpy sp point'},
#  {'name': 'air flow sensor point'},
#  {'name': 'air flow sp point'},
#  {'name': 'air humidity sensor point'},
#  {'name': 'air humidity sp point'},
#  {'name': 'air pressure sensor point'},
#  {'name': 'air pressure sp point'},
#  {'name': 'air temp sensor point'},
#  {'name': 'air temp sp point'},
#  {'name': 'air velocity sensor point'},
#  {'name': 'air velocity sp point'},
#  {'name': 'alarm sensor point'},
#  {'name': 'avg ac elec current angle sensor point'},
#  {'name': 'avg ac elec current imbalance sensor point'},
#  {'name': 'avg ac elec current magnitude sensor point'},
#  {'name': 'avg ac elec current thd sensor point'},
#  {'name': 'avg ac elec pf sensor point'},
#  {'name': 'avg ac elec volt angle sensor point'},
#  {'name': 'avg ac elec volt imbalance sensor point'},
#  {'name': 'avg ac elec volt magnitude sensor point'},
#  {'name': 'avg ac elec volt thd sensor point'},
#  {'name': 'bypass damper cmd point'},
#  {'name': 'chilled water bypass equip'},
#  {'name': 'chilled water bypass flow sensor point'},
#  {'name': 'chilled water bypass flow sp point'},
#  {'name': 'chilled water bypass pipe equip'},
#  {'name': 'chilled water bypass point'},
#  {'name': 'chilled water bypass pressure sensor point'},
#  {'name': 'chilled water bypass pressure sp point'},
#  {'name': 'chilled water bypass pump alarm sensor point'},
#  {'name': 'chilled water bypass pump enable cmd point'},
#  {'name': 'chilled water bypass pump enable sensor point'},
#  {'name': 'chilled water bypass pump equip'},
#  {'name': 'chilled water bypass pump motor equip'},
#  {'name': 'chilled water bypass pump point'},
#  {'name': 'chilled water bypass pump run cmd point'},
#  {'name': 'chilled water bypass pump run sensor point'},
#  {'name': 'chilled water bypass pump vfd freq cmd point'},
#  {'name': 'chilled water bypass pump vfd freq sensor point'},
#  {'name': 'chilled water bypass pump vfd speed cmd point'},
#  {'name': 'chilled water bypass pump vfd speed sensor point'},
#  {'name': 'chilled water bypass temp sensor point'},
#  {'name': 'chilled water bypass temp sp point'},
#  {'name': 'chilled water bypass valve actuator equip'},
#  {'name': 'chilled water bypass valve cmd point'},
#  {'name': 'chilled water bypass valve sensor point'},
#  {'name': 'chilled water cool valve cmd point'},
#  {'name': 'chilled water delta flow point'},
#  {'name': 'chilled water delta flow sensor point'},
#  {'name': 'chilled water delta pressure point'},
#  {'name': 'chilled water delta temp point'},
#  {'name': 'chilled water delta temp sensor point'},
#  {'name': 'chilled water entering equip'},
#  {'name': 'chilled water entering flow sensor point'},
#  {'name': 'chilled water entering flow sp point'},
#  {'name': 'chilled water entering pipe equip'},
#  {'name': 'chilled water entering point'},
#  {'name': 'chilled water entering pressure sensor point'},
#  {'name': 'chilled water entering pressure sp point'},
#  {'name': 'chilled water entering pump alarm sensor point'},
#  {'name': 'chilled water entering pump enable cmd point'},
#  {'name': 'chilled water entering pump enable sensor point'},
#  {'name': 'chilled water entering pump equip'},
#  {'name': 'chilled water entering pump motor equip'},
#  {'name': 'chilled water entering pump point'},
#  {'name': 'chilled water entering pump run cmd point'},
#  {'name': 'chilled water entering pump run sensor point'},
#  {'name': 'chilled water entering pump vfd freq cmd point'},
#  {'name': 'chilled water entering pump vfd freq sensor point'},
#  {'name': 'chilled water entering pump vfd speed cmd point'},
#  {'name': 'chilled water entering pump vfd speed sensor point'},
#  {'name': 'chilled water entering temp sensor point'},
#  {'name': 'chilled water entering temp sp point'},
#  {'name': 'chilled water entering valve actuator equip'},
#  {'name': 'chilled water entering valve cmd point'},
#  {'name': 'chilled water entering valve sensor point'},
#  {'name': 'chilled water header equip'},
#  {'name': 'chilled water header flow sensor point'},
#  {'name': 'chilled water header flow sp point'},
#  {'name': 'chilled water header pipe equip'},
#  {'name': 'chilled water header point'},
#  {'name': 'chilled water header pressure sensor point'},
#  {'name': 'chilled water header pressure sp point'},
#  {'name': 'chilled water header pump alarm sensor point'},
#  {'name': 'chilled water header pump enable cmd point'},
#  {'name': 'chilled water header pump enable sensor point'},
#  {'name': 'chilled water header pump equip'},
#  {'name': 'chilled water header pump motor equip'},
#  {'name': 'chilled water header pump point'},
#  {'name': 'chilled water header pump run cmd point'},
#  {'name': 'chilled water header pump run sensor point'},
#  {'name': 'chilled water header pump vfd freq cmd point'},
#  {'name': 'chilled water header pump vfd freq sensor point'},
#  {'name': 'chilled water header pump vfd speed cmd point'},
#  {'name': 'chilled water header pump vfd speed sensor point'},
#  {'name': 'chilled water header temp sensor point'},
#  {'name': 'chilled water header temp sp point'},
#  {'name': 'chilled water header valve actuator equip'},
#  {'name': 'chilled water header valve cmd point'},
#  {'name': 'chilled water header valve sensor point'},
#  {'name': 'chilled water heatExchanger equip'},
#  {'name': 'chilled water leaving equip'},
#  {'name': 'chilled water leaving flow sensor point'},
#  {'name': 'chilled water leaving flow sp point'},
#  {'name': 'chilled water leaving pipe equip'},
#  {'name': 'chilled water leaving point'},
#  {'name': 'chilled water leaving pressure sensor point'},
#  {'name': 'chilled water leaving pressure sp point'},
#  {'name': 'chilled water leaving pump alarm sensor point'},
#  {'name': 'chilled water leaving pump enable cmd point'},
#  {'name': 'chilled water leaving pump enable sensor point'},
#  {'name': 'chilled water leaving pump equip'},
#  {'name': 'chilled water leaving pump motor equip'},
#  {'name': 'chilled water leaving pump point'},
#  {'name': 'chilled water leaving pump run cmd point'},
#  {'name': 'chilled water leaving pump run sensor point'},
#  {'name': 'chilled water leaving pump vfd freq cmd point'},
#  {'name': 'chilled water leaving pump vfd freq sensor point'},
#  {'name': 'chilled water leaving pump vfd speed cmd point'},
#  {'name': 'chilled water leaving pump vfd speed sensor point'},
#  {'name': 'chilled water leaving temp sensor point'},
#  {'name': 'chilled water leaving temp sp point'},
#  {'name': 'chilled water leaving valve actuator equip'},
#  {'name': 'chilled water leaving valve cmd point'},
#  {'name': 'chilled water leaving valve sensor point'},
#  {'name': 'chilled water mixing valve cmd point'},
#  {'name': 'chilled water valve isolation cmd point'},
#  {'name': 'chiller equip'},
#  {'name': 'circ equip'},
#  {'name': 'circ flow sensor point'},
#  {'name': 'circ flow sp point'},
#  {'name': 'circ pipe equip'},
#  {'name': 'circ point'},
#  {'name': 'circ pressure sensor point'},
#  {'name': 'circ pressure sp point'},
#  {'name': 'circ pump alarm sensor point'},
#  {'name': 'circ pump enable cmd point'},
#  {'name': 'circ pump enable sensor point'},
#  {'name': 'circ pump equip'},
#  {'name': 'circ pump motor equip'},
#  {'name': 'circ pump point'},
#  {'name': 'circ pump run cmd point'},
#  {'name': 'circ pump run sensor point'},
#  {'name': 'circ pump vfd freq cmd point'},
#  {'name': 'circ pump vfd freq sensor point'},
#  {'name': 'circ pump vfd speed cmd point'},
#  {'name': 'circ pump vfd speed sensor point'},
#  {'name': 'circ temp sensor point'},
#  {'name': 'circ temp sp point'},
#  {'name': 'circ valve actuator equip'},
#  {'name': 'circ valve cmd point'},
#  {'name': 'circ valve sensor point'},
#  {'name': 'condensate entering equip'},
#  {'name': 'condensate entering flow sensor point'},
#  {'name': 'condensate entering flow sp point'},
#  {'name': 'condensate entering pipe equip'},
#  {'name': 'condensate entering point'},
#  {'name': 'condensate entering pressure sensor point'},
#  {'name': 'condensate entering pressure sp point'},
#  {'name': 'condensate entering pump alarm sensor point'},
#  {'name': 'condensate entering pump enable cmd point'},
#  {'name': 'condensate entering pump enable sensor point'},
#  {'name': 'condensate entering pump equip'},
#  {'name': 'condensate entering pump motor equip'},
#  {'name': 'condensate entering pump point'},
#  {'name': 'condensate entering pump run cmd point'},
#  {'name': 'condensate entering pump run sensor point'},
#  {'name': 'condensate entering pump vfd freq cmd point'},
#  {'name': 'condensate entering pump vfd freq sensor point'},
#  {'name': 'condensate entering pump vfd speed cmd point'},
#  {'name': 'condensate entering pump vfd speed sensor point'},
#  {'name': 'condensate entering temp sensor point'},
#  {'name': 'condensate entering temp sp point'},
#  {'name': 'condensate entering valve actuator equip'},
#  {'name': 'condensate entering valve cmd point'},
#  {'name': 'condensate entering valve sensor point'},
#  {'name': 'condenser refrig pressure sensor point'},
#  {'name': 'condenser refrig temp sensor point'},
#  {'name': 'condenser run cmd point'},
#  {'name': 'condenser run sensor point'},
#  {'name': 'condenser water bypass equip'},
#  {'name': 'condenser water bypass flow sensor point'},
#  {'name': 'condenser water bypass flow sp point'},
#  {'name': 'condenser water bypass pipe equip'},
#  {'name': 'condenser water bypass point'},
#  {'name': 'condenser water bypass pressure sensor point'},
#  {'name': 'condenser water bypass pressure sp point'},
#  {'name': 'condenser water bypass pump alarm sensor point'},
#  {'name': 'condenser water bypass pump enable cmd point'},
#  {'name': 'condenser water bypass pump enable sensor point'},
#  {'name': 'condenser water bypass pump equip'},
#  {'name': 'condenser water bypass pump motor equip'},
#  {'name': 'condenser water bypass pump point'},
#  {'name': 'condenser water bypass pump run cmd point'},
#  {'name': 'condenser water bypass pump run sensor point'},
#  {'name': 'condenser water bypass pump vfd freq cmd point'},
#  {'name': 'condenser water bypass pump vfd freq sensor point'},
#  {'name': 'condenser water bypass pump vfd speed cmd point'},
#  {'name': 'condenser water bypass pump vfd speed sensor point'},
#  {'name': 'condenser water bypass temp sensor point'},
#  {'name': 'condenser water bypass temp sp point'},
#  {'name': 'condenser water bypass valve actuator equip'},
#  {'name': 'condenser water bypass valve cmd point'},
#  {'name': 'condenser water bypass valve sensor point'},
#  {'name': 'condenser water delta flow sensor point'},
#  {'name': 'condenser water delta pressure sensor point'},
#  {'name': 'condenser water delta temp sensor point'},
#  {'name': 'condenser water entering equip'},
#  {'name': 'condenser water entering flow sensor point'},
#  {'name': 'condenser water entering flow sp point'},
#  {'name': 'condenser water entering pipe equip'},
#  {'name': 'condenser water entering point'},
#  {'name': 'condenser water entering pressure sensor point'},
#  {'name': 'condenser water entering pressure sp point'},
#  {'name': 'condenser water entering pump alarm sensor point'},
#  {'name': 'condenser water entering pump enable cmd point'},
#  {'name': 'condenser water entering pump enable sensor point'},
#  {'name': 'condenser water entering pump equip'},
#  {'name': 'condenser water entering pump motor equip'},
#  {'name': 'condenser water entering pump point'},
#  {'name': 'condenser water entering pump run cmd point'},
#  {'name': 'condenser water entering pump run sensor point'},
#  {'name': 'condenser water entering pump vfd freq cmd point'},
#  {'name': 'condenser water entering pump vfd freq sensor point'},
#  {'name': 'condenser water entering pump vfd speed cmd point'},
#  {'name': 'condenser water entering pump vfd speed sensor point'},
#  {'name': 'condenser water entering temp sensor point'},
#  {'name': 'condenser water entering temp sp point'},
#  {'name': 'condenser water entering valve actuator equip'},
#  {'name': 'condenser water entering valve cmd point'},
#  {'name': 'condenser water entering valve sensor point'},
#  {'name': 'condenser water leaving equip'},
#  {'name': 'condenser water leaving flow sensor point'},
#  {'name': 'condenser water leaving flow sp point'},
#  {'name': 'condenser water leaving pipe equip'},
#  {'name': 'condenser water leaving point'},
#  {'name': 'condenser water leaving pressure sensor point'},
#  {'name': 'condenser water leaving pressure sp point'},
#  {'name': 'condenser water leaving pump alarm sensor point'},
#  {'name': 'condenser water leaving pump enable cmd point'},
#  {'name': 'condenser water leaving pump enable sensor point'},
#  {'name': 'condenser water leaving pump equip'},
#  {'name': 'condenser water leaving pump motor equip'},
#  {'name': 'condenser water leaving pump point'},
#  {'name': 'condenser water leaving pump run cmd point'},
#  {'name': 'condenser water leaving pump run sensor point'},
#  {'name': 'condenser water leaving pump vfd freq cmd point'},
#  {'name': 'condenser water leaving pump vfd freq sensor point'},
#  {'name': 'condenser water leaving pump vfd speed cmd point'},
#  {'name': 'condenser water leaving pump vfd speed sensor point'},
#  {'name': 'condenser water leaving temp sensor point'},
#  {'name': 'condenser water leaving temp sp point'},
#  {'name': 'condenser water leaving valve actuator equip'},
#  {'name': 'condenser water leaving valve cmd point'},
#  {'name': 'condenser water leaving valve sensor point'},
#  {'name': 'condenser water valve isolation cmd point'},
#  {'name': 'controller device'},
#  {'name': 'cool cmd point'},
#  {'name': 'cool water flow thermal meter equip'},
#  {'name': 'cool well equip'},
#  {'name': 'coolingCoil equip'},
#  {'name': 'coolingTower equip'},
#  {'name': 'crac fcu equip'},
#  {'name': 'damper actuator equip'},
#  {'name': 'damper cmd point'},
#  {'name': 'damper sensor point'},
#  {'name': 'dc elec stateOfCharge sensor point'},
#  {'name': 'dessicantDehumidifier cmd point'},
#  {'name': 'discharge air co2 concentration sensor point'},
#  {'name': 'discharge air co2 concentration sp point'},
#  {'name': 'discharge air dewPoint sensor point'},
#  {'name': 'discharge air dewPoint sp point'},
#  {'name': 'discharge air enthalpy sensor point'},
#  {'name': 'discharge air enthalpy sp point'},
#  {'name': 'discharge air flow sensor point'},
#  {'name': 'discharge air flow sp point'},
#  {'name': 'discharge air humidity sensor point'},
#  {'name': 'discharge air humidity sp point'},
#  {'name': 'discharge air pressure sensor point'},
#  {'name': 'discharge air pressure sp point'},
#  {'name': 'discharge air temp sensor point'},
#  {'name': 'discharge air temp sp point'},
#  {'name': 'discharge chilled water cool valve cmd point'},
#  {'name': 'discharge coolingCoil equip'},
#  {'name': 'discharge damper actuator equip'},
#  {'name': 'discharge damper cmd point'},
#  {'name': 'discharge damper sensor point'},
#  {'name': 'discharge duct equip'},
#  {'name': 'discharge equip'},
#  {'name': 'discharge fan alarm sensor point'},
#  {'name': 'discharge fan enable cmd point'},
#  {'name': 'discharge fan enable sensor point'},
#  {'name': 'discharge fan equip'},
#  {'name': 'discharge fan motor equip'},
#  {'name': 'discharge fan point'},
#  {'name': 'discharge fan run cmd point'},
#  {'name': 'discharge fan run sensor point'},
#  {'name': 'discharge fan vfd freq cmd point'},
#  {'name': 'discharge fan vfd freq sensor point'},
#  {'name': 'discharge fan vfd speed cmd point'},
#  {'name': 'discharge fan vfd speed sensor point'},
#  {'name': 'discharge heatingCoil equip'},
#  {'name': 'discharge hot water heat valve cmd point'},
#  {'name': 'discharge point'},
#  {'name': 'discharge stage:1 cool run cmd point'},
#  {'name': 'discharge stage:1 heat run cmd point'},
#  {'name': 'discharge steam heat valve cmd point'},
#  {'name': 'ductArea sp point'},
#  {'name': 'economizer air co2 concentration sensor point'},
#  {'name': 'economizer air co2 concentration sp point'},
#  {'name': 'economizer air dewPoint sensor point'},
#  {'name': 'economizer air dewPoint sp point'},
#  {'name': 'economizer air enthalpy sensor point'},
#  {'name': 'economizer air enthalpy sp point'},
#  {'name': 'economizer air flow sensor point'},
#  {'name': 'economizer air flow sp point'},
#  {'name': 'economizer air humidity sensor point'},
#  {'name': 'economizer air humidity sp point'},
#  {'name': 'economizer air pressure sensor point'},
#  {'name': 'economizer air pressure sp point'},
#  {'name': 'economizer air temp sensor point'},
#  {'name': 'economizer air temp sp point'},
#  {'name': 'economizer chilled water cool valve cmd point'},
#  {'name': 'economizer coolingCoil equip'},
#  {'name': 'economizer damper actuator equip'},
#  {'name': 'economizer damper cmd point'},
#  {'name': 'economizer damper sensor point'},
#  {'name': 'economizer duct equip'},
#  {'name': 'economizer equip'},
#  {'name': 'economizer fan alarm sensor point'},
#  {'name': 'economizer fan enable cmd point'},
#  {'name': 'economizer fan enable sensor point'},
#  {'name': 'economizer fan equip'},
#  {'name': 'economizer fan motor equip'},
#  {'name': 'economizer fan point'},
#  {'name': 'economizer fan run cmd point'},
#  {'name': 'economizer fan run sensor point'},
#  {'name': 'economizer fan vfd freq cmd point'},
#  {'name': 'economizer fan vfd freq sensor point'},
#  {'name': 'economizer fan vfd speed cmd point'},
#  {'name': 'economizer fan vfd speed sensor point'},
#  {'name': 'economizer heatingCoil equip'},
#  {'name': 'economizer hot water heat valve cmd point'},
#  {'name': 'economizer point'},
#  {'name': 'economizer stage:1 cool run cmd point'},
#  {'name': 'economizer stage:1 heat run cmd point'},
#  {'name': 'economizer steam heat valve cmd point'},
#  {'name': 'economizing cmd point'},
#  {'name': 'efficiency sensor point'},
#  {'name': 'enable cmd point'},
#  {'name': 'enable sensor point'},
#  {'name': 'equip'},
#  {'name': 'evaporator refrig pressure sensor point'},
#  {'name': 'evaporator refrig temp sensor point'},
#  {'name': 'evse cable equip'},
#  {'name': 'evse evseStatus sensor point'},
#  {'name': 'evse port equip'},
#  {'name': 'exhaust air co2 concentration sensor point'},
#  {'name': 'exhaust air co2 concentration sp point'},
#  {'name': 'exhaust air dewPoint sensor point'},
#  {'name': 'exhaust air dewPoint sp point'},
#  {'name': 'exhaust air enthalpy sensor point'},
#  {'name': 'exhaust air enthalpy sp point'},
#  {'name': 'exhaust air flow sensor point'},
#  {'name': 'exhaust air flow sp point'},
#  {'name': 'exhaust air humidity sensor point'},
#  {'name': 'exhaust air humidity sp point'},
#  {'name': 'exhaust air pressure sensor point'},
#  {'name': 'exhaust air pressure sp point'},
#  {'name': 'exhaust air temp sensor point'},
#  {'name': 'exhaust air temp sp point'},
#  {'name': 'exhaust chilled water cool valve cmd point'},
#  {'name': 'exhaust coolingCoil equip'},
#  {'name': 'exhaust damper actuator equip'},
#  {'name': 'exhaust damper cmd point'},
#  {'name': 'exhaust damper sensor point'},
#  {'name': 'exhaust duct equip'},
#  {'name': 'exhaust equip'},
#  {'name': 'exhaust fan alarm sensor point'},
#  {'name': 'exhaust fan enable cmd point'},
#  {'name': 'exhaust fan enable sensor point'},
#  {'name': 'exhaust fan equip'},
#  {'name': 'exhaust fan motor equip'},
#  {'name': 'exhaust fan point'},
#  {'name': 'exhaust fan run cmd point'},
#  {'name': 'exhaust fan run sensor point'},
#  {'name': 'exhaust fan vfd freq cmd point'},
#  {'name': 'exhaust fan vfd freq sensor point'},
#  {'name': 'exhaust fan vfd speed cmd point'},
#  {'name': 'exhaust fan vfd speed sensor point'},
#  {'name': 'exhaust heatingCoil equip'},
#  {'name': 'exhaust hot water heat valve cmd point'},
#  {'name': 'exhaust point'},
#  {'name': 'exhaust stage:1 cool run cmd point'},
#  {'name': 'exhaust stage:1 heat run cmd point'},
#  {'name': 'exhaust steam heat valve cmd point'},
#  {'name': 'extraction well equip'},
#  {'name': 'faceBypass cmd point'},
#  {'name': 'fan alarm sensor point'},
#  {'name': 'fan enable cmd point'},
#  {'name': 'fan enable sensor point'},
#  {'name': 'fan equip'},
#  {'name': 'fan motor equip'},
#  {'name': 'fan point'},
#  {'name': 'fan run cmd point'},
#  {'name': 'fan run sensor point'},
#  {'name': 'fan vfd freq cmd point'},
#  {'name': 'fan vfd freq sensor point'},
#  {'name': 'fan vfd speed cmd point'},
#  {'name': 'fan vfd speed sensor point'},
#  {'name': 'filter sensor point'},
#  {'name': 'flow sensor point'},
#  {'name': 'flow sp point'},
#  {'name': 'flowInverter equip'},
#  {'name': 'flue air co2 concentration sensor point'},
#  {'name': 'flue air co2 concentration sp point'},
#  {'name': 'flue air dewPoint sensor point'},
#  {'name': 'flue air dewPoint sp point'},
#  {'name': 'flue air enthalpy sensor point'},
#  {'name': 'flue air enthalpy sp point'},
#  {'name': 'flue air flow sensor point'},
#  {'name': 'flue air flow sp point'},
#  {'name': 'flue air humidity sensor point'},
#  {'name': 'flue air humidity sp point'},
#  {'name': 'flue air pressure sensor point'},
#  {'name': 'flue air pressure sp point'},
#  {'name': 'flue air temp sensor point'},
#  {'name': 'flue air temp sp point'},
#  {'name': 'flue chilled water cool valve cmd point'},
#  {'name': 'flue coolingCoil equip'},
#  {'name': 'flue damper actuator equip'},
#  {'name': 'flue damper cmd point'},
#  {'name': 'flue damper sensor point'},
#  {'name': 'flue duct equip'},
#  {'name': 'flue equip'},
#  {'name': 'flue fan alarm sensor point'},
#  {'name': 'flue fan enable cmd point'},
#  {'name': 'flue fan enable sensor point'},
#  {'name': 'flue fan equip'},
#  {'name': 'flue fan motor equip'},
#  {'name': 'flue fan point'},
#  {'name': 'flue fan run cmd point'},
#  {'name': 'flue fan run sensor point'},
#  {'name': 'flue fan vfd freq cmd point'},
#  {'name': 'flue fan vfd freq sensor point'},
#  {'name': 'flue fan vfd speed cmd point'},
#  {'name': 'flue fan vfd speed sensor point'},
#  {'name': 'flue heatingCoil equip'},
#  {'name': 'flue hot water heat valve cmd point'},
#  {'name': 'flue point'},
#  {'name': 'flue stage:1 cool run cmd point'},
#  {'name': 'flue stage:1 heat run cmd point'},
#  {'name': 'flue steam heat valve cmd point'},
#  {'name': 'freezeStat sensor point'},
#  {'name': 'ground water flow sensor point'},
#  {'name': 'ground water pressure sensor point'},
#  {'name': 'ground water volume sensor point'},
#  {'name': 'heat cmd point'},
#  {'name': 'heatExchanger equip'},
#  {'name': 'heatWheel cmd point'},
#  {'name': 'heatingCoil equip'},
#  {'name': 'hot water boiler equip'},
#  {'name': 'hot water bypass equip'},
#  {'name': 'hot water bypass flow sensor point'},
#  {'name': 'hot water bypass flow sp point'},
#  {'name': 'hot water bypass pipe equip'},
#  {'name': 'hot water bypass point'},
#  {'name': 'hot water bypass pressure sensor point'},
#  {'name': 'hot water bypass pressure sp point'},
#  {'name': 'hot water bypass pump alarm sensor point'},
#  {'name': 'hot water bypass pump enable cmd point'},
#  {'name': 'hot water bypass pump enable sensor point'},
#  {'name': 'hot water bypass pump equip'},
#  {'name': 'hot water bypass pump motor equip'},
#  {'name': 'hot water bypass pump point'},
#  {'name': 'hot water bypass pump run cmd point'},
#  {'name': 'hot water bypass pump run sensor point'},
#  {'name': 'hot water bypass pump vfd freq cmd point'},
#  {'name': 'hot water bypass pump vfd freq sensor point'},
#  {'name': 'hot water bypass pump vfd speed cmd point'},
#  {'name': 'hot water bypass pump vfd speed sensor point'},
#  {'name': 'hot water bypass temp sensor point'},
#  {'name': 'hot water bypass temp sp point'},
#  {'name': 'hot water bypass valve actuator equip'},
#  {'name': 'hot water bypass valve cmd point'},
#  {'name': 'hot water bypass valve sensor point'},
#  {'name': 'hot water delta flow sensor point'},
#  {'name': 'hot water delta pressure sensor point'},
#  {'name': 'hot water delta temp sensor point'},
#  {'name': 'hot water entering equip'},
#  {'name': 'hot water entering flow sensor point'},
#  {'name': 'hot water entering flow sp point'},
#  {'name': 'hot water entering pipe equip'},
#  {'name': 'hot water entering point'},
#  {'name': 'hot water entering pressure sensor point'},
#  {'name': 'hot water entering pressure sp point'},
#  {'name': 'hot water entering pump alarm sensor point'},
#  {'name': 'hot water entering pump enable cmd point'},
#  {'name': 'hot water entering pump enable sensor point'},
#  {'name': 'hot water entering pump equip'},
#  {'name': 'hot water entering pump motor equip'},
#  {'name': 'hot water entering pump point'},
#  {'name': 'hot water entering pump run cmd point'},
#  {'name': 'hot water entering pump run sensor point'},
#  {'name': 'hot water entering pump vfd freq cmd point'},
#  {'name': 'hot water entering pump vfd freq sensor point'},
#  {'name': 'hot water entering pump vfd speed cmd point'},
#  {'name': 'hot water entering pump vfd speed sensor point'},
#  {'name': 'hot water entering temp sensor point'},
#  {'name': 'hot water entering temp sp point'},
#  {'name': 'hot water entering valve actuator equip'},
#  {'name': 'hot water entering valve cmd point'},
#  {'name': 'hot water entering valve sensor point'},
#  {'name': 'hot water header equip'},
#  {'name': 'hot water header flow sensor point'},
#  {'name': 'hot water header flow sp point'},
#  {'name': 'hot water header pipe equip'},
#  {'name': 'hot water header point'},
#  {'name': 'hot water header pressure sensor point'},
#  {'name': 'hot water header pressure sp point'},
#  {'name': 'hot water header pump alarm sensor point'},
#  {'name': 'hot water header pump enable cmd point'},
#  {'name': 'hot water header pump enable sensor point'},
#  {'name': 'hot water header pump equip'},
#  {'name': 'hot water header pump motor equip'},
#  {'name': 'hot water header pump point'},
#  {'name': 'hot water header pump run cmd point'},
#  {'name': 'hot water header pump run sensor point'},
#  {'name': 'hot water header pump vfd freq cmd point'},
#  {'name': 'hot water header pump vfd freq sensor point'},
#  {'name': 'hot water header pump vfd speed cmd point'},
#  {'name': 'hot water header pump vfd speed sensor point'},
#  {'name': 'hot water header temp sensor point'},
#  {'name': 'hot water header temp sp point'},
#  {'name': 'hot water header valve actuator equip'},
#  {'name': 'hot water header valve cmd point'},
#  {'name': 'hot water header valve sensor point'},
#  {'name': 'hot water heat valve cmd point'},
#  {'name': 'hot water heatExchanger equip'},
#  {'name': 'hot water leaving equip'},
#  {'name': 'hot water leaving flow sensor point'},
#  {'name': 'hot water leaving flow sp point'},
#  {'name': 'hot water leaving pipe equip'},
#  {'name': 'hot water leaving point'},
#  {'name': 'hot water leaving pressure sensor point'},
#  {'name': 'hot water leaving pressure sp point'},
#  {'name': 'hot water leaving pump alarm sensor point'},
#  {'name': 'hot water leaving pump enable cmd point'},
#  {'name': 'hot water leaving pump enable sensor point'},
#  {'name': 'hot water leaving pump equip'},
#  {'name': 'hot water leaving pump motor equip'},
#  {'name': 'hot water leaving pump point'},
#  {'name': 'hot water leaving pump run cmd point'},
#  {'name': 'hot water leaving pump run sensor point'},
#  {'name': 'hot water leaving pump vfd freq cmd point'},
#  {'name': 'hot water leaving pump vfd freq sensor point'},
#  {'name': 'hot water leaving pump vfd speed cmd point'},
#  {'name': 'hot water leaving pump vfd speed sensor point'},
#  {'name': 'hot water leaving temp sensor point'},
#  {'name': 'hot water leaving temp sp point'},
#  {'name': 'hot water leaving valve actuator equip'},
#  {'name': 'hot water leaving valve cmd point'},
#  {'name': 'hot water leaving valve sensor point'},
#  {'name': 'hot water mixing valve cmd point'},
#  {'name': 'humidifier enable cmd point'},
#  {'name': 'humidifier equip'},
#  {'name': 'humidifier run cmd point'},
#  {'name': 'hvacMode sp point'},
#  {'name': 'import ac elec active energy hisTotalized sensor point'},
#  {'name': 'import ac elec active power max sp point'},
#  {'name': 'import ac elec active power sensor point'},
#  {'name': 'import ac elec magnitude current max sp point'},
#  {'name': 'import ac elec magnitude current sensor point'},
#  {'name': 'import ac elec magnitude volt sensor point'},
#  {'name': 'import ac elec pfScope pf sensor point'},
#  {'name': 'import dc elec current max sp point'},
#  {'name': 'import dc elec current sensor point'},
#  {'name': 'import dc elec energy hisTotalized sensor point'},
#  {'name': 'import dc elec power max sp point'},
#  {'name': 'import dc elec power sensor point'},
#  {'name': 'import dc elec volt sensor point'},
#  {'name': 'infiltration well equip'},
#  {'name': 'inlet air co2 concentration sensor point'},
#  {'name': 'inlet air co2 concentration sp point'},
#  {'name': 'inlet air dewPoint sensor point'},
#  {'name': 'inlet air dewPoint sp point'},
#  {'name': 'inlet air enthalpy sensor point'},
#  {'name': 'inlet air enthalpy sp point'},
#  {'name': 'inlet air flow sensor point'},
#  {'name': 'inlet air flow sp point'},
#  {'name': 'inlet air humidity sensor point'},
#  {'name': 'inlet air humidity sp point'},
#  {'name': 'inlet air pressure sensor point'},
#  {'name': 'inlet air pressure sp point'},
#  {'name': 'inlet air temp sensor point'},
#  {'name': 'inlet air temp sp point'},
#  {'name': 'inlet chilled water cool valve cmd point'},
#  {'name': 'inlet coolingCoil equip'},
#  {'name': 'inlet damper actuator equip'},
#  {'name': 'inlet damper cmd point'},
#  {'name': 'inlet damper sensor point'},
#  {'name': 'inlet duct equip'},
#  {'name': 'inlet equip'},
#  {'name': 'inlet fan alarm sensor point'},
#  {'name': 'inlet fan enable cmd point'},
#  {'name': 'inlet fan enable sensor point'},
#  {'name': 'inlet fan equip'},
#  {'name': 'inlet fan motor equip'},
#  {'name': 'inlet fan point'},
#  {'name': 'inlet fan run cmd point'},
#  {'name': 'inlet fan run sensor point'},
#  {'name': 'inlet fan vfd freq cmd point'},
#  {'name': 'inlet fan vfd freq sensor point'},
#  {'name': 'inlet fan vfd speed cmd point'},
#  {'name': 'inlet fan vfd speed sensor point'},
#  {'name': 'inlet heatingCoil equip'},
#  {'name': 'inlet hot water heat valve cmd point'},
#  {'name': 'inlet point'},
#  {'name': 'inlet stage:1 cool run cmd point'},
#  {'name': 'inlet stage:1 heat run cmd point'},
#  {'name': 'inlet steam heat valve cmd point'},
#  {'name': 'level sensor point'},
#  {'name': 'light illuminance sensor point'},
#  {'name': 'light level sensor point'},
#  {'name': 'light level sp point'},
#  {'name': 'light luminous flux sensor point'},
#  {'name': 'load cmd point'},
#  {'name': 'load sensor point'},
#  {'name': 'makeup water entering equip'},
#  {'name': 'makeup water entering flow sensor point'},
#  {'name': 'makeup water entering flow sp point'},
#  {'name': 'makeup water entering pipe equip'},
#  {'name': 'makeup water entering point'},
#  {'name': 'makeup water entering pressure sensor point'},
#  {'name': 'makeup water entering pressure sp point'},
#  {'name': 'makeup water entering pump alarm sensor point'},
#  {'name': 'makeup water entering pump enable cmd point'},
#  {'name': 'makeup water entering pump enable sensor point'},
#  {'name': 'makeup water entering pump equip'},
#  {'name': 'makeup water entering pump motor equip'},
#  {'name': 'makeup water entering pump point'},
#  {'name': 'makeup water entering pump run cmd point'},
#  {'name': 'makeup water entering pump run sensor point'},
#  {'name': 'makeup water entering pump vfd freq cmd point'},
#  {'name': 'makeup water entering pump vfd freq sensor point'},
#  {'name': 'makeup water entering pump vfd speed cmd point'},
#  {'name': 'makeup water entering pump vfd speed sensor point'},
#  {'name': 'makeup water entering temp sensor point'},
#  {'name': 'makeup water entering temp sp point'},
#  {'name': 'makeup water entering valve actuator equip'},
#  {'name': 'makeup water entering valve cmd point'},
#  {'name': 'makeup water entering valve sensor point'},
#  {'name': 'mixed air co2 concentration sensor point'},
#  {'name': 'mixed air co2 concentration sp point'},
#  {'name': 'mixed air dewPoint sensor point'},
#  {'name': 'mixed air dewPoint sp point'},
#  {'name': 'mixed air enthalpy sensor point'},
#  {'name': 'mixed air enthalpy sp point'},
#  {'name': 'mixed air flow sensor point'},
#  {'name': 'mixed air flow sp point'},
#  {'name': 'mixed air humidity sensor point'},
#  {'name': 'mixed air humidity sp point'},
#  {'name': 'mixed air pressure sensor point'},
#  {'name': 'mixed air pressure sp point'},
#  {'name': 'mixed air temp sensor point'},
#  {'name': 'mixed air temp sp point'},
#  {'name': 'mixed chilled water cool valve cmd point'},
#  {'name': 'mixed coolingCoil equip'},
#  {'name': 'mixed damper actuator equip'},
#  {'name': 'mixed damper cmd point'},
#  {'name': 'mixed damper sensor point'},
#  {'name': 'mixed duct equip'},
#  {'name': 'mixed equip'},
#  {'name': 'mixed fan alarm sensor point'},
#  {'name': 'mixed fan enable cmd point'},
#  {'name': 'mixed fan enable sensor point'},
#  {'name': 'mixed fan equip'},
#  {'name': 'mixed fan motor equip'},
#  {'name': 'mixed fan point'},
#  {'name': 'mixed fan run cmd point'},
#  {'name': 'mixed fan run sensor point'},
#  {'name': 'mixed fan vfd freq cmd point'},
#  {'name': 'mixed fan vfd freq sensor point'},
#  {'name': 'mixed fan vfd speed cmd point'},
#  {'name': 'mixed fan vfd speed sensor point'},
#  {'name': 'mixed heatingCoil equip'},
#  {'name': 'mixed hot water heat valve cmd point'},
#  {'name': 'mixed point'},
#  {'name': 'mixed stage:1 cool run cmd point'},
#  {'name': 'mixed stage:1 heat run cmd point'},
#  {'name': 'mixed steam heat valve cmd point'},
#  {'name': 'networking device'},
#  {'name': 'occupancy sensor point'},
#  {'name': 'occupied sensor point'},
#  {'name': 'occupied sp point'},
#  {'name': 'outside air co2 concentration sensor point'},
#  {'name': 'outside air co2 concentration sp point'},
#  {'name': 'outside air dewPoint sensor point'},
#  {'name': 'outside air dewPoint sp point'},
#  {'name': 'outside air enthalpy sensor point'},
#  {'name': 'outside air enthalpy sp point'},
#  {'name': 'outside air flow sensor point'},
#  {'name': 'outside air flow sp point'},
#  {'name': 'outside air humidity sensor point'},
#  {'name': 'outside air humidity sp point'},
#  {'name': 'outside air pressure sensor point'},
#  {'name': 'outside air pressure sp point'},
#  {'name': 'outside air temp sensor point'},
#  {'name': 'outside air temp sp point'},
#  {'name': 'outside chilled water cool valve cmd point'},
#  {'name': 'outside coolingCoil equip'},
#  {'name': 'outside damper actuator equip'},
#  {'name': 'outside damper cmd point'},
#  {'name': 'outside damper sensor point'},
#  {'name': 'outside duct equip'},
#  {'name': 'outside equip'},
#  {'name': 'outside fan alarm sensor point'},
#  {'name': 'outside fan enable cmd point'},
#  {'name': 'outside fan enable sensor point'},
#  {'name': 'outside fan equip'},
#  {'name': 'outside fan motor equip'},
#  {'name': 'outside fan point'},
#  {'name': 'outside fan run cmd point'},
#  {'name': 'outside fan run sensor point'},
#  {'name': 'outside fan vfd freq cmd point'},
#  {'name': 'outside fan vfd freq sensor point'},
#  {'name': 'outside fan vfd speed cmd point'},
#  {'name': 'outside fan vfd speed sensor point'},
#  {'name': 'outside heatingCoil equip'},
#  {'name': 'outside hot water heat valve cmd point'},
#  {'name': 'outside point'},
#  {'name': 'outside stage:1 cool run cmd point'},
#  {'name': 'outside stage:1 heat run cmd point'},
#  {'name': 'outside steam heat valve cmd point'},
#  {'name': 'perimeterHeat cmd point'},
#  {'name': 'phase:"A" ac elec current angle sensor point'},
#  {'name': 'phase:"A" ac elec current imbalance sensor point'},
#  {'name': 'phase:"A" ac elec current magnitude sensor point'},
#  {'name': 'phase:"A" ac elec current thd sensor point'},
#  {'name': 'phase:"A" ac elec pf sensor point'},
#  {'name': 'phase:"A" ac elec volt angle sensor point'},
#  {'name': 'phase:"A" ac elec volt imbalance sensor point'},
#  {'name': 'phase:"A" ac elec volt magnitude sensor point'},
#  {'name': 'phase:"A" ac elec volt thd sensor point'},
#  {'name': 'phase:"A" active ac elec power sensor point'},
#  {'name': 'phase:"A" apparent ac elec power sensor point'},
#  {'name': 'phase:"A" net ac elec active energy sensor point'},
#  {'name': 'phase:"A" reactive ac elec power sensor point'},
#  {'name': 'point'},
#  {'name': 'pressure sensor point'},
#  {'name': 'pressure sp point'},
#  {'name': 'pump alarm sensor point'},
#  {'name': 'pump enable cmd point'},
#  {'name': 'pump enable sensor point'},
#  {'name': 'pump equip'},
#  {'name': 'pump motor equip'},
#  {'name': 'pump point'},
#  {'name': 'pump run cmd point'},
#  {'name': 'pump run sensor point'},
#  {'name': 'pump vfd freq cmd point'},
#  {'name': 'pump vfd freq sensor point'},
#  {'name': 'pump vfd speed cmd point'},
#  {'name': 'pump vfd speed sensor point'},
#  {'name': 'purge water flow sensor point'},
#  {'name': 'purge water volume sensor point'},
#  {'name': 'rack equip'},
#  {'name': 'reheat cmd point'},
#  {'name': 'return air co2 concentration sensor point'},
#  {'name': 'return air co2 concentration sp point'},
#  {'name': 'return air dewPoint sensor point'},
#  {'name': 'return air dewPoint sp point'},
#  {'name': 'return air enthalpy sensor point'},
#  {'name': 'return air enthalpy sp point'},
#  {'name': 'return air flow sensor point'},
#  {'name': 'return air flow sp point'},
#  {'name': 'return air humidity sensor point'},
#  {'name': 'return air humidity sp point'},
#  {'name': 'return air pressure sensor point'},
#  {'name': 'return air pressure sp point'},
#  {'name': 'return air temp sensor point'},
#  {'name': 'return air temp sp point'},
#  {'name': 'return chilled water cool valve cmd point'},
#  {'name': 'return coolingCoil equip'},
#  {'name': 'return damper actuator equip'},
#  {'name': 'return damper cmd point'},
#  {'name': 'return damper sensor point'},
#  {'name': 'return duct equip'},
#  {'name': 'return equip'},
#  {'name': 'return fan alarm sensor point'},
#  {'name': 'return fan enable cmd point'},
#  {'name': 'return fan enable sensor point'},
#  {'name': 'return fan equip'},
#  {'name': 'return fan motor equip'},
#  {'name': 'return fan point'},
#  {'name': 'return fan run cmd point'},
#  {'name': 'return fan run sensor point'},
#  {'name': 'return fan vfd freq cmd point'},
#  {'name': 'return fan vfd freq sensor point'},
#  {'name': 'return fan vfd speed cmd point'},
#  {'name': 'return fan vfd speed sensor point'},
#  {'name': 'return heatingCoil equip'},
#  {'name': 'return hot water heat valve cmd point'},
#  {'name': 'return point'},
#  {'name': 'return stage:1 cool run cmd point'},
#  {'name': 'return stage:1 heat run cmd point'},
#  {'name': 'return steam heat valve cmd point'},
#  {'name': 'run cmd point'},
#  {'name': 'run sensor point'},
#  {'name': 'server device'},
#  {'name': 'space'},
#  {'name': 'stage:1 cool run cmd point'},
#  {'name': 'stage:1 heat run cmd point'},
#  {'name': 'steam boiler equip'},
#  {'name': 'steam bypass equip'},
#  {'name': 'steam bypass flow sensor point'},
#  {'name': 'steam bypass flow sp point'},
#  {'name': 'steam bypass pipe equip'},
#  {'name': 'steam bypass point'},
#  {'name': 'steam bypass pressure sensor point'},
#  {'name': 'steam bypass pressure sp point'},
#  {'name': 'steam bypass pump alarm sensor point'},
#  {'name': 'steam bypass pump enable cmd point'},
#  {'name': 'steam bypass pump enable sensor point'},
#  {'name': 'steam bypass pump equip'},
#  {'name': 'steam bypass pump motor equip'},
#  {'name': 'steam bypass pump point'},
#  {'name': 'steam bypass pump run cmd point'},
#  {'name': 'steam bypass pump run sensor point'},
#  {'name': 'steam bypass pump vfd freq cmd point'},
#  {'name': 'steam bypass pump vfd freq sensor point'},
#  {'name': 'steam bypass pump vfd speed cmd point'},
#  {'name': 'steam bypass pump vfd speed sensor point'},
#  {'name': 'steam bypass temp sensor point'},
#  {'name': 'steam bypass temp sp point'},
#  {'name': 'steam bypass valve actuator equip'},
#  {'name': 'steam bypass valve cmd point'},
#  {'name': 'steam bypass valve sensor point'},
#  {'name': 'steam delta flow sensor point'},
#  {'name': 'steam delta pressure sensor point'},
#  {'name': 'steam delta temp sensor point'},
#  {'name': 'steam header equip'},
#  {'name': 'steam header flow sensor point'},
#  {'name': 'steam header flow sp point'},
#  {'name': 'steam header pipe equip'},
#  {'name': 'steam header point'},
#  {'name': 'steam header pressure sensor point'},
#  {'name': 'steam header pressure sp point'},
#  {'name': 'steam header pump alarm sensor point'},
#  {'name': 'steam header pump enable cmd point'},
#  {'name': 'steam header pump enable sensor point'},
#  {'name': 'steam header pump equip'},
#  {'name': 'steam header pump motor equip'},
#  {'name': 'steam header pump point'},
#  {'name': 'steam header pump run cmd point'},
#  {'name': 'steam header pump run sensor point'},
#  {'name': 'steam header pump vfd freq cmd point'},
#  {'name': 'steam header pump vfd freq sensor point'},
#  {'name': 'steam header pump vfd speed cmd point'},
#  {'name': 'steam header pump vfd speed sensor point'},
#  {'name': 'steam header temp sensor point'},
#  {'name': 'steam header temp sp point'},
#  {'name': 'steam header valve actuator equip'},
#  {'name': 'steam header valve cmd point'},
#  {'name': 'steam header valve sensor point'},
#  {'name': 'steam heat valve cmd point'},
#  {'name': 'steam heatExchanger equip'},
#  {'name': 'steam leaving equip'},
#  {'name': 'steam leaving flow sensor point'},
#  {'name': 'steam leaving flow sp point'},
#  {'name': 'steam leaving pipe equip'},
#  {'name': 'steam leaving point'},
#  {'name': 'steam leaving pressure sensor point'},
#  {'name': 'steam leaving pressure sp point'},
#  {'name': 'steam leaving pump alarm sensor point'},
#  {'name': 'steam leaving pump enable cmd point'},
#  {'name': 'steam leaving pump enable sensor point'},
#  {'name': 'steam leaving pump equip'},
#  {'name': 'steam leaving pump motor equip'},
#  {'name': 'steam leaving pump point'},
#  {'name': 'steam leaving pump run cmd point'},
#  {'name': 'steam leaving pump run sensor point'},
#  {'name': 'steam leaving pump vfd freq cmd point'},
#  {'name': 'steam leaving pump vfd freq sensor point'},
#  {'name': 'steam leaving pump vfd speed cmd point'},
#  {'name': 'steam leaving pump vfd speed sensor point'},
#  {'name': 'steam leaving temp sensor point'},
#  {'name': 'steam leaving temp sp point'},
#  {'name': 'steam leaving valve actuator equip'},
#  {'name': 'steam leaving valve cmd point'},
#  {'name': 'steam leaving valve sensor point'},
#  {'name': 'steam mixing valve cmd point'},
#  {'name': 'temp sensor point'},
#  {'name': 'temp sp point'},
#  {'name': 'thermostat equip'},
#  {'name': 'total ac elec demand sensor point'},
#  {'name': 'total active ac elec power sensor point'},
#  {'name': 'total apparent ac elec power sensor point'},
#  {'name': 'total export ac elec active energy sensor point'},
#  {'name': 'total import ac elec active energy sensor point'},
#  {'name': 'total net ac elec active energy sensor point'},
#  {'name': 'total reactive ac elec power sensor point'},
#  {'name': 'valve actuator equip'},
#  {'name': 'valve cmd point'},
#  {'name': 'valve sensor point'},
#  {'name': 'ventilation air co2 concentration sensor point'},
#  {'name': 'ventilation air co2 concentration sp point'},
#  {'name': 'ventilation air dewPoint sensor point'},
#  {'name': 'ventilation air dewPoint sp point'},
#  {'name': 'ventilation air enthalpy sensor point'},
#  {'name': 'ventilation air enthalpy sp point'},
#  {'name': 'ventilation air flow sensor point'},
#  {'name': 'ventilation air flow sp point'},
#  {'name': 'ventilation air humidity sensor point'},
#  {'name': 'ventilation air humidity sp point'},
#  {'name': 'ventilation air pressure sensor point'},
#  {'name': 'ventilation air pressure sp point'},
#  {'name': 'ventilation air temp sensor point'},
#  {'name': 'ventilation air temp sp point'},
#  {'name': 'ventilation chilled water cool valve cmd point'},
#  {'name': 'ventilation coolingCoil equip'},
#  {'name': 'ventilation damper actuator equip'},
#  {'name': 'ventilation damper cmd point'},
#  {'name': 'ventilation damper sensor point'},
#  {'name': 'ventilation duct equip'},
#  {'name': 'ventilation equip'},
#  {'name': 'ventilation fan alarm sensor point'},
#  {'name': 'ventilation fan enable cmd point'},
#  {'name': 'ventilation fan enable sensor point'},
#  {'name': 'ventilation fan equip'},
#  {'name': 'ventilation fan motor equip'},
#  {'name': 'ventilation fan point'},
#  {'name': 'ventilation fan run cmd point'},
#  {'name': 'ventilation fan run sensor point'},
#  {'name': 'ventilation fan vfd freq cmd point'},
#  {'name': 'ventilation fan vfd freq sensor point'},
#  {'name': 'ventilation fan vfd speed cmd point'},
#  {'name': 'ventilation fan vfd speed sensor point'},
#  {'name': 'ventilation heatingCoil equip'},
#  {'name': 'ventilation hot water heat valve cmd point'},
#  {'name': 'ventilation point'},
#  {'name': 'ventilation stage:1 cool run cmd point'},
#  {'name': 'ventilation stage:1 heat run cmd point'},
#  {'name': 'ventilation steam heat valve cmd point'},
#  {'name': 'vfd freq cmd point'},
#  {'name': 'vfd freq sensor point'},
#  {'name': 'vfd speed cmd point'},
#  {'name': 'vfd speed sensor point'},
#  {'name': 'vrf branchSelector equip'},
#  {'name': 'vrf indoorUnit equip'},
#  {'name': 'vrf outdoorUnit equip'},
#  {'name': 'vrf refrig plant equip'},
#  {'name': 'warm water flow thermal meter equip'},
#  {'name': 'warm well equip'},
#  {'name': 'water flow sensor point'},
#  {'name': 'water level sensor point'},
#  {'name': 'water pressure sensor point'},
#  {'name': 'water pump alarm sensor point'},
#  {'name': 'water pump enable cmd point'},
#  {'name': 'water pump enable sensor point'},
#  {'name': 'water pump equip'},
#  {'name': 'water pump motor equip'},
#  {'name': 'water pump point'},
#  {'name': 'water pump run cmd point'},
#  {'name': 'water pump run sensor point'},
#  {'name': 'water pump vfd freq cmd point'},
#  {'name': 'water pump vfd freq sensor point'},
#  {'name': 'water pump vfd speed cmd point'},
#  {'name': 'water pump vfd speed sensor point'},
#  {'name': 'water temp sensor point'},
#  {'name': 'water volume sensor point'},
#  {'name': 'weather air dewPoint sensor point'},
#  {'name': 'weather air enthalpy sensor point'},
#  {'name': 'weather air feelsLike sensor point'},
#  {'name': 'weather air humidity sensor point'},
#  {'name': 'weather air temp sensor point'},
#  {'name': 'weather air wetBulb sensor point'},
#  {'name': 'weather atmospheric pressure sensor point'},
#  {'name': 'weather cloudage sensor point'},
#  {'name': 'weather daytime sensor point'},
#  {'name': 'weather precipitation sensor point'},
#  {'name': 'weather solar irradiance sensor point'},
#  {'name': 'weather visibility sensor point'},
#  {'name': 'weather weatherCond sensor point'},
#  {'name': 'weather wind direction sensor point'},
#  {'name': 'weather wind speed sensor point'},
#  {'name': 'zone air ch2o concentration sensor point'},
#  {'name': 'zone air co concentration sensor point'},
#  {'name': 'zone air co2 concentration sensor point'},
#  {'name': 'zone air co2 concentration sp point'},
#  {'name': 'zone air dewPoint sensor point'},
#  {'name': 'zone air dewPoint sp point'},
#  {'name': 'zone air enthalpy sensor point'},
#  {'name': 'zone air enthalpy sp point'},
#  {'name': 'zone air humidity sensor point'},
#  {'name': 'zone air humidity sp point'},
#  ...]

# %%
# create a new Mapper object which knows about the definitions. This will
# access OpenAI to compute embeddings if necessary
m = Mapper(defns, "haystack_proto.index")

# define which set of Brick classes we want to match against
# all points which aren't parameters (these have similar enough names it can confuse the mapping)
points = m.get_brick_classes(BRICK.Point, [BRICK.Parameter])
# all equipment in Brick
equips = m.get_brick_classes(BRICK.Equipment)
# concatenate these two lists of Brick classes
bcs = points + equips

# bcs
# Out:
# 2025-01-06 17:16:57.897 | INFO     | brickmapper:populate_external_embeddings:73 - No local 'self.external_index_file' found. Computing embeddings for external concepts
#
# 00%|███████████████████████████████████████████████████████████████████████████████████| 1020/1020 [00:00<00:00, 84241.21it/s]
# ++++
# air co2 concentration sensor point
# ++++
# air co2 concentration sp point
# ++++
# air dewPoint sensor point
# ++++
# air dewPoint sp point
# ++++
# air enthalpy sensor point
# ++++
# air enthalpy sp point
# ++++
# air flow sensor point
# ++++
# air flow sp point
# ++++
# air humidity sensor point
# ++++
# air humidity sp point
# ++++
# air pressure sensor point
# ++++
# air pressure sp point
# ++++
# air temp sensor point
# ++++
# air temp sp point
# ++++
# air velocity sensor point
# ++++
# air velocity sp point
# ++++
# alarm sensor point
# ++++
# avg ac elec current angle sensor point
# ++++
# avg ac elec current imbalance sensor point
# ++++
# avg ac elec current magnitude sensor point
# ++++
# avg ac elec current thd sensor point
# ++++
# avg ac elec pf sensor point
# ++++
# avg ac elec volt angle sensor point
# ++++
# avg ac elec volt imbalance sensor point
# ++++
# avg ac elec volt magnitude sensor point
# ++++
# avg ac elec volt thd sensor point
# ++++
# bypass damper cmd point
# ++++
# chilled water bypass equip
# ++++
# chilled water bypass flow sensor point
# ++++
# chilled water bypass flow sp point
# ++++
# chilled water bypass pipe equip
# ++++
# chilled water bypass point
# ++++
# chilled water bypass pressure sensor point
# ++++
# chilled water bypass pressure sp point
# ++++
# chilled water bypass pump alarm sensor point
# ++++
# chilled water bypass pump enable cmd point
# ++++
# chilled water bypass pump enable sensor point
# ++++
# chilled water bypass pump equip
# ++++
# chilled water bypass pump motor equip
# ++++
# chilled water bypass pump point
# ++++
# chilled water bypass pump run cmd point
# ++++
# chilled water bypass pump run sensor point
# ++++
# chilled water bypass pump vfd freq cmd point
# ++++
# chilled water bypass pump vfd freq sensor point
# ++++
# chilled water bypass pump vfd speed cmd point
# ++++
# chilled water bypass pump vfd speed sensor point
# ++++
# chilled water bypass temp sensor point
# ++++
# chilled water bypass temp sp point
# ++++
# chilled water bypass valve actuator equip
# ++++
# chilled water bypass valve cmd point
# ++++
# chilled water bypass valve sensor point
# ++++
# chilled water cool valve cmd point
# ++++
# chilled water delta flow point
# ++++
# chilled water delta flow sensor point
# ++++
# chilled water delta pressure point
# ++++
# chilled water delta temp point
# ++++
# chilled water delta temp sensor point
# ++++
# chilled water entering equip
# ++++
# chilled water entering flow sensor point
# ++++
# chilled water entering flow sp point
# ++++
# chilled water entering pipe equip
# ++++
# chilled water entering point
# ++++
# chilled water entering pressure sensor point
# ++++
# chilled water entering pressure sp point
# ++++
# chilled water entering pump alarm sensor point
# ++++
# chilled water entering pump enable cmd point
# ++++
# chilled water entering pump enable sensor point
# ++++
# chilled water entering pump equip
# ++++
# chilled water entering pump motor equip
# ++++
# chilled water entering pump point
# ++++
# chilled water entering pump run cmd point
# ++++
# chilled water entering pump run sensor point
# ++++
# chilled water entering pump vfd freq cmd point
# ++++
# chilled water entering pump vfd freq sensor point
# ++++
# chilled water entering pump vfd speed cmd point
# ++++
# chilled water entering pump vfd speed sensor point
# ++++
# chilled water entering temp sensor point
# ++++
# chilled water entering temp sp point
# ++++
# chilled water entering valve actuator equip
# ++++
# chilled water entering valve cmd point
# ++++
# chilled water entering valve sensor point
# ++++
# chilled water header equip
# ++++
# chilled water header flow sensor point
# ++++
# chilled water header flow sp point
# ++++
# chilled water header pipe equip
# ++++
# chilled water header point
# ++++
# chilled water header pressure sensor point
# ++++
# chilled water header pressure sp point
# ++++
# chilled water header pump alarm sensor point
# ++++
# chilled water header pump enable cmd point
# ++++
# chilled water header pump enable sensor point
# ++++
# chilled water header pump equip
# ++++
# chilled water header pump motor equip
# ++++
# chilled water header pump point
# ++++
# chilled water header pump run cmd point
# ++++
# chilled water header pump run sensor point
# ++++
# chilled water header pump vfd freq cmd point
# ++++
# chilled water header pump vfd freq sensor point
# ++++
# chilled water header pump vfd speed cmd point
# ++++
# chilled water header pump vfd speed sensor point
# ++++
# chilled water header temp sensor point
# ++++
# chilled water header temp sp point
# ++++
# chilled water header valve actuator equip
# ++++
# chilled water header valve cmd point
# ++++
# chilled water header valve sensor point
# ++++
# chilled water heatExchanger equip
# ++++
# chilled water leaving equip
# ++++
# chilled water leaving flow sensor point
# ++++
# chilled water leaving flow sp point
# ++++
# chilled water leaving pipe equip
# ++++
# chilled water leaving point
# ++++
# chilled water leaving pressure sensor point
# ++++
# chilled water leaving pressure sp point
# ++++
# chilled water leaving pump alarm sensor point
# ++++
# chilled water leaving pump enable cmd point
# ++++
# chilled water leaving pump enable sensor point
# ++++
# chilled water leaving pump equip
# ++++
# chilled water leaving pump motor equip
# ++++
# chilled water leaving pump point
# ++++
# chilled water leaving pump run cmd point
# ++++
# chilled water leaving pump run sensor point
# ++++
# chilled water leaving pump vfd freq cmd point
# ++++
# chilled water leaving pump vfd freq sensor point
# ++++
# chilled water leaving pump vfd speed cmd point
# ++++
# chilled water leaving pump vfd speed sensor point
# ++++
# chilled water leaving temp sensor point
# ++++
# chilled water leaving temp sp point
# ++++
# chilled water leaving valve actuator equip
# ++++
# chilled water leaving valve cmd point
# ++++
# chilled water leaving valve sensor point
# ++++
# chilled water mixing valve cmd point
# ++++
# chilled water valve isolation cmd point
# ++++
# chiller equip
# ++++
# circ equip
# ++++
# circ flow sensor point
# ++++
# circ flow sp point
# ++++
# circ pipe equip
# ++++
# circ point
# ++++
# circ pressure sensor point
# ++++
# circ pressure sp point
# ++++
# circ pump alarm sensor point
# ++++
# circ pump enable cmd point
# ++++
# circ pump enable sensor point
# ++++
# circ pump equip
# ++++
# circ pump motor equip
# ++++
# circ pump point
# ++++
# circ pump run cmd point
# ++++
# circ pump run sensor point
# ++++
# circ pump vfd freq cmd point
# ++++
# circ pump vfd freq sensor point
# ++++
# circ pump vfd speed cmd point
# ++++
# circ pump vfd speed sensor point
# ++++
# circ temp sensor point
# ++++
# circ temp sp point
# ++++
# circ valve actuator equip
# ++++
# circ valve cmd point
# ++++
# circ valve sensor point
# ++++
# condensate entering equip
# ++++
# condensate entering flow sensor point
# ++++
# condensate entering flow sp point
# ++++
# condensate entering pipe equip
# ++++
# condensate entering point
# ++++
# condensate entering pressure sensor point
# ++++
# condensate entering pressure sp point
# ++++
# condensate entering pump alarm sensor point
# ++++
# condensate entering pump enable cmd point
# ++++
# condensate entering pump enable sensor point
# ++++
# condensate entering pump equip
# ++++
# condensate entering pump motor equip
# ++++
# condensate entering pump point
# ++++
# condensate entering pump run cmd point
# ++++
# condensate entering pump run sensor point
# ++++
# condensate entering pump vfd freq cmd point
# ++++
# condensate entering pump vfd freq sensor point
# ++++
# condensate entering pump vfd speed cmd point
# ++++
# condensate entering pump vfd speed sensor point
# ++++
# condensate entering temp sensor point
# ++++
# condensate entering temp sp point
# ++++
# condensate entering valve actuator equip
# ++++
# condensate entering valve cmd point
# ++++
# condensate entering valve sensor point
# ++++
# condenser refrig pressure sensor point
# ++++
# condenser refrig temp sensor point
# ++++
# condenser run cmd point
# ++++
# condenser run sensor point
# ++++
# condenser water bypass equip
# ++++
# condenser water bypass flow sensor point
# ++++
# condenser water bypass flow sp point
# ++++
# condenser water bypass pipe equip
# ++++
# condenser water bypass point
# ++++
# condenser water bypass pressure sensor point
# ++++
# condenser water bypass pressure sp point
# ++++
# condenser water bypass pump alarm sensor point
# ++++
# condenser water bypass pump enable cmd point
# ++++
# condenser water bypass pump enable sensor point
# ++++
# condenser water bypass pump equip
# ++++
# condenser water bypass pump motor equip
# ++++
# condenser water bypass pump point
# ++++
# condenser water bypass pump run cmd point
# ++++
# condenser water bypass pump run sensor point
# ++++
# condenser water bypass pump vfd freq cmd point
# ++++
# condenser water bypass pump vfd freq sensor point
# ++++
# condenser water bypass pump vfd speed cmd point
# ++++
# condenser water bypass pump vfd speed sensor point
# ++++
# condenser water bypass temp sensor point
# ++++
# condenser water bypass temp sp point
# ++++
# condenser water bypass valve actuator equip
# ++++
# condenser water bypass valve cmd point
# ++++
# condenser water bypass valve sensor point
# ++++
# condenser water delta flow sensor point
# ++++
# condenser water delta pressure sensor point
# ++++
# condenser water delta temp sensor point
# ++++
# condenser water entering equip
# ++++
# condenser water entering flow sensor point
# ++++
# condenser water entering flow sp point
# ++++
# condenser water entering pipe equip
# ++++
# condenser water entering point
# ++++
# condenser water entering pressure sensor point
# ++++
# condenser water entering pressure sp point
# ++++
# condenser water entering pump alarm sensor point
# ++++
# condenser water entering pump enable cmd point
# ++++
# condenser water entering pump enable sensor point
# ++++
# condenser water entering pump equip
# ++++
# condenser water entering pump motor equip
# ++++
# condenser water entering pump point
# ++++
# condenser water entering pump run cmd point
# ++++
# condenser water entering pump run sensor point
# ++++
# condenser water entering pump vfd freq cmd point
# ++++
# condenser water entering pump vfd freq sensor point
# ++++
# condenser water entering pump vfd speed cmd point
# ++++
# condenser water entering pump vfd speed sensor point
# ++++
# condenser water entering temp sensor point
# ++++
# condenser water entering temp sp point
# ++++
# condenser water entering valve actuator equip
# ++++
# condenser water entering valve cmd point
# ++++
# condenser water entering valve sensor point
# ++++
# condenser water leaving equip
# ++++
# condenser water leaving flow sensor point
# ++++
# condenser water leaving flow sp point
# ++++
# condenser water leaving pipe equip
# ++++
# condenser water leaving point
# ++++
# condenser water leaving pressure sensor point
# ++++
# condenser water leaving pressure sp point
# ++++
# condenser water leaving pump alarm sensor point
# ++++
# condenser water leaving pump enable cmd point
# ++++
# condenser water leaving pump enable sensor point
# ++++
# condenser water leaving pump equip
# ++++
# condenser water leaving pump motor equip
# ++++
# condenser water leaving pump point
# ++++
# condenser water leaving pump run cmd point
# ++++
# condenser water leaving pump run sensor point
# ++++
# condenser water leaving pump vfd freq cmd point
# ++++
# condenser water leaving pump vfd freq sensor point
# ++++
# condenser water leaving pump vfd speed cmd point
# ++++
# condenser water leaving pump vfd speed sensor point
# ++++
# condenser water leaving temp sensor point
# ++++
# condenser water leaving temp sp point
# ++++
# condenser water leaving valve actuator equip
# ++++
# condenser water leaving valve cmd point
# ++++
# condenser water leaving valve sensor point
# ++++
# condenser water valve isolation cmd point
# ++++
# controller device
# ++++
# cool cmd point
# ++++
# cool water flow thermal meter equip
# ++++
# cool well equip
# ++++
# coolingCoil equip
# ++++
# coolingTower equip
# ++++
# crac fcu equip
# ++++
# damper actuator equip
# ++++
# damper cmd point
# ++++
# damper sensor point
# ++++
# dc elec stateOfCharge sensor point
# ++++
# dessicantDehumidifier cmd point
# ++++
# discharge air co2 concentration sensor point
# ++++
# discharge air co2 concentration sp point
# ++++
# discharge air dewPoint sensor point
# ++++
# discharge air dewPoint sp point
# ++++
# discharge air enthalpy sensor point
# ++++
# discharge air enthalpy sp point
# ++++
# discharge air flow sensor point
# ++++
# discharge air flow sp point
# ++++
# discharge air humidity sensor point
# ++++
# discharge air humidity sp point
# ++++
# discharge air pressure sensor point
# ++++
# discharge air pressure sp point
# ++++
# discharge air temp sensor point
# ++++
# discharge air temp sp point
# ++++
# discharge chilled water cool valve cmd point
# ++++
# discharge coolingCoil equip
# ++++
# discharge damper actuator equip
# ++++
# discharge damper cmd point
# ++++
# discharge damper sensor point
# ++++
# discharge duct equip
# ++++
# discharge equip
# ++++
# discharge fan alarm sensor point
# ++++
# discharge fan enable cmd point
# ++++
# discharge fan enable sensor point
# ++++
# discharge fan equip
# ++++
# discharge fan motor equip
# ++++
# discharge fan point
# ++++
# discharge fan run cmd point
# ++++
# discharge fan run sensor point
# ++++
# discharge fan vfd freq cmd point
# ++++
# discharge fan vfd freq sensor point
# ++++
# discharge fan vfd speed cmd point
# ++++
# discharge fan vfd speed sensor point
# ++++
# discharge heatingCoil equip
# ++++
# discharge hot water heat valve cmd point
# ++++
# discharge point
# ++++
# discharge stage:1 cool run cmd point
# ++++
# discharge stage:1 heat run cmd point
# ++++
# discharge steam heat valve cmd point
# ++++
# ductArea sp point
# ++++
# economizer air co2 concentration sensor point
# ++++
# economizer air co2 concentration sp point
# ++++
# economizer air dewPoint sensor point
# ++++
# economizer air dewPoint sp point
# ++++
# economizer air enthalpy sensor point
# ++++
# economizer air enthalpy sp point
# ++++
# economizer air flow sensor point
# ++++
# economizer air flow sp point
# ++++
# economizer air humidity sensor point
# ++++
# economizer air humidity sp point
# ++++
# economizer air pressure sensor point
# ++++
# economizer air pressure sp point
# ++++
# economizer air temp sensor point
# ++++
# economizer air temp sp point
# ++++
# economizer chilled water cool valve cmd point
# ++++
# economizer coolingCoil equip
# ++++
# economizer damper actuator equip
# ++++
# economizer damper cmd point
# ++++
# economizer damper sensor point
# ++++
# economizer duct equip
# ++++
# economizer equip
# ++++
# economizer fan alarm sensor point
# ++++
# economizer fan enable cmd point
# ++++
# economizer fan enable sensor point
# ++++
# economizer fan equip
# ++++
# economizer fan motor equip
# ++++
# economizer fan point
# ++++
# economizer fan run cmd point
# ++++
# economizer fan run sensor point
# ++++
# economizer fan vfd freq cmd point
# ++++
# economizer fan vfd freq sensor point
# ++++
# economizer fan vfd speed cmd point
# ++++
# economizer fan vfd speed sensor point
# ++++
# economizer heatingCoil equip
# ++++
# economizer hot water heat valve cmd point
# ++++
# economizer point
# ++++
# economizer stage:1 cool run cmd point
# ++++
# economizer stage:1 heat run cmd point
# ++++
# economizer steam heat valve cmd point
# ++++
# economizing cmd point
# ++++
# efficiency sensor point
# ++++
# enable cmd point
# ++++
# enable sensor point
# ++++
# equip
# ++++
# evaporator refrig pressure sensor point
# ++++
# evaporator refrig temp sensor point
# ++++
# evse cable equip
# ++++
# evse evseStatus sensor point
# ++++
# evse port equip
# ++++
# exhaust air co2 concentration sensor point
# ++++
# exhaust air co2 concentration sp point
# ++++
# exhaust air dewPoint sensor point
# ++++
# exhaust air dewPoint sp point
# ++++
# exhaust air enthalpy sensor point
# ++++
# exhaust air enthalpy sp point
# ++++
# exhaust air flow sensor point
# ++++
# exhaust air flow sp point
# ++++
# exhaust air humidity sensor point
# ++++
# exhaust air humidity sp point
# ++++
# exhaust air pressure sensor point
# ++++
# exhaust air pressure sp point
# ++++
# exhaust air temp sensor point
# ++++
# exhaust air temp sp point
# ++++
# exhaust chilled water cool valve cmd point
# ++++
# exhaust coolingCoil equip
# ++++
# exhaust damper actuator equip
# ++++
# exhaust damper cmd point
# ++++
# exhaust damper sensor point
# ++++
# exhaust duct equip
# ++++
# exhaust equip
# ++++
# exhaust fan alarm sensor point
# ++++
# exhaust fan enable cmd point
# ++++
# exhaust fan enable sensor point
# ++++
# exhaust fan equip
# ++++
# exhaust fan motor equip
# ++++
# exhaust fan point
# ++++
# exhaust fan run cmd point
# ++++
# exhaust fan run sensor point
# ++++
# exhaust fan vfd freq cmd point
# ++++
# exhaust fan vfd freq sensor point
# ++++
# exhaust fan vfd speed cmd point
# ++++
# exhaust fan vfd speed sensor point
# ++++
# exhaust heatingCoil equip
# ++++
# exhaust hot water heat valve cmd point
# ++++
# exhaust point
# ++++
# exhaust stage:1 cool run cmd point
# ++++
# exhaust stage:1 heat run cmd point
# ++++
# exhaust steam heat valve cmd point
# ++++
# extraction well equip
# ++++
# faceBypass cmd point
# ++++
# fan alarm sensor point
# ++++
# fan enable cmd point
# ++++
# fan enable sensor point
# ++++
# fan equip
# ++++
# fan motor equip
# ++++
# fan point
# ++++
# fan run cmd point
# ++++
# fan run sensor point
# ++++
# fan vfd freq cmd point
# ++++
# fan vfd freq sensor point
# ++++
# fan vfd speed cmd point
# ++++
# fan vfd speed sensor point
# ++++
# filter sensor point
# ++++
# flow sensor point
# ++++
# flow sp point
# ++++
# flowInverter equip
# ++++
# flue air co2 concentration sensor point
# ++++
# flue air co2 concentration sp point
# ++++
# flue air dewPoint sensor point
# ++++
# flue air dewPoint sp point
# ++++
# flue air enthalpy sensor point
# ++++
# flue air enthalpy sp point
# ++++
# flue air flow sensor point
# ++++
# flue air flow sp point
# ++++
# flue air humidity sensor point
# ++++
# flue air humidity sp point
# ++++
# flue air pressure sensor point
# ++++
# flue air pressure sp point
# ++++
# flue air temp sensor point
# ++++
# flue air temp sp point
# ++++
# flue chilled water cool valve cmd point
# ++++
# flue coolingCoil equip
# ++++
# flue damper actuator equip
# ++++
# flue damper cmd point
# ++++
# flue damper sensor point
# ++++
# flue duct equip
# ++++
# flue equip
# ++++
# flue fan alarm sensor point
# ++++
# flue fan enable cmd point
# ++++
# flue fan enable sensor point
# ++++
# flue fan equip
# ++++
# flue fan motor equip
# ++++
# flue fan point
# ++++
# flue fan run cmd point
# ++++
# flue fan run sensor point
# ++++
# flue fan vfd freq cmd point
# ++++
# flue fan vfd freq sensor point
# ++++
# flue fan vfd speed cmd point
# ++++
# flue fan vfd speed sensor point
# ++++
# flue heatingCoil equip
# ++++
# flue hot water heat valve cmd point
# ++++
# flue point
# ++++
# flue stage:1 cool run cmd point
# ++++
# flue stage:1 heat run cmd point
# ++++
# flue steam heat valve cmd point
# ++++
# freezeStat sensor point
# ++++
# ground water flow sensor point
# ++++
# ground water pressure sensor point
# ++++
# ground water volume sensor point
# ++++
# heat cmd point
# ++++
# heatExchanger equip
# ++++
# heatWheel cmd point
# ++++
# heatingCoil equip
# ++++
# hot water boiler equip
# ++++
# hot water bypass equip
# ++++
# hot water bypass flow sensor point
# ++++
# hot water bypass flow sp point
# ++++
# hot water bypass pipe equip
# ++++
# hot water bypass point
# ++++
# hot water bypass pressure sensor point
# ++++
# hot water bypass pressure sp point
# ++++
# hot water bypass pump alarm sensor point
# ++++
# hot water bypass pump enable cmd point
# ++++
# hot water bypass pump enable sensor point
# ++++
# hot water bypass pump equip
# ++++
# hot water bypass pump motor equip
# ++++
# hot water bypass pump point
# ++++
# hot water bypass pump run cmd point
# ++++
# hot water bypass pump run sensor point
# ++++
# hot water bypass pump vfd freq cmd point
# ++++
# hot water bypass pump vfd freq sensor point
# ++++
# hot water bypass pump vfd speed cmd point
# ++++
# hot water bypass pump vfd speed sensor point
# ++++
# hot water bypass temp sensor point
# ++++
# hot water bypass temp sp point
# ++++
# hot water bypass valve actuator equip
# ++++
# hot water bypass valve cmd point
# ++++
# hot water bypass valve sensor point
# ++++
# hot water delta flow sensor point
# ++++
# hot water delta pressure sensor point
# ++++
# hot water delta temp sensor point
# ++++
# hot water entering equip
# ++++
# hot water entering flow sensor point
# ++++
# hot water entering flow sp point
# ++++
# hot water entering pipe equip
# ++++
# hot water entering point
# ++++
# hot water entering pressure sensor point
# ++++
# hot water entering pressure sp point
# ++++
# hot water entering pump alarm sensor point
# ++++
# hot water entering pump enable cmd point
# ++++
# hot water entering pump enable sensor point
# ++++
# hot water entering pump equip
# ++++
# hot water entering pump motor equip
# ++++
# hot water entering pump point
# ++++
# hot water entering pump run cmd point
# ++++
# hot water entering pump run sensor point
# ++++
# hot water entering pump vfd freq cmd point
# ++++
# hot water entering pump vfd freq sensor point
# ++++
# hot water entering pump vfd speed cmd point
# ++++
# hot water entering pump vfd speed sensor point
# ++++
# hot water entering temp sensor point
# ++++
# hot water entering temp sp point
# ++++
# hot water entering valve actuator equip
# ++++
# hot water entering valve cmd point
# ++++
# hot water entering valve sensor point
# ++++
# hot water header equip
# ++++
# hot water header flow sensor point
# ++++
# hot water header flow sp point
# ++++
# hot water header pipe equip
# ++++
# hot water header point
# ++++
# hot water header pressure sensor point
# ++++
# hot water header pressure sp point
# ++++
# hot water header pump alarm sensor point
# ++++
# hot water header pump enable cmd point
# ++++
# hot water header pump enable sensor point
# ++++
# hot water header pump equip
# ++++
# hot water header pump motor equip
# ++++
# hot water header pump point
# ++++
# hot water header pump run cmd point
# ++++
# hot water header pump run sensor point
# ++++
# hot water header pump vfd freq cmd point
# ++++
# hot water header pump vfd freq sensor point
# ++++
# hot water header pump vfd speed cmd point
# ++++
# hot water header pump vfd speed sensor point
# ++++
# hot water header temp sensor point
# ++++
# hot water header temp sp point
# ++++
# hot water header valve actuator equip
# ++++
# hot water header valve cmd point
# ++++
# hot water header valve sensor point
# ++++
# hot water heat valve cmd point
# ++++
# hot water heatExchanger equip
# ++++
# hot water leaving equip
# ++++
# hot water leaving flow sensor point
# ++++
# hot water leaving flow sp point
# ++++
# hot water leaving pipe equip
# ++++
# hot water leaving point
# ++++
# hot water leaving pressure sensor point
# ++++
# hot water leaving pressure sp point
# ++++
# hot water leaving pump alarm sensor point
# ++++
# hot water leaving pump enable cmd point
# ++++
# hot water leaving pump enable sensor point
# ++++
# hot water leaving pump equip
# ++++
# hot water leaving pump motor equip
# ++++
# hot water leaving pump point
# ++++
# hot water leaving pump run cmd point
# ++++
# hot water leaving pump run sensor point
# ++++
# hot water leaving pump vfd freq cmd point
# ++++
# hot water leaving pump vfd freq sensor point
# ++++
# hot water leaving pump vfd speed cmd point
# ++++
# hot water leaving pump vfd speed sensor point
# ++++
# hot water leaving temp sensor point
# ++++
# hot water leaving temp sp point
# ++++
# hot water leaving valve actuator equip
# ++++
# hot water leaving valve cmd point
# ++++
# hot water leaving valve sensor point
# ++++
# hot water mixing valve cmd point
# ++++
# humidifier enable cmd point
# ++++
# humidifier equip
# ++++
# humidifier run cmd point
# ++++
# hvacMode sp point
# ++++
# import ac elec active energy hisTotalized sensor point
# ++++
# import ac elec active power max sp point
# ++++
# import ac elec active power sensor point
# ++++
# import ac elec magnitude current max sp point
# ++++
# import ac elec magnitude current sensor point
# ++++
# import ac elec magnitude volt sensor point
# ++++
# import ac elec pfScope pf sensor point
# ++++
# import dc elec current max sp point
# ++++
# import dc elec current sensor point
# ++++
# import dc elec energy hisTotalized sensor point
# ++++
# import dc elec power max sp point
# ++++
# import dc elec power sensor point
# ++++
# import dc elec volt sensor point
# ++++
# infiltration well equip
# ++++
# inlet air co2 concentration sensor point
# ++++
# inlet air co2 concentration sp point
# ++++
# inlet air dewPoint sensor point
# ++++
# inlet air dewPoint sp point
# ++++
# inlet air enthalpy sensor point
# ++++
# inlet air enthalpy sp point
# ++++
# inlet air flow sensor point
# ++++
# inlet air flow sp point
# ++++
# inlet air humidity sensor point
# ++++
# inlet air humidity sp point
# ++++
# inlet air pressure sensor point
# ++++
# inlet air pressure sp point
# ++++
# inlet air temp sensor point
# ++++
# inlet air temp sp point
# ++++
# inlet chilled water cool valve cmd point
# ++++
# inlet coolingCoil equip
# ++++
# inlet damper actuator equip
# ++++
# inlet damper cmd point
# ++++
# inlet damper sensor point
# ++++
# inlet duct equip
# ++++
# inlet equip
# ++++
# inlet fan alarm sensor point
# ++++
# inlet fan enable cmd point
# ++++
# inlet fan enable sensor point
# ++++
# inlet fan equip
# ++++
# inlet fan motor equip
# ++++
# inlet fan point
# ++++
# inlet fan run cmd point
# ++++
# inlet fan run sensor point
# ++++
# inlet fan vfd freq cmd point
# ++++
# inlet fan vfd freq sensor point
# ++++
# inlet fan vfd speed cmd point
# ++++
# inlet fan vfd speed sensor point
# ++++
# inlet heatingCoil equip
# ++++
# inlet hot water heat valve cmd point
# ++++
# inlet point
# ++++
# inlet stage:1 cool run cmd point
# ++++
# inlet stage:1 heat run cmd point
# ++++
# inlet steam heat valve cmd point
# ++++
# level sensor point
# ++++
# light illuminance sensor point
# ++++
# light level sensor point
# ++++
# light level sp point
# ++++
# light luminous flux sensor point
# ++++
# load cmd point
# ++++
# load sensor point
# ++++
# makeup water entering equip
# ++++
# makeup water entering flow sensor point
# ++++
# makeup water entering flow sp point
# ++++
# makeup water entering pipe equip
# ++++
# makeup water entering point
# ++++
# makeup water entering pressure sensor point
# ++++
# makeup water entering pressure sp point
# ++++
# makeup water entering pump alarm sensor point
# ++++
# makeup water entering pump enable cmd point
# ++++
# makeup water entering pump enable sensor point
# ++++
# makeup water entering pump equip
# ++++
# makeup water entering pump motor equip
# ++++
# makeup water entering pump point
# ++++
# makeup water entering pump run cmd point
# ++++
# makeup water entering pump run sensor point
# ++++
# makeup water entering pump vfd freq cmd point
# ++++
# makeup water entering pump vfd freq sensor point
# ++++
# makeup water entering pump vfd speed cmd point
# ++++
# makeup water entering pump vfd speed sensor point
# ++++
# makeup water entering temp sensor point
# ++++
# makeup water entering temp sp point
# ++++
# makeup water entering valve actuator equip
# ++++
# makeup water entering valve cmd point
# ++++
# makeup water entering valve sensor point
# ++++
# mixed air co2 concentration sensor point
# ++++
# mixed air co2 concentration sp point
# ++++
# mixed air dewPoint sensor point
# ++++
# mixed air dewPoint sp point
# ++++
# mixed air enthalpy sensor point
# ++++
# mixed air enthalpy sp point
# ++++
# mixed air flow sensor point
# ++++
# mixed air flow sp point
# ++++
# mixed air humidity sensor point
# ++++
# mixed air humidity sp point
# ++++
# mixed air pressure sensor point
# ++++
# mixed air pressure sp point
# ++++
# mixed air temp sensor point
# ++++
# mixed air temp sp point
# ++++
# mixed chilled water cool valve cmd point
# ++++
# mixed coolingCoil equip
# ++++
# mixed damper actuator equip
# ++++
# mixed damper cmd point
# ++++
# mixed damper sensor point
# ++++
# mixed duct equip
# ++++
# mixed equip
# ++++
# mixed fan alarm sensor point
# ++++
# mixed fan enable cmd point
# ++++
# mixed fan enable sensor point
# ++++
# mixed fan equip
# ++++
# mixed fan motor equip
# ++++
# mixed fan point
# ++++
# mixed fan run cmd point
# ++++
# mixed fan run sensor point
# ++++
# mixed fan vfd freq cmd point
# ++++
# mixed fan vfd freq sensor point
# ++++
# mixed fan vfd speed cmd point
# ++++
# mixed fan vfd speed sensor point
# ++++
# mixed heatingCoil equip
# ++++
# mixed hot water heat valve cmd point
# ++++
# mixed point
# ++++
# mixed stage:1 cool run cmd point
# ++++
# mixed stage:1 heat run cmd point
# ++++
# mixed steam heat valve cmd point
# ++++
# networking device
# ++++
# occupancy sensor point
# ++++
# occupied sensor point
# ++++
# occupied sp point
# ++++
# outside air co2 concentration sensor point
# ++++
# outside air co2 concentration sp point
# ++++
# outside air dewPoint sensor point
# ++++
# outside air dewPoint sp point
# ++++
# outside air enthalpy sensor point
# ++++
# outside air enthalpy sp point
# ++++
# outside air flow sensor point
# ++++
# outside air flow sp point
# ++++
# outside air humidity sensor point
# ++++
# outside air humidity sp point
# ++++
# outside air pressure sensor point
# ++++
# outside air pressure sp point
# ++++
# outside air temp sensor point
# ++++
# outside air temp sp point
# ++++
# outside chilled water cool valve cmd point
# ++++
# outside coolingCoil equip
# ++++
# outside damper actuator equip
# ++++
# outside damper cmd point
# ++++
# outside damper sensor point
# ++++
# outside duct equip
# ++++
# outside equip
# ++++
# outside fan alarm sensor point
# ++++
# outside fan enable cmd point
# ++++
# outside fan enable sensor point
# ++++
# outside fan equip
# ++++
# outside fan motor equip
# ++++
# outside fan point
# ++++
# outside fan run cmd point
# ++++
# outside fan run sensor point
# ++++
# outside fan vfd freq cmd point
# ++++
# outside fan vfd freq sensor point
# ++++
# outside fan vfd speed cmd point
# ++++
# outside fan vfd speed sensor point
# ++++
# outside heatingCoil equip
# ++++
# outside hot water heat valve cmd point
# ++++
# outside point
# ++++
# outside stage:1 cool run cmd point
# ++++
# outside stage:1 heat run cmd point
# ++++
# outside steam heat valve cmd point
# ++++
# perimeterHeat cmd point
# ++++
# phase:"A" ac elec current angle sensor point
# ++++
# phase:"A" ac elec current imbalance sensor point
# ++++
# phase:"A" ac elec current magnitude sensor point
# ++++
# phase:"A" ac elec current thd sensor point
# ++++
# phase:"A" ac elec pf sensor point
# ++++
# phase:"A" ac elec volt angle sensor point
# ++++
# phase:"A" ac elec volt imbalance sensor point
# ++++
# phase:"A" ac elec volt magnitude sensor point
# ++++
# phase:"A" ac elec volt thd sensor point
# ++++
# phase:"A" active ac elec power sensor point
# ++++
# phase:"A" apparent ac elec power sensor point
# ++++
# phase:"A" net ac elec active energy sensor point
# ++++
# phase:"A" reactive ac elec power sensor point
# ++++
# point
# ++++
# pressure sensor point
# ++++
# pressure sp point
# ++++
# pump alarm sensor point
# ++++
# pump enable cmd point
# ++++
# pump enable sensor point
# ++++
# pump equip
# ++++
# pump motor equip
# ++++
# pump point
# ++++
# pump run cmd point
# ++++
# pump run sensor point
# ++++
# pump vfd freq cmd point
# ++++
# pump vfd freq sensor point
# ++++
# pump vfd speed cmd point
# ++++
# pump vfd speed sensor point
# ++++
# purge water flow sensor point
# ++++
# purge water volume sensor point
# ++++
# rack equip
# ++++
# reheat cmd point
# ++++
# return air co2 concentration sensor point
# ++++
# return air co2 concentration sp point
# ++++
# return air dewPoint sensor point
# ++++
# return air dewPoint sp point
# ++++
# return air enthalpy sensor point
# ++++
# return air enthalpy sp point
# ++++
# return air flow sensor point
# ++++
# return air flow sp point
# ++++
# return air humidity sensor point
# ++++
# return air humidity sp point
# ++++
# return air pressure sensor point
# ++++
# return air pressure sp point
# ++++
# return air temp sensor point
# ++++
# return air temp sp point
# ++++
# return chilled water cool valve cmd point
# ++++
# return coolingCoil equip
# ++++
# return damper actuator equip
# ++++
# return damper cmd point
# ++++
# return damper sensor point
# ++++
# return duct equip
# ++++
# return equip
# ++++
# return fan alarm sensor point
# ++++
# return fan enable cmd point
# ++++
# return fan enable sensor point
# ++++
# return fan equip
# ++++
# return fan motor equip
# ++++
# return fan point
# ++++
# return fan run cmd point
# ++++
# return fan run sensor point
# ++++
# return fan vfd freq cmd point
# ++++
# return fan vfd freq sensor point
# ++++
# return fan vfd speed cmd point
# ++++
# return fan vfd speed sensor point
# ++++
# return heatingCoil equip
# ++++
# return hot water heat valve cmd point
# ++++
# return point
# ++++
# return stage:1 cool run cmd point
# ++++
# return stage:1 heat run cmd point
# ++++
# return steam heat valve cmd point
# ++++
# run cmd point
# ++++
# run sensor point
# ++++
# server device
# ++++
# space
# ++++
# stage:1 cool run cmd point
# ++++
# stage:1 heat run cmd point
# ++++
# steam boiler equip
# ++++
# steam bypass equip
# ++++
# steam bypass flow sensor point
# ++++
# steam bypass flow sp point
# ++++
# steam bypass pipe equip
# ++++
# steam bypass point
# ++++
# steam bypass pressure sensor point
# ++++
# steam bypass pressure sp point
# ++++
# steam bypass pump alarm sensor point
# ++++
# steam bypass pump enable cmd point
# ++++
# steam bypass pump enable sensor point
# ++++
# steam bypass pump equip
# ++++
# steam bypass pump motor equip
# ++++
# steam bypass pump point
# ++++
# steam bypass pump run cmd point
# ++++
# steam bypass pump run sensor point
# ++++
# steam bypass pump vfd freq cmd point
# ++++
# steam bypass pump vfd freq sensor point
# ++++
# steam bypass pump vfd speed cmd point
# ++++
# steam bypass pump vfd speed sensor point
# ++++
# steam bypass temp sensor point
# ++++
# steam bypass temp sp point
# ++++
# steam bypass valve actuator equip
# ++++
# steam bypass valve cmd point
# ++++
# steam bypass valve sensor point
# ++++
# steam delta flow sensor point
# ++++
# steam delta pressure sensor point
# ++++
# steam delta temp sensor point
# ++++
# steam header equip
# ++++
# steam header flow sensor point
# ++++
# steam header flow sp point
# ++++
# steam header pipe equip
# ++++
# steam header point
# ++++
# steam header pressure sensor point
# ++++
# steam header pressure sp point
# ++++
# steam header pump alarm sensor point
# ++++
# steam header pump enable cmd point
# ++++
# steam header pump enable sensor point
# ++++
# steam header pump equip
# ++++
# steam header pump motor equip
# ++++
# steam header pump point
# ++++
# steam header pump run cmd point
# ++++
# steam header pump run sensor point
# ++++
# steam header pump vfd freq cmd point
# ++++
# steam header pump vfd freq sensor point
# ++++
# steam header pump vfd speed cmd point
# ++++
# steam header pump vfd speed sensor point
# ++++
# steam header temp sensor point
# ++++
# steam header temp sp point
# ++++
# steam header valve actuator equip
# ++++
# steam header valve cmd point
# ++++
# steam header valve sensor point
# ++++
# steam heat valve cmd point
# ++++
# steam heatExchanger equip
# ++++
# steam leaving equip
# ++++
# steam leaving flow sensor point
# ++++
# steam leaving flow sp point
# ++++
# steam leaving pipe equip
# ++++
# steam leaving point
# ++++
# steam leaving pressure sensor point
# ++++
# steam leaving pressure sp point
# ++++
# steam leaving pump alarm sensor point
# ++++
# steam leaving pump enable cmd point
# ++++
# steam leaving pump enable sensor point
# ++++
# steam leaving pump equip
# ++++
# steam leaving pump motor equip
# ++++
# steam leaving pump point
# ++++
# steam leaving pump run cmd point
# ++++
# steam leaving pump run sensor point
# ++++
# steam leaving pump vfd freq cmd point
# ++++
# steam leaving pump vfd freq sensor point
# ++++
# steam leaving pump vfd speed cmd point
# ++++
# steam leaving pump vfd speed sensor point
# ++++
# steam leaving temp sensor point
# ++++
# steam leaving temp sp point
# ++++
# steam leaving valve actuator equip
# ++++
# steam leaving valve cmd point
# ++++
# steam leaving valve sensor point
# ++++
# steam mixing valve cmd point
# ++++
# temp sensor point
# ++++
# temp sp point
# ++++
# thermostat equip
# ++++
# total ac elec demand sensor point
# ++++
# total active ac elec power sensor point
# ++++
# total apparent ac elec power sensor point
# ++++
# total export ac elec active energy sensor point
# ++++
# total import ac elec active energy sensor point
# ++++
# total net ac elec active energy sensor point
# ++++
# total reactive ac elec power sensor point
# ++++
# valve actuator equip
# ++++
# valve cmd point
# ++++
# valve sensor point
# ++++
# ventilation air co2 concentration sensor point
# ++++
# ventilation air co2 concentration sp point
# ++++
# ventilation air dewPoint sensor point
# ++++
# ventilation air dewPoint sp point
# ++++
# ventilation air enthalpy sensor point
# ++++
# ventilation air enthalpy sp point
# ++++
# ventilation air flow sensor point
# ++++
# ventilation air flow sp point
# ++++
# ventilation air humidity sensor point
# ++++
# ventilation air humidity sp point
# ++++
# ventilation air pressure sensor point
# ++++
# ventilation air pressure sp point
# ++++
# ventilation air temp sensor point
# ++++
# ventilation air temp sp point
# ++++
# ventilation chilled water cool valve cmd point
# ++++
# ventilation coolingCoil equip
# ++++
# ventilation damper actuator equip
# ++++
# ventilation damper cmd point
# ++++
# ventilation damper sensor point
# ++++
# ventilation duct equip
# ++++
# ventilation equip
# ++++
# ventilation fan alarm sensor point
# ++++
# ventilation fan enable cmd point
# ++++
# ventilation fan enable sensor point
# ++++
# ventilation fan equip
# ++++
# ventilation fan motor equip
# ++++
# ventilation fan point
# ++++
# ventilation fan run cmd point
# ++++
# ventilation fan run sensor point
# ++++
# ventilation fan vfd freq cmd point
# ++++
# ventilation fan vfd freq sensor point
# ++++
# ventilation fan vfd speed cmd point
# ++++
# ventilation fan vfd speed sensor point
# ++++
# ventilation heatingCoil equip
# ++++
# ventilation hot water heat valve cmd point
# ++++
# ventilation point
# ++++
# ventilation stage:1 cool run cmd point
# ++++
# ventilation stage:1 heat run cmd point
# ++++
# ventilation steam heat valve cmd point
# ++++
# vfd freq cmd point
# ++++
# vfd freq sensor point
# ++++
# vfd speed cmd point
# ++++
# vfd speed sensor point
# ++++
# vrf branchSelector equip
# ++++
# vrf indoorUnit equip
# ++++
# vrf outdoorUnit equip
# ++++
# vrf refrig plant equip
# ++++
# warm water flow thermal meter equip
# ++++
# warm well equip
# ++++
# water flow sensor point
# ++++
# water level sensor point
# ++++
# water pressure sensor point
# ++++
# water pump alarm sensor point
# ++++
# water pump enable cmd point
# ++++
# water pump enable sensor point
# ++++
# water pump equip
# ++++
# water pump motor equip
# ++++
# water pump point
# ++++
# water pump run cmd point
# ++++
# water pump run sensor point
# ++++
# water pump vfd freq cmd point
# ++++
# water pump vfd freq sensor point
# ++++
# water pump vfd speed cmd point
# ++++
# water pump vfd speed sensor point
# ++++
# water temp sensor point
# ++++
# water volume sensor point
# ++++
# weather air dewPoint sensor point
# ++++
# weather air enthalpy sensor point
# ++++
# weather air feelsLike sensor point
# ++++
# weather air humidity sensor point
# ++++
# weather air temp sensor point
# ++++
# weather air wetBulb sensor point
# ++++
# weather atmospheric pressure sensor point
# ++++
# weather cloudage sensor point
# ++++
# weather daytime sensor point
# ++++
# weather precipitation sensor point
# ++++
# weather solar irradiance sensor point
# ++++
# weather visibility sensor point
# ++++
# weather weatherCond sensor point
# ++++
# weather wind direction sensor point
# ++++
# weather wind speed sensor point
# ++++
# zone air ch2o concentration sensor point
# ++++
# zone air co concentration sensor point
# ++++
# zone air co2 concentration sensor point
# ++++
# zone air co2 concentration sp point
# ++++
# zone air dewPoint sensor point
# ++++
# zone air dewPoint sp point
# ++++
# zone air enthalpy sensor point
# ++++
# zone air enthalpy sp point
# ++++
# zone air humidity sensor point
# ++++
# zone air humidity sp point
# ++++
# zone air hvacMode sp point
# ++++
# zone air nh3 concentration sensor point
# ++++
# zone air no2 concentration sensor point
# ++++
# zone air o3 concentration sensor point
# ++++
# zone air pm01 concentration sensor point
# ++++
# zone air pm10 concentration sensor point
# ++++
# zone air pm25 concentration sensor point
# ++++
# zone air pressure sensor point
# ++++
# zone air pressure sp point
# ++++
# zone air temp effective cooling sp point
# ++++
# zone air temp effective heating sp point
# ++++
# zone air temp effective sp point
# ++++
# zone air temp occ cooling sp point
# ++++
# zone air temp occ heating sp point
# ++++
# zone air temp sensor point
# ++++
# zone air temp standby cooling sp point
# ++++
# zone air temp standby heating sp point
# ++++
# zone air temp unocc cooling sp point
# ++++
# zone air temp unocc heating sp point
# ++++
# zone air tvoc concentration sensor point

# %%
# compute a 'stable' mapping (1:1 mapping)
stable = m.get_mapping(bcs, allow_collisions=False)
# compute an 'unstable' mapping that allows 1:n and n:1 matches
unstable = m.get_mapping(bcs, allow_collisions=True)

# loop through and print the stable/unstable matches
for k,v in unstable.items():
    print(f"{k}:\n\tunstable: {v}\n\tstable: {stable.get(k)}")
# Out:
# 00%|███████████████████████████████████████████████████████████████████████████████████| 1121/1121 [00:00<00:00, 15798.58it/s]

# %%
m.external_to_brick_mapping
# Out:
# {rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Temperature_High_Reset_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Return_Air_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Outside_Air_Temperature_High_Reset_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Overload_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Filter_Reset_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Switch_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Humidity_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Hot_Water_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Exhaust_Air_Velocity_Pressure_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Medium_Temperature_Hot_Water_Differential_Pressure_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Thermal_Power_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Lead_Lag_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Condenser_Water_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Duration_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Output_Frequency_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Average_Zone_Air_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Air_Flow_Deadband_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Enable_Differential_Enthalpy_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Zone_Air_Cooling_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Mode_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Air_Grains_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Fan_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Effective_Target_Zone_Air_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Enable_Hot_Water_System_Outside_Air_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Hot_Water_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Air_Temperature_Low_Reset_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Humidity_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Occupied_Cooling_Mode_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Speed_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Differential_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Piezoelectric_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Room_Air_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Emergency_Power_Off_System_Activated_By_Leak_Detection_System_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Disable_Hot_Water_System_Outside_Air_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Differential_Pressure_Load_Shed_Reset_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Deadband_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Domestic_Hot_Water_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Deionized_Water_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Differential_Pressure_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Static_Pressure_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Maintenance_Required_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#PM1_Level_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Exhaust_Air_Differential_Pressure_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#VFD_Enable_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Average_Supply_Air_Flow_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Power_Factor_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Battery_Voltage_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_High_Temperature_Hot_Water_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Torque_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Bypass_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Underfloor_Air_Plenum_Static_Pressure_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Usage_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Rated_Speed_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Damper_Position_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Temperature_Deadband_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Outside_Air_Lockout_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Outside_Air_Grains_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Water_Differential_Pressure_Deadband_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Discharge_Flow_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Usage_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Preheat_Demand_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Air_Temperature_Heating_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Standby_Target_Zone_Air_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Boiler_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Acceleration_Time_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Damper_Position_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#System_Shutdown_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#DC_Bus_Voltage_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Air_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Sensor_Failure_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Average_Cooling_Demand_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Soil_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Effective_Air_Temperature_Cooling_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Occupied_Air_Temperature_Cooling_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heating_Demand_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Occupancy_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#CO_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Effective_Heating_Zone_Air_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#No_Water_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#System_Enable_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Discharge_Flow_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Temperature_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Humidification_Start_Stop_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Natural_Gas_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Automatic_Mode_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Supply_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heat_Exchanger_Discharge_Water_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#High_Air_Flow_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Zone_Air_Dewpoint_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heating_Thermal_Power_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Point'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Max_Frequency_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Reset_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Hot_Water_Flow_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#CO2_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Reset_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Medium_Temperature_Hot_Water_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Overridden_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unit_Failure_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Air_Enthalpy_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Domestic_Hot_Water_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Medium_Temperature_Hot_Water_Temperature_High_Reset_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Outside_Air_Flow_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Motion_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#High_CO2_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Illuminance_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Differential_Pressure_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Start_Stop_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Building_Air_Static_Pressure_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Radon_Concentration_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Outside_Face_Surface_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Low_Supply_Air_Temperature_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Ammonia_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Differential_Pressure_Load_Shed_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Effective_Cooling_Zone_Air_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Emergency_Power_Off_System_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Static_Pressure_Deadband_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Outside_Air_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Valve_Position_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Cooling_Supply_Air_Temperature_Deadband_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_High_Temperature_Hot_Water_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Water_Flow_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Flow_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Flow_Reset_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Air_Quality_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Cooling_Supply_Air_Flow_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Water_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Zone_Occupied_Load_Shed_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Tint_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#On_Off_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Zone_Air_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Electric_Power_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Natural_Gas_Usage_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Domestic_Hot_Water_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Adjust_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Discharge_Water_Flow_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Standby_Glycool_Unit_On_Off_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Mixed_Air_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Discharge_Condenser_Water_Flow_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Short_Cycle_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Cooling_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Exhaust_Air_Flow_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Illuminance_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Static_Pressure_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Air_Flow_Demand_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Air_Temperature_Cooling_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Water_Flow_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Water_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Occupied_Air_Temperature_Heating_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Domestic_Hot_Water_Discharge_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Medium_Temperature_Hot_Water_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Hot_Water_Temperature_Load_Shed_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Electric_Energy_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#On_Off_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heating_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Cooling_Mode_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Occupied_Zone_Air_Temperaure_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Velocity_Pressure_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Target_Zone_Air_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Luminance_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Differential_Pressure_Load_Shed_Reset_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Mode_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Even_Month_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#High_Temperature_Hot_Water_Return_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Effective_Room_Air_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Stage_Enable_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Motor_On_Off_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Condenser_Water_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Speed_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Failure_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Lead_On_Off_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Occupied_Return_Air_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Voltage_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Zone_CO2_Level_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Overridden_On_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#PIR_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Temperature_Adjust_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Hot_Water_Flow_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Zone_Standby_Load_Shed_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Temperature_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Enable_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Speed_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Frost_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heat_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Differential_Pressure_Deadband_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Zone_Air_Humidity_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Air_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Rain_Level_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Relative_Humidity_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Solar_Zenith_Angle_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Differential_Speed_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Domestic_Hot_Water_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Solar_Azimuth_Angle_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Air_Differential_Pressure_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Medium_Temperature_Hot_Water_Discharge_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Differential_Pressure_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Frequency_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Deionised_Water_Level_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hold_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Hot_Water_Temperature_High_Reset_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Zone_Air_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Differential_Supply_Return_Water_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Condenser_Water_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Chilled_Water_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Differential_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Target_Zone_Air_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Hot_Water_Flow_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#On_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Humidifier_Fault_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Low_Air_Flow_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Max_Water_Level_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#CO2_Level_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Warm_Cool_Adjust_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Zone_Air_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Power_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Water_Flow_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Differential_Pressure_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Off_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Condenser_Water_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Peak_Demand_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Wind_Speed_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#PM10_Level_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Disable_Fixed_Temperature_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Discharge_Flow_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Outside_Air_Humidity_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Medium_Temperature_Hot_Water_Supply_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Exhaust_Air_Humidity_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Exhaust_Air_Stack_Flow_Deadband_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Water_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Occupancy_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Temperature_Differential_Reset_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Static_Pressure_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#System_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Curtailment_Override_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Outside_Illuminance_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Demand_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Lowest_Exhaust_Air_Static_Pressure_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#PM2.5_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Chilled_Water_Flow_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Light_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Water_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Cooling_Start_Stop_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Drive_Ready_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Medium_Temperature_Hot_Water_Temperature_Load_Shed_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Cooling_Demand_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Valve_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Differential_Pressure_Deadband_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Core_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Flow_High_Reset_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Low_Return_Air_Temperature_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Energy_Generation_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Refrigerant_Level_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Occupied_Mode_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Fan_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Low_Supply_Air_Flow_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Dewpoint_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Preheat_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Angle_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heating_Supply_Air_Flow_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Voltage_Ratio_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Power_Loss_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Absolute_Humidity_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Bypass_Air_Humidity_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Static_Pressure_Deadband_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Filter_Differential_Pressure_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Chilled_Water_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Cooling_Supply_Air_Flow_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Water_Flow_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Fault_Reset_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Humidity_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Off_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Building_Air_Static_Pressure_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Enable_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Flow_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Medium_Temperature_Hot_Water_Differential_Pressure_Load_Shed_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Flow_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Differential_Discharge_Return_Water_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Differential_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Supply_Air_Flow_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Remotely_On_Off_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Bypass_Water_Flow_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Exhaust_Air_Differential_Pressure_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Frequency_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Sash_Position_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Discharge_Condenser_Water_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#CO2_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Chilled_Water_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Average_Heating_Demand_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Humidity_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Capacity_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Low_Temperature_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Underfloor_Air_Plenum_Static_Pressure_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Enable_Fixed_Temperature_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Low_Suction_Pressure_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Liquid_Detection_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Load_Shed_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Luminance_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Supply_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Lockout_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Condenser_Water_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Current_Imbalance_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Chilled_Water_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heating_Mode_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Hot_Water_Flow_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Humidity_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Cooling_Zone_Air_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Air_Humidity_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Communication_Loss_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Inside_Face_Surface_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Coldest_Zone_Air_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Direction_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Run_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Outside_Air_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Supply_Flow_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Dewpoint_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Steam_On_Off_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hail_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#TVOC_Level_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Exhaust_Air_Flow_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Temperature_Cooling_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Medium_Temperature_Hot_Water_Temperature_Load_Shed_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Demand_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Max_Air_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#High_Humidity_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Return_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Photovoltaic_Current_Output_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Air_Humidity_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Zone_Air_Humidity_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Air_Flow_Loss_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Tint_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Open_Heating_Valve_Outside_Air_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Occupied_Heating_Temperature_Deadband_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Contact_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Occupied_Heating_Mode_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#CO2_Differential_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Power_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Supply_Flow_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Medium_Temperature_Hot_Water_Differential_Pressure_Load_Shed_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Occupied_Heating_Supply_Air_Flow_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Enable_Differential_Temperature_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Standby_Load_Shed_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Cooling_Temperature_Deadband_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Outside_Air_CO2_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Domestic_Hot_Water_Supply_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Outside_Air_Temperature_Enable_Differential_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Differential_Air_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Water_Temperature_Deadband_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Low_Voltage_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heating_Enable_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Position_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Air_Differential_Pressure_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Water_Flow_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Heating_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Supply_Air_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Damper_Position_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Load_Shed_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Velocity_Pressure_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Differential_Pressure_Deadband_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Dewpoint_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Bypass_Water_Flow_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Low_Humidity_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Air_Differential_Pressure_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heating_Demand_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Occupancy_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Air_Dewpoint_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Load_Shed_Differential_Pressure_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Temperature_Deadband_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Temperature_Low_Reset_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heating_Start_Stop_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#High_Temperature_Hot_Water_Discharge_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Occupied_Load_Shed_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Water_Differential_Pressure_Deadband_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Smoke_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Domestic_Hot_Water_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Pressure_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Effective_Air_Temperature_Heating_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Flow_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Direction_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Outside_Air_Temperature_Low_Reset_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Loss_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Unoccupied_Heating_Supply_Air_Flow_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Mixed_Air_Humidity_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Flow_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Fume_Hood_Air_Flow_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Medium_Temperature_Hot_Water_Temperature_Low_Reset_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Emergency_Push_Button_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Water_Flow_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Air_Grains_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Hot_Water_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Air_Enthalpy_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Outside_Face_Surface_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Hot_Water_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Collection_Basin_Water_Level_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Last_Fault_Code_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Valve_Position_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#On_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Outside_Air_CO_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Level_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Differential_Pressure_Load_Shed_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Zone_Unoccupied_Load_Shed_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Pre_Filter_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Reactive_Power_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Air_Flow_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Collection_Basin_Water_Level_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Frequency_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Temporary_Occupancy_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Load_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Water_Temperature_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Run_Request_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Flow_Low_Reset_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Condenser_Water_Flow_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Outside_Air_Flow_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Supply_Flow_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Static_Pressure_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heat_Exchanger_Leaving_Water_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#TVOC_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Energy_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Load_Shed_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Differential_Pressure_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Hot_Water_Temperature_Load_Shed_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Differential_Pressure_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Domestic_Hot_Water_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Standby_Unit_On_Off_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Effective_Return_Air_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Domestic_Hot_Water_Discharge_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Return_Flow_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Humidity_Deadband_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Cooling_Enable_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Operating_Mode_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_System_Enable_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Usage_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Exhaust_Air_Stack_Flow_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Air_CO2_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Disable_Differential_Enthalpy_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Max_Water_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Velocity_Pressure_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Occupied_Supply_Air_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Temperature_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Differential_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Deionised_Water_Conductivity_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Relay_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Entering_Medium_Temperature_Hot_Water_Temperature_High_Reset_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Pump_On_Off_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Differential_Pressure_Load_Shed_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Enable_Fixed_Enthalpy_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Radiant_Panel_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Domestic_Hot_Water_Supply_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Emergency_Air_Flow_System_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Enthalpy_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#CO_Differential_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Differential_Pressure_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Medium_Temperature_Hot_Water_Differential_Pressure_Load_Shed_Reset_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Solar_Radiance_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Condenser_Water_Flow_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Stages_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Duct_Pressure_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Availability_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Medium_Temperature_Hot_Water_Temperature_Low_Reset_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Flow_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Water_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Min_Frequency_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Differential_Pressure_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Motor_Speed_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Chilled_Water_Flow_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Mixed_Air_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Exhaust_Fan_Disable_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Humidify_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#NO2_Level_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Warmest_Zone_Air_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Differential_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Occupied_Supply_Air_Flow_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Overridden_Off_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Building_Air_Humidity_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Energy_Usage_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Emergency_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Motor_Torque_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Differential_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Run_Enable_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heat_Exchanger_Supply_Water_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Preheat_Supply_Air_Temperature_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Min_Water_Level_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#High_Supply_Air_Temperature_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Load_Shed_Command'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Pressure_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Freeze_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Speed_Mode_Status'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Condenser_Water_Flow_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Damper_Position_Sensor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Discharge_Flow_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Air_Temperature_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Discharge_Hot_Water_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Radiant_Panel_Temperature_Setpoint'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Leaving_Water_Temperature_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Thermostat_Status'): [],
# ...
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Dedicated_Outdoor_Air_System_Unit'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Pump'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Radiator'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Building_Hot_Water_Meter'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Inverter'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#HVAC_Valve'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Valve'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Fire_Alarm_Control_Panel'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Dual_Duct_Air_Handling_Unit'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Heater'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Variable_Frequency_Drive'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Electrical_Meter'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Coil'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Outside_Fan'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Compressor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Fire_Alarm'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Fan_VFD'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Evaporative_Heat_Exchanger'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Filter'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Motor'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Luminaire'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Computer_Room_Air_Conditioning'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Bus_Riser'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Sensor_Equipment'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Pre_Filter'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Fan'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Automated_External_Defibrillator'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Economizer_Damper'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Motor_Control_Center'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Pump'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Deck'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Condenser_Water_Isolation_Valve'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Building_Electrical_Meter'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Air_Plenum'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Direct_Expansion_Cooling_Coil'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Fire_Control_Panel'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Jet_Nozzle_Air_Diffuser'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Safety_Equipment'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Humidifier'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Interface'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Outside_Damper'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Baseboard_Radiator'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Preheat_Hot_Water_Valve'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heat_Wheel_VFD'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Natural_Gas_Boiler'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Pump_VFD'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Displacement_Flow_Air_Diffuser'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Mixed_Air_Filter'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Relief_Damper'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Luminaire_Driver'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Variable_Air_Volume_Box'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Camera'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Electrical_Equipment'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Damper'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Surveillance_Camera'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Space_Heater'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Absorption_Chiller'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Video_Intercom'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Cooling_Tower_Fan'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Condenser_Heat_Exchanger'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Centrifugal_Chiller'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Building_Meter'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Weather_Station'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Fan'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Eye_Wash_Station'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Relief_Fan'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Passive_Chilled_Beam'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Condensing_Natural_Gas_Boiler'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Natural_Gas_Seismic_Shutoff_Valve'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Radiant_Ceiling_Panel'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Beam'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#PV_Panel'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Collection_Basin_Water_Heater'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Constant_Air_Volume_Box'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Steam_Distribution'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Manual_Fire_Alarm_Activation_Equipment'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Fan'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Dimmer'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Computer_Room_Air_Handler'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Furniture'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heat_Exchanger'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Gas_Valve'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Blind'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Condenser_Water_Bypass_Valve'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Transfer_Fan'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Induction_Unit'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Stage_Riser'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Elevator'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Fire_Alarm_Pull_Station'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Audio_Visual_Equipment'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Equipment'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Intercom_Equipment'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Network_Video_Recorder'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Makeup_Air_Unit'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Thermostat'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Safety_Shower'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Thermostatic_Mixing_Valve'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#HVAC_Equipment'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Coil'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Valve'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Access_Reader'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Booster_Fan'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Pump'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Smoke_Detector'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Cooling_Tower'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Battery'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Radiant_Panel'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Dry_Cooler'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Air_Diffuser'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Reheat_Valve'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Bypass_Valve'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Condenser_Water_Valve'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Steam_Baseboard_Radiator'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Differential_Pressure_Bypass_Valve'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Air_Filter'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Steam_Radiator'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Access_Control_Equipment'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Final_Filter'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Building_Water_Meter'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heat_Detector'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Boiler'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Video_Surveillance_Equipment'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Thermal_Power_Meter'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Underfloor_Air_Plenum'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Relay'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Fire_Safety_Equipment'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Damper'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Thermally_Activated_Building_System_Panel'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Emergency_Phone'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Breaker_Panel'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Supply_Air_Plenum'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Variable_Air_Volume_Box_With_Reheat'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Fan_Coil_Unit'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Touchpanel'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Switchgear'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Active_Chilled_Beam'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Drench_Hose'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Valve'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Fume_Hood'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Electric_Radiator'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Air_Plenum'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Meter'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Meter'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Disconnect_Switch'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heat_Wheel'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Fresh_Air_Fan'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Switch'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Intrusion_Detection_Equipment'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Standby_Fan'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Pump'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Embedded_Surface_System_Panel'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Exhaust_Fan'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Meter'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Shading_Equipment'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Transformer'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Solar_Thermal_Collector'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Isolation_Valve'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Return_Heating_Valve'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Lighting_Equipment'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Terminal_Unit'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chilled_Water_Valve'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Ceiling_Fan'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Electric_Baseboard_Radiator'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Cooling_Valve'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Coil'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Exhaust_Damper'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Gas_Meter'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Electric_Boiler'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Distribution'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Building_Gas_Meter'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heating_Coil'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Cooling_Coil'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Heating_Valve'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Lighting'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Energy_Storage'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Condenser_Water_Pump'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#First_Aid_Kit'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Laminar_Flow_Air_Diffuser'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Chiller'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Mixed_Damper'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Cold_Deck'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Air_Handling_Unit'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Gas_Distribution'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Hot_Water_Baseboard_Radiator'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Water_Meter'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Noncondensing_Natural_Gas_Boiler'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Rooftop_Unit'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Fire_Alarm_Manual_Call_Point'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Automatic_Tint_Window'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#PlugStrip'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Pre-Cooling_Air_Unit'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Radiator'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Emergency_Wash_Station'): [],
#  rdflib.term.URIRef('https://brickschema.org/schema/Brick#Security_Equipment'): []}
